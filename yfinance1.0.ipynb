# %% [markdown]
# # Importando pacotes

# %%
################################################## Trazendo os pacotes de fora ###################################
import importlib

def install_and_import(package):
    try:
        importlib.import_module(package)  # Tenta importar o pacote
    except ImportError:
        print(f"{package} não está instalado. Instalando agora...")
        # !pip install {package}  # Instala o pacote
    finally:
        globals()[package] = importlib.import_module(package)  # Importa o pacote
        
        
install_and_import('sklearn')
install_and_import('numpy')
install_and_import('statsmodels')
install_and_import('seaborn')
install_and_import('oauth2client')

'''!pip install wbdata
# !pip install -- update pandas
# !pip install pandas_datareader
# !pip install gspread
# !pip install oauth2client
# !pip install openpyxl
# !pip install --update yfinance
# !pip install selenium
# !pip install -- update newspaper3k
# !pip install -- update requests
# !pip install bs4
# !pip install -- update transformers
# !pip install googletrans==3.1.0a0'''
# Out:
# '!pip install wbdata\n!pip install -- update pandas\n!pip install pandas_datareader\n!pip install gspread\n!pip install oauth2client\n!pip install openpyxl\n!pip install --update yfinance\n!pip install selenium\n!pip install -- update newspaper3k\n!pip install -- update requests\n!pip install bs4\n!pip install -- update transformers\n!pip install googletrans==3.1.0a0'

# %%
###################################### Importando bibliotecas ######################################

import os
os.environ['PYTHONHASHSEED'] = '0' # Remove os erros de cache persistente

import gspread
import datetime
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from sklearn import datasets
import seaborn as sns
from oauth2client.service_account import ServiceAccountCredentials
import openpyxl
from sklearn.metrics import r2_score
import numpy as np
import sklearn
import yfinance as yf
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from datetime import datetime, timedelta
import sqlite3
import pandas_datareader as pdr
import wbdata
import requests
from bs4 import BeautifulSoup
import newspaper
import sys
from transformers import T5Tokenizer
from transformers import T5Model, T5ForConditionalGeneration
from googletrans import Translator
# Out:
# Key '3102556937548122548' not in persistent cache.
# Key '-4234448868769758742' not in persistent cache.
# Key '-3271024741395444231' not in persistent cache.
# Key '5787994508776503245' not in persistent cache.
# Key '-8380044144209301077' not in persistent cache.
# Key '-5175449123767948148' not in persistent cache.
# Key '601179666744852784' not in persistent cache.
# Key '-6462577094242654910' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '1356937418198972370' not in persistent cache.
# Key '1575696149826776889' not in persistent cache.
# Key '-3350734430392407492' not in persistent cache.
# Key '6233305078380940078' not in persistent cache.
# Key '9048712620071959161' not in persistent cache.
# Key '7128095669656675928' not in persistent cache.
# Key '7172845095254540865' not in persistent cache.
# Key '-3187095136606176847' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '-3594300373998024076' not in persistent cache.
# Key '-768792205138924804' not in persistent cache.
# Key '-2309217291317146999' not in persistent cache.
# Key '-3767944707664054474' not in persistent cache.
# Key '-1698185433163402280' not in persistent cache.
# Key '-7980632520789847360' not in persistent cache.
# Key '7154457738857568473' not in persistent cache.
# Key '6496099768709875305' not in persistent cache.
# Key '-1912696223559660913' not in persistent cache.
# Key '-4572702492176845336' not in persistent cache.
# Key '-6120589009367034790' not in persistent cache.
# Key '-5435466030030865267' not in persistent cache.
# Key '-1220883215413861543' not in persistent cache.
# Key '4651892571096099288' not in persistent cache.
# Key '6735668193789696600' not in persistent cache.
# Key '-4141096034074351602' not in persistent cache.
# Key '-1392007982932190405' not in persistent cache.
# Key '-6026342968701119771' not in persistent cache.
# Key '-4469321748939846039' not in persistent cache.
# Key '8523196113003720047' not in persistent cache.
# Key '-954833538456958472' not in persistent cache.
# Key '70795934309762566' not in persistent cache.
# Key '-1119646987488483079' not in persistent cache.
# Key '-3572103822034015462' not in persistent cache.
# Key '3291734623656691823' not in persistent cache.
# Key '4339676715344100148' not in persistent cache.
# Key '-5374742341806034072' not in persistent cache.
# Key '5789637627548618243' not in persistent cache.
# Key '5670539197080405682' not in persistent cache.
# Key '-1423319049444543492' not in persistent cache.
# Key '8349381833997857003' not in persistent cache.
# Key '-1171392728251296724' not in persistent cache.
# Key '-3884580734697661563' not in persistent cache.
# Key '-4252701145888093245' not in persistent cache.
# Key '-1387382566760711187' not in persistent cache.
# Key '-3264258303582621807' not in persistent cache.
# Key '-8479610526752131749' not in persistent cache.
# Key '5813590281325390628' not in persistent cache.
# Key '5141844452528412451' not in persistent cache.
# Key '-2129846178414497264' not in persistent cache.
# Key '5165376976047139882' not in persistent cache.
# Key '-4015574321529216135' not in persistent cache.
# Key '1129168001896511' not in persistent cache.
# Key '5152479697370225513' not in persistent cache.
# Key '-3313486236398830127' not in persistent cache.
# Key '6404428623534518572' not in persistent cache.
# Key '-4491806569000789972' not in persistent cache.
# Key '1004063903700100343' not in persistent cache.
# Key '-8483348231242714722' not in persistent cache.
# Key '-5644028868430172816' not in persistent cache.
# Key '3993014548961753189' not in persistent cache.
# Key '-7976493629907633271' not in persistent cache.
# Key '-847013833455430897' not in persistent cache.
# Key '8121292001577221138' not in persistent cache.
# Key '1631262944403877578' not in persistent cache.
# Key '8696682562247777684' not in persistent cache.
# Key '-6908265419515113045' not in persistent cache.
# Key '-4553972181428311811' not in persistent cache.
# Key '5225308985068329689' not in persistent cache.
# Key '7395016627423358133' not in persistent cache.
# Key '4662313797175611649' not in persistent cache.
# Key '311529827648063320' not in persistent cache.
# Key '-6926614700212945123' not in persistent cache.
# Key '4932923341154945590' not in persistent cache.
# Key '-210133247495408708' not in persistent cache.
# Key '-7810529516836829982' not in persistent cache.
# Key '-7990493543569073028' not in persistent cache.
# Key '8999243311026711007' not in persistent cache.
# Key '-5210354348978105386' not in persistent cache.
# Key '-6694933023285545799' not in persistent cache.
# Key '1659699937768239869' not in persistent cache.
# Key '7009978911393625690' not in persistent cache.
# Key '196762001520271189' not in persistent cache.
# Key '-8137983185589295373' not in persistent cache.
# Key '-6227860527770104144' not in persistent cache.
# Key '82521502058754877' not in persistent cache.
# Key '-4036655932012371087' not in persistent cache.
# Key '-7563174186043379211' not in persistent cache.
# Key '-3619737222154957419' not in persistent cache.
# Key '-3800143223280858070' not in persistent cache.
# Key '-4528927291918495044' not in persistent cache.
# Key '1770113874246540904' not in persistent cache.
# Key '2095447031376656617' not in persistent cache.
# Key '2207672599306123041' not in persistent cache.
# Key '-2030240240941626735' not in persistent cache.
# Key '4951982163052713018' not in persistent cache.
# Key '-2184239808903160312' not in persistent cache.
# Key '4340807306741959260' not in persistent cache.
# Key '5593129540980419611' not in persistent cache.
# Key '-2279514302209101308' not in persistent cache.
# Key '-5269489138686834727' not in persistent cache.
# Key '-3455595863390443504' not in persistent cache.
# Key '-1494040086661851834' not in persistent cache.
# Key '8842561685689459323' not in persistent cache.
# Key '-4759706899327009950' not in persistent cache.
# Key '-5929515267786941850' not in persistent cache.
# Key '6884763707318947702' not in persistent cache.
# Key '4981510136186099279' not in persistent cache.
# Key '8417275058167263013' not in persistent cache.
# Key '2085320981855299826' not in persistent cache.
# Key '-9161098021987640131' not in persistent cache.
# Key '-3630839027725814959' not in persistent cache.
# Key '-7501292391366835233' not in persistent cache.
# Key '-5137611785889621070' not in persistent cache.
# Key '-1330565924543490855' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '5186339036083400126' not in persistent cache.
# Key '3177393347917034894' not in persistent cache.
# Key '-141600272684357806' not in persistent cache.
# Key '406392519383435738' not in persistent cache.
# Key '4945594271948976621' not in persistent cache.
# Key '1111435735975982879' not in persistent cache.
# Key '-7824595624327036960' not in persistent cache.
# Key '8576994827276944915' not in persistent cache.
# Key '-7932336670990724357' not in persistent cache.
# Key '-436090364741466735' not in persistent cache.
# Key '-5301802715296799878' not in persistent cache.
# Key '-6135379275674801045' not in persistent cache.
# Key '697404484150694782' not in persistent cache.
# Key '6134575435862280585' not in persistent cache.
# Key '7789573713722566288' not in persistent cache.
# Key '643474958669453426' not in persistent cache.
# Key '-1433385293694204802' not in persistent cache.
# Key '-7835089815454943782' not in persistent cache.
# Key '6946658875172000613' not in persistent cache.
# Key '2224567309438456501' not in persistent cache.
# Key '-7746613153503867731' not in persistent cache.
# Key '2719403000331075176' not in persistent cache.
# Key '-8762044805085739253' not in persistent cache.
# Key '-2694708103176780487' not in persistent cache.
# Key '2089708812865680022' not in persistent cache.
# Key '343373119097555686' not in persistent cache.
# Key '42808324619179028' not in persistent cache.
# Key '3225434001564039825' not in persistent cache.
# Key '-7991761799792081855' not in persistent cache.
# Key '-1564700063741299778' not in persistent cache.
# Key '-886963769150323435' not in persistent cache.
# Key '3238917588527601218' not in persistent cache.
# Key '8565016657747171247' not in persistent cache.
# Key '7861917867335250263' not in persistent cache.
# Key '3658501865169136019' not in persistent cache.
# Key '-5854353045973770764' not in persistent cache.
# Key '-5928794557845479376' not in persistent cache.
# Key '-6501111166368627501' not in persistent cache.
# Key '-7607664117647251452' not in persistent cache.
# Key '-334527739356025505' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '-3594300373998024076' not in persistent cache.
# Key '-768792205138924804' not in persistent cache.
# Key '-2309217291317146999' not in persistent cache.
# Key '6233305078380940078' not in persistent cache.
# Key '-3767944707664054474' not in persistent cache.
# Key '-1698185433163402280' not in persistent cache.
# Key '-7980632520789847360' not in persistent cache.
# Key '7154457738857568473' not in persistent cache.
# Key '6496099768709875305' not in persistent cache.
# Key '-1912696223559660913' not in persistent cache.
# Key '-4572702492176845336' not in persistent cache.
# Key '-6120589009367034790' not in persistent cache.
# Key '-5435466030030865267' not in persistent cache.
# Key '-1220883215413861543' not in persistent cache.
# Key '4651892571096099288' not in persistent cache.
# Key '6735668193789696600' not in persistent cache.
# Key '-4141096034074351602' not in persistent cache.
# Key '-1392007982932190405' not in persistent cache.
# Key '-6026342968701119771' not in persistent cache.
# Key '-4469321748939846039' not in persistent cache.
# Key '8523196113003720047' not in persistent cache.
# Key '-954833538456958472' not in persistent cache.
# Key '70795934309762566' not in persistent cache.
# Key '-1119646987488483079' not in persistent cache.
# Key '-3572103822034015462' not in persistent cache.
# Key '3291734623656691823' not in persistent cache.
# Key '4339676715344100148' not in persistent cache.
# Key '-5374742341806034072' not in persistent cache.
# Key '5789637627548618243' not in persistent cache.
# Key '5670539197080405682' not in persistent cache.
# Key '-1423319049444543492' not in persistent cache.
# Key '8349381833997857003' not in persistent cache.
# Key '-1171392728251296724' not in persistent cache.
# Key '-3884580734697661563' not in persistent cache.
# Key '-4252701145888093245' not in persistent cache.
# Key '-1387382566760711187' not in persistent cache.
# Key '-3264258303582621807' not in persistent cache.
# Key '-8479610526752131749' not in persistent cache.
# Key '5813590281325390628' not in persistent cache.
# Key '5141844452528412451' not in persistent cache.
# Key '-2129846178414497264' not in persistent cache.
# Key '5165376976047139882' not in persistent cache.
# Key '-4015574321529216135' not in persistent cache.
# Key '1129168001896511' not in persistent cache.
# Key '5152479697370225513' not in persistent cache.
# Key '-3313486236398830127' not in persistent cache.
# Key '-4759041265851768420' not in persistent cache.
# Key '3663907478339851166' not in persistent cache.
# Key '3158909696101848986' not in persistent cache.
# Key '-3476725781920286171' not in persistent cache.
# Key '7288067780787630934' not in persistent cache.
# Key '-4491806569000789972' not in persistent cache.
# Key '1004063903700100343' not in persistent cache.
# Key '-8483348231242714722' not in persistent cache.
# Key '-5644028868430172816' not in persistent cache.
# Key '3993014548961753189' not in persistent cache.
# Key '-7976493629907633271' not in persistent cache.
# Key '-847013833455430897' not in persistent cache.
# Key '8121292001577221138' not in persistent cache.
# Key '1631262944403877578' not in persistent cache.
# Key '8696682562247777684' not in persistent cache.
# Key '-6908265419515113045' not in persistent cache.
# Key '-4553972181428311811' not in persistent cache.
# Key '5225308985068329689' not in persistent cache.
# Key '7395016627423358133' not in persistent cache.
# Key '4662313797175611649' not in persistent cache.
# Key '311529827648063320' not in persistent cache.
# Key '-6926614700212945123' not in persistent cache.
# Key '4932923341154945590' not in persistent cache.
# Key '-210133247495408708' not in persistent cache.
# Key '-7810529516836829982' not in persistent cache.
# Key '-7990493543569073028' not in persistent cache.
# Key '8999243311026711007' not in persistent cache.
# Key '-5210354348978105386' not in persistent cache.
# Key '-6694933023285545799' not in persistent cache.
# Key '1659699937768239869' not in persistent cache.
# Key '7009978911393625690' not in persistent cache.
# Key '196762001520271189' not in persistent cache.
# Key '-8137983185589295373' not in persistent cache.
# Key '-6227860527770104144' not in persistent cache.
# Key '82521502058754877' not in persistent cache.
# Key '-4036655932012371087' not in persistent cache.
# Key '-7563174186043379211' not in persistent cache.
# Key '-3619737222154957419' not in persistent cache.
# Key '-3800143223280858070' not in persistent cache.
# Key '-4528927291918495044' not in persistent cache.
# Key '1770113874246540904' not in persistent cache.
# Key '2095447031376656617' not in persistent cache.
# Key '2207672599306123041' not in persistent cache.
# Key '-2030240240941626735' not in persistent cache.
# Key '4951982163052713018' not in persistent cache.
# Key '-2184239808903160312' not in persistent cache.
# Key '4340807306741959260' not in persistent cache.
# Key '5593129540980419611' not in persistent cache.
# Key '-2279514302209101308' not in persistent cache.
# Key '-5269489138686834727' not in persistent cache.
# Key '-3455595863390443504' not in persistent cache.
# Key '-1494040086661851834' not in persistent cache.
# Key '8842561685689459323' not in persistent cache.
# Key '-4759706899327009950' not in persistent cache.
# Key '-5929515267786941850' not in persistent cache.
# Key '6884763707318947702' not in persistent cache.
# Key '4981510136186099279' not in persistent cache.
# Key '8417275058167263013' not in persistent cache.
# Key '2085320981855299826' not in persistent cache.
# Key '-9161098021987640131' not in persistent cache.
# Key '-3630839027725814959' not in persistent cache.
# Key '-7501292391366835233' not in persistent cache.
# Key '-5137611785889621070' not in persistent cache.
# Key '-1330565924543490855' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '5186339036083400126' not in persistent cache.
# Key '3177393347917034894' not in persistent cache.
# Key '-141600272684357806' not in persistent cache.
# Key '406392519383435738' not in persistent cache.
# Key '4945594271948976621' not in persistent cache.
# Key '1111435735975982879' not in persistent cache.
# Key '-7824595624327036960' not in persistent cache.
# Key '8576994827276944915' not in persistent cache.
# Key '-7932336670990724357' not in persistent cache.
# Key '-436090364741466735' not in persistent cache.
# Key '-5301802715296799878' not in persistent cache.
# Key '-6135379275674801045' not in persistent cache.
# Key '697404484150694782' not in persistent cache.
# Key '6134575435862280585' not in persistent cache.
# Key '7789573713722566288' not in persistent cache.
# Key '643474958669453426' not in persistent cache.
# Key '-1433385293694204802' not in persistent cache.
# Key '-7835089815454943782' not in persistent cache.
# Key '6946658875172000613' not in persistent cache.
# Key '2224567309438456501' not in persistent cache.
# Key '-7746613153503867731' not in persistent cache.
# Key '2719403000331075176' not in persistent cache.
# Key '-8762044805085739253' not in persistent cache.
# Key '-2694708103176780487' not in persistent cache.
# Key '2089708812865680022' not in persistent cache.
# Key '343373119097555686' not in persistent cache.
# Key '42808324619179028' not in persistent cache.
# Key '3225434001564039825' not in persistent cache.
# Key '-7991761799792081855' not in persistent cache.
# Key '-1564700063741299778' not in persistent cache.
# Key '-886963769150323435' not in persistent cache.
# Key '3238917588527601218' not in persistent cache.
# Key '8565016657747171247' not in persistent cache.
# Key '7861917867335250263' not in persistent cache.
# Key '3658501865169136019' not in persistent cache.
# Key '-5854353045973770764' not in persistent cache.
# Key '-5928794557845479376' not in persistent cache.
# Key '-6501111166368627501' not in persistent cache.
# Key '-7607664117647251452' not in persistent cache.
# Key '-334527739356025505' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '3102556937548122548' not in persistent cache.
# Key '-4234448868769758742' not in persistent cache.
# Key '-3271024741395444231' not in persistent cache.
# Key '5787994508776503245' not in persistent cache.
# Key '-8380044144209301077' not in persistent cache.
# Key '-5175449123767948148' not in persistent cache.
# Key '601179666744852784' not in persistent cache.
# Key '-6462577094242654910' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '1356937418198972370' not in persistent cache.
# Key '1575696149826776889' not in persistent cache.
# Key '-3350734430392407492' not in persistent cache.
# Key '6233305078380940078' not in persistent cache.
# Key '9048712620071959161' not in persistent cache.
# Key '7128095669656675928' not in persistent cache.
# Key '7172845095254540865' not in persistent cache.
# Key '-3187095136606176847' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '-3594300373998024076' not in persistent cache.
# Key '-768792205138924804' not in persistent cache.
# Key '-2309217291317146999' not in persistent cache.
# Key '-3767944707664054474' not in persistent cache.
# Key '-1698185433163402280' not in persistent cache.
# Key '-7980632520789847360' not in persistent cache.
# Key '7154457738857568473' not in persistent cache.
# Key '6496099768709875305' not in persistent cache.
# Key '-1912696223559660913' not in persistent cache.
# Key '-4572702492176845336' not in persistent cache.
# Key '-6120589009367034790' not in persistent cache.
# Key '-5435466030030865267' not in persistent cache.
# Key '-1220883215413861543' not in persistent cache.
# Key '4651892571096099288' not in persistent cache.
# Key '6735668193789696600' not in persistent cache.
# Key '-4141096034074351602' not in persistent cache.
# Key '-1392007982932190405' not in persistent cache.
# Key '-6026342968701119771' not in persistent cache.
# Key '-4469321748939846039' not in persistent cache.
# Key '8523196113003720047' not in persistent cache.
# Key '-954833538456958472' not in persistent cache.
# Key '70795934309762566' not in persistent cache.
# Key '-1119646987488483079' not in persistent cache.
# Key '-3572103822034015462' not in persistent cache.
# Key '3291734623656691823' not in persistent cache.
# Key '4339676715344100148' not in persistent cache.
# Key '-5374742341806034072' not in persistent cache.
# Key '5789637627548618243' not in persistent cache.
# Key '5670539197080405682' not in persistent cache.
# Key '-1423319049444543492' not in persistent cache.
# Key '8349381833997857003' not in persistent cache.
# Key '-1171392728251296724' not in persistent cache.
# Key '-3884580734697661563' not in persistent cache.
# Key '-4252701145888093245' not in persistent cache.
# Key '-1387382566760711187' not in persistent cache.
# Key '-3264258303582621807' not in persistent cache.
# Key '-8479610526752131749' not in persistent cache.
# Key '5813590281325390628' not in persistent cache.
# Key '5141844452528412451' not in persistent cache.
# Key '-2129846178414497264' not in persistent cache.
# Key '5165376976047139882' not in persistent cache.
# Key '-4015574321529216135' not in persistent cache.
# Key '1129168001896511' not in persistent cache.
# Key '5152479697370225513' not in persistent cache.
# Key '-3313486236398830127' not in persistent cache.
# Key '6404428623534518572' not in persistent cache.
# Key '-4491806569000789972' not in persistent cache.
# Key '1004063903700100343' not in persistent cache.
# Key '-8483348231242714722' not in persistent cache.
# Key '-5644028868430172816' not in persistent cache.
# Key '3993014548961753189' not in persistent cache.
# Key '-7976493629907633271' not in persistent cache.
# Key '-847013833455430897' not in persistent cache.
# Key '8121292001577221138' not in persistent cache.
# Key '1631262944403877578' not in persistent cache.
# Key '8696682562247777684' not in persistent cache.
# Key '-6908265419515113045' not in persistent cache.
# Key '-4553972181428311811' not in persistent cache.
# Key '5225308985068329689' not in persistent cache.
# Key '7395016627423358133' not in persistent cache.
# Key '4662313797175611649' not in persistent cache.
# Key '311529827648063320' not in persistent cache.
# Key '-6926614700212945123' not in persistent cache.
# Key '4932923341154945590' not in persistent cache.
# Key '-210133247495408708' not in persistent cache.
# Key '-7810529516836829982' not in persistent cache.
# Key '-7990493543569073028' not in persistent cache.
# Key '8999243311026711007' not in persistent cache.
# Key '-5210354348978105386' not in persistent cache.
# Key '-6694933023285545799' not in persistent cache.
# Key '1659699937768239869' not in persistent cache.
# Key '7009978911393625690' not in persistent cache.
# Key '196762001520271189' not in persistent cache.
# Key '-8137983185589295373' not in persistent cache.
# Key '-6227860527770104144' not in persistent cache.
# Key '82521502058754877' not in persistent cache.
# Key '-4036655932012371087' not in persistent cache.
# Key '-7563174186043379211' not in persistent cache.
# Key '-3619737222154957419' not in persistent cache.
# Key '-3800143223280858070' not in persistent cache.
# Key '-4528927291918495044' not in persistent cache.
# Key '1770113874246540904' not in persistent cache.
# Key '2095447031376656617' not in persistent cache.
# Key '2207672599306123041' not in persistent cache.
# Key '-2030240240941626735' not in persistent cache.
# Key '4951982163052713018' not in persistent cache.
# Key '-2184239808903160312' not in persistent cache.
# Key '4340807306741959260' not in persistent cache.
# Key '5593129540980419611' not in persistent cache.
# Key '-2279514302209101308' not in persistent cache.
# Key '-5269489138686834727' not in persistent cache.
# Key '-3455595863390443504' not in persistent cache.
# Key '-1494040086661851834' not in persistent cache.
# Key '8842561685689459323' not in persistent cache.
# Key '-4759706899327009950' not in persistent cache.
# Key '-5929515267786941850' not in persistent cache.
# Key '6884763707318947702' not in persistent cache.
# Key '4981510136186099279' not in persistent cache.
# Key '8417275058167263013' not in persistent cache.
# Key '2085320981855299826' not in persistent cache.
# Key '-9161098021987640131' not in persistent cache.
# Key '-3630839027725814959' not in persistent cache.
# Key '-7501292391366835233' not in persistent cache.
# Key '-5137611785889621070' not in persistent cache.
# Key '-1330565924543490855' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '5186339036083400126' not in persistent cache.
# Key '3177393347917034894' not in persistent cache.
# Key '-141600272684357806' not in persistent cache.
# Key '406392519383435738' not in persistent cache.
# Key '4945594271948976621' not in persistent cache.
# Key '1111435735975982879' not in persistent cache.
# Key '-7824595624327036960' not in persistent cache.
# Key '8576994827276944915' not in persistent cache.
# Key '-7932336670990724357' not in persistent cache.
# Key '-436090364741466735' not in persistent cache.
# Key '-5301802715296799878' not in persistent cache.
# Key '-6135379275674801045' not in persistent cache.
# Key '697404484150694782' not in persistent cache.
# Key '6134575435862280585' not in persistent cache.
# Key '7789573713722566288' not in persistent cache.
# Key '643474958669453426' not in persistent cache.
# Key '-1433385293694204802' not in persistent cache.
# Key '-7835089815454943782' not in persistent cache.
# Key '6946658875172000613' not in persistent cache.
# Key '2224567309438456501' not in persistent cache.
# Key '-7746613153503867731' not in persistent cache.
# Key '2719403000331075176' not in persistent cache.
# Key '-8762044805085739253' not in persistent cache.
# Key '-2694708103176780487' not in persistent cache.
# Key '2089708812865680022' not in persistent cache.
# Key '343373119097555686' not in persistent cache.
# Key '42808324619179028' not in persistent cache.
# Key '3225434001564039825' not in persistent cache.
# Key '-7991761799792081855' not in persistent cache.
# Key '-1564700063741299778' not in persistent cache.
# Key '-886963769150323435' not in persistent cache.
# Key '3238917588527601218' not in persistent cache.
# Key '8565016657747171247' not in persistent cache.
# Key '7861917867335250263' not in persistent cache.
# Key '3658501865169136019' not in persistent cache.
# Key '-5854353045973770764' not in persistent cache.
# Key '-5928794557845479376' not in persistent cache.
# Key '-6501111166368627501' not in persistent cache.
# Key '-7607664117647251452' not in persistent cache.
# Key '-334527739356025505' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '-3594300373998024076' not in persistent cache.
# Key '-768792205138924804' not in persistent cache.
# Key '-2309217291317146999' not in persistent cache.
# Key '6233305078380940078' not in persistent cache.
# Key '-3767944707664054474' not in persistent cache.
# Key '-1698185433163402280' not in persistent cache.
# Key '-7980632520789847360' not in persistent cache.
# Key '7154457738857568473' not in persistent cache.
# Key '6496099768709875305' not in persistent cache.
# Key '-1912696223559660913' not in persistent cache.
# Key '-4572702492176845336' not in persistent cache.
# Key '-6120589009367034790' not in persistent cache.
# Key '-5435466030030865267' not in persistent cache.
# Key '-1220883215413861543' not in persistent cache.
# Key '4651892571096099288' not in persistent cache.
# Key '6735668193789696600' not in persistent cache.
# Key '-4141096034074351602' not in persistent cache.
# Key '-1392007982932190405' not in persistent cache.
# Key '-6026342968701119771' not in persistent cache.
# Key '-4469321748939846039' not in persistent cache.
# Key '8523196113003720047' not in persistent cache.
# Key '-954833538456958472' not in persistent cache.
# Key '70795934309762566' not in persistent cache.
# Key '-1119646987488483079' not in persistent cache.
# Key '-3572103822034015462' not in persistent cache.
# Key '3291734623656691823' not in persistent cache.
# Key '4339676715344100148' not in persistent cache.
# Key '-5374742341806034072' not in persistent cache.
# Key '5789637627548618243' not in persistent cache.
# Key '5670539197080405682' not in persistent cache.
# Key '-1423319049444543492' not in persistent cache.
# Key '8349381833997857003' not in persistent cache.
# Key '-1171392728251296724' not in persistent cache.
# Key '-3884580734697661563' not in persistent cache.
# Key '-4252701145888093245' not in persistent cache.
# Key '-1387382566760711187' not in persistent cache.
# Key '-3264258303582621807' not in persistent cache.
# Key '-8479610526752131749' not in persistent cache.
# Key '5813590281325390628' not in persistent cache.
# Key '5141844452528412451' not in persistent cache.
# Key '-2129846178414497264' not in persistent cache.
# Key '5165376976047139882' not in persistent cache.
# Key '-4015574321529216135' not in persistent cache.
# Key '1129168001896511' not in persistent cache.
# Key '5152479697370225513' not in persistent cache.
# Key '-3313486236398830127' not in persistent cache.
# Key '-4759041265851768420' not in persistent cache.
# Key '3663907478339851166' not in persistent cache.
# Key '3158909696101848986' not in persistent cache.
# Key '-3476725781920286171' not in persistent cache.
# Key '7288067780787630934' not in persistent cache.
# Key '-4491806569000789972' not in persistent cache.
# Key '1004063903700100343' not in persistent cache.
# Key '-8483348231242714722' not in persistent cache.
# Key '-5644028868430172816' not in persistent cache.
# Key '3993014548961753189' not in persistent cache.
# Key '-7976493629907633271' not in persistent cache.
# Key '-847013833455430897' not in persistent cache.
# Key '8121292001577221138' not in persistent cache.
# Key '1631262944403877578' not in persistent cache.
# Key '8696682562247777684' not in persistent cache.
# Key '-6908265419515113045' not in persistent cache.
# Key '-4553972181428311811' not in persistent cache.
# Key '5225308985068329689' not in persistent cache.
# Key '7395016627423358133' not in persistent cache.
# Key '4662313797175611649' not in persistent cache.
# Key '311529827648063320' not in persistent cache.
# Key '-6926614700212945123' not in persistent cache.
# Key '4932923341154945590' not in persistent cache.
# Key '-210133247495408708' not in persistent cache.
# Key '-7810529516836829982' not in persistent cache.
# Key '-7990493543569073028' not in persistent cache.
# Key '8999243311026711007' not in persistent cache.
# Key '-5210354348978105386' not in persistent cache.
# Key '-6694933023285545799' not in persistent cache.
# Key '1659699937768239869' not in persistent cache.
# Key '7009978911393625690' not in persistent cache.
# Key '196762001520271189' not in persistent cache.
# Key '-8137983185589295373' not in persistent cache.
# Key '-6227860527770104144' not in persistent cache.
# Key '82521502058754877' not in persistent cache.
# Key '-4036655932012371087' not in persistent cache.
# Key '-7563174186043379211' not in persistent cache.
# Key '-3619737222154957419' not in persistent cache.
# Key '-3800143223280858070' not in persistent cache.
# Key '-4528927291918495044' not in persistent cache.
# Key '1770113874246540904' not in persistent cache.
# Key '2095447031376656617' not in persistent cache.
# Key '2207672599306123041' not in persistent cache.
# Key '-2030240240941626735' not in persistent cache.
# Key '4951982163052713018' not in persistent cache.
# Key '-2184239808903160312' not in persistent cache.
# Key '4340807306741959260' not in persistent cache.
# Key '5593129540980419611' not in persistent cache.
# Key '-2279514302209101308' not in persistent cache.
# Key '-5269489138686834727' not in persistent cache.
# Key '-3455595863390443504' not in persistent cache.
# Key '-1494040086661851834' not in persistent cache.
# Key '8842561685689459323' not in persistent cache.
# Key '-4759706899327009950' not in persistent cache.
# Key '-5929515267786941850' not in persistent cache.
# Key '6884763707318947702' not in persistent cache.
# Key '4981510136186099279' not in persistent cache.
# Key '8417275058167263013' not in persistent cache.
# Key '2085320981855299826' not in persistent cache.
# Key '-9161098021987640131' not in persistent cache.
# Key '-3630839027725814959' not in persistent cache.
# Key '-7501292391366835233' not in persistent cache.
# Key '-5137611785889621070' not in persistent cache.
# Key '-1330565924543490855' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '5186339036083400126' not in persistent cache.
# Key '3177393347917034894' not in persistent cache.
# Key '-141600272684357806' not in persistent cache.
# Key '406392519383435738' not in persistent cache.
# Key '4945594271948976621' not in persistent cache.
# Key '1111435735975982879' not in persistent cache.
# Key '-7824595624327036960' not in persistent cache.
# Key '8576994827276944915' not in persistent cache.
# Key '-7932336670990724357' not in persistent cache.
# Key '-436090364741466735' not in persistent cache.
# Key '-5301802715296799878' not in persistent cache.
# Key '-6135379275674801045' not in persistent cache.
# Key '697404484150694782' not in persistent cache.
# Key '6134575435862280585' not in persistent cache.
# Key '7789573713722566288' not in persistent cache.
# Key '643474958669453426' not in persistent cache.
# Key '-1433385293694204802' not in persistent cache.
# Key '-7835089815454943782' not in persistent cache.
# Key '6946658875172000613' not in persistent cache.
# Key '2224567309438456501' not in persistent cache.
# Key '-7746613153503867731' not in persistent cache.
# Key '2719403000331075176' not in persistent cache.
# Key '-8762044805085739253' not in persistent cache.
# Key '-2694708103176780487' not in persistent cache.
# Key '2089708812865680022' not in persistent cache.
# Key '343373119097555686' not in persistent cache.
# Key '42808324619179028' not in persistent cache.
# Key '3225434001564039825' not in persistent cache.
# Key '-7991761799792081855' not in persistent cache.
# Key '-1564700063741299778' not in persistent cache.
# Key '-886963769150323435' not in persistent cache.
# Key '3238917588527601218' not in persistent cache.
# Key '8565016657747171247' not in persistent cache.
# Key '7861917867335250263' not in persistent cache.
# Key '3658501865169136019' not in persistent cache.
# Key '-5854353045973770764' not in persistent cache.
# Key '-5928794557845479376' not in persistent cache.
# Key '-6501111166368627501' not in persistent cache.
# Key '-7607664117647251452' not in persistent cache.
# Key '-334527739356025505' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '3102556937548122548' not in persistent cache.
# Key '-4234448868769758742' not in persistent cache.
# Key '-3271024741395444231' not in persistent cache.
# Key '5787994508776503245' not in persistent cache.
# Key '-8380044144209301077' not in persistent cache.
# Key '-5175449123767948148' not in persistent cache.
# Key '601179666744852784' not in persistent cache.
# Key '-6462577094242654910' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '1356937418198972370' not in persistent cache.
# Key '1575696149826776889' not in persistent cache.
# Key '-3350734430392407492' not in persistent cache.
# Key '6233305078380940078' not in persistent cache.
# Key '9048712620071959161' not in persistent cache.
# Key '7128095669656675928' not in persistent cache.
# Key '7172845095254540865' not in persistent cache.
# Key '-3187095136606176847' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '-3594300373998024076' not in persistent cache.
# Key '-768792205138924804' not in persistent cache.
# Key '-2309217291317146999' not in persistent cache.
# Key '-3767944707664054474' not in persistent cache.
# Key '-1698185433163402280' not in persistent cache.
# Key '-7980632520789847360' not in persistent cache.
# Key '7154457738857568473' not in persistent cache.
# Key '6496099768709875305' not in persistent cache.
# Key '-1912696223559660913' not in persistent cache.
# Key '-4572702492176845336' not in persistent cache.
# Key '-6120589009367034790' not in persistent cache.
# Key '-5435466030030865267' not in persistent cache.
# Key '-1220883215413861543' not in persistent cache.
# Key '4651892571096099288' not in persistent cache.
# Key '6735668193789696600' not in persistent cache.
# Key '-4141096034074351602' not in persistent cache.
# Key '-1392007982932190405' not in persistent cache.
# Key '-6026342968701119771' not in persistent cache.
# Key '-4469321748939846039' not in persistent cache.
# Key '8523196113003720047' not in persistent cache.
# Key '-954833538456958472' not in persistent cache.
# Key '70795934309762566' not in persistent cache.
# Key '-1119646987488483079' not in persistent cache.
# Key '-3572103822034015462' not in persistent cache.
# Key '3291734623656691823' not in persistent cache.
# Key '4339676715344100148' not in persistent cache.
# Key '-5374742341806034072' not in persistent cache.
# Key '5789637627548618243' not in persistent cache.
# Key '5670539197080405682' not in persistent cache.
# Key '-1423319049444543492' not in persistent cache.
# Key '8349381833997857003' not in persistent cache.
# Key '-1171392728251296724' not in persistent cache.
# Key '-3884580734697661563' not in persistent cache.
# Key '-4252701145888093245' not in persistent cache.
# Key '-1387382566760711187' not in persistent cache.
# Key '-3264258303582621807' not in persistent cache.
# Key '-8479610526752131749' not in persistent cache.
# Key '5813590281325390628' not in persistent cache.
# Key '5141844452528412451' not in persistent cache.
# Key '-2129846178414497264' not in persistent cache.
# Key '5165376976047139882' not in persistent cache.
# Key '-4015574321529216135' not in persistent cache.
# Key '1129168001896511' not in persistent cache.
# Key '5152479697370225513' not in persistent cache.
# Key '-3313486236398830127' not in persistent cache.
# Key '6404428623534518572' not in persistent cache.
# Key '-4491806569000789972' not in persistent cache.
# Key '1004063903700100343' not in persistent cache.
# Key '-8483348231242714722' not in persistent cache.
# Key '-5644028868430172816' not in persistent cache.
# Key '3993014548961753189' not in persistent cache.
# Key '-7976493629907633271' not in persistent cache.
# Key '-847013833455430897' not in persistent cache.
# Key '8121292001577221138' not in persistent cache.
# Key '1631262944403877578' not in persistent cache.
# Key '8696682562247777684' not in persistent cache.
# Key '-6908265419515113045' not in persistent cache.
# Key '-4553972181428311811' not in persistent cache.
# Key '5225308985068329689' not in persistent cache.
# Key '7395016627423358133' not in persistent cache.
# Key '4662313797175611649' not in persistent cache.
# Key '311529827648063320' not in persistent cache.
# Key '-6926614700212945123' not in persistent cache.
# Key '4932923341154945590' not in persistent cache.
# Key '-210133247495408708' not in persistent cache.
# Key '-7810529516836829982' not in persistent cache.
# Key '-7990493543569073028' not in persistent cache.
# Key '8999243311026711007' not in persistent cache.
# Key '-5210354348978105386' not in persistent cache.
# Key '-6694933023285545799' not in persistent cache.
# Key '1659699937768239869' not in persistent cache.
# Key '7009978911393625690' not in persistent cache.
# Key '196762001520271189' not in persistent cache.
# Key '-8137983185589295373' not in persistent cache.
# Key '-6227860527770104144' not in persistent cache.
# Key '82521502058754877' not in persistent cache.
# Key '-4036655932012371087' not in persistent cache.
# Key '-7563174186043379211' not in persistent cache.
# Key '-3619737222154957419' not in persistent cache.
# Key '-3800143223280858070' not in persistent cache.
# Key '-4528927291918495044' not in persistent cache.
# Key '1770113874246540904' not in persistent cache.
# Key '2095447031376656617' not in persistent cache.
# Key '2207672599306123041' not in persistent cache.
# Key '-2030240240941626735' not in persistent cache.
# Key '4951982163052713018' not in persistent cache.
# Key '-2184239808903160312' not in persistent cache.
# Key '4340807306741959260' not in persistent cache.
# Key '5593129540980419611' not in persistent cache.
# Key '-2279514302209101308' not in persistent cache.
# Key '-5269489138686834727' not in persistent cache.
# Key '-3455595863390443504' not in persistent cache.
# Key '-1494040086661851834' not in persistent cache.
# Key '8842561685689459323' not in persistent cache.
# Key '-4759706899327009950' not in persistent cache.
# Key '-5929515267786941850' not in persistent cache.
# Key '6884763707318947702' not in persistent cache.
# Key '4981510136186099279' not in persistent cache.
# Key '8417275058167263013' not in persistent cache.
# Key '2085320981855299826' not in persistent cache.
# Key '-9161098021987640131' not in persistent cache.
# Key '-3630839027725814959' not in persistent cache.
# Key '-7501292391366835233' not in persistent cache.
# Key '-5137611785889621070' not in persistent cache.
# Key '-1330565924543490855' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '5186339036083400126' not in persistent cache.
# Key '3177393347917034894' not in persistent cache.
# Key '-141600272684357806' not in persistent cache.
# Key '406392519383435738' not in persistent cache.
# Key '4945594271948976621' not in persistent cache.
# Key '1111435735975982879' not in persistent cache.
# Key '-7824595624327036960' not in persistent cache.
# Key '8576994827276944915' not in persistent cache.
# Key '-7932336670990724357' not in persistent cache.
# Key '-436090364741466735' not in persistent cache.
# Key '-5301802715296799878' not in persistent cache.
# Key '-6135379275674801045' not in persistent cache.
# Key '697404484150694782' not in persistent cache.
# Key '6134575435862280585' not in persistent cache.
# Key '7789573713722566288' not in persistent cache.
# Key '643474958669453426' not in persistent cache.
# Key '-1433385293694204802' not in persistent cache.
# Key '-7835089815454943782' not in persistent cache.
# Key '6946658875172000613' not in persistent cache.
# Key '2224567309438456501' not in persistent cache.
# Key '-7746613153503867731' not in persistent cache.
# Key '2719403000331075176' not in persistent cache.
# Key '-8762044805085739253' not in persistent cache.
# Key '-2694708103176780487' not in persistent cache.
# Key '2089708812865680022' not in persistent cache.
# Key '343373119097555686' not in persistent cache.
# Key '42808324619179028' not in persistent cache.
# Key '3225434001564039825' not in persistent cache.
# Key '-7991761799792081855' not in persistent cache.
# Key '-1564700063741299778' not in persistent cache.
# Key '-886963769150323435' not in persistent cache.
# Key '3238917588527601218' not in persistent cache.
# Key '8565016657747171247' not in persistent cache.
# Key '7861917867335250263' not in persistent cache.
# Key '3658501865169136019' not in persistent cache.
# Key '-5854353045973770764' not in persistent cache.
# Key '-5928794557845479376' not in persistent cache.
# Key '-6501111166368627501' not in persistent cache.
# Key '-7607664117647251452' not in persistent cache.
# Key '-334527739356025505' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '-3594300373998024076' not in persistent cache.
# Key '-768792205138924804' not in persistent cache.
# Key '-2309217291317146999' not in persistent cache.
# Key '6233305078380940078' not in persistent cache.
# Key '-3767944707664054474' not in persistent cache.
# Key '-1698185433163402280' not in persistent cache.
# Key '-7980632520789847360' not in persistent cache.
# Key '7154457738857568473' not in persistent cache.
# Key '6496099768709875305' not in persistent cache.
# Key '-1912696223559660913' not in persistent cache.
# Key '-4572702492176845336' not in persistent cache.
# Key '-6120589009367034790' not in persistent cache.
# Key '-5435466030030865267' not in persistent cache.
# Key '-1220883215413861543' not in persistent cache.
# Key '4651892571096099288' not in persistent cache.
# Key '6735668193789696600' not in persistent cache.
# Key '-4141096034074351602' not in persistent cache.
# Key '-1392007982932190405' not in persistent cache.
# Key '-6026342968701119771' not in persistent cache.
# Key '-4469321748939846039' not in persistent cache.
# Key '8523196113003720047' not in persistent cache.
# Key '-954833538456958472' not in persistent cache.
# Key '70795934309762566' not in persistent cache.
# Key '-1119646987488483079' not in persistent cache.
# Key '-3572103822034015462' not in persistent cache.
# Key '3291734623656691823' not in persistent cache.
# Key '4339676715344100148' not in persistent cache.
# Key '-5374742341806034072' not in persistent cache.
# Key '5789637627548618243' not in persistent cache.
# Key '5670539197080405682' not in persistent cache.
# Key '-1423319049444543492' not in persistent cache.
# Key '8349381833997857003' not in persistent cache.
# Key '-1171392728251296724' not in persistent cache.
# Key '-3884580734697661563' not in persistent cache.
# Key '-4252701145888093245' not in persistent cache.
# Key '-1387382566760711187' not in persistent cache.
# Key '-3264258303582621807' not in persistent cache.
# Key '-8479610526752131749' not in persistent cache.
# Key '5813590281325390628' not in persistent cache.
# Key '5141844452528412451' not in persistent cache.
# Key '-2129846178414497264' not in persistent cache.
# Key '5165376976047139882' not in persistent cache.
# Key '-4015574321529216135' not in persistent cache.
# Key '1129168001896511' not in persistent cache.
# Key '5152479697370225513' not in persistent cache.
# Key '-3313486236398830127' not in persistent cache.
# Key '-4759041265851768420' not in persistent cache.
# Key '3663907478339851166' not in persistent cache.
# Key '3158909696101848986' not in persistent cache.
# Key '-3476725781920286171' not in persistent cache.
# Key '7288067780787630934' not in persistent cache.
# Key '-4491806569000789972' not in persistent cache.
# Key '1004063903700100343' not in persistent cache.
# Key '-8483348231242714722' not in persistent cache.
# Key '-5644028868430172816' not in persistent cache.
# Key '3993014548961753189' not in persistent cache.
# Key '-7976493629907633271' not in persistent cache.
# Key '-847013833455430897' not in persistent cache.
# Key '8121292001577221138' not in persistent cache.
# Key '1631262944403877578' not in persistent cache.
# Key '8696682562247777684' not in persistent cache.
# Key '-6908265419515113045' not in persistent cache.
# Key '-4553972181428311811' not in persistent cache.
# Key '5225308985068329689' not in persistent cache.
# Key '7395016627423358133' not in persistent cache.
# Key '4662313797175611649' not in persistent cache.
# Key '311529827648063320' not in persistent cache.
# Key '-6926614700212945123' not in persistent cache.
# Key '4932923341154945590' not in persistent cache.
# Key '-210133247495408708' not in persistent cache.
# Key '-7810529516836829982' not in persistent cache.
# Key '-7990493543569073028' not in persistent cache.
# Key '8999243311026711007' not in persistent cache.
# Key '-5210354348978105386' not in persistent cache.
# Key '-6694933023285545799' not in persistent cache.
# Key '1659699937768239869' not in persistent cache.
# Key '7009978911393625690' not in persistent cache.
# Key '196762001520271189' not in persistent cache.
# Key '-8137983185589295373' not in persistent cache.
# Key '-6227860527770104144' not in persistent cache.
# Key '82521502058754877' not in persistent cache.
# Key '-4036655932012371087' not in persistent cache.
# Key '-7563174186043379211' not in persistent cache.
# Key '-3619737222154957419' not in persistent cache.
# Key '-3800143223280858070' not in persistent cache.
# Key '-4528927291918495044' not in persistent cache.
# Key '1770113874246540904' not in persistent cache.
# Key '2095447031376656617' not in persistent cache.
# Key '2207672599306123041' not in persistent cache.
# Key '-2030240240941626735' not in persistent cache.
# Key '4951982163052713018' not in persistent cache.
# Key '-2184239808903160312' not in persistent cache.
# Key '4340807306741959260' not in persistent cache.
# Key '5593129540980419611' not in persistent cache.
# Key '-2279514302209101308' not in persistent cache.
# Key '-5269489138686834727' not in persistent cache.
# Key '-3455595863390443504' not in persistent cache.
# Key '-1494040086661851834' not in persistent cache.
# Key '8842561685689459323' not in persistent cache.
# Key '-4759706899327009950' not in persistent cache.
# Key '-5929515267786941850' not in persistent cache.
# Key '6884763707318947702' not in persistent cache.
# Key '4981510136186099279' not in persistent cache.
# Key '8417275058167263013' not in persistent cache.
# Key '2085320981855299826' not in persistent cache.
# Key '-9161098021987640131' not in persistent cache.
# Key '-3630839027725814959' not in persistent cache.
# Key '-7501292391366835233' not in persistent cache.
# Key '-5137611785889621070' not in persistent cache.
# Key '-1330565924543490855' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '5186339036083400126' not in persistent cache.
# Key '3177393347917034894' not in persistent cache.
# Key '-141600272684357806' not in persistent cache.
# Key '406392519383435738' not in persistent cache.
# Key '4945594271948976621' not in persistent cache.
# Key '1111435735975982879' not in persistent cache.
# Key '-7824595624327036960' not in persistent cache.
# Key '8576994827276944915' not in persistent cache.
# Key '-7932336670990724357' not in persistent cache.
# Key '-436090364741466735' not in persistent cache.
# Key '-5301802715296799878' not in persistent cache.
# Key '-6135379275674801045' not in persistent cache.
# Key '697404484150694782' not in persistent cache.
# Key '6134575435862280585' not in persistent cache.
# Key '7789573713722566288' not in persistent cache.
# Key '643474958669453426' not in persistent cache.
# Key '-1433385293694204802' not in persistent cache.
# Key '-7835089815454943782' not in persistent cache.
# Key '6946658875172000613' not in persistent cache.
# Key '2224567309438456501' not in persistent cache.
# Key '-7746613153503867731' not in persistent cache.
# Key '2719403000331075176' not in persistent cache.
# Key '-8762044805085739253' not in persistent cache.
# ...
# Key '601179666744852784' not in persistent cache.
# Key '-6462577094242654910' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '1356937418198972370' not in persistent cache.
# Key '1575696149826776889' not in persistent cache.
# Key '-3350734430392407492' not in persistent cache.
# Key '6233305078380940078' not in persistent cache.
# Key '9048712620071959161' not in persistent cache.
# Key '7128095669656675928' not in persistent cache.
# Key '7172845095254540865' not in persistent cache.
# Key '-3187095136606176847' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '-3594300373998024076' not in persistent cache.
# Key '-768792205138924804' not in persistent cache.
# Key '-2309217291317146999' not in persistent cache.
# Key '-3767944707664054474' not in persistent cache.
# Key '-1698185433163402280' not in persistent cache.
# Key '-7980632520789847360' not in persistent cache.
# Key '7154457738857568473' not in persistent cache.
# Key '6496099768709875305' not in persistent cache.
# Key '-1912696223559660913' not in persistent cache.
# Key '-4572702492176845336' not in persistent cache.
# Key '-6120589009367034790' not in persistent cache.
# Key '-5435466030030865267' not in persistent cache.
# Key '-1220883215413861543' not in persistent cache.
# Key '4651892571096099288' not in persistent cache.
# Key '6735668193789696600' not in persistent cache.
# Key '-4141096034074351602' not in persistent cache.
# Key '-1392007982932190405' not in persistent cache.
# Key '-6026342968701119771' not in persistent cache.
# Key '-4469321748939846039' not in persistent cache.
# Key '8523196113003720047' not in persistent cache.
# Key '-954833538456958472' not in persistent cache.
# Key '70795934309762566' not in persistent cache.
# Key '-1119646987488483079' not in persistent cache.
# Key '-3572103822034015462' not in persistent cache.
# Key '3291734623656691823' not in persistent cache.
# Key '4339676715344100148' not in persistent cache.
# Key '-5374742341806034072' not in persistent cache.
# Key '5789637627548618243' not in persistent cache.
# Key '5670539197080405682' not in persistent cache.
# Key '-1423319049444543492' not in persistent cache.
# Key '8349381833997857003' not in persistent cache.
# Key '-1171392728251296724' not in persistent cache.
# Key '-3884580734697661563' not in persistent cache.
# Key '-4252701145888093245' not in persistent cache.
# Key '-1387382566760711187' not in persistent cache.
# Key '-3264258303582621807' not in persistent cache.
# Key '-8479610526752131749' not in persistent cache.
# Key '5813590281325390628' not in persistent cache.
# Key '5141844452528412451' not in persistent cache.
# Key '-2129846178414497264' not in persistent cache.
# Key '5165376976047139882' not in persistent cache.
# Key '-4015574321529216135' not in persistent cache.
# Key '1129168001896511' not in persistent cache.
# Key '5152479697370225513' not in persistent cache.
# Key '-3313486236398830127' not in persistent cache.
# Key '6404428623534518572' not in persistent cache.
# Key '-4491806569000789972' not in persistent cache.
# Key '1004063903700100343' not in persistent cache.
# Key '-8483348231242714722' not in persistent cache.
# Key '-5644028868430172816' not in persistent cache.
# Key '3993014548961753189' not in persistent cache.
# Key '-7976493629907633271' not in persistent cache.
# Key '-847013833455430897' not in persistent cache.
# Key '8121292001577221138' not in persistent cache.
# Key '1631262944403877578' not in persistent cache.
# Key '8696682562247777684' not in persistent cache.
# Key '-6908265419515113045' not in persistent cache.
# Key '-4553972181428311811' not in persistent cache.
# Key '5225308985068329689' not in persistent cache.
# Key '7395016627423358133' not in persistent cache.
# Key '4662313797175611649' not in persistent cache.
# Key '311529827648063320' not in persistent cache.
# Key '-6926614700212945123' not in persistent cache.
# Key '4932923341154945590' not in persistent cache.
# Key '-210133247495408708' not in persistent cache.
# Key '-7810529516836829982' not in persistent cache.
# Key '-7990493543569073028' not in persistent cache.
# Key '8999243311026711007' not in persistent cache.
# Key '-5210354348978105386' not in persistent cache.
# Key '-6694933023285545799' not in persistent cache.
# Key '1659699937768239869' not in persistent cache.
# Key '7009978911393625690' not in persistent cache.
# Key '196762001520271189' not in persistent cache.
# Key '-8137983185589295373' not in persistent cache.
# Key '-6227860527770104144' not in persistent cache.
# Key '82521502058754877' not in persistent cache.
# Key '-4036655932012371087' not in persistent cache.
# Key '-7563174186043379211' not in persistent cache.
# Key '-3619737222154957419' not in persistent cache.
# Key '-3800143223280858070' not in persistent cache.
# Key '-4528927291918495044' not in persistent cache.
# Key '1770113874246540904' not in persistent cache.
# Key '2095447031376656617' not in persistent cache.
# Key '2207672599306123041' not in persistent cache.
# Key '-2030240240941626735' not in persistent cache.
# Key '4951982163052713018' not in persistent cache.
# Key '-2184239808903160312' not in persistent cache.
# Key '4340807306741959260' not in persistent cache.
# Key '5593129540980419611' not in persistent cache.
# Key '-2279514302209101308' not in persistent cache.
# Key '-5269489138686834727' not in persistent cache.
# Key '-3455595863390443504' not in persistent cache.
# Key '-1494040086661851834' not in persistent cache.
# Key '8842561685689459323' not in persistent cache.
# Key '-4759706899327009950' not in persistent cache.
# Key '-5929515267786941850' not in persistent cache.
# Key '6884763707318947702' not in persistent cache.
# Key '4981510136186099279' not in persistent cache.
# Key '8417275058167263013' not in persistent cache.
# Key '2085320981855299826' not in persistent cache.
# Key '-9161098021987640131' not in persistent cache.
# Key '-3630839027725814959' not in persistent cache.
# Key '-7501292391366835233' not in persistent cache.
# Key '-5137611785889621070' not in persistent cache.
# Key '-1330565924543490855' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '5186339036083400126' not in persistent cache.
# Key '3177393347917034894' not in persistent cache.
# Key '-141600272684357806' not in persistent cache.
# Key '406392519383435738' not in persistent cache.
# Key '4945594271948976621' not in persistent cache.
# Key '1111435735975982879' not in persistent cache.
# Key '-7824595624327036960' not in persistent cache.
# Key '8576994827276944915' not in persistent cache.
# Key '-7932336670990724357' not in persistent cache.
# Key '-436090364741466735' not in persistent cache.
# Key '-5301802715296799878' not in persistent cache.
# Key '-6135379275674801045' not in persistent cache.
# Key '697404484150694782' not in persistent cache.
# Key '6134575435862280585' not in persistent cache.
# Key '7789573713722566288' not in persistent cache.
# Key '643474958669453426' not in persistent cache.
# Key '-1433385293694204802' not in persistent cache.
# Key '-7835089815454943782' not in persistent cache.
# Key '6946658875172000613' not in persistent cache.
# Key '2224567309438456501' not in persistent cache.
# Key '-7746613153503867731' not in persistent cache.
# Key '2719403000331075176' not in persistent cache.
# Key '-8762044805085739253' not in persistent cache.
# Key '-2694708103176780487' not in persistent cache.
# Key '2089708812865680022' not in persistent cache.
# Key '343373119097555686' not in persistent cache.
# Key '42808324619179028' not in persistent cache.
# Key '3225434001564039825' not in persistent cache.
# Key '-7991761799792081855' not in persistent cache.
# Key '-1564700063741299778' not in persistent cache.
# Key '-886963769150323435' not in persistent cache.
# Key '3238917588527601218' not in persistent cache.
# Key '8565016657747171247' not in persistent cache.
# Key '7861917867335250263' not in persistent cache.
# Key '3658501865169136019' not in persistent cache.
# Key '-5854353045973770764' not in persistent cache.
# Key '-5928794557845479376' not in persistent cache.
# Key '-6501111166368627501' not in persistent cache.
# Key '-7607664117647251452' not in persistent cache.
# Key '-334527739356025505' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.
# Key '-3594300373998024076' not in persistent cache.
# Key '-768792205138924804' not in persistent cache.
# Key '-2309217291317146999' not in persistent cache.
# Key '6233305078380940078' not in persistent cache.
# Key '-3767944707664054474' not in persistent cache.
# Key '-1698185433163402280' not in persistent cache.
# Key '-7980632520789847360' not in persistent cache.
# Key '7154457738857568473' not in persistent cache.
# Key '6496099768709875305' not in persistent cache.
# Key '-1912696223559660913' not in persistent cache.
# Key '-4572702492176845336' not in persistent cache.
# Key '-6120589009367034790' not in persistent cache.
# Key '-5435466030030865267' not in persistent cache.
# Key '-1220883215413861543' not in persistent cache.
# Key '4651892571096099288' not in persistent cache.
# Key '6735668193789696600' not in persistent cache.
# Key '-4141096034074351602' not in persistent cache.
# Key '-1392007982932190405' not in persistent cache.
# Key '-6026342968701119771' not in persistent cache.
# Key '-4469321748939846039' not in persistent cache.
# Key '8523196113003720047' not in persistent cache.
# Key '-954833538456958472' not in persistent cache.
# Key '70795934309762566' not in persistent cache.
# Key '-1119646987488483079' not in persistent cache.
# Key '-3572103822034015462' not in persistent cache.
# Key '3291734623656691823' not in persistent cache.
# Key '4339676715344100148' not in persistent cache.
# Key '-5374742341806034072' not in persistent cache.
# Key '5789637627548618243' not in persistent cache.
# Key '5670539197080405682' not in persistent cache.
# Key '-1423319049444543492' not in persistent cache.
# Key '8349381833997857003' not in persistent cache.
# Key '-1171392728251296724' not in persistent cache.
# Key '-3884580734697661563' not in persistent cache.
# Key '-4252701145888093245' not in persistent cache.
# Key '-1387382566760711187' not in persistent cache.
# Key '-3264258303582621807' not in persistent cache.
# Key '-8479610526752131749' not in persistent cache.
# Key '5813590281325390628' not in persistent cache.
# Key '5141844452528412451' not in persistent cache.
# Key '-2129846178414497264' not in persistent cache.
# Key '5165376976047139882' not in persistent cache.
# Key '-4015574321529216135' not in persistent cache.
# Key '1129168001896511' not in persistent cache.
# Key '5152479697370225513' not in persistent cache.
# Key '-3313486236398830127' not in persistent cache.
# Key '-4759041265851768420' not in persistent cache.
# Key '3663907478339851166' not in persistent cache.
# Key '3158909696101848986' not in persistent cache.
# Key '-3476725781920286171' not in persistent cache.
# Key '7288067780787630934' not in persistent cache.
# Key '-4491806569000789972' not in persistent cache.
# Key '1004063903700100343' not in persistent cache.
# Key '-8483348231242714722' not in persistent cache.
# Key '-5644028868430172816' not in persistent cache.
# Key '3993014548961753189' not in persistent cache.
# Key '-7976493629907633271' not in persistent cache.
# Key '-847013833455430897' not in persistent cache.
# Key '8121292001577221138' not in persistent cache.
# Key '1631262944403877578' not in persistent cache.
# Key '8696682562247777684' not in persistent cache.
# Key '-6908265419515113045' not in persistent cache.
# Key '-4553972181428311811' not in persistent cache.
# Key '5225308985068329689' not in persistent cache.
# Key '7395016627423358133' not in persistent cache.
# Key '4662313797175611649' not in persistent cache.
# Key '311529827648063320' not in persistent cache.
# Key '-6926614700212945123' not in persistent cache.
# Key '4932923341154945590' not in persistent cache.
# Key '-210133247495408708' not in persistent cache.
# Key '-7810529516836829982' not in persistent cache.
# Key '-7990493543569073028' not in persistent cache.
# Key '8999243311026711007' not in persistent cache.
# Key '-5210354348978105386' not in persistent cache.
# Key '-6694933023285545799' not in persistent cache.
# Key '1659699937768239869' not in persistent cache.
# Key '7009978911393625690' not in persistent cache.
# Key '196762001520271189' not in persistent cache.
# Key '-8137983185589295373' not in persistent cache.
# Key '-6227860527770104144' not in persistent cache.
# Key '82521502058754877' not in persistent cache.
# Key '-4036655932012371087' not in persistent cache.
# Key '-7563174186043379211' not in persistent cache.
# Key '-3619737222154957419' not in persistent cache.
# Key '-3800143223280858070' not in persistent cache.
# Key '-4528927291918495044' not in persistent cache.
# Key '1770113874246540904' not in persistent cache.
# Key '2095447031376656617' not in persistent cache.
# Key '2207672599306123041' not in persistent cache.
# Key '-2030240240941626735' not in persistent cache.
# Key '4951982163052713018' not in persistent cache.
# Key '-2184239808903160312' not in persistent cache.
# Key '4340807306741959260' not in persistent cache.
# Key '5593129540980419611' not in persistent cache.
# Key '-2279514302209101308' not in persistent cache.
# Key '-5269489138686834727' not in persistent cache.
# Key '-3455595863390443504' not in persistent cache.
# Key '-1494040086661851834' not in persistent cache.
# Key '8842561685689459323' not in persistent cache.
# Key '-4759706899327009950' not in persistent cache.
# Key '-5929515267786941850' not in persistent cache.
# Key '6884763707318947702' not in persistent cache.
# Key '4981510136186099279' not in persistent cache.
# Key '8417275058167263013' not in persistent cache.
# Key '2085320981855299826' not in persistent cache.
# Key '-9161098021987640131' not in persistent cache.
# Key '-3630839027725814959' not in persistent cache.
# Key '-7501292391366835233' not in persistent cache.
# Key '-5137611785889621070' not in persistent cache.
# Key '-1330565924543490855' not in persistent cache.
# Key '-7072931216006105854' not in persistent cache.
# Key '5186339036083400126' not in persistent cache.
# Key '3177393347917034894' not in persistent cache.
# Key '-141600272684357806' not in persistent cache.
# Key '406392519383435738' not in persistent cache.
# Key '4945594271948976621' not in persistent cache.
# Key '1111435735975982879' not in persistent cache.
# Key '-7824595624327036960' not in persistent cache.
# Key '8576994827276944915' not in persistent cache.
# Key '-7932336670990724357' not in persistent cache.
# Key '-436090364741466735' not in persistent cache.
# Key '-5301802715296799878' not in persistent cache.
# Key '-6135379275674801045' not in persistent cache.
# Key '697404484150694782' not in persistent cache.
# Key '6134575435862280585' not in persistent cache.
# Key '7789573713722566288' not in persistent cache.
# Key '643474958669453426' not in persistent cache.
# Key '-1433385293694204802' not in persistent cache.
# Key '-7835089815454943782' not in persistent cache.
# Key '6946658875172000613' not in persistent cache.
# Key '2224567309438456501' not in persistent cache.
# Key '-7746613153503867731' not in persistent cache.
# Key '2719403000331075176' not in persistent cache.
# Key '-8762044805085739253' not in persistent cache.
# Key '-2694708103176780487' not in persistent cache.
# Key '2089708812865680022' not in persistent cache.
# Key '343373119097555686' not in persistent cache.
# Key '42808324619179028' not in persistent cache.
# Key '3225434001564039825' not in persistent cache.
# Key '-7991761799792081855' not in persistent cache.
# Key '-1564700063741299778' not in persistent cache.
# Key '-886963769150323435' not in persistent cache.
# Key '3238917588527601218' not in persistent cache.
# Key '8565016657747171247' not in persistent cache.
# Key '7861917867335250263' not in persistent cache.
# Key '3658501865169136019' not in persistent cache.
# Key '-5854353045973770764' not in persistent cache.
# Key '-5928794557845479376' not in persistent cache.
# Key '-6501111166368627501' not in persistent cache.
# Key '-7607664117647251452' not in persistent cache.
# Key '-334527739356025505' not in persistent cache.
# Key '8878581912456497519' not in persistent cache.

# %% [markdown]
# # Plano de escrita
# > Abaixo descreveremos quais são os objetivos desse algorítimo e quais passos serão utilizados para a realização dele.

# %% [markdown]
# ## Objetivo principal
# > Esse algoritimo busca a análise econômica dos países da América do Sul produzindo um reporte que será acessado através de uma plataforma de visualização de dados.
#
# ## Objetivos específicos
# 1. Coletar, armazenar e processar dados das principais empresas dos países selecionados através do Yahoo Finance
#     1.1 Além das empresas nacionais, é importante também produzir dados de empresas transnacionais relevantes para a região
# 2. Coletar, armazenar e processar dados macroeconômicos dos países relevantes através de alguma ferramenta
# 3. Coletar as principais notícias nos jornais nacionais dos países em questão e através de uma inteligência artifical gerar resumos dessas notícias para serem apresentados no reporte
#
# ## Descrição das etapas pretendidas
# - Criação de um sistema de coleta, armazenamento local e consulta de dados dos ativos selecionados
#     - Os ativos relevantes são: cestas das bolsas de valores locais, taxa de câmbio com o dólar e em um escopo de região vamos extrair também os preços de commodities
#     - O armazenamento será através de um Banco de Dados. **Será utilizado o SQLite***
#     - Parte do processo de armazenamento é estabelecer um sistema eficiênte de datas para não sobrecarregar o yf
#     - O armazenamento é pensado como um Banco de Dados SQL
#     - Criar sistema de download dos dados históricos sem sobrecarregar YF
# - À partir dos dados obtidos executar os processamentos relevantes
#     - Executar análise do desvio padrão, correlação entre as bolsas, etc
#     - **Bonus:** Buscar bibliotecas que façam análise de risco e estudar ligeiramente as teorias dos ativos
#     - Armazenar todos os dados localmente
# - Organizar os dados em planilhas com conteúdo compatível com o software de visualização dos dados
#     - O software de visualização dos dados escolhi no momento foi o **Google Data Stuidio*
#     - Relevante aprender a utilizar
# - Utilizar a biblioteca de interação com o Drive para fazer o upload para uma pasta no drive que alimentará google data studio
# - Buscar e raspar principais notícias do dia e criar um resumo direcionado ao país através da IA
# - Armazenar localmente de forma compacta e fazer upload para o drive onde alimentará também o Google Data Studio
# - A ideia geral da visualização dos dados no google data stuidio é:
#     - Resumo geral da região
#         - Principais variações regionais em ativos de bolsa
#         - Commodities
#         - Agregados e a última data de atualização
#         - Principais cestas de bolsa
#         - Tabela com as taxas de câmbio e variações
#         - Resumo das notícias locais em um pequeno resumo da região
#     - Resumo individual
#         - Descrição detalhada dos agregados
#         - Análise de nível médio de detalhe das ações relevantes pra unidade nacional
#         - Resumo de três parágrafos das três primeiras notícias das manchetes

# %% [markdown]
# # Documentações e Links relevantes
#
# Código da IA: https://stackoverflow.com/questions/77816871/error-with-linux-for-google-api-gemini-ai
# Documentação do YF: https://pypi.org/project/yfinance/

# %% [markdown]
# # Informações sobre os dados:

# %% [markdown]
#    ## Sobre moedas:
#     Brasil (BRL): Real
#     Argentina (ARS): Peso argentino
#     Chile (CLP): Peso chileno
#     Colômbia (COP): Peso colombiano
#     México (MXN): Peso mexicano
#     Peru (PEN): Sol peruano
#     Uruguai (UYU): Peso uruguaio
#     Venezuela (VES): Bolívar soberano
#     Belize: Dólar de Belize (BZD)
#     Costa Rica: Colón costa-riquenho (CRC)
#     Guatemala: Quetzal guatemalteco (GTQ)
#     Honduras: Lempira hondurenho (HNL)
#     Nicarágua: Córdoba nicaraguense (NIO)
#     Panamá: Balboa panamenho (PAB)

# %% [markdown]
# # Sistemas

# %%
# Sistema de data

today = datetime.today()
today = today.strftime("%Y-%m-%d")

print(today)

def printype(ty):
    print(ty)
    print(type(ty))
# Out:
# 2024-05-09

# %%
# Recuperar tabelas do BD SQL em um objeto pandas

def sqltodf(pandas):
    # Conectar ao banco de dados SQLite
    conn = sqlite3.connect('yfhistoric.db')
    # Consulta SQL para recuperar os dados da tabela
    query = f"SELECT * FROM {pandas}"
    # Ler os dados do banco de dados para um DataFrame do pandas
    df = pd.read_sql_query(query, conn)
    # Fechar a conexão com o banco de dados
    conn.close()
    return df

# %%
### FUNÇÃO PARA RESGATAR A DATA CORRETA DE ATUALIZAÇÃO

# Tentei integrar essa função no meu código sem ter que abrir e fechar o DB a caba iteração, mas não soube. 

'''commcode = "HYMTF" #"HYMTF" #PRT não tem date @@@@@@@@@@@@@@@@ SÓ PARA UM TESTE'''
todaydelta = datetime.strptime(today, "%Y-%m-%d")
tenyragodelta = todaydelta - timedelta(days=10*365)
tenyragovar = tenyragodelta.strftime("%Y-%m-%d")
todayvar = todaydelta.strftime("%Y-%m-%d")
todaydt = datetime.strptime(today, "%Y-%m-%d")


#####
def datecheck(commcode):
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    print(f"@@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '{commcode}' @@@@@@@@@@@@@@@@")
    noatt = "no att" # PARA QUANDO A INSTRUÇÃO SEJA NÃO ATUALIZAR 
    commcode = commcode.lower()
    command = f'SELECT MIN(date) FROM "{commcode}"'
    cursor.execute(command)
    lastdate = cursor.fetchall()
    lastdate = [row[0] for row in lastdate]
    lastdatetest = f'{lastdate[0]}'
    # Testando se está vazio
    if lastdatetest == "None":
        print("é none") ######### AQUI COLOCAR 10 ANOS ATRÁS
        return tenyragovar
    else: # FAZER A DIFERENÇA DE TEMPO
        print("não é none, fazendo subtração")
        print(f"lastdatetest é {lastdatetest}")
        lastdatedt = datetime.strptime(lastdatetest, "%Y-%m-%d %H:%M:%S")
        timedif = lastdatedt - tenyragodelta
        if lastdatedt > tenyragodelta: # SE A LASTDATE FOR MAIOR (MAIS NOVA, MAIS RECENTE) VAI ATIVAR ESSE. ESSE TESTE É "QUAL DATA É MAIS RECENTE?"
            print("SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS") # SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
            return tenyragovar
        else: # SE NÃO VAI ATIVAR ESSE, OU SEJA, A LASTDATE É MENOR OU IGUAL A "DEZ ANOS ATRÁS".
            print("TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA") # TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
            command = f'SELECT MAX(date) FROM "{commcode}"'
            cursor.execute(command)
            earlydate = cursor.fetchall()
            earlydate = [row[0] for row in earlydate]
            earlydate = f'{earlydate[0]}'
            earlydatedt = datetime.strptime(earlydate, "%Y-%m-%d %H:%M:%S")
            earlydate = datetime.strftime(earlydatedt, "%Y-%m-%d")
            if earlydatedt == todaydt:
                print(f"{commcode} do not need att")
                return noatt
            else:
                print(f"Att from {earlydatedt} to {todaydt}")
                return earlydate

    conn.close()

'''##############
print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ISSO É UM TESTE@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")

datetest = datecheck(commcode)

print(datetest)'''
# Out:
# '##############\nprint("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ISSO É UM TESTE@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")\n\ndatetest = datecheck(commcode)\n\nprint(datetest)'

# %% [markdown]
# # Atualizações/Instalações

# %%
# Criar/conectar um BD

# Primeiro é importante verificar se o arquivo do database está presente no "root" da instalação

rootdire =  os.getcwd()
rootdire_list = os.listdir(rootdire)

if 'yfhistoric.db' in rootdire_list:
    conexao = sqlite3.connect('yfhistoric.db')
    print('Você já tem um Banco de Dados')
else:
    conexao = sqlite3.connect('yfhistoric.db')
    print('Criando um banco de dados')
    cursor = conexao.cursor()
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS indicators(
        id INTEGER PRIMARY KEY,
        datatype TEXT NOT NULL
    )
    ''')
    conexao.close()

### CRIANDO AS TABELAS SE ELAS NÃO EXISTEM ###
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

###### TABELAS MÃE #####
cursor.execute('''
    CREATE TABLE IF NOT EXISTS indicators(
        id INTEGER PRIMARY KEY,
        datatype TEXT NOT NULL
    );
    
    ''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS texts(
        id INTEGER PRIMARY KEY,
        datatype TEXT NOT NULL
    );    
    ''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS countries( 
        id INTEGER PRIMARY KEY,
        country TEXT,
        alpha3code TEXT,
        latam TEXT
        
    );    
    ''')
# Na chave "latam" adicionar "yes", "no" e "world" 


cursor.execute('''
    CREATE TABLE IF NOT EXISTS niche( 
        id INTEGER PRIMARY KEY,
        niche TEXT
    );    
    ''')

##### TABELAS FILHA
cursor.execute('''
    CREATE TABLE IF NOT EXISTS currencies(
        id INTEGER PRIMARY KEY,
        currcode TEXT NOT NULL,
        currname TEXT NOT NULL,
        country TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES indicators(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''')

cursor.execute('''
    CREATE TABLE IF NOT EXISTS tickets(
        id INTEGER PRIMARY KEY,
        ticcode TEXT NOT NULL,
        ticname TEXT NOT NULL,
        ticcat TEXT NOT NULL,
        datatype TEXT NOT NULL,
        country TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES indicators(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''')

cursor.execute('''
    CREATE TABLE IF NOT EXISTS commodities(
        id INTEGER PRIMARY KEY,
        commcode TEXT NOT NULL,
        comname TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES indicators(datatype)
    );    
    ''')

cursor.execute('''
    CREATE TABLE IF NOT EXISTS agregates(
        id INTEGER PRIMARY KEY,
        agrcode TEXT NOT NULL,
        agrcodewb TEXT NOT NULL,
        agrname TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES indicators(datatype)
    );    
    ''')


cursor.execute('''
    CREATE TABLE IF NOT EXISTS cripto(
        id INTEGER PRIMARY KEY,
        criptoname TEXT NOT NULL, 
        criptocode TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES text(datatype)
    );    
    ''')

####### text

cursor.execute('''
    CREATE TABLE IF NOT EXISTS news(
        id INTEGER PRIMARY KEY,
        newspapername TEXT NOT NULL,
        newspaperlink TEXT NOT NULL,
        country TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES text(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''')

cursor.execute('''
    CREATE TABLE IF NOT EXISTS summary(
        id INTEGER PRIMARY KEY,
        summhierarquy TEXT NOT NULL, 
        country TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES text(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''')



###### TESTES E END
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
table = cursor.fetchall()


conn.commit()
conn.close()

# print(rootdire      , ' !!!!! ', rootdire_list)  Para verificar
#print(rootdire      , ' !!!!! ', rootdire_list)


# Conectar ao banco de dados (isso criará o banco de dados se não existir)
# conexao = sqlite3.connect('yfhistoric.db')
# Out:
# Você já tem um Banco de Dados

# %%
########## GATILHOS DAS CATEGORIAS MÃE (INCOMPLETO, FAZER DEPOIS)
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

indicatorsdt = ('currencies', 'tickets', 'commodities', 'agregates')

textdt = ('news', 'summary')

countriescat = ('Brasil', 'Argentina', 'Chile', 'Colômbia', 'México', 'Peru', 'Uruguai', 'Venezuela', 'Belize', 'Costa Rica', 'Estados Unidos', 'Guatemala', 'Honduras', 'Nicarágua', 'Bolívia', 'Mundo', 'Criptomoeda', 'União Europeia')

conn.close()

# %%
##### INSERIR DADOS TABELA MÃE


data = (indicatorsdt, textdt, countriescat)

conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

for indi in indicatorsdt:
    command = '''
        INSERT INTO indicators (datatype)
        SELECT ? AS datatype
        WHERE NOT EXISTS (
            SELECT 1 FROM indicators WHERE datatype = ?
        )
    '''
    conn.execute(command, (indi, indi))
    conn.commit()

for dt in textdt:
    command = '''
        INSERT INTO texts (datatype)
        SELECT ? AS datatype
        WHERE NOT EXISTS (
            SELECT 1 FROM indicators WHERE datatype = ?
        )
    '''
    conn.execute(command, (dt, dt))
    conn.commit()

# %% [markdown]
# # TABELAS FILHAS/NETAS

# %% [markdown]
# # Currencies

# %%
##### CURRENCIES
currencies_todf = {  # EDITAR ISSO PARA ADICIONAR OU REMOVER MOEDAS RELEVANTES A SEREM ANALISADAS
    
'pais': ['Brasil', 'Argentina', 'Chile', 'Colômbia', 'México', 'Peru', 'Uruguai', 'Venezuela', 'Belize', 'Costa Rica', 'Estados Unidos', 'Guatemala', 'Honduras', 'Nicarágua', 'Bolívia'],
'moeda': ['Real', 'Peso argentino', 'Peso chileno', 'Peso colombiano', 'Peso mexicano', 
          'Sol peruano', 'Peso uruguaio', 'Bolívar soberano', 'Dólar de Belize', 'Colón costa-riquenho', 'Dólar dos Estados Unidos', 'Quetzal guatemalteco', 
           'Lempira hondurenho', 'Córdoba nicaraguense', 'Boliviano'],
'codigo': ['BRL', 'ARS', 'CLP', 'COP', 'MXN', 'PEN', 'UYU', 'VES', 'BZD', 'CRC', 'USD', 'GTQ', 'HNL', 'NIO', 'BOB']
}

currenciesdf = pd.DataFrame(currencies_todf)
currenciesdf.head(20)
# Out:
#               pais                     moeda codigo
# 0           Brasil                      Real    BRL
# 1        Argentina            Peso argentino    ARS
# 2            Chile              Peso chileno    CLP
# 3         Colômbia           Peso colombiano    COP
# 4           México             Peso mexicano    MXN
# 5             Peru               Sol peruano    PEN
# 6          Uruguai             Peso uruguaio    UYU
# 7        Venezuela          Bolívar soberano    VES
# 8           Belize           Dólar de Belize    BZD
# 9       Costa Rica      Colón costa-riquenho    CRC
# 10  Estados Unidos  Dólar dos Estados Unidos    USD
# 11       Guatemala      Quetzal guatemalteco    GTQ
# 12        Honduras        Lempira hondurenho    HNL
# 13       Nicarágua      Córdoba nicaraguense    NIO
# 14         Bolívia                 Boliviano    BOB

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

for index, row in currenciesdf.iterrows():
    code = row['codigo']
    name = row['moeda']
    country = row['pais']
    datatype = 'currencies'
    dados = (code, name, country, datatype) 
    command = '''
        INSERT INTO currencies (currcode, currname, country, datatype)
        SELECT ?, ?, ?, ?
        WHERE NOT EXISTS (
            SELECT 1 FROM currencies 
            WHERE currcode = ? AND currname = ? AND country = ? AND datatype = ?
        )
    '''
    cursor.execute(command, dados + dados)
    conn.commit()
conn.close()

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

command = 'SELECT currcode FROM currencies'

cursor.execute(command)

# Recuperar os resultados da consulta
resultados = cursor.fetchall()

# Armazenar os valores da coluna em uma lista Python
coluna_lista = [row[0] for row in resultados]

# Exibir a lista
print(coluna_lista)
# Out:
# ['BRL', 'ARS', 'CLP', 'COP', 'MXN', 'PEN', 'UYU', 'VES', 'BZD', 'CRC', 'USD', 'GTQ', 'HNL', 'NIO', 'BOB']

# %%
for codeit in coluna_lista:
    codeit = codeit.lower()
    command = f'''
        CREATE TABLE IF NOT EXISTS {codeit}(
            id INTEGER PRIMARY KEY,
            code TEXT NOT NULL,
            date DATE,
            open REAL,
            high REAL,
            low REAL,
            close REAL,
            volume REAL,
            datatype TEXT NOT NULL
        );    
        '''
    cursor.execute(command)
    conn.commit()


# Fechar a conexão com o banco de dados
conn.close()

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

for currcode in coluna_lista:
    currcode = currcode.lower()
    command = f'SELECT MIN(date) FROM {currcode}'
    cursor.execute(command)
    lastdate = cursor.fetchall()
    lastdatetest = f'{lastdate}'
    lastdatetest = len(lastdatetest)
    if lastdatetest == 9: # GAMBIARRA MÁXIMA
        tenyragovar = tenyragodelta.strftime("%Y-%m-%d")
        todayvar = todaydelta.strftime("%Y-%m-%d")
        downloadv = yf.download(f"USD{currcode}=X", start=f"{tenyragovar}", end=f"{todayvar}")
        downloadv = downloadv.drop('Adj Close', axis=1)
        downloadv['datatype'] = 'currencies'
        downloadv['code'] = f'{currcode}'
        downloadv.reset_index(inplace=True)
        downloadv['Date'] = pd.to_datetime(downloadv['Date'])
        currcodel = currcode.lower()
        downloadv.to_sql(f'{currcodel}', conn, if_exists='append', index=False, dtype={'Date': 'DATE'})
        
    else:
        command = f'SELECT MAX(date) FROM {currcode}'
        cursor.execute(command)
        firstdate = cursor.fetchall()
        lastdatestr = lastdate[0][0].split()[0]
        lastdatedatetime = datetime.strptime(lastdatestr, '%Y-%m-%d')
        firstdatestr = firstdate[0][0].split()[0]
        firstdatedatetime = datetime.strptime(firstdatestr, '%Y-%m-%d')
        todayvar = todaydelta.strftime("%Y-%m-%d")
        firstdatestr = firstdatedatetime.strftime("%Y-%m-%d")
        print(firstdatedatetime)
        print(todaydelta)
        print(type(todaydelta))
        print(todayvar)
        print(firstdatestr)
        if firstdatestr == todaydelta:
            print('Up to date')
        else:
            downloadv = yf.download(f"USD{currcode}=X", start=f"{firstdatestr}", end=f"{todayvar}") # o Yahoo Finance só resgata os tickets de moeda depois do fechamento do dia. 
            # Rodar esse programa UMA VEZ POR DIA
            # PARA UMA ATUALIZAÇÃO: ADICIONAR UMA CHAVE DE "ATUALIZATION DATE"
            downloadv = downloadv.drop('Adj Close', axis=1)
            downloadv['datatype'] = 'currencies'
            downloadv['code'] = f'{currcode}'
            downloadv.reset_index(inplace=True)
            downloadv['Date'] = pd.to_datetime(downloadv['Date'])
            currcodel = currcode.lower()
            downloadv.to_sql(f'{currcodel}', conn, if_exists='replace', index=False, dtype={'Date': 'DATE'})
            print(downloadv)
            conn.commit()

conn.close()
# Out:
# 2024-05-03 00:00:00
# 2024-05-09 00:00:00
# <class 'datetime.datetime'>
# 2024-05-09
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
#         Date    Open    High       Low   Close  Volume    datatype code
# 0 2024-05-03  5.1103  5.1131  5.043200  5.1103       0  currencies  brl
# 1 2024-05-06  5.0709  5.0892  5.063600  5.0709       0  currencies  brl
# 2 2024-05-07  5.0749  5.0815  5.047162  5.0749       0  currencies  brl
# 3 2024-05-08  5.0733  5.1062  5.062943  5.0733       0  currencies  brl
# 2024-05-03 00:00:00
# 2024-05-09 00:00:00
# <class 'datetime.datetime'>
# 2024-05-09
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close  Volume  \
# 0 2024-05-03  878.200012  878.892578  876.892090  878.200012       0
# 1 2024-05-06  876.997986  880.326599  875.886597  876.997986       0
# 2 2024-05-07  880.118286  880.835022  880.024292  880.118286       0
# 3 2024-05-08  880.651611  881.819641  880.556519  880.651611       0
#
#      datatype code
# 0  currencies  ars
# 1  currencies  ars
# 2  currencies  ars
# 3  currencies  ars
# 2024-05-03 00:00:00
# 2024-05-09 00:00:00
# <class 'datetime.datetime'>
# 2024-05-09
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close  Volume  \
# 0 2024-05-03  947.150024  947.150024  931.520203  947.150024       0
# 1 2024-05-06  942.750000  942.880005  930.005920  942.750000       0
# 2 2024-05-07  929.390015  937.799988  925.229980  929.390015       0
# 3 2024-05-08  936.530029  936.530029  936.530029  936.530029       0
#
#      datatype code
# 0  currencies  clp
# 1  currencies  clp
# 2  currencies  clp
# 3  currencies  clp
# 2024-05-03 00:00:00
# 2024-05-09 00:00:00
# <class 'datetime.datetime'>
# 2024-05-09
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['USDUSD=X']: IndexError('index 0 is out of bounds for axis 0 with size 0')
# 2024-05-03 00:00:00
# 2024-05-09 00:00:00
# <class 'datetime.datetime'>
# 2024-05-09
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
#         Date      Open      High       Low     Close  Volume    datatype code
# 0 2024-05-03  7.566545  7.584160  7.566545  7.588147       0  currencies  gtq
# 1 2024-05-06  7.570284  7.588320  7.570284  7.573519       0  currencies  gtq
# 2 2024-05-07  7.585010  7.585073  7.585010  7.588320       0  currencies  gtq
# 3 2024-05-08  7.598552  7.598552  7.585937  7.585073       0  currencies  gtq
# 2024-05-03 00:00:00
# 2024-05-09 00:00:00
# <class 'datetime.datetime'>
# 2024-05-09
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Volume    datatype  \
# 0 2024-05-03  24.179367  24.510000  24.179367  24.247833       0  currencies
# 1 2024-05-06  24.184561  24.240482  24.184561  24.195122       0  currencies
# 2 2024-05-07  24.233171  24.600000  24.233171  24.600000       0  currencies
# 3 2024-05-08  24.294388  24.294388  24.252998  24.610001       0  currencies
#
#   code
# 0  hnl
# 1  hnl
# 2  hnl
# 3  hnl
# 2024-05-03 00:00:00
# 2024-05-09 00:00:00
# <class 'datetime.datetime'>
# 2024-05-09
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Volume    datatype  \
# 0 2024-05-03  36.249439  36.509998  36.249439  36.352592       0  currencies
# 1 2024-05-06  36.266880  36.345406  36.266880  36.283390       0  currencies
# 2 2024-05-07  36.334442  36.509998  36.334442  36.509998       0  currencies
# 3 2024-05-08  36.416416  36.416416  36.356361  36.529999       0  currencies
#
#   code
# 0  nio
# 1  nio
# 2  nio
# 3  nio
# 2024-05-03 00:00:00
# 2024-05-09 00:00:00
# <class 'datetime.datetime'>
# 2024-05-09
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
#         Date      Open      High       Low     Close  Volume    datatype code
# 0 2024-05-03  6.705524  6.736325  6.705524  6.724762       0  currencies  bob
# 1 2024-05-06  6.724156  6.727999  6.724156  6.727062       0  currencies  bob
# 2 2024-05-07  6.722970  6.725054  6.722970  6.725092       0  currencies  bob
# 3 2024-05-08  6.737005  6.737005  6.725168  6.725054       0  currencies  bob

# %% [markdown]
# # Cripto

# %%
### Cripto

cripto_df = pd.read_excel("cripto.xlsx")
print(cripto_df)
# Out:
#            criptoname criptocode
# 0             Bitcoin        BTC
# 1            Ethereum        ETH
# 2        Binance Coin        BNB
# 3              Solana        SOL
# 4             Cardano        ADA
# 5              Tether       USDT
# 6                 XRP        XRP
# 7            Polkadot        DOT
# 8            USD Coin       USDC
# 9            Dogecoin       DOGE
# 10          Avalanche       AVAX
# 11          Chainlink       LINK
# 12              Terra       LUNA
# 13           Litecoin        LTC
# 14           Algorand       ALGO
# 15          Shiba Inu       SHIB
# 16            Polygon      MATIC
# 17       Bitcoin Cash        BCH
# 18            Stellar        XLM
# 19  Internet Computer        ICP
# 20    Wrapped Bitcoin       WBTC
# 21   Ethereum Classic        ETC
# 22            VeChain        VET
# 23           Filecoin        FIL
# 24               TRON        TRX
# 25      Theta Network      THETA
# 26             Cosmos       ATOM
# 27          FTX Token        FTT
# 28                Dai        DAI
# 29               Aave       AAVE

# %%
def updatecripto(cripto):
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    cripto = pd.DataFrame(cripto)
    for index, row in cripto.iterrows():
        code = row['criptocode']
        name = row['criptoname']
        datatype = 'criptocurrencies'
        dados = (code, name, datatype) 
        command = '''
            INSERT INTO cripto (criptocode, criptoname, datatype)
            SELECT ?, ?, ?
            WHERE NOT EXISTS (
                SELECT 1 FROM cripto
                WHERE criptocode = ? AND criptoname = ? AND datatype = ?
            )
        '''
        cursor.execute(command, dados + dados)
        conn.commit()
    # SELECIONA TODOS OS CÓDIGOS DE TICKERS QUE VAMOS VER NO NOSSO DB
    command = 'SELECT criptocode FROM cripto'
    cursor.execute(command)
    
    
    # RECUPERA A CONSULTA EM UMA LISTA DE TUPLAS
    resultados = cursor.fetchall()
    # Armazenar os valores da coluna em uma lista Python comum
    coluna_lista = [row[0] for row in resultados]
    # CRIA UMA TABELA PARA CADA CÓDIGO
    for codeit in coluna_lista:
        codeit = codeit.lower()
        command = f'''
            CREATE TABLE IF NOT EXISTS "{codeit}"(
                id INTEGER PRIMARY KEY,
                code TEXT NOT NULL,
                date DATE,
                open REAL,
                high REAL,
                low REAL,
                close REAL,
                volume REAL,
                datatype TEXT NOT NULL
            );    
            '''
        cursor.execute(command)
        conn.commit()
       



    ############################## PREENCHER CADA TABELA COM O YAHOO FINANCE



    for commcode in coluna_lista: ### COMMCODE AQUI DEVERIA SER TICCODE
        attdate = datecheck(commcode)
        print(attdate)
        if attdate == "no att":
            print(f"Sem att para o ticker {commcode}")
        else:
            
            try:
                downloadv = yf.download(f"{commcode}", start=f"{attdate}", end=f"{todayvar}")
            except Exception as e:
                ex = f"{e}"
                download_errors.append(ex)
                print(f"O erro do código {commcode} foi {ex}")
            downloadv = downloadv.drop('Adj Close', axis=1)
            downloadv['datatype'] = 'cripto'
            downloadv['code'] = f'{commcode}'
            downloadv.reset_index(inplace=True)
            downloadv['Date'] = pd.to_datetime(downloadv['Date'])
            commcodel = commcode.lower()
            downloadv.to_sql(f'{commcodel}', conn, if_exists='replace', index=False, dtype={'Date': 'DATE'})
            conn.commit()
    conn.close()

############################ executando a função

updatecripto(cripto_df)
# Out:
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BTC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2020-10-01 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ETH' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ETH']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BNB' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2020-04-29 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SOL' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-04-26 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ADA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ADA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'USDT' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['USDT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'XRP' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['XRP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'DOT' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2017-03-13 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'USDC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2023-07-06 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'DOGE' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['DOGE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'AVAX' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['AVAX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'LINK' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-04-26 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'LUNA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-04-26 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'LTC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-04-26 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ALGO' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ALGO']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SHIB' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['SHIB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'MATIC' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['MATIC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BCH' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-02 00:00:00 to 2024-05-09 00:00:00
# 2024-05-02
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'XLM' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2016-01-27 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ICP' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ICP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'WBTC' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['WBTC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ETC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2022-03-02 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'VET' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-04-26 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'FIL' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2018-01-30 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'TRX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-04-26 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'THETA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['THETA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ATOM' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2016-08-08 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'FTT' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['FTT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'DAI' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2018-03-02 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'AAVE' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['AAVE']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %% [markdown]
# # Commodities

# %%
########################### commodities
commodities_todf = {
    'commodity': ['Ouro', 'Prata', 'Petróleo Crude (WTI)', 'Petróleo Brent Crude', 'Cobre', 'Gás Natural', 'Milho', 'Trigo', 'Café', 'Açúcar'],
    'codigo': ['GC=F', 'SI=F', 'CL=F', 'BZ=F', 'HG=F', 'NG=F', 'C=F', 'W=F', 'KC=F', 'SB=F']
}
commoditiesdf = pd.DataFrame(commodities_todf)

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

command = 'SELECT commcode FROM commodities'

cursor.execute(command)

# Recuperar os resultados da consulta
resultados = cursor.fetchall()

# Armazenar os valores da coluna em uma lista Python
coluna_lista = [row[0] for row in resultados]

# Exibir a lista
print(coluna_lista)
# Out:
# ['GC=F', 'SI=F', 'CL=F', 'BZ=F', 'HG=F', 'NG=F', 'C=F', 'W=F', 'KC=F', 'SB=F']

# %%
def updatecommodities(dcticket):
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    dcticketdf = pd.DataFrame(dcticket)
    for index, row in dcticketdf.iterrows():
        code = row['codigo']
        name = row['commodity']
        datatype = 'commodities'
        dados = (code, name, datatype) 
        command = '''
            INSERT INTO commodities (commcode, comname, datatype)
            SELECT ?, ?, ?
            WHERE NOT EXISTS (
                SELECT 1 FROM commodities
                WHERE commcode = ? AND comname = ? AND datatype = ?
            )
        '''
        cursor.execute(command, dados + dados)
        conn.commit()
    # SELECIONA TODOS OS CÓDIGOS DE TICKERS QUE VAMOS VER NO NOSSO DB
    command = 'SELECT commcode FROM commodities'
    cursor.execute(command)
    
    
    # RECUPERA A CONSULTA EM UMA LISTA DE TUPLAS
    resultados = cursor.fetchall()
    # Armazenar os valores da coluna em uma lista Python comum
    coluna_lista = [row[0] for row in resultados]
    # CRIA UMA TABELA PARA CADA CÓDIGO
    for codeit in coluna_lista:
        codeit = codeit.lower()
        command = f'''
            CREATE TABLE IF NOT EXISTS "{codeit}"(
                id INTEGER PRIMARY KEY,
                code TEXT NOT NULL,
                date DATE,
                open REAL,
                high REAL,
                low REAL,
                close REAL,
                volume REAL,
                datatype TEXT NOT NULL
            );    
            '''
        cursor.execute(command)
        conn.commit()
       



    ############################## PREENCHER CADA TABELA COM O YAHOO FINANCE



    for commcode in coluna_lista: ### COMMCODE AQUI DEVERIA SER TICCODE
        attdate = datecheck(commcode)
        print(attdate)
        if attdate == "no att":
            print(f"Sem att para o ticker {commcode}")
        else:
            
            try:
                downloadv = yf.download(f"{commcode}", start=f"{attdate}", end=f"{todayvar}")
            except Exception as e:
                ex = f"{e}"
                download_errors.append(ex)
                print(f"O erro do código {commcode} foi {ex}")
            downloadv = downloadv.drop('Adj Close', axis=1)
            downloadv['datatype'] = 'commodities'
            downloadv['code'] = f'{commcode}'
            downloadv.reset_index(inplace=True)
            downloadv['Date'] = pd.to_datetime(downloadv['Date'])
            commcodel = commcode.lower()
            downloadv.to_sql(f'{commcodel}', conn, if_exists='replace', index=False, dtype={'Date': 'DATE'})
            conn.commit()
    conn.close()

updatecommodities(commoditiesdf)
# Out:
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GC=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SI=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CL=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BZ=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'HG=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'NG=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'C=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2020-08-21 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'W=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2020-08-21 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'KC=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SB=F' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Tickets
#
# >Estava com problemas para fazer a função if de consulta da última data de atualização e diversas formas de fazer o download para não sobrecarregar o Yahoo Finance, mas parece que o yf é robusto
# >e fazer download de 10 anos dos tickers não vai ser problema. Mas é algo a ser otimizado. Uma forma é fazer uma subtração do lastdate. Pra frente veremos.
# >O mesmo vale para as saídas de erro com tickers com código incorreto, isso depende dos ajustes que tem que ser feitos com o código pronto.

# %%
###### CRIAÇÃO E MANUTENÇÃO DIRETÓRIO TICKERS ####

# Nome da pasta que você deseja verificar/criar
nome_pasta = "tickets"
# Verificar se o diretório existe
if not os.path.exists(nome_pasta):
    # Se não existir, criar o diretório
    os.makedirs(nome_pasta)
    
# Diretório onde estão os arquivos Excel
diretorio_tickets = "tickets"

# Lista para armazenar os dataframes
tickets = []

# Verificar se o diretório existe
if os.path.exists(diretorio_tickets):
    # Listar todos os arquivos na pasta
    arquivos_excel = [arquivo for arquivo in os.listdir(diretorio_tickets) if arquivo.endswith('.xlsx')] # LISTA TODOS OS 
    
    # Ler cada arquivo Excel e adicionar o dataframe à lista
    for arquivo in arquivos_excel:
        caminho_arquivo = os.path.join(diretorio_tickets, arquivo)
        df = pd.read_excel(caminho_arquivo)
        tickets.append(df) # UMA LISTA DE DATFRAMES
else:
    print(f"O diretório '{diretorio_tickets}' não existe.")

# %%
download_errors = []

caminho_arquivo_e = f"tickererrors_{today}.txt"
caminho_arquivo_e = os.path.join(rootdire, caminho_arquivo_e)

def updateticket(dcticket):
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    dcticketdf = pd.DataFrame(dcticket)
    for index, row in dcticketdf.iterrows():
        code = row['codigo']
        name = row['empresa']
        country = row['pais']
        niche = row['nicho']
        datatype = 'tickets'
        dados = (code, name, datatype, niche, country) 
        command = '''
            INSERT INTO tickets (ticcode, ticname, datatype, ticcat, country)
            SELECT ?, ?, ?, ?, ?
            WHERE NOT EXISTS (
                SELECT 1 FROM tickets
                WHERE ticcode = ? AND ticname = ? AND datatype = ? AND ticcat = ? AND country = ?
            )
        '''
        cursor.execute(command, dados + dados)
        conn.commit()
    # SELECIONA TODOS OS CÓDIGOS DE TICKERS QUE VAMOS VER NO NOSSO DB
    command = 'SELECT ticcode FROM tickets'
    cursor.execute(command)
    
    
    # RECUPERA A CONSULTA EM UMA LISTA DE TUPLAS
    resultados = cursor.fetchall()
    # Armazenar os valores da coluna em uma lista Python comum
    coluna_lista = [row[0] for row in resultados]
    # CRIA UMA TABELA PARA CADA CÓDIGO
    for codeit in coluna_lista:
        codeit = codeit.lower()
        command = f'''
            CREATE TABLE IF NOT EXISTS "{codeit}"(
                id INTEGER PRIMARY KEY,
                code TEXT NOT NULL,
                date DATE,
                open REAL,
                high REAL,
                low REAL,
                close REAL,
                volume REAL,
                datatype TEXT NOT NULL
            );    
            '''
        cursor.execute(command)
        conn.commit()
       



    ############################## PREENCHER CADA TABELA COM O YAHOO FINANCE



    for commcode in coluna_lista: ### COMMCODE AQUI DEVERIA SER TICCODE
        attdate = datecheck(commcode)
        print(attdate)
        if attdate == "no att":
            print(f"Sem att para o ticker {commcode}")
        else:
            
            try:
                downloadv = yf.download(f"{commcode}", start=f"{attdate}", end=f"{todayvar}")
            except Exception as e:
                ex = f"{e}"
                download_errors.append(ex)
                print(f"O erro do código {commcode} foi {ex}")
            downloadv = downloadv.drop('Adj Close', axis=1)
            downloadv['datatype'] = 'tickets'
            downloadv['code'] = f'{commcode}'
            downloadv.reset_index(inplace=True)
            downloadv['Date'] = pd.to_datetime(downloadv['Date'])
            commcodel = commcode.lower()
            downloadv.to_sql(f'{commcodel}', conn, if_exists='replace', index=False, dtype={'Date': 'DATE'})
            conn.commit()
    conn.close()

# Abrir o arquivo no modo de escrita
with open(caminho_arquivo_e, 'wb') as arquivo:
    # Escrever cada elemento da lista em uma nova linha do arquivo
    for elemento in download_errors:
        
        arquivo.write('%s\n' % elemento)

############################ executando a função

for tic in tickets:
    updateticket(tic)
# Out:
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'YPFD.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GGAL.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BMA.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'MELI.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'TECO2.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BBAR.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CRES.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'PAMP.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'TS.BA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['TS.BA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GLOB.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-04-26 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BMA.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-05-03 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'TXAR.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CEPU.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'RIO.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SUPV.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2016-05-19 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'YPFL.BA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['YPFL.BA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BBVA.BA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BBVA.BA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'TGSU2.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'DESP.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2020-03-12 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GGAL.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-05-03 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ALUA.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'MOLI.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'EDN.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'IRSA.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BPAT.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'TECO2.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-05-03 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ERAR.BA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ERAR.BA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CTIO.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'MOLA.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2017-06-26 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'TGSU2.BA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-05-03 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'VALE3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ITUB4.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BBDC4.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ABEV3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BBAS3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'B3SA3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'PETR4.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CIEL3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ELET6.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'MGLU3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'VVAR3.SA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['VVAR3.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GGBR4.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'RAIL3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2015-04-02 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CYRE3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'KLBN11.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'RAPT4.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'UGPA3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'USIM5.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'LAME4.SA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['LAME4.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SUZB3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'FLRY3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GOLL4.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SANB11.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'RENT3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ECOR3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BRKM5.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'WEGE3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'JBSS3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'IRBR3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2017-07-31 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CCRO3.SA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SAN.SN' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['SAN.SN']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'LTM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['LTM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CENCOSUD' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['CENCOSUD']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ENELCHILE' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ENELCHILE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SQM' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-02 00:00:00 to 2024-05-09 00:00:00
# 2024-05-02
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BCH' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-05-02 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CAP' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['CAP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ANDINA-A' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ANDINA-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ENELAM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ENELAM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BICE' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BICE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'COLBUN' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['COLBUN']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'COPEC' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['COPEC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ENTEL' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ENTEL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'COPEC' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['COPEC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SMU' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2016-02-25 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'FALABELLA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['FALABELLA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BSANTANDER' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BSANTANDER']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BCI' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2017-03-31 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ILC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-01 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2016-10-26 00:00:00 to 2024-05-09 00:00:00
# 2016-10-26
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SONDA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['SONDA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ESTADO' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ESTADO']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'PARAUCO' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['PARAUCO']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ITAUCORP' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ITAUCORP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CONCHATORO' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['CONCHATORO']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SAAM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['SAAM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BSAN.SN' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BSAN.SN']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SECURITY' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['SECURITY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ENELCHILE' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ENELCHILE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ILC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2016-10-26 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BCI' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2017-03-31 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ECOPETROL' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ECOPETROL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BIC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2022-03-02 00:00:00 to 2024-05-09 00:00:00
# 2022-03-02
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SUR' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2020-01-24 00:00:00 to 2024-05-09 00:00:00
# 2020-01-24
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ARGOS' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ARGOS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BOLIVAR' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BOLIVAR']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CORONA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['CORONA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'NUTRESA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['NUTRESA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'EXITO' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['EXITO']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CENCOSUD' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['CENCOSUD']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'AVAL' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-09-23 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GEB' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2022-03-01 00:00:00 to 2024-05-09 00:00:00
# 2022-03-01
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'PROMIGAS' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['PROMIGAS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'EPM' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-02 00:00:00 to 2024-05-09 00:00:00
# 2024-05-02
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CELSIA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['CELSIA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ISA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2022-03-01 00:00:00 to 2024-05-09 00:00:00
# 2022-03-01
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'PFBCOLOM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['PFBCOLOM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'DAVIVIENDA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['DAVIVIENDA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GNC' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['GNC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ARGOS' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ARGOS']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SURA' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['SURA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'PFG' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-02 00:00:00 to 2024-05-09 00:00:00
# 2024-05-02
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'AMXL.MX' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['AMXL.MX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GMEXICOB.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'FEMSAUBD.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BIMBOA.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CEMEXCPO.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GFNORTEO.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ELEKTRA.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GRUMAB.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GAPB.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ALFAA.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'OMAB.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GCARSOA1.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'LABB.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ASURB.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GACMAB.MX' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['GACMAB.MX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SIMECB.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ALPEKA.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'VLRS.MX' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['VLRS.MX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GENTERA.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BSMXB.MX' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BSMXB.MX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'TLEVISACPO.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'LALAB.MX' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['LALAB.MX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'HERDEZ.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GCC.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GIGANTE.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BBAJIOO.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2017-06-08 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GSANBORB-1.MX' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['GSANBORB-1.MX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'FUNO11.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GRUMAB.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-05-03 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'KUOB.MX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-02 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BAP.LM' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'SCCO' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'VOLC.OB' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['VOLC.OB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BCP.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BCP.LM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GRA.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['GRA.LM']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ENE.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ENE.LM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'FER.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['FER.LM']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BVN.LM' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BCO.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BCO.LM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'IFS.LM' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-09 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'LAP.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['LAP.LM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CEM.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['CEM.LM']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'INRE.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['INRE.LM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'IPA.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['IPA.LM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ALICORP.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ALICORP.LM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'HOC.L' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-01 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-03 00:00:00 to 2024-05-09 00:00:00
# 2024-05-03
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'COPEC' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['COPEC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'BACKUS.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['BACKUS.LM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ARE.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ARE.LM']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'RLP.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['RLP.LM']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'PSEG.LM' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# ...
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['METR.DE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'YUMC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2016-10-17 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ROST' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'FIVE.L' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'M' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'AD.AS' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'NXT' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2023-02-09 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ZAL' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-10-01 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'RAD' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['RAD']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '9983.T' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'HNNMY' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'GPS' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'LB' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['LB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CTC.A' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['CTC.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ORLY' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'KGF.L' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'ULTA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'JMT' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['JMT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'TSCO' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-05-08 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'JSA.L' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['JSA.L']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'MKS.L' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'DG' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'CO.PA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^BVSP' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^GSPC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^IXIC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^FTSE' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^GDAXI' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^FCHI' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^N225' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^HSI' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '000001.SS' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^BSESN' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^KS11' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^AXJO' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^GSPTSE' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^IBEX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER 'FTSEMIB.MI' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^RTSI' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['^RTSI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^IMOEX.ME' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['^IMOEX.ME']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^BVSP' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-05-08 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^MXX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^COLCAP' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['^COLCAP']: Exception('%ticker%: No timezone found, symbol may be delisted')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^MERV' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^MXX' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2024-05-08 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^IPSA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2019-06-14 00:00:00 to 2024-05-09 00:00:00
# 2019-06-14
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^BVP' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['^BVP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^SPBLPGPT' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2021-09-30 00:00:00 to 2024-05-09 00:00:00
# 2021-09-30
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^IGPA' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2021-09-30 00:00:00 to 2024-05-09 00:00:00
# 2021-09-30
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^BVLG' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2014-05-12 00:00:00
# TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
# Att from 2024-05-08 00:00:00 to 2024-05-09 00:00:00
# 2024-05-08
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^ITC' @@@@@@@@@@@@@@@@
# não é none, fazendo subtração
# lastdatetest é 2015-10-20 00:00:00
# SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# @@@@@@@@@@@@@@@@@@@@@@ REPORTE DO TICKER '^JALSH' @@@@@@@@@@@@@@@@
# é none
# 2014-05-12
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['^JALSH']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-12 -> 2024-05-09)')

# %%
#################### TABELA COUNTRIES

## AQUI A TABELA COUNTRIES REGISTRA TODOS OS PAÍSES TRATADOS ATÉ O MOMENTO
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND sql LIKE '%country%'")
tables = cursor.fetchall()
tables = [tupla[0] for tupla in tables]

print(tables)

for tab in tables:
    print(tab)
    command = f''' 
            INSERT INTO countries (country)
            SELECT DISTINCT country FROM {tab}
            WHERE NOT EXISTS (
                SELECT 1 FROM countries WHERE country = {tab}.country 
            )
            '''
  
    cursor.execute(command)
    conn.commit()
    


latam = ['Argentina', 'Bolívia', 'Brasil', 'Chile', 'Colômbia', 'Costa Rica', 'Cuba', 'Equador',
        'El Salvador', 'Guiana', 'Guatemala', 'Haiti', 'Honduras', 'México',
        'Nicarágua', 'Panamá', 'Paraguai', 'Peru', 'República Dominicana', 'Suriname', 
        'Uruguai', 'Venezuela', 'Belize'] # O CONCEITO DE AMÉRICA LATINA AQUI É EXPANDIDO. SÃO TODOS PAÍSES PRA BAIXO DO RIO BRAVO, INCLUINDO CARIBE.



command = "SELECT country FROM countries"
cursor.execute(command)
countriesvar = cursor.fetchall()
countriesvar = [tupla[0] for tupla in countriesvar]

countriesvar = pd.DataFrame(countriesvar, columns = ['country'])

# Cria um novo dataframe com os países adicionais
new_countries_df = pd.DataFrame({'country': latam})

# Adiciona os novos países ao dataframe existente
countriesvar = countriesvar.append(new_countries_df, ignore_index=True)

# Remove duplicatas, se houver
countriesvar = countriesvar.drop_duplicates().reset_index(drop=True)


print(countriesvar)


countriesvar['latam'] = ['Latam' if country in latam else 'Not Latam' for country in countriesvar['country']]

countriesvar.to_sql('countries', conn, if_exists='replace', index=False)


alpha3code = pd.read_excel('alpha.xlsx') # IMPORTANTE: SE FAZ NECESSÁRIO UM ARQUIVO COM UMA LISTA DE ALPHA3 CODE PARA CONSULTA DE AGREGADOS


countriesvar = pd.merge(countriesvar, alpha3code, on='country', how='left')
countriesvar.to_sql('countries', conn, if_exists='replace', index=False)

conn.close()
# Out:
# ['currencies', 'tickets', 'news', 'summary', 'mlearning', 'countries']
# currencies
# tickets
# news
# summary
# mlearning
# countries
#                    country
# 0                   Brasil
# 1                Argentina
# 2                    Chile
# 3                 Colômbia
# 4                   México
# 5                     Peru
# 6                  Uruguai
# 7                Venezuela
# 8                   Belize
# 9               Costa Rica
# 10          Estados Unidos
# 11               Guatemala
# 12                Honduras
# 13               Nicarágua
# 14                 Bolívia
# 15                   Japão
# 16                Alemanha
# 17                     EUA
# 18           Coreia do Sul
# 19                  Suécia
# 20                  Itália
# 21                  França
# 22             Reino Unido
# 23                   China
# 24                   Índia
# 25                 Espanha
# 26                 Irlanda
# 27          Arábia Saudita
# 28                 Holanda
# 29                  Rússia
# 30                  Kuwait
# 31  Emirados Árabes Unidos
# 32                 Noruega
# 33               Indonésia
# 34                  Canadá
# 35               Austrália
# 36                   Suíça
# 37           África do Sul
# 38               Dinamarca
# 39                  Israel
# 40                Portugal
# 41               Hong Kong
# 42                Paraguai
# 43                Mongólia
# 44                    Cuba
# 45                 Equador
# 46             El Salvador
# 47                  Guiana
# 48                   Haiti
# 49                  Panamá
# 50    República Dominicana
# 51                Suriname
# 52                Colombia
# 53              Inglaterra
# 54                  Russia
# C:\Users\yanme\AppData\Local\Temp\ipykernel_22668\4098830755.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   countriesvar = countriesvar.append(new_countries_df, ignore_index=True)

# %% [markdown]
# # AGREGADOS

# %% [markdown]
# Os dados são extraidos através da API do World Bank. Eles tem pesos diferentes.
#
# O PIB é o Produto Interno Bruto em dólares americanos (USD). Não é ajustado pela inflação
# PIB/capta é em USD, normal.
# POPCRESC é a porcentagem de crescimento da população desse país.
# TXIFLA é a porcentagem de crescimento da inflação
# DIVPUB é a porcentagem do PIB que um país tem como dívida pública

# %%
############## AGREGADOS
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

# Regatar alpha3code que é o código ISO9001 padrão mundial para referir-se aos países.
command = "SELECT alpha3code FROM countries"
cursor.execute(command)
alpha3cod = cursor.fetchall()
alpha3cod = [tupla[0] for tupla in alpha3cod]

# Insere/atualiza os códigos dos agregados no World Bank
agrcodes = pd.read_excel('pandas_datareaderagregates.xlsx')
agrcodes.to_sql('agregates', conn, if_exists='replace', index=False)

agrcodes = sqltodf('agregates')

print(agrcodes)
# Out:
#                                         agrname          agrcodewb    agrcode
# 0  PIB nominal (USD, não corrigido pela infla)      NY.GDP.MKTP.CD        PIB
# 1                           PIB per Capta (USD)     NY.GDP.PCAP.CD  PIBPCAPTA
# 2                               População Total        SP.POP.TOTL   POPTOTAL
# 3                           Taxa de Crescimento        SP.POP.GROW   POPCRESC
# 4                              Taxa de Inflação     FP.CPI.TOTL.ZG    TXINFLA
# 5                                    Desemprego     SL.UEM.TOTL.ZS      DESEM
# 6                                Dívida Pública  GC.DOD.TOTL.GD.ZS     DIVPUB
# 7                                 Taxa de Juros        FR.INR.LEND      TXJUR
# 8                             Exportações (USD)     NE.EXP.GNFS.CD        EXP
# 9                                   Importações     NE.IMP.GNFS.CD        IMP

# %%
# Sistema de data e tipos de variáveis
todayyear = datetime.today()
tenyearsago = todayyear - timedelta(365 * 10)
todayyear = todayyear.strftime("%Y")
tenyearsago = tenyearsago.strftime("%Y")
todayyear = f'{todayyear}'
tenyearsago = f'{tenyearsago}'

# Reorganização Alpha 3 Codes 
alpha3cod = list(filter(lambda x: x is not None, alpha3cod))




for index, row in agrcodes.iterrows():
    name2 = row['agrcode']
    name2 = f'{name2}'
    print(name2)
    agr = row['agrcodewb']
    for alp in alpha3cod:
        data = wbdata.get_data(agr, country=alp, date=(tenyearsago, todayyear))
        data = pd.DataFrame(data)
        data['datatype'] = 'agregates'
        data['agrcode'] = name2
        name = f"{alp}_WB_{name2}"
        name = name.replace(".", "_") # Dando problema na consulta e preenchimento do country acima no BD SQL
        name = f'{name}'
        drop = ['indicator', 'country', 'obs_status', 'unit', 'decimal']
        data = data.drop(columns=drop, inplace=False)
        data.rename(columns={'countryiso3code': 'iso3code'}, inplace=True)
        print(data)
        conn = sqlite3.connect('yfhistoric.db')
        cursor = conn.cursor()
        data.to_sql(name, conn, if_exists='replace', index=False)
    conn.close()

    
conn.close()
# Out:
# PIB
# Key '-4491806569000789972' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1004063903700100343' not in persistent cache.
#   iso3code  date         value   datatype agrcode
# 0      BRA  2023           NaN  agregates     PIB
# 1      BRA  2022  1.920096e+12  agregates     PIB
# 2      BRA  2021  1.649623e+12  agregates     PIB
# 3      BRA  2020  1.476107e+12  agregates     PIB
# 4      BRA  2019  1.873288e+12  agregates     PIB
# 5      BRA  2018  1.916934e+12  agregates     PIB
# 6      BRA  2017  2.063515e+12  agregates     PIB
# 7      BRA  2016  1.795693e+12  agregates     PIB
# 8      BRA  2015  1.802212e+12  agregates     PIB
# 9      BRA  2014  2.456044e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      ARG  2023           NaN  agregates     PIB
# 1      ARG  2022  6.311334e+11  agregates     PIB
# 2      ARG  2021  4.879026e+11  agregates     PIB
# 3      ARG  2020  3.857405e+11  agregates     PIB
# 4      ARG  2019  4.477547e+11  agregates     PIB
# 5      ARG  2018  5.248199e+11  agregates     PIB
# 6      ARG  2017  6.436284e+11  agregates     PIB
# 7      ARG  2016  5.575323e+11  agregates     PIB
# 8      ARG  2015  5.947493e+11  agregates     PIB
# 9      ARG  2014  5.263197e+11  agregates     PIB
# WARNING:shelved_cache.persistent_cache:Key '-8483348231242714722' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-
agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      MNG  2023           NaN  agregates     PIB
# 1      MNG  2022  1.714647e+10  agregates     PIB
# 2      MNG  2021  1.528644e+10  agregates     PIB
# 3      MNG  2020  1.331298e+10  agregates     PIB
# 4      MNG  2019  1.420636e+10  agregates     PIB
# 5      MNG  2018  1.317809e+10  agregates     PIB
# 6      MNG  2017  1.148085e+10  agregates     PIB
# 7      MNG  2016  1.118135e+10  agregates     PIB
# 8      MNG  2015  1.161989e+10  agregates     PIB
# 9      MNG  2014  1.222651e+10  agregates     PIB
# WARNING:shelved_cache.persistent_cache:Key '-2279514302209101308' not in persistent cache.
#   iso3code  date         value   datatype agrcode
# 0      CUB  2023           NaN  agregates     PIB
# 1      CUB  2022           NaN  agregates     PIB
# 2      CUB  2021           NaN  agregates     PIB
# 3      CUB  2020  1.073518e+11  agregates     PIB
# 4      CUB  2019  1.034276e+11  agregates     PIB
# 5      CUB  2018  1.000500e+11  agregates     PIB
# 6      CUB  2017  9.685065e+10  agregates     PIB
# 7      CUB  2016  9.137041e+10  agregates     PIB
# 8      CUB  2015  8.713280e+10  agregates     PIB
# 9      CUB  2014  8.065610e+10  agregates     PIB
# WARNING:shelved_cache.persistent_cache:Key '-5269489138686834727' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3455595863390443504' not in persistent cache.
#   iso3code  date         value   datatype agrcode
# 0      ECU  2023           NaN  agregates     PIB
# 1      ECU  2022  1.150495e+11  agregates     PIB
# 2      ECU  2021  1.061659e+11  agregates     PIB
# 3      ECU  2020  9.929112e+10  agregates     PIB
# 4      ECU  2019  1.081080e+11  agregates     PIB
# 5      ECU  2018  1.075620e+11  agregates     PIB
# 6      ECU  2017  1.042959e+11  agregates     PIB
# 7      ECU  2016  9.993770e+10  agregates     PIB
# 8      ECU  2015  9.929038e+10  agregates     PIB
# 9      ECU  2014  1.017263e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      SLV  2023           NaN  agregates     PIB
# 1      SLV  2022  3.248872e+10  agregates     PIB
# 2      SLV  2021  2.945124e+10  agregates     PIB
# 3      SLV  2020  2.493008e+10  agregates     PIB
# 4      SLV  2019  2.688114e+10  agregates     PIB
# 5      SLV  2018  2.602085e+10  agregates     PIB
# 6      SLV  2017  2.497919e+10  agregates     PIB
# 7      SLV  2016  2.419143e+10  agregates     PIB
# 8      SLV  2015  2.343824e+10  agregates     PIB
# 9      SLV  2014  2.259347e+10  agregates     PIB
# WARNING:shelved_cache.persistent_cache:Key '-1494040086661851834' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8842561685689459323' not in persistent cache.
#   iso3code  date         value   datatype agrcode
# 0      GUY  2023           NaN  agregates     PIB
# 1      GUY  2022  1.471839e+10  agregates     PIB
# 2      GUY  2021  8.041362e+09  agregates     PIB
# 3      GUY  2020  5.471257e+09  agregates     PIB
# 4      GUY  2019  5.173760e+09  agregates     PIB
# 5      GUY  2018  4.787637e+09  agregates     PIB
# 6      GUY  2017  4.748174e+09  agregates     PIB
# 7      GUY  2016  4.482697e+09  agregates     PIB
# 8      GUY  2015  4.279840e+09  agregates     PIB
# 9      GUY  2014  4.127660e+09  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      HTI  2023           NaN  agregates     PIB
# 1      HTI  2022  2.025355e+10  agregates     PIB
# 2      HTI  2021  2.087741e+10  agregates     PIB
# 3      HTI  2020  1.450822e+10  agregates     PIB
# 4      HTI  2019  1.501609e+10  agregates     PIB
# 5      HTI  2018  1.640386e+10  agregates     PIB
# 6      HTI  2017  1.509336e+10  agregates     PIB
# 7      HTI  2016  1.406928e+10  agregates     PIB
# 8      HTI  2015  1.484963e+10  agregates     PIB
# 9      HTI  2014  1.514688e+10  agregates     PIB
# WARNING:shelved_cache.persistent_cache:Key '-4759706899327009950' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5929515267786941850' not in persistent cache.
#   iso3code  date         value   datatype agrcode
# 0      PAN  2023           NaN  agregates     PIB
# 1      PAN  2022  7.652251e+10  agregates     PIB
# 2      PAN  2021  6.740674e+10  agregates     PIB
# 3      PAN  2020  5.708684e+10  agregates     PIB
# 4      PAN  2019  6.972179e+10  agregates     PIB
# 5      PAN  2018  6.729417e+10  agregates     PIB
# 6      PAN  2017  6.220270e+10  agregates     PIB
# 7      PAN  2016  5.790770e+10  agregates     PIB
# 8      PAN  2015  5.409180e+10  agregates     PIB
# 9      PAN  2014  4.992140e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      DOM  2023           NaN  agregates     PIB
# 1      DOM  2022  1.135374e+11  agregates     PIB
# 2      DOM  2021  9.424343e+10  agregates     PIB
# 3      DOM  2020  7.884466e+10  agregates     PIB
# 4      DOM  2019  8.894137e+10  agregates     PIB
# 5      DOM  2018  8.555539e+10  agregates     PIB
# 6      DOM  2017  7.999805e+10  agregates     PIB
# 7      DOM  2016  7.570465e+10  agregates     PIB
# 8      DOM  2015  7.116483e+10  agregates     PIB
# 9      DOM  2014  6.717996e+10  agregates     PIB
# WARNING:shelved_cache.persistent_cache:Key '6884763707318947702' not in persistent cache.
#   iso3code  date         value   datatype agrcode
# 0      SUR  2023           NaN  agregates     PIB
# 1      SUR  2022  3.620988e+09  agregates     PIB
# 2      SUR  2021  3.081402e+09  agregates     PIB
# 3      SUR  2020  2.911807e+09  agregates     PIB
# 4      SUR  2019  4.016041e+09  agregates     PIB
# 5      SUR  2018  3.996199e+09  agregates     PIB
# 6      SUR  2017  3.591679e+09  agregates     PIB
# 7      SUR  2016  3.317422e+09  agregates     PIB
# 8      SUR  2015  5.126238e+09  agregates     PIB
# 9      SUR  2014  5.240606e+09  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      RUS  2023           NaN  agregates     PIB
# 1      RUS  2022  2.240422e+12  agregates     PIB
# 2      RUS  2021  1.836892e+12  agregates     PIB
# 3      RUS  2020  1.493076e+12  agregates     PIB
# 4      RUS  2019  1.693115e+12  agregates     PIB
# 5      RUS  2018  1.657329e+12  agregates     PIB
# 6      RUS  2017  1.574199e+12  agregates     PIB
# 7      RUS  2016  1.276786e+12  agregates     PIB
# 8      RUS  2015  1.363482e+12  agregates     PIB
# 9      RUS  2014  2.059242e+12  agregates     PIB
# PIBPCAPTA
# WARNING:shelved_cache.persistent_cache:Key '4981510136186099279' not in persistent cache.
#   iso3code  date         value   datatype    agrcode
# 0      BRA  2023           NaN  agregates  PIBPCAPTA
# 1      BRA  2022   8917.674911  agregates  PIBPCAPTA
# 2      BRA  2021   7696.784830  agregates  PIBPCAPTA
# 3      BRA  2020   6923.699912  agregates  PIBPCAPTA
# 4      BRA  2019   8845.324149  agregates  PIBPCAPTA
# 5      BRA  2018   9121.020995  agregates  PIBPCAPTA
# 6      BRA  2017   9896.718895  agregates  PIBPCAPTA
# 7      BRA  2016   8680.736469  agregates  PIBPCAPTA
# 8      BRA  2015   8783.215424  agregates  PIBPCAPTA
# 9      BRA  2014  12071.404464  agregates  PIBPCAPTA
# WARNING:shelved_cache.persistent_cache:Key '8417275058167263013' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2085320981855299826' not in persistent cache.
#   iso3code  date         value   datatype    agrcode
# 0      ARG  2023           NaN  agregates  PIBPCAPTA
# 1      ARG  2022  13650.604629  agregates  PIBPCAPTA
# 2      ARG  2021  10650.860460  agregates  PIBPCAPTA
# 3      ARG  2020   8500.837939  agregates  PIBPCAPTA
# 4      ARG  2019   9963.674162  agregates  PIBPCAPTA
# 5      ARG  2018  11795.162745  agregates  PIBPCAPTA
# 6      ARG  2017  14613.035649  agregates  PIBPCAPTA
# 7      ARG  2016  12790.264140  agregates  PIBPCAPTA
# 8      ARG  2015  13789.060425  agregates  PIBPCAPTA
# 9      ARG  2014  12334.798245  agregates  PIBPCAPTA
# WARNING:shelved_cache.persistent_cache:Key '-9161098021987640131' not in persistent cache.
#   iso3code  date         value   datatype    agrcode
# 0      CHL  2023           NaN  agregates  PIBPCAPTA
# 1      CHL  2022  15355.479740  agregates  PIBPCAPTA
# 2      CHL  2021  16240.607776  agregates  PIBPCAPTA
# 3      CHL  2020  13173.784794  agregates  PIBPCAPTA
# 4      CHL  2019  14632.690308  agregates  PIBPCAPTA
# 5      CHL  2018  15820.033357  agregates  PIBPCAPTA
# 6      CHL  2017  15034.058425  agregates  PIBPCAPTA
# 7      CHL  2016  13788.240016  agregates  PIBPCAPTA
# 8      CHL  2015  13567.357217  agregates  PIBPCAPTA
# 9      CHL  2014  14675.150873  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      COL  2023          NaN  agregates  PIBPCAPTA
# 1      COL  2022  6624.165393  agregates  PIBPCAPTA
# 2      COL  2021  6182.707099  agregates  PIBPCAPTA
# 3      COL  2020  5304.289129  agregates  PIBPCAPTA
# 4      COL  2019  6436.509215  agregates  PIBPCAPTA
# 5      COL  2018  6782.037920  agregates  PIBPCAPTA
# 6      COL  2017  6449.970987  agregates  PIBPCAPTA
# 7      COL  2016  5936.261022  agregates  PIBPCAPTA
# 8      COL  2015  6228.651622  agregates  PIBPCAPTA
# 9      COL  2014  8167.472842  agregates  PIBPCAPTA
# WARNING:shelved_cache.persistent_cache:Key '-3630839027725814959' not in persistent cache.
#   iso3code  date         value   datatype    agrcode
# 0      MEX  2023           NaN  agregates  PIBPCAPTA
# 1      MEX  2022  11496.522872  agregates  PIBPCAPTA
# 2      MEX  2021  10359.149863  agregates  PIBPCAPTA
# 3      MEX  2020   8894.890650  agregates  PIBPCAPTA
# 4      MEX  2019  10434.578365  agregates  PIBPCAPTA
# 5      MEX  2018  10130.320698  agregates  PIBPCAPTA
# 6      MEX  2017   9693.330091  agregates  PIBPCAPTA
# 7      MEX  2016   9152.737223  agregates  PIBPCAPTA
# 8      MEX  2015  10098.173181  agregates  PIBPCAPTA
# 9      MEX  2014  11490.021690  agregates  PIBPCAPTA
# WARNING:shelved_cache.persistent_cache:Key '-7501292391366835233' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-
not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-141600272684357806' not in persistent cache.
#   iso3code  date         value   datatype    agrcode
# 0      USA  2023           NaN  agregates  PIBPCAPTA
# 1      USA  2022  76329.582265  agregates  PIBPCAPTA
# 2      USA  2021  70219.472454  agregates  PIBPCAPTA
# 3      USA  2020  63528.634303  agregates  PIBPCAPTA
# 4      USA  2019  65120.394663  agregates  PIBPCAPTA
# 5      USA  2018  62823.309438  agregates  PIBPCAPTA
# 6      USA  2017  59907.754261  agregates  PIBPCAPTA
# 7      USA  2016  57866.744934  agregates  PIBPCAPTA
# 8      USA  2015  56762.729452  agregates  PIBPCAPTA
# 9      USA  2014  55123.849787  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      GTM  2023          NaN  agregates  PIBPCAPTA
# 1      GTM  2022  5473.208564  agregates  PIBPCAPTA
# 2      GTM  2021  5029.477555  agregates  PIBPCAPTA
# 3      GTM  2020  4609.897258  agregates  PIBPCAPTA
# 4      GTM  2019  4647.807541  agregates  PIBPCAPTA
# 5      GTM  2018  4485.752135  agregates  PIBPCAPTA
# 6      GTM  2017  4454.024509  agregates  PIBPCAPTA
# 7      GTM  2016  4173.281349  agregates  PIBPCAPTA
# 8      GTM  2015  3994.629085  agregates  PIBPCAPTA
# 9      GTM  2014  3779.626205  agregates  PIBPCAPTA
# WARNING:shelved_cache.persistent_cache:Key '406392519383435738' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4945594271948976621' not in persistent cache.
#   iso3code  date        value   datatype    agrcode
# 0      HND  2023          NaN  agregates  PIBPCAPTA
# 1      HND  2022  3040.173046  agregates  PIBPCAPTA
# 2      HND  2021  2771.722654  agregates  PIBPCAPTA
# 3      HND  2020  2354.121434  agregates  PIBPCAPTA
# 4      HND  2019  2519.366185  agregates  PIBPCAPTA
# 5      HND  2018  2457.686042  agregates  PIBPCAPTA
# 6      HND  2017  2403.306088  agregates  PIBPCAPTA
# 7      HND  2016  2295.536270  agregates  PIBPCAPTA
# 8      HND  2015  2257.225284  agregates  PIBPCAPTA
# 9      HND  2014  2164.424550  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      NIC  2023          NaN  agregates  PIBPCAPTA
# 1      NIC  2022  2255.425995  agregates  PIBPCAPTA
# 2      NIC  2021  2064.929246  agregates  PIBPCAPTA
# 3      NIC  2020  1876.607378  agregates  PIBPCAPTA
# 4      NIC  2019  1905.638328  agregates  PIBPCAPTA
# 5      NIC  2018  1981.858367  agregates  PIBPCAPTA
# 6      NIC  2017  2127.282818  agregates  PIBPCAPTA
# 7      NIC  2016  2079.451027  agregates  PIBPCAPTA
# 8      NIC  2015  2025.321432  agregates  PIBPCAPTA
# 9      NIC  2014  1913.521348  agregates  PIBPCAPTA
# WARNING:shelved_cache.persistent_cache:Key '1111435735975982879' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-
# 6      KOR  2017  31600.735874  agregates  PIBPCAPTA
# 7      KOR  2016  29280.440317  agregates  PIBPCAPTA
# 8      KOR  2015  28737.439171  agregates  PIBPCAPTA
# 9      KOR  2014  29252.931238  agregates  PIBPCAPTA
# WARNING:shelved_cache.persistent_cache:Key '-5301802715296799878' not in persistent cache.
#   iso3code  date         value   datatype    agrcode
# 0      SWE  2023           NaN  agregates  PIBPCAPTA
# 1      SWE  2022  56424.284699  agregates  PIBPCAPTA
# 2      SWE  2021  61417.680877  agregates  PIBPCAPTA
# 3      SWE  2020  52837.903978  agregates  PIBPCAPTA
# 4      SWE  2019  51939.429745  agregates  PIBPCAPTA
# 5      SWE  2018  54589.060386  agregates  PIBPCAPTA
# 6      SWE  2017  53791.508730  agregates  PIBPCAPTA
# 7      SWE  2016  51965.157153  agregates  PIBPCAPTA
# 8      SWE  2015  51545.483610  agregates  PIBPCAPTA
# 9      SWE  2014  60020.360458  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      ITA  2023           NaN  agregates  PIBPCAPTA
# 1      ITA  2022  34776.423234  agregates  PIBPCAPTA
# 2      ITA  2021  36449.258338  agregates  PIBPCAPTA
# 3      ITA  2020  31922.919163  agregates  PIBPCAPTA
# 4      ITA  2019  33673.750963  agregates  PIBPCAPTA
# 5      ITA  2018  34622.169666  agregates  PIBPCAPTA
# 6      ITA  2017  32406.720315  agregates  PIBPCAPTA
# 7      ITA  2016  30960.731509  agregates  PIBPCAPTA
# 8      ITA  2015  30242.386135  agregates  PIBPCAPTA
# 9      ITA  2014  35565.721377  agregates  PIBPCAPTA
# WARNING:shelved_cache.persistent_cache:Key '-6135379275674801045' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '697404484150694782' not in persistent cache.
#   iso3code  date         value   datatype    agrcode
# 0      FRA  2023           NaN  agregates  PIBPCAPTA
# ...
# 6      CHN  2017  2.208519e+12  agregates     IMP
# 7      CHN  2016  1.944491e+12  agregates     IMP
# 8      CHN  2015  2.003261e+12  agregates     IMP
# 9      CHN  2014  2.241276e+12  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      IND  2023           NaN  agregates     IMP
# 1      IND  2022  9.034575e+11  agregates     IMP
# 2      IND  2021  7.609029e+11  agregates     IMP
# 3      IND  2020  5.102447e+11  agregates     IMP
# 4      IND  2019  6.023151e+11  agregates     IMP
# 5      IND  2018  6.403008e+11  agregates     IMP
# 6      IND  2017  5.820180e+11  agregates     IMP
# 7      IND  2016  4.801691e+11  agregates     IMP
# 8      IND  2015  4.650976e+11  agregates     IMP
# 9      IND  2014  5.292394e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      ESP  2023           NaN  agregates     IMP
# 1      ESP  2022  5.623343e+11  agregates     IMP
# 2      ESP  2021  4.801713e+11  agregates     IMP
# 3      ESP  2020  3.750058e+11  agregates     IMP
# 4      ESP  2019  4.457221e+11  agregates     IMP
# 5      ESP  2018  4.610565e+11  agregates     IMP
# 6      ESP  2017  4.140202e+11  agregates     IMP
# 7      ESP  2016  3.685545e+11  agregates     IMP
# 8      ESP  2015  3.656932e+11  agregates     IMP
# 9      ESP  2014  4.166258e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0
+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      NOR  2023           NaN  agregates     IMP
# 1      NOR  2022  1.609112e+11  agregates     IMP
# 2      NOR  2021  1.418814e+11  agregates     IMP
# 3      NOR  2020  1.218471e+11  agregates     IMP
# 4      NOR  2019  1.400144e+11  agregates     IMP
# 5      NOR  2018  1.397744e+11  agregates     IMP
# 6      NOR  2017  1.300711e+11  agregates     IMP
# 7      NOR  2016  1.230785e+11  agregates     IMP
# 8      NOR  2015  1.236547e+11  agregates     IMP
# 9      NOR  2014  1.475592e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      IDN  2023           NaN  agregates     IMP
# 1      IDN  2022  2.757032e+11  agregates     IMP
# 2      IDN  2021  2.229400e+11  agregates     IMP
# 3      IDN  2020  1.656468e+11  agregates     IMP
# 4      IDN  2019  2.130346e+11  agregates     IMP
# 5      IDN  2018  2.300456e+11  agregates     IMP
# 6      IDN  2017  1.947773e+11  agregates     IMP
# 7      IDN  2016  1.708350e+11  agregates     IMP
# 8      IDN  2015  1.788637e+11  agregates     IMP
# 9      IDN  2014  2.174852e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      CAN  2023           NaN  agregates     IMP
# 1      CAN  2022  7.287192e+11  agregates     IMP
# 2      CAN  2021  6.264881e+11  agregates     IMP
# 3      CAN  2020  5.245726e+11  agregates     IMP
# 4      CAN  2019  5.897067e+11  agregates     IMP
# 5      CAN  2018  5.913476e+11  agregates     IMP
# 6      CAN  2017  5.549227e+11  agregates     IMP
# 7      CAN  2016  5.173960e+11  agregates     IMP
# 8      CAN  2015  5.341151e+11  agregates     IMP
# 9      CAN  2014  5.894344e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      AUS  2023           NaN  agregates     IMP
# 1      AUS  2022  3.336753e+11  agregates     IMP
# 2      AUS  2021  2.763472e+11  agregates     IMP
# 3      AUS  2020  2.684134e+11  agregates     IMP
# 4      AUS  2019  3.017675e+11  agregates     IMP
# 5      AUS  2018  3.073001e+11  agregates     IMP
# 6      AUS  2017  2.748462e+11  agregates     IMP
# 7      AUS  2016  2.600213e+11  agregates     IMP
# 8      AUS  2015  2.911190e+11  agregates     IMP
# 9      AUS  2014  3.137027e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      CHE  2023           NaN  agregates     IMP
# 1      CHE  2022  5.175233e+11  agregates     IMP
# 2      CHE  2021  4.796558e+11  agregates     IMP
# 3      CHE  2020  4.280626e+11  agregates     IMP
# 4      CHE  2019  4.123506e+11  agregates     IMP
# 5      CHE  2018  4.132137e+11  agregates     IMP
# 6      CHE  2017  3.981646e+11  agregates     IMP
# 7      CHE  2016  3.903683e+11  agregates     IMP
# 8      CHE  2015  3.700311e+11  agregates     IMP
# 9      CHE  2014  3.986960e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      ZAF  2023           NaN  agregates     IMP
# 1      ZAF  2022  1.277507e+11  agregates     IMP
# 2      ZAF  2021  1.049173e+11  agregates     IMP
# 3      ZAF  2020  7.834657e+10  agregates     IMP
# 4      ZAF  2019  1.039350e+11  agregates     IMP
# 5      ZAF  2018  1.093738e+11  agregates     IMP
# 6      ZAF  2017  9.992378e+10  agregates     IMP
# 7      ZAF  2016  8.964991e+10  agregates     IMP
# 8      ZAF  2015  1.005910e+11  agregates     IMP
# 9      ZAF  2014  1.162617e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      DNK  2023           NaN  agregates     IMP
# 1      DNK  2022  2.357676e+11  agregates     IMP
# 2      DNK  2021  2.109953e+11  agregates     IMP
# 3      DNK  2020  1.725427e+11  agregates     IMP
# 4      DNK  2019  1.787159e+11  agregates     IMP
# 5      DNK  2018  1.799022e+11  agregates     IMP
# 6      DNK  2017  1.590927e+11  agregates     IMP
# 7      DNK  2016  1.463593e+11  agregates     IMP
# 8      DNK  2015  1.471901e+11  agregates     IMP
# 9      DNK  2014  1.682042e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      ISR  2023           NaN  agregates     IMP
# 1      ISR  2022  1.510746e+11  agregates     IMP
# 2      ISR  2021  1.260284e+11  agregates     IMP
# 3      ISR  2020  9.689509e+10  agregates     IMP
# 4      ISR  2019  1.095532e+11  agregates     IMP
# 5      ISR  2018  1.093198e+11  agregates     IMP
# 6      ISR  2017  9.786594e+10  agregates     IMP
# 7      ISR  2016  9.047554e+10  agregates     IMP
# 8      ISR  2015  8.508055e+10  agregates     IMP
# 9      ISR  2014  9.521130e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      PRT  2023           NaN  agregates     IMP
# 1      PRT  2022  1.327180e+11  agregates     IMP
# 2      PRT  2021  1.130082e+11  agregates     IMP
# 3      PRT  2020  8.975922e+10  agregates     IMP
# 4      PRT  2019  1.033295e+11  agregates     IMP
# 5      PRT  2018  1.041535e+11  agregates     IMP
# 6      PRT  2017  9.233916e+10  agregates     IMP
# 7      PRT  2016  8.063709e+10  agregates     IMP
# 8      PRT  2015  7.950994e+10  agregates     IMP
# 9      PRT  2014  9.211330e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      HKG  2023           NaN  agregates     IMP
# 1      HKG  2022  6.834407e+11  agregates     IMP
# 2      HKG  2021  7.321774e+11  agregates     IMP
# 3      HKG  2020  6.014954e+11  agregates     IMP
# 4      HKG  2019  6.393460e+11  agregates     IMP
# 5      HKG  2018  6.820558e+11  agregates     IMP
# 6      HKG  2017  6.412295e+11  agregates     IMP
# 7      HKG  2016  5.926999e+11  agregates     IMP
# 8      HKG  2015  5.986870e+11  agregates     IMP
# 9      HKG  2014  6.204759e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      PRY  2023           NaN  agregates     IMP
# 1      PRY  2022  1.642867e+10  agregates     IMP
# 2      PRY  2021  1.368525e+10  agregates     IMP
# 3      PRY  2020  1.044880e+10  agregates     IMP
# 4      PRY  2019  1.332502e+10  agregates     IMP
# 5      PRY  2018  1.416579e+10  agregates     IMP
# 6      PRY  2017  1.283429e+10  agregates     IMP
# 7      PRY  2016  1.104925e+10  agregates     IMP
# 8      PRY  2015  1.165299e+10  agregates     IMP
# 9      PRY  2014  1.357478e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      MNG  2023           NaN  agregates     IMP
# 1      MNG  2022  1.221970e+10  agregates     IMP
# 2      MNG  2021  9.255820e+09  agregates     IMP
# 3      MNG  2020  7.345877e+09  agregates     IMP
# 4      MNG  2019  9.259603e+09  agregates     IMP
# 5      MNG  2018  8.986287e+09  agregates     IMP
# 6      MNG  2017  6.517244e+09  agregates     IMP
# 7      MNG  2016  5.611142e+09  agregates     IMP
# 8      MNG  2015  5.283520e+09  agregates     IMP
# 9      MNG  2014  6.978077e+09  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      CUB  2023           NaN  agregates     IMP
# 1      CUB  2022           NaN  agregates     IMP
# 2      CUB  2021           NaN  agregates     IMP
# 3      CUB  2020  8.067000e+09  agregates     IMP
# 4      CUB  2019  1.097100e+10  agregates     IMP
# 5      CUB  2018  1.256700e+10  agregates     IMP
# 6      CUB  2017  1.130400e+10  agregates     IMP
# 7      CUB  2016  1.122600e+10  agregates     IMP
# 8      CUB  2015  1.260500e+10  agregates     IMP
# 9      CUB  2014  1.386500e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      ECU  2023           NaN  agregates     IMP
# 1      ECU  2022  3.281025e+10  agregates     IMP
# 2      ECU  2021  2.675130e+10  agregates     IMP
# 3      ECU  2020  1.937895e+10  agregates     IMP
# 4      ECU  2019  2.489560e+10  agregates     IMP
# 5      ECU  2018  2.555399e+10  agregates     IMP
# 6      ECU  2017  2.251633e+10  agregates     IMP
# 7      ECU  2016  1.900470e+10  agregates     IMP
# 8      ECU  2015  2.381545e+10  agregates     IMP
# 9      ECU  2014  3.016828e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      SLV  2023           NaN  agregates     IMP
# 1      SLV  2022  1.807044e+10  agregates     IMP
# 2      SLV  2021  1.545868e+10  agregates     IMP
# 3      SLV  2020  1.040031e+10  agregates     IMP
# 4      SLV  2019  1.238847e+10  agregates     IMP
# 5      SLV  2018  1.215154e+10  agregates     IMP
# 6      SLV  2017  1.130930e+10  agregates     IMP
# 7      SLV  2016  1.073144e+10  agregates     IMP
# 8      SLV  2015  1.103334e+10  agregates     IMP
# 9      SLV  2014  1.096948e+10  agregates     IMP
#   iso3code  date value   datatype agrcode
# 0      GUY  2023  None  agregates     IMP
# 1      GUY  2022  None  agregates     IMP
# 2      GUY  2021  None  agregates     IMP
# 3      GUY  2020  None  agregates     IMP
# 4      GUY  2019  None  agregates     IMP
# 5      GUY  2018  None  agregates     IMP
# 6      GUY  2017  None  agregates     IMP
# 7      GUY  2016  None  agregates     IMP
# 8      GUY  2015  None  agregates     IMP
# 9      GUY  2014  None  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      HTI  2023           NaN  agregates     IMP
# 1      HTI  2022  5.932425e+09  agregates     IMP
# 2      HTI  2021  6.269039e+09  agregates     IMP
# 3      HTI  2020  3.983064e+09  agregates     IMP
# 4      HTI  2019  5.107129e+09  agregates     IMP
# 5      HTI  2018  5.635999e+09  agregates     IMP
# 6      HTI  2017  4.689669e+09  agregates     IMP
# 7      HTI  2016  4.193901e+09  agregates     IMP
# 8      HTI  2015  4.481320e+09  agregates     IMP
# 9      HTI  2014  4.752591e+09  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      PAN  2023           NaN  agregates     IMP
# 1      PAN  2022           NaN  agregates     IMP
# 2      PAN  2021           NaN  agregates     IMP
# 3      PAN  2020           NaN  agregates     IMP
# 4      PAN  2019           NaN  agregates     IMP
# 5      PAN  2018           NaN  agregates     IMP
# 6      PAN  2017  2.837949e+10  agregates     IMP
# 7      PAN  2016  2.631060e+10  agregates     IMP
# 8      PAN  2015  2.826380e+10  agregates     IMP
# 9      PAN  2014  3.181650e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      DOM  2023           NaN  agregates     IMP
# 1      DOM  2022  3.652360e+10  agregates     IMP
# 2      DOM  2021  2.919865e+10  agregates     IMP
# 3      DOM  2020  2.049800e+10  agregates     IMP
# 4      DOM  2019  2.485188e+10  agregates     IMP
# 5      DOM  2018  2.438717e+10  agregates     IMP
# 6      DOM  2017  2.123383e+10  agregates     IMP
# 7      DOM  2016  2.095247e+10  agregates     IMP
# 8      DOM  2015  2.021757e+10  agregates     IMP
# 9      DOM  2014  2.038578e+10  agregates     IMP
#   iso3code  date value   datatype agrcode
# 0      SUR  2023  None  agregates     IMP
# 1      SUR  2022  None  agregates     IMP
# 2      SUR  2021  None  agregates     IMP
# 3      SUR  2020  None  agregates     IMP
# 4      SUR  2019  None  agregates     IMP
# 5      SUR  2018  None  agregates     IMP
# 6      SUR  2017  None  agregates     IMP
# 7      SUR  2016  None  agregates     IMP
# 8      SUR  2015  None  agregates     IMP
# 9      SUR  2014  None  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      RUS  2023           NaN  agregates     IMP
# 1      RUS  2022  3.491746e+11  agregates     IMP
# 2      RUS  2021  3.795542e+11  agregates     IMP
# 3      RUS  2020  3.052552e+11  agregates     IMP
# 4      RUS  2019  3.520887e+11  agregates     IMP
# 5      RUS  2018  3.445196e+11  agregates     IMP
# 6      RUS  2017  3.272075e+11  agregates     IMP
# 7      RUS  2016  2.638305e+11  agregates     IMP
# 8      RUS  2015  2.816403e+11  agregates     IMP
# 9      RUS  2014  4.260621e+11  agregates     IMP

# %% [markdown]
# # Projeções
# ##

# %% [markdown]
# Aqui vamos fazer as projeções diárias e projeções aproveitando os dados coletados.
#
# ### PROJEÇÕES DIÁRIAS:
# + Variação do High e Low
# + Tendência de um ticker em curto-prazo (definir posteriormente)
#
# ### PROJEÇÕES PERMANENTES
# + PIB dos países exportadores de petróleo vs empresas de petróleo a nível mundial ou local
# + Preço do petróleo nas duas formas vs PIB dos petroleiros
# + Mesma lógica pra outras commodities
# + Commodities em geral vs PIB da América Latina em geral. vs Inflação, desemprego, etc

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()
cursor.execute('''
    CREATE TABLE IF NOT EXISTS mlearning(
        id INTEGER PRIMARY KEY,
        model TEXT NOT NULL,
        dataorigin TEXT NOT NULL, 
        period DATE,
        country TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES text(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''') 
# dataorigin é o código do ticker, moeda, commoditie etc. 
# period é a data inicial e final da análise. 
# model é o modelo de previsão


conn.close()

# %%
def showsql(sqltable):
    df = sqltodf(f'{sqltable}')
    print(df)

# %%
showsql('commodities')
# Out:
#    id commcode               comname     datatype
# 0   1     GC=F                  Ouro  commodities
# 1   2     SI=F                 Prata  commodities
# 2   3     CL=F  Petróleo Crude (WTI)  commodities
# 3   4     BZ=F  Petróleo Brent Crude  commodities
# 4   5     HG=F                 Cobre  commodities
# 5   6     NG=F           Gás Natural  commodities
# 6   7      C=F                 Milho  commodities
# 7   8      W=F                 Trigo  commodities
# 8   9     KC=F                  Café  commodities
# 9  10     SB=F                Açúcar  commodities

# %%
showsql('"bz=f"')
# Out:
#                   Date       Open       High        Low      Close  Volume  \
# 0  2024-05-03 00:00:00  83.800003  84.400002  82.800003  82.959999   31511
# 1  2024-05-06 00:00:00  82.980003  83.820000  82.760002  83.330002   23246
# 2  2024-05-07 00:00:00  83.589996  83.870003  82.400002  83.160004   33414
# 3  2024-05-08 00:00:00  83.779999  83.980003  83.660004  83.930000     618
#
#       datatype  code
# 0  commodities  BZ=F
# 1  commodities  BZ=F
# 2  commodities  BZ=F
# 3  commodities  BZ=F

# %%
df = sqltodf('tickets')
niche = df['ticcat'].unique() 
print(niche)
# Out:
# ['Petróleo e Gás' 'Serviços Financeiros' 'Tecnologia' 'Telecomunicações'
#  'Agricultura' 'Energia' 'Metalurgia' 'Alimentício' 'Imobiliário'
#  'Consultoria' 'Mineração' 'Bebidas' 'Tecnologia Financeira' 'Varejo'
#  'Diversificado' 'Logística' 'Construção Civil' 'Papel e Celulose'
#  'Automotivo' 'Saúde' 'Transporte Aéreo' 'Aluguel de Carros'
#  'Infraestrutura' 'Petroquímica' 'Seguros' 'Indústria' 'Petróleo e gás'
#  'Serviços financeiros' 'Seguros e investimentos' 'Cimento e energia'
#  'Materiais de construção' 'Alimentos e bebidas' 'Gás natural'
#  'Energia e infraestrutura' 'Construção' 'Transporte' 'Conglomerado'
#  'Farmacêutico' 'Químico' 'Mídia' 'Distribuição' 'Imóveis' 'Automotiva'
#  'Índices das Bolsas']

# %%
# Todas as empresas petroliferas ('Petróleo e gás', 'Petróleo e Gás', 'Petroquímica')

conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()
cursor.execute('''
SELECT ticcode
FROM tickets
WHERE ticcat IN ('Petróleo e gás', 'Petróleo e Gás', 'Petroquímica');

    ''') 
petroleo = cursor.fetchall()
petroleo = [row[0] for row in petroleo]
print(petroleo)

conn.close()
# Out:
# ['YPFD.BA', 'YPFL.BA', 'TGSU2.BA', 'PETR4.SA', 'BRKM5.SA', 'ECOPETROL', 'RLP.LM', '2222.SR', 'XOM', 'RDS.A', 'PTR', 'BP', 'TTE', 'CVX', 'OGZPY', 'ROSN.ME', 'KPC', 'PTR', 'ENI', 'ABD.NE', 'SNP', 'VLO', 'PSX', 'PBR', 'RELIANCE', 'EQNR', 'PERT.JK', 'COP', 'EOG', 'LKOH.ME', 'MPC', 'PXX', '2010.SE', 'ENB', 'BHP', 'OXY', 'SLB', 'HAL', 'BKR', 'WFT', 'RIG', 'VAL', 'DO', 'NE', 'RDC', 'ESV', 'SDRL', 'AKSO.OL', 'FTI', 'SPM.MI', 'MDR', 'SUBC.L', 'RBS', 'OSXB3', 'QGOG3']

# %%
# CORRELAÇÃO ENTRE O PIB DOS PAÍSES PRODUTORES DE PETRÓLEO E A MÉDIA ANUAL DO PREÇO DO PETRÓLEO

'''sqltodf('''
# Out:
# 'sqltodf('

# %% [markdown]
# # News e Texts
# #### Para essa parte é necessário um processo de Scrapping das páginas dos principais jornais de cada país. A parte complicada é essa. Como exemplo eu produzi um scrapping de 4 páginas, 3 do Brasil e uma da Argentina. O que é complicado é encontrar a secção nos códigos fonte HTML onde você encontra as headlines, normalmente os jornais "mudam de padrão" dessa informação para não ser tão fácil "raspar" a página através apenas da página inicial. Isso significa que o trabalho é passar de página em página e identificar os 35 box de headlines nos sites escolhidos ('news_source.xlsx'). Uma alternativa que tive em mente é um algoritimo de linguagem natural (NLP) pra encontrar a headline ou uma LLM comum que analise o HTML inteiro para tal. Para a LLM analisando o código inteiro a limitação é a quantidade de tokens de processamento que torna impossível "em uma tacada só" e não sei se teremos efetividade se "desmembrarmos" o código, fora o tempo de processamento porque são, no exemplo da Folha de São Paulo, 400.000 tokens. 12,000 linhas de HTML.
# #### Vou construir manualmente por enquanto, mas é um processo que com certeza pode ser automatizado com algum tipo de ferramenta da área de IA.
#
# #### Para a produção dos resumos duas opções foram cogitadas: o Gemini que é rápido e fácil, mas limitado. A outra opção é rodar alguma LLM localmente através de uma biblioteca ou programa mesmo. Os problemas que isso gera são: custo de processamento; possível imprecisão pelo fato das LLMs rodando localmente serem menos potentes; demora na produção. A vantagem possível é futuramente fazer um "fine tuning" para que a LLM se adeque à tarefa.
# #### Pelo fato de que as notícias podem conter conteúdo "nocivo" e o Gemini não processar algumas, vamos optar primeiramente pelo LLM Studio que é simples e rápido.

# %%
####### Sites que foram pensados

newspaperDF = pd.read_excel('news_source.xlsx')
newspaperDF.head(40)
# Out:
#        country              newspaper                          mainlink
# 0       Brasil     Folha de São Paulo     https://www.folha.uol.com.br/
# 1       Brasil                Estadao       https://www.estadao.com.br/
# 2       Brasil           Uol Economia      https://economia.uol.com.br/
# 3    Argentina                 Clarín           https://www.clarin.com/
# 4    Argentina              La Nacion      https://www.lanacion.com.ar/
# 5    Argentina                 Ambito           https://www.ambito.com/
# 6     Colombia              El Tiempo         https://www.eltiempo.com/
# 7     Colombia          El Espectador     https://www.elespectador.com/
# 8     Colombia             Portafolio        https://www.portafolio.co/
# 9       México           El Universal   https://www.eluniversal.com.mx/
# 10      México                Reforma          https://www.reforma.com/
# 11      México          El Financiero  https://www.elfinanciero.com.mx/
# 12        Peru            El Comercio            https://elcomercio.pe/
# 13        Peru           La Republica           https://larepublica.pe/
# 14        Peru                Gestion               https://gestion.pe/
# 15       Chile            El Mercurio   https://digital.elmercurio.com/
# 16       Chile             La Tercera        https://www.latercera.com/
# 17       Chile     Diario Financierop                https://www.df.cl/
# 18     Bolívia               El Deber           https://eldeber.com.bo/
# 19     Bolívia               La Razon         https://www.la-razon.com/
# 20    Paraguai                    ABC           https://www.abc.com.py/
# 21    Paraguai         Ultima Hora PY       https://www.ultimahora.com/
# 22     Equador            El Universo       https://www.eluniverso.com/
# 23     Uruguai          El Observador  https://www.elobservador.com.uy/
# 24  Inglaterra           The Guardian      https://www.theguardian.com/
# 25     Espanha           El País [ES]       https://elpais.com/america/
# 26      França               Le Monde        https://www.lemonde.fr/en/
# 27         EUA        Washington Post   https://www.washingtonpost.com/
# 28       China          Peoples Daily              http://en.people.cn/
# 29       China            Xinhua News          https://english.news.cn/
# 30      Russia     Rossiyskaya Gazeta                    https://rg.ru/
# 31      Russia             Kommersant        https://www.kommersant.ru/
# 32        Cuba                 Granma            https://www.granma.cu/
# 33    Alemanha  Frankfurter Rundschau                https://www.fr.de/

# %%
######### SQL manual para armazenar os textos

conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

for index, row in newspaperDF.iterrows():
    code = row['mainlink']
    name = row['newspaper']
    country = row['country']
    datatype = 'news'
    dados = (code, name, country, datatype) 
    command = '''
        INSERT INTO news (newspaperlink , newspapername, country, datatype)
        SELECT ?, ?, ?, ?
        WHERE NOT EXISTS (
            SELECT 1 FROM news
            WHERE newspapername = ? AND newspaperlink = ? AND country = ? AND datatype = ?
        )
    '''
    cursor.execute(command, dados + dados)
    conn.commit()
conn.close()

# %%
# OPÇÃO 1: LLM STUDIO
def llmstudio(noticia):
    # Point to the local server
    client = OpenAI(base_url="http://localhost:1234/v1", api_key="not-needed")

    completion = client.chat.completions.create(
      model="local-model", # this field is currently unused
      messages=[
        {"role": "system", "content": "Você agora é um jornalista preocupado em resumir notícias. A forma com que você escreverá é como se estivesse escrevendo essa notícia em um site. Você está escrevendo para um resumo geral de notícias que aparecerá em uma pequena caixa em um site. Você resumirá a notícia em no máximo 500 caracteres e 3 parágrafos."},
        {"role": "user", "content": f"Resuma em português a seguinte notícia em aproximadamente 500 caracteres e 3 parágrafos:{noticia}"}
      ],
      temperature=0.5,
      timeout = 999  
    )

    texto = completion.choices[0].message
    # Acessando o texto da mensagem
    texto_noticia = texto.content
    return texto_noticia
    
# OPÇÃO 2: SUMARRIZER DO HUGGINFACE (APENAS EM PT-PT)


def ptt5(text):
    token_name = 'unicamp-dl/ptt5-base-portuguese-vocab'
    model_name = 'phpaiola/ptt5-base-summ-xlsum'

    tokenizer = T5Tokenizer.from_pretrained(token_name )
    model_pt = T5ForConditionalGeneration.from_pretrained(model_name)
    inputs = tokenizer.encode(text, max_length=9999, truncation=True, return_tensors='pt')
    summary_ids = model_pt.generate(inputs, max_length=700, min_length=300, num_beams=3, no_repeat_ngram_size=3, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0])
    return summary

# %%
# Tradutor para línguas diferentes do português. O SUMMARIZADOR SÓ RESUME EM PORTUGUÊS!!!

def to_pt(text):
    translator = Translator()
    translated_text = translator.translate(text, dest='pt')
    return translated_text.text

# %%
# Por uma questão de visualização e redundancia, vamos utilizar o próprio sistema também para armazenar os "sumários" e "notícias cruas"

foldersumtext = "text_summaries"
text_summaries = os.path.join(rootdire, foldersumtext)
todaytsfolder = os.path.join(text_summaries, today)
if os.path.exists(text_summaries):
    todaytsfolder = os.path.join(text_summaries, today)
    print(f"trying {todaytsfolder}")
    if os.path.exists(todaytsfolder):
          print("Todays folder for texts and summaries already exists")
    else:
          try:
              os.mkdir(todaytsfolder)
              print("Making diretory")
          except Exception as e:
              print(e)
else:      
    try:
            os.mkdir(text_summaries)
            os.mkdir(todaytsfolder)
            print(f"Making diretory {todaysfolder}")
    except Exception as e:
              print(e)
# Out:
# trying C:\Users\yanme\OneDrive\Área de Trabalho\Portifólio\yfanalise\text_summaries\2024-05-09
# Making diretory

# %%
# Função para pegar as notícias, sumarizar, traduzir se necessário
def newsatt(journal_url, country, journal_name, arg):
    # Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
    response = requests.get(journal_url)
    response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida

    # Criando um objeto BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    arg = f'''arg'''
    exec(arg)

    headline_text = {}
    summaries = {}
    print(headlines)
    # Acessando os links e obtendo o texto de cada manchete
    for headline in headlines:
        link = headline['href']  # Obtendo o link da manchete

        # Adicionando '12ft.io/' ao link para contornar o paywall
        link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

        # Inicializando o objeto Article da biblioteca newspaper3k
        article = newspaper.Article(link)

        # Baixando e parseando o conteúdo da manchete
        article.download()
        article.parse()

        # Obtendo o texto da manchete
        hlarticle = article.text.strip()
        headline_text[headline] = hlarticle
        if country != "Brasil":
            headline_text[headline] = to_pt(headline_text[headline])
        else:
            pass
        summary = ptt5(headline_text[headline])
        summaries[headline] = summary 
        print(headline_text[headline])
        print('*' * 50) 
        print(summary)
        print('!' * 500)
        name = link.replace("/", "_")
        name = name.replace("https://webcache.googleusercontent.com/search?q=cache:https:__www1.folha.uol.com.br_", " ")
        name = name.strip()
        country = country.lower()
        mother_folder = os.path.join(todaytsfolder, country)
        os.makedirs(mother_folder)
        journal_name = journal_name.lower()
        mother_folder = os.path.join(mother_folder, journal_name)
        os.makedirs(mother_folder)
        print(f"@@@@@@@@ {name} @@@@@@@@@@@@@")
        caminho_arquivo = f'{name}.txt' 
        caminho_arquivo = os.path.join(mother_folder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(headline_text[headline])

        caminho_arquivo = f'sum_{name}.txt'
        caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(summary)

# %%
news_source = pd.read_excel("news_source_arg.xlsx")

news_source.head(4)
# Out:
#      country           newspaper                       mainlink  \
# 0     Brasil  Folha de São Paulo  https://www.folha.uol.com.br/
# 1     Brasil             Estadao    https://www.estadao.com.br/
# 2     Brasil        Uol Economia   https://economia.uol.com.br/
# 3  Argentina              Clarín        https://www.clarin.com/
#
#                                                  arg
# 0  headlines = soup.select('.c-rotate-headlines__...
# 1  headline_section = soup.find('div', class_='no...
# 2  headline_section = soup.find('div', class_='ro...
# 3  headline_section = soup.find(attrs={attribute:...

# %%
teste = '''for index, rows in news_source.iterrows(): #journal_url, country, journal_name, argument
    country = rows['country']
    journal_name = rows['newspaper']
    journal_url = rows['mainlink']
    arg = rows['arg']
    print(f" ############## Tentando {journal_name}") 
    newsatt(journal_url, country, journal_name, arg)'''

# %%
##### Folha de São Paulo

journal_url = 'https://www1.folha.uol.com.br/'

# Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
response = requests.get(journal_url)
response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida

# Criando um objeto BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Encontrando as manchetes
headlines = soup.select('.c-rotate-headlines__link')[:3]  # Extrai os três primeiros links das manchetes ####### A PARTE DIFÍCIL ESTÁ AQUI

headline_text = {}
summaries = {}

# Acessando os links e obtendo o texto de cada manchete
for headline in headlines:
    link = headline['href']  # Obtendo o link da manchete
    
    # Adicionando '12ft.io/' ao link para contornar o paywall
    link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

    # Inicializando o objeto Article da biblioteca newspaper3k
    article = newspaper.Article(link)

    # Baixando e parseando o conteúdo da manchete
    article.download()
    article.parse()

    # Obtendo o texto da manchete
    hlarticle = article.text.strip()
    headline_text[headline] = hlarticle
    summary = ptt5(headline_text[headline])
    summaries[headline] = summary 
    print(headline_text[headline])
    print('*' * 50) 
    print(summary)
    print('!' * 500)
    name = link.replace("/", "_")
    name = name.replace("https://webcache.googleusercontent.com/search?q=cache:https:__www1.folha.uol.com.br_", " ")
    name = name.replace("https:__webcache.googleusercontent.com_search?q=cache:https:__f5.folha.uol.com.br", " ")
    name = name.replace("https:__webcache.googleusercontent.com_search?q=cache:", " ")
    name = name.strip()
    print(f"@@@@@@@@ {name} @@@@@@@@@@@@@")
    caminho_arquivo = f'{name}.txt' 
    caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
    with open(caminho_arquivo, "w") as arquivo:
    # Escrever o texto no arquivo
        arquivo.write(headline_text[headline])
    
    caminho_arquivo = f'sum_{name}.txt'
    caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
    with open(caminho_arquivo, "w") as arquivo:
    # Escrever o texto no arquivo
        arquivo.write(summary)
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Ícone de compartilhamento
#
# Canoas e Eldorado do Sul estão entre as cidades mais afetadas pelas chuvas no sul
# **************************************************
# <pad> As chuvas que atingiram a região sul da Bahia nos últimos dias já mataram pelo menos 15 pessoas, entre elas duas crianças, na região central da capital do país, Canoas, e Eldorado do Sul, segundo informações do Ministério das Relações Exteriores do Rio de Janeiro (Minustah, na sigla em inglês), divulgados nesta terça-feira. A cidade está sendo afetada pelas chuvas que já afetam o sul do Brasil e o sul da Argentina. A região foi atingida pelas chuvas torrenciais no sul do país e também pela enchente que atingiu a região no fim de semana. Outras cidades também foram afetadas pelas enchentes que atingiram o sul dos Estados Unidos e o norte da Argentina, no sul da capital, Rio Grande do Sul e o Sul do Sul. Outras duas cidades foram atingidas pelas chuvas no sul e no norte do país. Outras três cidades também estão afetadas pela chuva. Outras 20 cidades também ficaram afetadas pelo furacão Katrina, que já matou pelo menos 13 pessoas. Outras 30 cidades também tiveram prejuízos. O sul da cidade também foi atingido pelas chuvas, segundo a agência de notícias oficial do Brasil, a Canoa, e o Rio do Sul do sul do Rio, de acordo com as autoridades locais. O Brasil também está entre as cidades mais afetadas pelos fortes chuvas que atingem o Sul da Bahia e o oeste do sul da Ásia. A tragédia é a região metropolitana de Buenos Aires e a cidade de Eldorado do Norte. A previsão é de chuvas de até 15 de janeiro.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
, ainda não conseguiu recuperar totalmente o acervo do Museu do Rio Grande da Sul, que já foi inundado por enchentes e deixou mais de 2 mil pessoas afetadas pela inundação que atingiu o centro histórico da capital gaúcha, Porto Alegre e o Memorial de São Paulo (Museu de Arte, em tradução livre), o Museu da Memória e a Fundação Iberê Camargo (Fundação Cultural) do Estado de Santa Maria, no Centro Histórico de Nova York, e também o Centro Cultural Capitólio, em São Paulo, e outros centros de cultura e economia do estado, que foram afetados pelas enchentes na semana passada e também por conta das enchentes provocadas pelas chuvas que atingiram a capital gaúcha. A informação foi divulgada nesta terça-feira pela Secretaria Municipal da Cultura (Facebook), órgão responsável pela fiscalização do governo do Estado.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# @@@@@@@@ https:__www1.folha.uol.com.br_ilustrada_2024_05_museus-do-rio-grande-do-sul-tentam-proteger-seus-acervos-mas-sofrem-danos.shtml @@@@@@@@@@@@@

# %%
##### estadão

journal_url = 'https://www.estadao.com.br/'

# Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
response = requests.get(journal_url)
response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida

# Criando um objeto BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Encontrando a parte do HTML que contém as manchetes
headline_section = soup.find('div', class_='noticia-content-block')

        # Verificando se a seção de manchetes foi encontrada
if headline_section:
            # Extrair os links das manchetes
    headlines = headline_section.find_all('a')[:3]  # Extrai os três primeiros links das manchetes

    headlines_text = []

            # Acessando os links e obtendo o texto de cada manchete
    for headline in headlines:
        link = headline['href']  # Obtendo o link da manchete
                
                # Adicionando '12ft.io/' ao link para contornar o paywall
        link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

        # Inicializando o objeto Article da biblioteca newspaper3k
        article = newspaper.Article(link)

        # Baixando e parseando o conteúdo da manchete
        article.download()
        article.parse()

                
        hlarticle = article.text.strip()
        headline_text[headline] = hlarticle
        summary = ptt5(headline_text[headline])
        summaries[headline] = summary 
        print(headline_text[headline])
        print('*' * 50) 
        print(summary)
        print('!' * 500)
        name = link.replace("/", "_")
        name = name.replace("https:__webcache.googleusercontent.com_search?q=cache:https:__www.estadao.com.br_", " ")
        name = name.strip()
     
        print(f"@@@@@@@@ {name} @@@@@@@@@@@@@")
        caminho_arquivo = f'{name}.txt'
        caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(headline_text[headline])

        caminho_arquivo = f'sum_{name}.txt'
        caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(summary)
else: 
    print('error')
# Out:
# Nascido em grande medida do repúdio do eleitorado ao candidato adversário, o governo Lula 3 continua tendo grandes dificuldades para entender a razão do que ele mesmo descreve como problema de popularidade. É o próprio Lula.
#
# PUBLICIDADE O presidente tem desconcertado aliados históricos e velhos companheiros de jornada pela morosidade com que joga num campo onde sempre se considerou o maior craque, o da articulação e negociação políticas. Talvez ainda não consiga compreender o quanto esse campo mudou – além das regras do jogo. Além disso, Lula 3 sofre de maneira cada vez mais acentuada com um fenômeno clássico da política, que é o da percepção dos fatos. Em grande parte do público ela não tem sido aquela que o governo esperava em relação a dados da economia, emprego e, principalmente, preços e impostos.
milhão de feridos no país, o que, segundo analistas, é um “desamparo” e um “desequilibramento” da política brasileira e, por outro lado, a crise política no Brasil, que já dura mais de dois meses e é uma das maiores tragédias da história recente do país. Mas, para muitos, a tragédia não é apenas a tragédia política, mas também o desafio de encontrar uma solução para a crise que se alastrou pelo país e por um “agora é para onde vai” em meio a uma tragédia que se espalha por todo o país, que é uma tragédia de proporções alarmantes, como a tragédia do Rio Grande de Sul, o Brasil e o Brasil, e não apenas o Brasil – o que não é um problema de popularidade, mas sim o que está por trás da tragédia. E, por isso, o desafio é muito mais complexo do que nunca, e é um desafio a ser enfrentado.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# @@@@@@@@ politica_william-waack_preocupado-com-indices-de-popularidade-lula-3-vai-para-mais-um-dificil-teste-na-tragedia-do-sul_ @@@@@@@@@@@@@

# %%
##### UOL

journal_url = 'https://economia.uol.com.br/'

# Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
response = requests.get(journal_url)
response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida

# Criando um objeto BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Encontrando a parte do HTML que contém as manchetes
headline_section = soup.find('div', class_='row')

        # Verificando se a seção de manchetes foi encontrada
if headline_section:
            # Extrair os links das manchetes
    headlines = headline_section.find_all('a')[:3]  # Extrai os três primeiros links das manchetes

    headlines_text = []

            # Acessando os links e obtendo o texto de cada manchete
    for headline in headlines:
        link = headline['href']  # Obtendo o link da manchete
                
                # Adicionando '12ft.io/' ao link para contornar o paywall
        link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

        # Inicializando o objeto Article da biblioteca newspaper3k
        article = newspaper.Article(link)

        # Baixando e parseando o conteúdo da manchete
        article.download()
        article.parse()

                
        hlarticle = article.text.strip()
        headline_text[headline] = hlarticle
        summary = ptt5(headline_text[headline])
        summaries[headline] = summary 
        print(headline_text[headline])
        print('*' * 50) 
        print(summary)
        print('!' * 500)
        name = link.replace("/", "_")
        name = name.replace("https:__webcache.googleusercontent.com_search?q=cache:https:__economia.uol.com.br_", " ")
        name = name.strip()
        print(f"@@@@@@@@ {name} @@@@@@@@@@@@@")
        caminho_arquivo = f'{name}.txt'
        caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(headline_text[headline])
        caminho_arquivo = f'sum_{name}.txt'
        caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(summary)
else: 
    print('error')
# Out:
# O estado é o segundo maior produtor de soja no Brasil, cuja colheita estava em 70% da área total até o início das inundações. Os 30% restantes não colhidos representam cerca de 2 milhões de hectares e 6,5 milhões de toneladas. Segundo o consultor, esse volume sob risco representa 5% da safra estimada para o país, algo em torno de 147 milhões de toneladas.
#
# "Quem tem condições, está correndo para salvar o que está na lavoura. Essa perda, que a gente ainda não consegue estimar, vai afetar o total da produção brasileira, aumentar preço lá fora, aqui dentro e causar impacto nas cadeias de carne. O Brasil ainda tinha uma safra relativamente grande, mas que pode cair de 142 a 145 milhões de toneladas. Fica uma safra insuficiente para acalmar os ânimos globais", ele afirma.
</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# @@@@@@@@ noticias_redacao_2024_05_08_haddad-ministerios-entregam-propostas-para-reconstruir-o-rs-ate-sexta.htm @@@@@@@@@@@@@

# %%
##### Clarín

journal_url = 'https://www.clarin.com/'

# Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
response = requests.get(journal_url)
response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida


# Criando um objeto BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Encontrando a parte do HTML que contém as manchetes
attribute = 'data-mrf-recirculation'
headline_section = soup.find(attrs={attribute: True})

headlines = headline_section.find_all('a')[:3]
        # Verificando se a seção de manchetes foi encontrada
if headline_section:
            # Extrair os links das manchetes
    headlines = headline_section.find_all('a')[:3]  # Extrai os três primeiros links das manchetes

    headlines_text = []

            # Acessando os links e obtendo o texto de cada manchete
    for headline in headlines:
        link = headline['href']  # Obtendo o link da manchete
                
                # Adicionando '12ft.io/' ao link para contornar o paywall
        link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

        # Inicializando o objeto Article da biblioteca newspaper3k
        article = newspaper.Article(link)

        # Baixando e parseando o conteúdo da manchete
        article.download()
        article.parse()

                
        hlarticle = article.text.strip()
        headline_text[headline] = hlarticle
        headline_text[headline] = to_pt(headline_text[headline])
        summary = ptt5(headline_text[headline])
        summaries[headline] = summary 
        print(headline_text[headline])
        print('*' * 50) 
        print(summary)
        print('!' * 500)
        name = link.replace("/", "_")
        name = name.replace("https:__webcache.googleusercontent.com_search?q=cache:https:__www.clarin.com_", " ")
        name = name.strip()
        print(f"@@@@@@@@ {name} @@@@@@@@@@@@@")
        caminho_arquivo = f'{name}.txt'
        caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(headline_text[headline])

        caminho_arquivo = f'sum_{name}.txt'
        caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(summary)
else: 
    print('error')
# Out:
# **************************************************
# <pad> O governo do Estado de Nova York anunciou nesta quarta-feira que o primeiro-ministro do país, George W. Bush, e o presidente da Câmara dos Deputados, John Kerry, começaram a trabalhar juntos como parte de um plano de resgate para a população do país. Mas, até agora, não há previsão oficial de quando isso acontecerá, mas os resultados serão divulgados no final deste mês. A informação foi divulgada pela primeira vez por meio de um porta-voz do Ministério do Interior do Estado, na Grã-Bretanha, e por meio do site da BBC Brasil, na internet, na terça-feira (horário de Brasília), de acordo com a agência de notícias oficial do país, a BBC News Brasil (Apec, na sigla em inglês), e a BBC Brasil não foram divulgados oficialmente, como havia sido divulgado anteriormente, mas desvendado pela BBC Brasil e divulgados pela imprensa local. A BBC Brasil divulgou um comunicado dizendo que a situação era muito pior do que a que se passou e que os efeitos colaterais da crise econômica são muito mais graves do que o que se esperava, segundo o governo. Mas o que aconteceu é que o resultado disso não foi um desastre para a saúde pública do país e não foi divulgado oficialmente, mas sim o fato de que o país é um dos países mais afetados pela crise econômica global, que já dura mais de um ano. A notícia foi publicada na revista especializada Proceedings of the National Geographics.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# @@@@@@@@ economia_paro-general-9-mayo-argentina-queda-desconectada-pierde-us-62-millones-vuelos-cancelados_0_4KMpoQEcek.html @@@@@@@@@@@@@

# %% [markdown]
# # PROTO CÓDIGO DOS TICKETS

# %%
'''
empresasbr = {
    'empresa': ['Vale', 'Itaú Unibanco', 'Bradesco', 'Ambev', 'Banco do Brasil', 'B3', 'Petrobras', 'Cielo', 'Eletrobras', 'Magazine Luiza',
                'Votorantim', 'Gerdau', 'Rumo', 'Cyrela', 'Klabin', 'Randon', 'Ultrapar', 'Usiminas', 'Lojas Americanas', 'Suzano',
                'Fleury', 'Gol', 'Santander Brasil', 'Localiza', 'Ecorodovias', 'Braskem', 'WEG', 'JBS', 'IRB Brasil', 'CCR'],
    'codigo': ['VALE3.SA', 'ITUB4.SA', 'BBDC4.SA', 'ABEV3.SA', 'BBAS3.SA', 'B3SA3.SA', 'PETR4.SA', 'CIEL3.SA', 'ELET6.SA', 'MGLU3.SA',
                'VVAR3.SA', 'GGBR4.SA', 'RAIL3.SA', 'CYRE3.SA', 'KLBN11.SA', 'RAPT4.SA', 'UGPA3.SA', 'USIM5.SA', 'LAME4.SA', 'SUZB3.SA',
                'FLRY3.SA', 'GOLL4.SA', 'SANB11.SA', 'RENT3.SA', 'ECOR3.SA', 'BRKM5.SA', 'WEGE3.SA', 'JBSS3.SA', 'IRBR3.SA', 'CCRO3.SA'],
    'pais': ['Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil',
              'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil'],
    'nicho': ['Mineração', 'Serviços Financeiros', 'Serviços Financeiros', 'Bebidas', 'Serviços Financeiros', 'Serviços Financeiros', 'Petróleo e Gás', 'Tecnologia Financeira', 'Energia', 'Varejo',
              'Diversificado', 'Metalurgia', 'Logística', 'Construção Civil', 'Papel e Celulose', 'Automotivo', 'Diversificado', 'Metalurgia', 'Varejo', 'Papel e Celulose',
              'Saúde', 'Transporte Aéreo', 'Serviços Financeiros', 'Aluguel de Carros', 'Infraestrutura', 'Petroquímica', 'Energia', 'Alimentício', 'Seguros', 'Infraestrutura']
}

empresasar = {
    'empresa': ['YPF', 'Grupo Financiero Galicia', 'Banco Macro', 'MercadoLibre', 'Telecom Argentina', 'BBVA Banco Francés', 'Cresud', 'Pampa Energía', 'Tenaris', 'Globant',
                'Banco de la Nación Argentina', 'Ternium', 'Central Puerto', 'Banco Santander Río', 'Grupo Supervielle', 'YPF Luz', 'Banco BBVA Argentina', 'Transportadora de Gas del Sur', 'Despegar.com', 'Banco de Galicia y Buenos Aires',
                'Aluar Aluminio', 'Molinos Río de la Plata', 'Edenor', 'IRSA Propiedades Comerciales', 'Banco Patagonia', 'Telefónica de Argentina', 'Siderar', 'Consultatio', 'Molinos Agro', 'TGS'],
    'codigo': ['YPFD.BA', 'GGAL.BA', 'BMA.BA', 'MELI.BA', 'TECO2.BA', 'BBAR.BA', 'CRES.BA', 'PAMP.BA', 'TS.BA', 'GLOB.BA',
               'BMA.BA', 'TXAR.BA', 'CEPU.BA', 'RIO.BA', 'SUPV.BA', 'YPFL.BA', 'BBVA.BA', 'TGSU2.BA', 'DESP.BA', 'GGAL.BA',
               'ALUA.BA', 'MOLI.BA', 'EDN.BA', 'IRSA.BA', 'BPAT.BA', 'TECO2.BA', 'ERAR.BA', 'CTIO.BA', 'MOLA.BA', 'TGSU2.BA'],
    'pais': ['Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina',
             'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina',
             'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina', 'Argentina'],
    'nicho': ['Petróleo e Gás', 'Serviços Financeiros', 'Serviços Financeiros', 'Tecnologia', 'Telecomunicações', 'Serviços Financeiros', 'Agricultura', 'Energia', 'Metalurgia', 'Tecnologia',
              'Serviços Financeiros', 'Metalurgia', 'Energia', 'Serviços Financeiros', 'Serviços Financeiros', 'Petróleo e Gás', 'Serviços Financeiros', 'Petróleo e Gás', 'Tecnologia', 'Serviços Financeiros',
              'Metalurgia', 'Alimentício', 'Energia', 'Imobiliário', 'Serviços Financeiros', 'Telecomunicações', 'Metalurgia', 'Consultoria', 'Alimentício', 'Energia']
}

empresasmex = {
    'empresa': ['América Móvil', 'Grupo México', 'FEMSA', 'Grupo Bimbo', 'Cemex', 'Grupo Financiero Banorte', 'Grupo Elektra', 'Gruma', 'Grupo Aeroportuario del Pacífico', 'Alfa', 
                'Grupo Aeroportuario del Centro Norte', 'Grupo Carso', 'Genomma Lab Internacional', 'Grupo Aeroportuario del Sureste', 'Grupo Aeroportuario de la Ciudad de México', 
                'Grupo Simec', 'Alpek', 'Controladora Vuela Compañía de Aviación', 'Gentera', 'Banco Santander México', 'Televisa', 'Grupo Lala', 'Grupo Herdez', 
                'Grupo Cementos de Chihuahua', 'Grupo Gigante', 'Banco del Bajío', 'Grupo Sanborns', 'Fibra Uno', 'Grupo Industrial Maseca', 'Grupo Kuo'],
    'codigo': ['AMXL.MX', 'GMEXICOB.MX', 'FEMSAUBD.MX', 'BIMBOA.MX', 'CEMEXCPO.MX', 'GFNORTEO.MX', 'ELEKTRA.MX', 'GRUMAB.MX', 'GAPB.MX', 'ALFAA.MX', 
                'OMAB.MX', 'GCARSOA1.MX', 'LABB.MX', 'ASURB.MX', 'GACMAB.MX', 'SIMECB.MX', 'ALPEKA.MX', 'VLRS.MX', 'GENTERA.MX', 'BSMXB.MX', 'TLEVISACPO.MX', 
                'LALAB.MX', 'HERDEZ.MX', 'GCC.MX', 'GIGANTE.MX', 'BBAJIOO.MX', 'GSANBORB-1.MX', 'FUNO11.MX', 'GRUMAB.MX', 'KUOB.MX'],
    'pais': ['México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 
             'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México', 'México'],
    'nicho': ['Telecomunicações', 'Mineração', 'Bebidas', 'Alimentício', 'Construção', 'Serviços Financeiros', 'Varejo', 'Alimentício', 'Transporte', 'Conglomerado',
              'Transporte', 'Conglomerado', 'Farmacêutico', 'Transporte', 'Transporte', 'Metalurgia', 'Químico', 'Transporte', 'Serviços Financeiros', 'Serviços Financeiros', 'Mídia',
              'Alimentício', 'Alimentício', 'Construção', 'Varejo', 'Serviços Financeiros', 'Varejo', 'Imobiliário', 'Indústria', 'Conglomerado']
}

empresascol = {
    'empresa': ['Ecopetrol', 'Grupo Aval', 'Bancolombia', 'Grupo Nutresa', 'Grupo Argos', 'Cementos Argos', 'Grupo Sura', 'Grupo Éxito', 'ISA', 'Banco de Bogotá',
                'Grupo Bolívar', 'Grupo EPM', 'Almacenes Éxito', 'Terpel', 'Celsia', 'Bancolombia Preferencial', 'Davivienda', 'Grupo Energía Bogotá', 'Cementos Argos Preferencial', 'Grupo Nutresa Preferencial',
                'Grupo Argos Preferencial', 'Grupo Aval Preferencial', 'Corficolombiana', 'ISA Preferencial', 'Banco de Bogotá Preferencial', 'Banco de Occidente', 'Grupo Sura Preferencial', 'Grupo Éxito Preferencial', 'Cemex Latam Holdings', 'ISA Pref A'],
    'codigo': ['ECOPETL.BO', 'AVAL.BO', 'CIB.BO', 'NUTRESA.BO', 'GRUPOARG.BO', 'CEMARGOS.BO', 'GRUPOSURA.BO', 'EXITO.BO', 'ISA.BO', 'BOGOTA.BO',
               'BOLIVAR.BO', 'EPM.BO', 'EXITO.BO', 'TERPEL.BO', 'CELSIA.BO', 'BCOLOMBIA.BO', 'PFDAVVNDA.BO', 'EEB.BO', 'CARTGENA.BO', 'NUTRESA.BO',
               'GRUPOARG.BO', 'AVAL.BO', 'COLFIC.BO', 'ISA.BO', 'BOGOTA.BO', 'OCCIDENTE.BO', 'GRUPOSURA.BO', 'EXITO.BO', 'CLH.BO', 'ISA.BO'],
    'pais': ['Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia',
             'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia',
             'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia', 'Colômbia'],
    'nicho': ['Petróleo e Gás', 'Serviços Financeiros', 'Serviços Financeiros', 'Alimentício', 'Construção', 'Construção', 'Serviços Financeiros', 'Varejo', 'Energia', 'Serviços Financeiros',
              'Serviços Financeiros', 'Energia', 'Varejo', 'Petróleo e Gás', 'Energia', 'Serviços Financeiros', 'Serviços Financeiros', 'Energia', 'Construção', 'Alimentício',
              'Construção', 'Serviços Financeiros', 'Serviços Financeiros', 'Serviços Financeiros', 'Energia', 'Serviços Financeiros', 'Serviços Financeiros', 'Varejo', 'Varejo', 'Construção', 'Energia']
}

empresaschi = {
    'empresa': ['Banco Santander Chile', 'LATAM Airlines Group S.A.', 'Cencosud S.A.', 'Enel Chile S.A.', 'SQM S.A.', 'Banco de Chile',
                'CAP S.A.', 'Embotelladora Andina S.A.', 'Empresa Nacional de Electricidad S.A.', 'Banco BICE', 'Colbún S.A.', 'Copec S.A.',
                'Entel Chile S.A.', 'Empresas Copec S.A.', 'SMU S.A.', 'Falabella S.A.', 'Banco Santander Chile', 'Banco de Crédito e Inversiones',
                'ILC Grupo Security S.A.', 'Sonda S.A.', 'Banco Estado', 'Parque Arauco S.A.', 'Itaú Corpbanca', 'Viña Concha y Toro S.A.',
                'Sociedad Matriz SAAM S.A.', 'Banco Santander Chile', 'Grupo Security S.A.', 'Enel Distribucion Chile S.A.', 'Inversiones La Construcción S.A.', 'BCI Seguros S.A.'],
    'codigo': ['SAN.SN', 'LTM', 'CENCOSUD', 'ENELCHILE', 'SQM', 'BCH', 'CAP', 'ANDINA-A', 'ENELAM', 'BICE', 'COLBUN', 'COPEC',
               'ENTEL', 'COPEC', 'SMU', 'FALABELLA', 'BSANTANDER', 'BCI', 'ILC', 'SONDA', 'ESTADO', 'PARAUCO', 'ITAUCORP', 'CONCHATORO',
               'SAAM', 'BSAN.SN', 'SECURITY', 'ENELCHILE', 'ILC', 'BCI'],
    'pais': ['Chile'] * 30,
    'nicho': ['Serviços Financeiros', 'Transporte Aéreo', 'Varejo', 'Energia', 'Mineração', 'Serviços Financeiros', 'Indústria', 'Indústria', 'Energia', 'Serviços Financeiros',
              'Energia', 'Energia', 'Telecomunicações', 'Indústria', 'Varejo', 'Varejo', 'Serviços Financeiros', 'Serviços Financeiros', 'Serviços Financeiros', 'Tecnologia',
              'Tecnologia', 'Serviços Financeiros', 'Imobiliário', 'Serviços Financeiros', 'Bebidas', 'Serviços Financeiros', 'Serviços Financeiros', 'Energia', 'Serviços Financeiros', 'Seguros']
}

empresasper = {
    'empresa': ['Credicorp Ltd.', 'Southern Copper Corporation', 'Volcan Compañía Minera S.A.A.', 'Banco de Crédito del Perú', 'Grana y Montero S.A.A.', 'Engie Energia Perú S.A.',
                'Ferreyros S.A.A.', 'Minera Buenaventura S.A.A.', 'Banco Continental', 'Intercorp Financial Services Inc.', 'Lima Airport Partners S.R.L.', 'Cementos Pacasmayo S.A.A.',
                'Graña y Montero S.A.A.', 'Inretail Peru Corporation S.A.', 'Inmobiliaria Panamericana S.A.A.', 'Alicorp S.A.A.', 'Hochschild Mining plc', 'Empresas Copec S.A.', 'Backus and Johnston',
                'Aceros Arequipa S.A.', 'Refinería La Pampilla S.A.A.', 'Pacífico Seguros', 'Alicorp S.A.A.', 'E.W. Scripps Company', 'Gloria S.A.', 'Cencosud Shopping Centers S.A.', 'Rímac Seguros y Reaseguros S.A.',
                'Ferreyros S.A.A.', 'Inmobiliaria Inversiones La Construcción S.A.A.'],
    'codigo': ['BAP', 'SCCO', 'VOLCABC1', 'BAP', 'GRAMONC1', 'ENGIEC1', 'FERREYC1', 'BUE', 'BAP', 'IFS', 'AAPL1', 'CPACASC1', 'GRAMONC1', 'INRETC1', 'PAPAC1', 'ALICORC1',
               'HOC.L', 'COPEC', 'BAP', 'BAP', 'RLP', 'BAP', 'ALICORC1', 'PRSGA', 'EWSCC1', 'PFA', 'CENCOSUD', 'RIMAC1', 'FERREYC1', 'ILCC1'],
    'pais': ['Peru'] * 30,
    'nicho': ['Serviços Financeiros', 'Mineração', 'Mineração', 'Serviços Financeiros', 'Construção', 'Energia', 'Construção', 'Mineração', 'Serviços Financeiros', 'Serviços Financeiros',
              'Transporte', 'Construção', 'Construção', 'Varejo', 'Imobiliário', 'Alimentício', 'Mineração', 'Energia', 'Bebidas', 'Manufatura',
              'Petróleo e Gás', 'Seguros', 'Alimentício', 'Mídia', 'Alimentício', 'Varejo', 'Seguros', 'Construção', 'Imobiliário']
}

empresas_tecnologicas = {
    'empresa': ['Apple Inc.', 'Microsoft Corporation', 'Amazon.com Inc.', 'Alphabet Inc.', 'Facebook, Inc.', 'Tesla, Inc.', 'NVIDIA Corporation',
                'Adobe Inc.', 'Intel Corporation', 'IBM (International Business Machines Corporation)', 'Netflix, Inc.', 'Salesforce.com, Inc.',
                'Tencent Holdings Limited', 'Oracle Corporation', 'Cisco Systems, Inc.', 'Qualcomm Incorporated', 'PayPal Holdings, Inc.', 'Sony Corporation',
                'Square, Inc.', 'Twitter, Inc.', 'Uber Technologies, Inc.', 'Zoom Video Communications, Inc.', 'Shopify Inc.', 'Palantir Technologies Inc.',
                'Alibaba Group Holding Limited', 'Snowflake Inc.', 'Pinterest, Inc.', 'DocuSign, Inc.', 'Twilio Inc.', 'ServiceNow, Inc.'],
    'codigo': ['AAPL', 'MSFT', 'AMZN', 'GOOGL', 'FB', 'TSLA', 'NVDA', 'ADBE', 'INTC', 'IBM', 'NFLX', 'CRM', 'TCEHY', 'ORCL', 'CSCO', 'QCOM', 'PYPL', 'SNE',
               'SQ', 'TWTR', 'UBER', 'ZM', 'SHOP', 'PLTR', 'BABA', 'SNOW', 'PINS', 'DOCU', 'TWLO', 'NOW'],
    'pais': ['EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'China', 'EUA', 'EUA', 'EUA', 'EUA', 'Japão', 'EUA',
             'EUA', 'EUA', 'EUA', 'Canadá', 'EUA', 'China', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA'],
    'nicho': ['Tecnologia'] * 30
}

empresas_financeiras = {
    'empresa': ['JPMorgan Chase & Co.', 'Berkshire Hathaway Inc.', 'Bank of America Corporation', 'Wells Fargo & Company', 'Citigroup Inc.', 'Goldman Sachs Group, Inc.',
                'Morgan Stanley', 'American Express Company', 'Mastercard Incorporated', 'Visa Inc.', 'The Charles Schwab Corporation', 'BlackRock, Inc.',
                'S&P Global Inc.', 'Fidelity National Information Services, Inc.', 'Fiserv, Inc.', 'Capital One Financial Corporation', 'Nasdaq, Inc.',
                'The Bank of New York Mellon Corporation', 'T. Rowe Price Group, Inc.', 'State Street Corporation', 'BB&T Corporation', 'Northern Trust Corporation',
                'Ally Financial Inc.', 'E*TRADE Financial Corporation', 'Discover Financial Services', 'Intercontinental Exchange, Inc.', 'Ameriprise Financial, Inc.',
                'CME Group Inc.', 'Raymond James Financial, Inc.', 'The Travelers Companies, Inc.'],
    'codigo': ['JPM', 'BRK.B', 'BAC', 'WFC', 'C', 'GS', 'MS', 'AXP', 'MA', 'V', 'SCHW', 'BLK', 'SPGI', 'FIS', 'FISV', 'COF', 'NDAQ', 'BK', 'TROW', 'STT', 'BBT', 'NTRS',
               'ALLY', 'ETFC', 'DFS', 'ICE', 'AMP', 'CME', 'RJF', 'TRV'],
    'pais': ['EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA',
             'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA'],
    'nicho': ['Serviços Financeiros'] * 30
}

empresas_energia = {
    'empresa': ['Saudi Aramco', 'Exxon Mobil', 'Royal Dutch Shell', 'China National Petroleum Corporation', 'BP', 'TotalEnergies', 'Saudi Arabian Oil Company', 'Chevron Corporation', 'Gazprom', 'Rosneft',
                'Kuwait Petroleum Corporation', 'PetroChina', 'Eni', 'Abu Dhabi National Oil Company', 'Sinopec', 'Valero Energy', 'Phillips 66', 'Petrobras', 'Reliance Industries', 'PetroChina', 
                'Equinor', 'PT Pertamina (Persero)', 'ConocoPhillips', 'EOG Resources', 'Lukoil', 'Marathon Petroleum', 'Pemex', 'Saudi Basic Industries Corporation (SABIC)', 'Enbridge', 'BHP',
                'Exxon Mobil', 'E.ON', 'Petronas', 'Petronas Chemicals Group Berhad', 'NextEra Energy', 'Suncor Energy', 'Indian Oil Corporation', 'Occidental Petroleum', 'Duke Energy', 'Chesapeake Energy',
                'Southern Company', 'Schlumberger', 'Canadian Natural Resources', 'Chevron Corporation', 'Woodside Petroleum', 'ConocoPhillips', 'EOG Resources', 'Repsol', 'EOG Resources', 'Devon Energy'],
    'codigo': ['ARAMCO', 'XOM', 'RDS.A', 'PTR', 'BP', 'TTE', '2222.SE', 'CVX', 'OGZPY', 'ROSN.ME', 'KPC', 'PTR', 'ENI', 'ABD.NE', 'SNP', 'VLO', 'PSX', 'PBR', 'RELIANCE.NS', 'PTR', 
               'EQNR', 'PERT.JK', 'COP', 'EOG', 'LKOH.ME', 'MPC', 'PXX', '2010.SE', 'ENB', 'BHP', 'XOM', 'EONGY', 'PETRONM', '5183.KL', 'NEE', 'SU', 'IOCL.NS', 'OXY', 'DUK', 'CHK',
               'SO', 'SLB', 'CNQ', 'CVX', 'WPL.AX', 'COP', 'EOG', 'REP.MC', 'EOG', 'DVN'],
    'pais': ['Arábia Saudita', 'EUA', 'Reino Unido / Países Baixos', 'China', 'Reino Unido', 'França', 'Arábia Saudita', 'EUA', 'Rússia', 'Rússia', 'Kuwait', 'China', 'Itália', 'Emirados Árabes Unidos',
             'China', 'EUA', 'EUA', 'Brasil', 'Índia', 'China', 'Noruega', 'Indonésia', 'EUA', 'EUA', 'Rússia', 'EUA', 'México', 'Arábia Saudita', 'Canadá', 'Austrália', 'EUA', 'Alemanha',
             'Malásia', 'Malásia', 'EUA', 'Canadá', 'Índia', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'Canadá', 'EUA', 'Austrália', 'EUA', 'EUA', 'Espanha', 'EUA', 'EUA'],
    'nicho': ['Energia'] * 50
}

empresas_automotivas = {
    'empresa': ['Toyota', 'Volkswagen', 'Daimler', 'General Motors', 'BMW', 'Honda', 'Ford', 'Nissan', 'Tesla', 'Hyundai', 'Audi', 'Volvo', 'Fiat Chrysler', 'Renault', 'Peugeot', 'Subaru', 'Kia', 'Mazda', 'Jaguar Land Rover', 'Mercedes-Benz',
                'Mitsubishi', 'Porsche', 'Geely', 'BYD', 'Tata Motors', 'Suzuki', 'Ferrari', 'Bentley', 'Lamborghini', 'Rolls-Royce'],
    'codigo': ['TM', 'VWAGY', 'DDAIF', 'GM', 'BMWYY', 'HMC', 'F', 'NSANY', 'TSLA', 'HYMTF', 'AUDVF', 'VOLVY', 'FCAU', 'RNSDF', 'PUGOY', 'FUJHY', 'HYMTF', 'MZDAY', 'TTM', 'DDAIF',
               'MSBHY', 'POAHY', 'GELYY', 'BYDDY', 'TTM', 'SZKMY', 'RACE', 'BNTGF', 'VLKAF', 'RYCEY'],
    'pais': ['Japão', 'Alemanha', 'Alemanha', 'EUA', 'Alemanha', 'Japão', 'EUA', 'Japão', 'EUA', 'Coreia do Sul', 'Alemanha', 'Suécia', 'Itália', 'França', 'França', 'Japão', 'Coreia do Sul', 'Japão', 'Reino Unido', 'Alemanha',
             'Japão', 'Alemanha', 'China', 'China', 'Índia', 'Japão', 'Itália', 'Reino Unido', 'Itália', 'Reino Unido'],
    'nicho': ['Automotiva'] * 30
}
empresas_varejo = {
    'empresa': ['Walmart', 'Amazon', 'Alibaba', 'Costco', 'Home Depot', 'Tesco', 'Lowe\'s', 'Aldi', 'Inditex', 'Carrefour', 'JD.com', 'Target', 'IKEA', 'CVS Health', 'LVMH', 'Woolworths', 'Kroger', 'Lidl', 'Seven & i Holdings', 'Walgreens Boots Alliance',
                'Best Buy', 'Shopify', 'Coles Group', 'Schwarz Group', 'Sainsbury\'s', 'Metro AG', 'Yum China Holdings', 'Ross Stores', 'X5 Retail Group', 'Macy\'s', 'Ahold Delhaize', 'Next plc', 'Zalando', 'Rite Aid', 'Fast Retailing', 'H&M', 'Gap', 'L Brands',
                'Canadian Tire', 'O\'Reilly Auto Parts', 'Kingfisher', 'Ulta Beauty', 'Migros', 'Jeronimo Martins', 'Tractor Supply Company', 'J. Sainsbury', 'Marks & Spencer', 'Dollar General', 'Casino Guichard-Perrachon'],
    'codigo': ['WMT', 'AMZN', 'BABA', 'COST', 'HD', 'TSCO', 'LOW', '', 'ITX', 'CA', 'JD', 'TGT', '', 'CVS', 'LVMUY', 'WOW', 'KR', '', '', '', 'WBA', 'BBY', 'SHOP', '', '', '', '', 'YUMC', 'ROST', '', 'M', 'ADRNY', 'NXT',
               'ZAL', 'RAD', 'FRCOY', 'HNNMY', 'GPS', 'LB', 'CDNAF', 'ORLY', '', 'ULTA', '', '', 'JMT', 'TSCO', 'SBRY', 'MAKSY', 'DG', 'CGUSY'],
    'pais': ['EUA', 'EUA', 'China', 'EUA', 'EUA', 'Reino Unido', 'EUA', 'Alemanha', 'Espanha', 'França', 'China', 'EUA', 'Suécia', 'EUA', 'França', 'Austrália', 'EUA', 'Alemanha', 'Japão', 'EUA', 'EUA', 'Canadá', 'Austrália', 'Alemanha',
             'Reino Unido', 'Alemanha', 'China', 'EUA', 'Rússia', 'EUA', 'Holanda', 'Reino Unido', 'Alemanha', 'EUA', 'Suécia', 'EUA', 'EUA', 'Canadá', 'EUA', 'Reino Unido', 'EUA', 'Suíça', 'Portugal', 'EUA', 'Reino Unido', 'Reino Unido',
             'EUA', 'França'],
    'nicho': ['Varejo'] * 30
}

empresas_saude = {
    'empresa': ['Johnson & Johnson', 'Roche Holding', 'Pfizer', 'Novartis', 'Merck & Co.', 'Abbott Laboratories', 'Sanofi', 'GlaxoSmithKline', 'Medtronic', 'Bristol-Myers Squibb',
                'Eli Lilly and Company', 'Amgen', 'AstraZeneca', 'Novo Nordisk', 'Takeda Pharmaceutical', 'Gilead Sciences', 'Bayer', 'Becton Dickinson', 'Teva Pharmaceutical Industries', 'Stryker',
                'AbbVie', 'Biogen', 'Regeneron Pharmaceuticals', 'Vertex Pharmaceuticals', 'Alexion Pharmaceuticals', 'Shire', 'Zoetis', 'Fresenius', 'Cigna', 'Cardinal Health'],
    'codigo': ['JNJ', 'ROG', 'PFE', 'NOVN', 'MRK', 'ABT', 'SNY', 'GSK', 'MDT', 'BMY', 'LLY', 'AMGN', 'AZN', 'NVO', '4502.T', 'GILD', 'BAYN', 'BDX', 'TEVA', 'SYK',
               'ABBV', 'BIIB', 'REGN', 'VRTX', 'ALXN', 'SHPG', 'ZTS', 'FRE', 'CI', 'CAH'],
    'pais': ['EUA', 'Suíça', 'EUA', 'Suíça', 'EUA', 'EUA', 'França', 'Reino Unido', 'EUA', 'EUA', 'EUA', 'EUA', 'Reino Unido', 'Dinamarca', 'Japão', 'EUA', 'Alemanha', 'EUA', 'Israel', 'EUA',
             'EUA', 'EUA', 'EUA', 'EUA', 'EUA', 'Irlanda', 'EUA', 'Alemanha', 'EUA', 'EUA', 'EUA'],
    'nicho': ['Saúde'] * 30
}

empresas_construcao_civil = {
    'empresa': ['China State Construction Engineering', 'China Railway Group', 'China Railway Construction', 'Vinci', 'ACS', 'Bouygues', 'Larsen & Toubro', 'Actividades de Construcción y Servicios', 'China Communications Construction', 'China Evergrande Group',
                'Shimizu', 'Skanska', 'Bechtel', 'China Metallurgical Group', 'Power Construction Corporation of China', 'Obayashi Corporation', 'China Energy Engineering Corporation', 'Shanghai Construction Group', 'China National Building Material Group', 'China Resources Cement Holdings',
                'VINCI Construction', 'China Gezhouba Group', 'CRH', 'China Railway Engineering Corporation', 'China National Machinery Industry Corporation', 'Sinohydro Group', 'Grupo ACS', 'China Railway Signal & Communication', 'China Communications Services Corporation', 'Beijing Urban Construction Group',
                'China National Erzhong Group', 'China National Nuclear Corporation', 'Balfour Beatty', 'Daikin Industries', 'United Technologies Corporation', 'Japan Airlines', 'China National Aviation Holding', 'China Southern Airlines', 'Air China', 'Delta Air Lines',
                'Sinopec', 'PetroChina', 'ExxonMobil', 'Royal Dutch Shell', 'Chevron', 'Total', 'BP', 'Petrobras', 'Schlumberger'],
    'codigo': ['601668.SS', '0390.HK', '1186.HK', 'DG.PA', 'ACS.MC', 'EN.PA', 'LT.NS', 'ACS.MC', '1800.HK', '3333.HK',
               '1803.T', 'SKA-B.ST', 'Privada', '1618.HK', '601669.SS', '1802.T', '601800.SS', '600170.SS', '601668.SS', '1899.HK', '1313.HK',
               'DG.PA', '600068.SS', 'CRG.IR', '3898.HK', 'SINOVIS.BO', '601618.SS', 'ACS.MC', '600548.SS', '0554.HK', 'Privada',
               '601268.SS', '601985.SS', 'BALF.L', '6367.T', 'UTX', '9201.T', '601111.SS', '1055.HK', '601111.SS', '601111.SS',
               '600028.SS', '601857.SS', 'XOM', 'RDS-A', 'CVX', 'FP.PA', 'BP', 'PBR', 'SLB'],
    'pais': ['China', 'China', 'China', 'França', 'Espanha', 'França', 'Índia', 'Espanha', 'China', 'China',
             'Japão', 'Suécia', 'Estados Unidos', 'China', 'China', 'Japão', 'China', 'China', 'China', 'China',
             'França', 'China', 'Irlanda', 'China', 'China', 'China', 'Espanha', 'China', 'China', 'China',
             'China', 'China', 'Reino Unido', 'Japão', 'Estados Unidos', 'Japão', 'China', 'China', 'China',
             'China', 'EUA', 'Holanda', 'EUA', 'EUA', 'França', 'Reino Unido', 'Brasil', 'EUA'],
    'nicho': ['Construção Civil'] * 50
}

empresas_mineracao = {
    'empresa': [
        "BHP Group", "Rio Tinto", "Vale", "Glencore", "Anglo American", "Freeport-McMoRan", "Newmont Corporation", "Barrick Gold", "Teck Resources", "South32",
        "Alcoa Corporation", "Gold Fields", "Newcrest Mining", "Fortescue Metals Group", "Southern Copper Corporation", "Aluminum Corporation of China Limited (Chalco)", "Codelco", "Nornickel", "Mosaic", "Lynas Rare Earths",
        "Vale Indonesia", "First Quantum Minerals", "Wheaton Precious Metals", "Hudbay Minerals", "Turquoise Hill Resources", "OZ Minerals", "Lundin Mining Corporation", "Evolution Mining", "Pan American Silver", "Northern Star Resources",
        "Kinross Gold Corporation", "Hecla Mining Company", "Yamana Gold", "SSR Mining", "Kirkland Lake Gold", "Alamos Gold", "Iamgold Corporation", "Agnico Eagle Mines Limited", "New Gold Inc.", "Endeavour Mining Corporation", "Harmony Gold Mining Company Limited",
        "Centamin plc", "Hochschild Mining plc", "MAG Silver Corporation", "Pretium Resources Inc.", "Osisko Gold Royalties Ltd", "Shandong Gold Mining Co., Ltd.", "Silvercorp Metals Inc.", "Royal Gold, Inc.", "Polymetal International plc", "Sandstorm Gold Ltd.",
        "Northern Dynasty Minerals Ltd.", "Fortuna Silver Mines Inc.", "Lundin Gold Inc."
    ],
    'codigo': [
        "BHP", "RIO", "VALE", "GLEN.L", "AAL.L", "FCX", "NEM", "GOLD", "TECK", "S32",
        "AA", "GFI", "NCM.AX", "FMG.AX", "SCCO", "2600.HK", "CODEL.SN", "GMKN.ME", "MOS", "LYC.AX",
        "INCO.JK", "FM.TO", "WPM", "HBM", "TRQ", "OZL.AX", "LUN.TO", "EVN.AX", "PAAS", "NST.AX",
        "KGC", "HL", "AUY", "SSRM", "KL", "AGI", "IAG", "AEM", "NGD", "EDV.TO", "HMY",
        "CEY.L", "HOC.L", "MAG", "PVG", "OR.TO", "600547.SS", "SVM", "RGLD", "POLY.L", "SAND",
        "NAK", "FSM", "LUG.TO"
    ],
    'pais': [
        'Austrália', 'Austrália', 'Brasil', 'Suíça', 'Reino Unido', 'Estados Unidos', 'Estados Unidos', 'Canadá', 'Canadá', 'Austrália',
        'Estados Unidos', 'África do Sul', 'Austrália', 'Austrália', 'Peru', 'China', 'Chile', 'Rússia', 'Estados Unidos', 'Austrália',
        'Indonésia', 'Canadá', 'Canadá', 'Canadá', 'Estados Unidos', 'Austrália', 'Canadá', 'Austrália', 'Estados Unidos', 'Austrália',
        'Canadá', 'Estados Unidos', 'Canadá', 'Estados Unidos', 'Canadá', 'Canadá', 'Canadá', 'Canadá', 'Canadá', 'Canadá', 'Reino Unido',
        'Reino Unido', 'Canadá', 'Canadá', 'Canadá', 'China', 'Canadá', 'Reino Unido', 'Rússia', 'Canadá', 'Canadá',
        'Estados Unidos', 'Canadá', 'Canadá'
    ],
    'nicho': ['Mineração'] * 50
}

indices_bolsas = {
    'empresa': [
        "Ibovespa", "S&P 500", "NASDAQ Composite", "FTSE 100", "DAX", "CAC 40", "Nikkei 225", "Hang Seng", "Shanghai Composite", "BSE Sensex",
        "KOSPI", "S&P/ASX 200", "TSX Composite", "IBEX 35", "FTSE MIB", "RTS Index", "MOEX Russia", "Bovespa", "IPC Mexico", "IPC Colombia",
        "MERVAL", "S&P/BMV IPC", "S&P/CLX IPSA", "BVC Bolivia", "BVN Peru", "IMC Chile", "BGS Paraguay", "IGBVL", "MSE Top 20 Index", "JSE All Share"
    ],
    'codigo': [
        "^BVSP", "^GSPC", "^IXIC", "^FTSE", "^GDAXI", "^FCHI", "^N225", "^HSI", "000001.SS", "^BSESN",
        "^KS11", "^AXJO", "^GSPTSE", "^IBEX", "FTSEMIB.MI", "^RTSI", "^IMOEX.ME", "^BVSP", "^MXX", "^COLCAP",
        "^MERV", "^MXX", "^IPSA", "^BVP", "^SPBLPGPT", "^IGPA", "^BVLG", "^ITC", "^JALSH"
    ],
    'pais': [
        "Brasil", "Estados Unidos", "Estados Unidos", "Reino Unido", "Alemanha", "França", "Japão", "Hong Kong", "China", "Índia",
        "Coreia do Sul", "Austrália", "Canadá", "Espanha", "Itália", "Rússia", "Rússia", "Brasil", "México", "Colômbia",
        "Argentina", "México", "Chile", "Bolívia", "Peru", "Chile", "Paraguai", "Peru", "Mongólia", "África do Sul"
    ],
    'nicho': ['Índices das Bolsas'] * 30
}

'''
# Out:
# '\nempresasbr = {\n    \'empresa\': [\'Vale\', \'Itaú Unibanco\', \'Bradesco\', \'Ambev\', \'Banco do Brasil\', \'B3\', \'Petrobras\', \'Cielo\', \'Eletrobras\', \'Magazine Luiza\',\n                \'Votorantim\', \'Gerdau\', \'Rumo\', \'Cyrela\', \'Klabin\', \'Randon\', \'Ultrapar\', \'Usiminas\', \'Lojas Americanas\', \'Suzano\',\n                \'Fleury\', \'Gol\', \'Santander Brasil\', \'Localiza\', \'Ecorodovias\', \'Braskem\', \'WEG\', \'JBS\', \'IRB Brasil\', \'CCR\'],\n    \'codigo\': [\'VALE3.SA\', \'ITUB4.SA\', \'BBDC4.SA\', \'ABEV3.SA\', \'BBAS3.SA\', \'B3SA3.SA\', \'PETR4.SA\', \'CIEL3.SA\', \'ELET6.SA\', \'MGLU3.SA\',\n                \'VVAR3.SA\', \'GGBR4.SA\', \'RAIL3.SA\', \'CYRE3.SA\', \'KLBN11.SA\', \'RAPT4.SA\', \'UGPA3.SA\', \'USIM5.SA\', \'LAME4.SA\', \'SUZB3.SA\',\n                \'FLRY3.SA\', \'GOLL4.SA\', \'SANB11.SA\', \'RENT3.SA\', \'ECOR3.SA\', \'BRKM5.SA\', \'WEGE3.SA\', \'JBSS3.SA\', \'IRBR3.SA\', \'CCRO3.SA\'],\n    \'pais\': [\'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\',\n              \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\', \'Brasil\'],\n    \'nicho\': [\'Mineração\', \'Serviços Financeiros\', \'Serviços Financeiros\', \'Bebidas\', \'Serviços Financeiros\', \'Serviços Financeiros\', \'Petróleo e Gás\', \'Tecnologia Financeira\', \'Energia\', \'Varejo\',\n              \'Diversificado\', \'Metalurgia\', \'Logística\', \'Construção Civil\', \'Papel e Celulose\', \'Automotivo\', \'Diversificado\', \'Metalurgia\', \'Varejo\', \'Papel e Celulose\',\n              \'Saúde\', \'Transporte Aéreo\', \'Serviços Financeiros\', \'Aluguel de Carros\', \'Infraestrutura\', \'Petroquímica\', \'Energia\', \'Alimentício\', \'Seguros\', \'Infraestrutura\']\n}\n\nempresasar = {\n    \'empresa\': [\'YPF\', \'Grupo Financiero Galicia\', \'Banco Macro\', \'MercadoLibre\', \'Telecom Argentina\', \'BBVA Banco Francés\', \'Cresud\', \'Pampa Energía\', \'Tenaris\', \'Globant\',\n                \'Banco de la Nación Argentina\', \'Ternium\', \'Central Puerto\', \'Banco Santander Río\', \'Grupo Supervielle\', \'YPF Luz\', \'Banco BBVA Argentina\', \'Transportadora de Gas del Sur\', \'Despegar.com\', \'Banco de Galicia y Buenos Aires\',\n                \'Aluar Aluminio\', \'Molinos Río de la Plata\', \'Edenor\', \'IRSA Propiedades Comerciales\', \'Banco Patagonia\', \'Telefónica de Argentina\', \'Siderar\', \'Consultatio\', \'Molinos Agro\', \'TGS\'],\n    \'codigo\': [\'YPFD.BA\', \'GGAL.BA\', \'BMA.BA\', \'MELI.BA\', \'TECO2.BA\', \'BBAR.BA\', \'CRES.BA\', \'PAMP.BA\', \'TS.BA\', \'GLOB.BA\',\n               \'BMA.BA\', \'TXAR.BA\', \'CEPU.BA\', \'RIO.BA\', \'SUPV.BA\', \'YPFL.BA\', \'BBVA.BA\', \'TGSU2.BA\', \'DESP.BA\', \'GGAL.BA\',\n               \'ALUA.BA\', \'MOLI.BA\', \'EDN.BA\', \'IRSA.BA\', \'BPAT.BA\', \'TECO2.BA\', \'ERAR.BA\', \'CTIO.BA\', \'MOLA.BA\', \'TGSU2.BA\'],\n    \'pais\': [\'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\',\n             \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\',\n             \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\', \'Argentina\'],\n    \'nicho\': [\'Petróleo e Gás\', \'Serviços Financeiros\', \'Serviços Financeiros\', \'Tecnologia\', \'Telecomunicações\', \'Serviços Financeiros\', \'Agricultura\', \'Energia\', \'Metalurgia\', \'Tecnologia\',\n              \'Serviços Financeiros\', \'Metalurgia\', \'Energia\', \'Serviços Financeiros\', \'Serviços Financeiros\', \'Petróleo e Gás\', \'Serviços Financeiros\', \'Petróleo e Gás\', \ ...

# %% [markdown]
# # Subir no GDS
