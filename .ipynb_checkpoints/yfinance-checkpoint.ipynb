# %% [markdown]
# # Importando pacotes

# %%
################################################## Trazendo os pacotes de fora ###################################
import importlib

def install_and_import(package):
    try:
        importlib.import_module(package)  # Tenta importar o pacote
    except ImportError:
        print(f"{package} não está instalado. Instalando agora...")
        # !pip install {package}  # Instala o pacote
    finally:
        globals()[package] = importlib.import_module(package)  # Importa o pacote
        
        
install_and_import('sklearn')
install_and_import('numpy')
install_and_import('statsmodels')
install_and_import('seaborn')
install_and_import('oauth2client')

# !pip install wbdata
# !pip install -- update pandas
# !pip install pandas_datareader
# !pip install gspread
# !pip install oauth2client
# !pip install openpyxl
# !pip install --update yfinance
# !pip install selenium
# !pip install -- update newspaper3k
# !pip install -- update requests
# !pip install bs4
# !pip install -- update transformers
# !pip install googletrans==3.1.0a0
# !pip install statsmodels
# !pip install google-api-python-client
# !pip install paramiko

# %%
###################################### Importando bibliotecas ######################################

import os
os.environ['PYTHONHASHSEED'] = '0' # Remove os erros de cache persistente

import gspread
import datetime
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import datasets
from sklearn.metrics import r2_score
import statsmodels.api as sm
import seaborn as sns
import openpyxl
import numpy as np
import yfinance as yf
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from datetime import datetime, timedelta
import sqlite3
import pandas_datareader as pdr
import wbdata
import requests
from bs4 import BeautifulSoup
import newspaper
import sys
from transformers import T5Tokenizer
from transformers import T5Model, T5ForConditionalGeneration
from googletrans import Translator
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_white
import logging
from googleapiclient.discovery import build
from google.oauth2.service_account import Credentials
from googleapiclient.http import MediaFileUpload
from unidecode import unidecode
import paramiko
from ftplib import FTP

# %% [markdown]
# # Plano de escrita
# > Abaixo descreveremos quais são os objetivos desse algorítimo e quais passos serão utilizados para a realização dele.

# %% [markdown]
# ## Objetivo principal
# > Esse algoritimo busca a análise econômica dos países da América do Sul produzindo um reporte que será acessado através de uma plataforma de visualização de dados.
#
# ## Objetivos específicos
# 1. Coletar, armazenar e processar dados das principais empresas dos países selecionados através do Yahoo Finance
#     1.1 Além das empresas nacionais, é importante também produzir dados de empresas transnacionais relevantes para a região
# 2. Coletar, armazenar e processar dados macroeconômicos dos países relevantes através de alguma ferramenta
# 3. Coletar as principais notícias nos jornais nacionais dos países em questão e através de uma inteligência artifical gerar resumos dessas notícias para serem apresentados no reporte
#
# ## Descrição das etapas pretendidas
# - Criação de um sistema de coleta, armazenamento local e consulta de dados dos ativos selecionados
#     - Os ativos relevantes são: cestas das bolsas de valores locais, taxa de câmbio com o dólar e em um escopo de região vamos extrair também os preços de commodities
#     - O armazenamento será através de um Banco de Dados. **Será utilizado o SQLite***
#     - Parte do processo de armazenamento é estabelecer um sistema eficiênte de datas para não sobrecarregar o yf
#     - O armazenamento é pensado como um Banco de Dados SQL
#     - Criar sistema de download dos dados históricos sem sobrecarregar YF
# - À partir dos dados obtidos executar os processamentos relevantes
#     - Executar análise do desvio padrão, correlação entre as bolsas, etc
#     - **Bonus:** Buscar bibliotecas que façam análise de risco e estudar ligeiramente as teorias dos ativos
#     - Armazenar todos os dados localmente
# - Organizar os dados em planilhas com conteúdo compatível com o software de visualização dos dados
#     - O software de visualização dos dados escolhi no momento foi o **Google Data Stuidio*
#     - Relevante aprender a utilizar
# - Utilizar a biblioteca de interação com o Drive para fazer o upload para uma pasta no drive que alimentará google data studio
# - Buscar e raspar principais notícias do dia e criar um resumo direcionado ao país através da IA
# - Armazenar localmente de forma compacta e fazer upload para o drive onde alimentará também o Google Data Studio
# - A ideia geral da visualização dos dados no google data stuidio é:
#     - Resumo geral da região
#         - Principais variações regionais em ativos de bolsa
#         - Commodities
#         - Agregados e a última data de atualização
#         - Principais cestas de bolsa
#         - Tabela com as taxas de câmbio e variações
#         - Resumo das notícias locais em um pequeno resumo da região
#     - Resumo individual
#         - Descrição detalhada dos agregados
#         - Análise de nível médio de detalhe das ações relevantes pra unidade nacional
#         - Resumo de três parágrafos das três primeiras notícias das manchetes

# %% [markdown]
#    ## Sobre moedas:
#     Brasil (BRL): Real
#     Argentina (ARS): Peso argentino
#     Chile (CLP): Peso chileno
#     Colômbia (COP): Peso colombiano
#     México (MXN): Peso mexicano
#     Peru (PEN): Sol peruano
#     Uruguai (UYU): Peso uruguaio
#     Venezuela (VES): Bolívar soberano
#     Belize: Dólar de Belize (BZD)
#     Costa Rica: Colón costa-riquenho (CRC)
#     Guatemala: Quetzal guatemalteco (GTQ)
#     Honduras: Lempira hondurenho (HNL)
#     Nicarágua: Córdoba nicaraguense (NIO)
#     Panamá: Balboa panamenho (PAB)

# %% [markdown]
# # Sistemas

# %%
# Sistema de data

today = datetime.today()
today = today.strftime("%Y-%m-%d")

print(today)

def printype(ty):
    print(ty)
    print(type(ty))
# Out:
# 2024-05-12

# %%
# Recuperar tabelas do BD SQL em um objeto pandas

def sqltodf(pandas):
    # Conectar ao banco de dados SQLite
    conn = sqlite3.connect('yfhistoric.db')
    # Consulta SQL para recuperar os dados da tabela
    query = f'SELECT * FROM "{pandas}"'
    # Ler os dados do banco de dados para um DataFrame do pandas
    df = pd.read_sql_query(query, conn)
    # Fechar a conexão com o banco de dados
    conn.close()
    return df
# Consultar SQL

def showsql(sqltable):
    df = sqltodf(f'{sqltable}')
    print(df)

# formatar sql pra ter preço e data
def closedate(df):
    df = df.drop(columns=['id', 'code', 'open', 'high', 'low', 'volume', 'datatype']) 
    return df
# get logs
def getlog(name):
    caminho_arquivo_e = f"{name}_{today}.txt"
    logging.basicConfig(filename=caminho_arquivo_e, level=logging.INFO, format='%(asctime)s @ %(levelname)s @ %(message)s')
    logger = logging.getLogger()

# %%
# Recouperação de datas. Sistma SIMPLESISSIMO. Muito a melhorar.
class DateOperations:
    def __init__(self, date):
        self.date = date

    def pastdays(self, days):
        pastdate = self.date - timedelta(days=days)
        pastdate = pastdate.strftime("%Y-%m-%d")
        pastdate = datetime.strptime(pastdate, "%Y-%m-%d")
        return pastdate

    def pastweeks(self, weeks):
        days = weeks * 7
        return self.pastdays(days)

    def pastmonths(self, months):
        days = months * 30
        return self.pastdays(days)

    def pastyears(self, years):
        days = years * 365
        return self.pastdays(days)

    def pastperiod(self, period, value):
        if period == "d":
            return self.pastdays(value)
        elif period == "w":
            return self.pastweeks(value)
        elif period == "m":
            return self.pastmonths(value)
        elif period == "y":
            return self.pastyears(value)
        else:
            raise ValueError("Period should be 'days = d', 'weeks = w', 'months = m', or 'years = y'")

def dateop(period, time):
    date_operation = DateOperations(datetime.now())
    date = date_operation.pastperiod(period, time)
    return date

def dateop_cut(lastdate, period, time):
    date_operation = DateOperations(lastdate)
    date = date_operation.pastperiod(period, time)
    return date

# %%
testday = datetime.today()
testdef = dateop("y", 10)
print(type(testdef))
# Out:
# <class 'datetime.datetime'>

# %%
### FUNÇÃO PARA RESGATAR A DATA CORRETA DE ATUALIZAÇÃO

# Tentei integrar essa função no meu código sem ter que abrir e fechar o DB a caba iteração, mas não soube. 

'''commcode = "HYMTF" #"HYMTF" #PRT não tem date @@@@@@@@@@@@@@@@ SÓ PARA UM TESTE'''
todaydelta = datetime.strptime(today, "%Y-%m-%d")
tenyragodelta = todaydelta - timedelta(days=10*365)
tenyragovar = tenyragodelta.strftime("%Y-%m-%d")
todayvar = todaydelta.strftime("%Y-%m-%d")
todaydt = datetime.strptime(today, "%Y-%m-%d")


#####
def datecheck(commcode):
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    noatt = "no att" # PARA QUANDO A INSTRUÇÃO SEJA NÃO ATUALIZAR 
    commcode = commcode.lower()
    command = f'SELECT MIN(date) FROM "{commcode}"'
    cursor.execute(command)
    lastdate = cursor.fetchall()
    lastdate = [row[0] for row in lastdate]
    lastdatetest = f'{lastdate[0]}'
    # Testando se está vazio
    if lastdatetest == "None":
        return tenyragovar
    else: # FAZER A DIFERENÇA DE TEMPO
        lastdatedt = datetime.strptime(lastdatetest, "%Y-%m-%d %H:%M:%S")
        timedif = lastdatedt - tenyragodelta
        if lastdatedt > tenyragodelta: # SE A LASTDATE FOR MAIOR (MAIS NOVA, MAIS RECENTE) VAI ATIVAR ESSE. ESSE TESTE É "QUAL DATA É MAIS RECENTE?"
             # SE A LAST DATE FOR MAIS RECENTE QUE 10 ANOS ATRÁS, VAMOS ATUALIZAR E COMPLETAR OS 10 ANOS
            return tenyragovar
        else: # SE NÃO VAI ATIVAR ESSE, OU SEJA, A LASTDATE É MENOR OU IGUAL A "DEZ ANOS ATRÁS". # TEM MAIS DE 10 ANOS DE REGISTRO JÁ, VER AGORA QUAL A ÚLTIMA DATA
            command = f'SELECT MAX(date) FROM "{commcode}"'
            cursor.execute(command)
            earlydate = cursor.fetchall()
            earlydate = [row[0] for row in earlydate]
            earlydate = f'{earlydate[0]}'
            earlydatedt = datetime.strptime(earlydate, "%Y-%m-%d %H:%M:%S")
            earlydate = datetime.strftime(earlydatedt, "%Y-%m-%d")
            if earlydatedt == todaydt:
                
                return noatt
            else:
                
                return earlydate

    conn.close()

'''##############
print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ISSO É UM TESTE@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")

datetest = datecheck(commcode)

print(datetest)'''
# Out:
# '##############\nprint("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ISSO É UM TESTE@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")\n\ndatetest = datecheck(commcode)\n\nprint(datetest)'

# %% [markdown]
# # Atualizações/Instalações

# %%
# Criar/conectar um BD

# Primeiro é importante verificar se o arquivo do database está presente no "root" da instalação

rootdire =  os.getcwd()
rootdire_list = os.listdir(rootdire)

if 'yfhistoric.db' in rootdire_list:
    conexao = sqlite3.connect('yfhistoric.db')
    print('Você já tem um Banco de Dados')
else:
    conexao = sqlite3.connect('yfhistoric.db')
    print('Criando um banco de dados')
    cursor = conexao.cursor()
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS indicators(
        id INTEGER PRIMARY KEY,
        datatype TEXT NOT NULL
    )
    ''')
    conexao.close()

### CRIANDO AS TABELAS SE ELAS NÃO EXISTEM ###
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

###### TABELAS MÃE #####
cursor.execute('''
    CREATE TABLE IF NOT EXISTS indicators(
        id INTEGER PRIMARY KEY,
        datatype TEXT NOT NULL
    );
    
    ''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS texts(
        id INTEGER PRIMARY KEY,
        datatype TEXT NOT NULL
    );    
    ''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS countries( 
        id INTEGER PRIMARY KEY,
        country TEXT,
        alpha3code TEXT,
        latam TEXT
        
    );    
    ''')
# Na chave "latam" adicionar "yes", "no" e "world" 


cursor.execute('''
    CREATE TABLE IF NOT EXISTS niche( 
        id INTEGER PRIMARY KEY,
        niche TEXT
    );    
    ''')

##### TABELAS FILHA
cursor.execute('''
    CREATE TABLE IF NOT EXISTS currencies(
        id INTEGER PRIMARY KEY,
        currcode TEXT NOT NULL,
        currname TEXT NOT NULL,
        country TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES indicators(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''')

cursor.execute('''
    CREATE TABLE IF NOT EXISTS tickets(
        id INTEGER PRIMARY KEY,
        ticcode TEXT NOT NULL,
        ticname TEXT NOT NULL,
        ticcat TEXT NOT NULL,
        datatype TEXT NOT NULL,
        country TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES indicators(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''')

cursor.execute('''
    CREATE TABLE IF NOT EXISTS commodities(
        id INTEGER PRIMARY KEY,
        commcode TEXT NOT NULL,
        comname TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES indicators(datatype)
    );    
    ''')

cursor.execute('''
    CREATE TABLE IF NOT EXISTS agregates(
        id INTEGER PRIMARY KEY,
        agrcode TEXT NOT NULL,
        agrcodewb TEXT NOT NULL,
        agrname TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES indicators(datatype)
    );    
    ''')


cursor.execute('''
    CREATE TABLE IF NOT EXISTS cripto(
        id INTEGER PRIMARY KEY,
        criptoname TEXT NOT NULL, 
        criptocode TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES text(datatype)
    );    
    ''')

####### text

cursor.execute('''
    CREATE TABLE IF NOT EXISTS news(
        id INTEGER PRIMARY KEY,
        newspapername TEXT NOT NULL,
        newspaperlink TEXT NOT NULL,
        country TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES text(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''')

cursor.execute('''
    CREATE TABLE IF NOT EXISTS summary(
        id INTEGER PRIMARY KEY,
        summhierarquy TEXT NOT NULL, 
        country TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES text(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''')



###### TESTES E END
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
table = cursor.fetchall()


conn.commit()
conn.close()

# print(rootdire      , ' !!!!! ', rootdire_list)  Para verificar
#print(rootdire      , ' !!!!! ', rootdire_list)


# Conectar ao banco de dados (isso criará o banco de dados se não existir)
# conexao = sqlite3.connect('yfhistoric.db')
# Out:
# Você já tem um Banco de Dados

# %%
########## GATILHOS DAS CATEGORIAS MÃE (INCOMPLETO, FAZER DEPOIS)
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

indicatorsdt = ('currencies', 'tickets', 'commodities', 'agregates', 'cripto')

textdt = ('news', 'summary')

countriescat = ('Brasil', 'Argentina', 'Chile', 'Colômbia', 'México', 'Peru', 'Uruguai', 'Venezuela', 'Belize', 'Costa Rica', 'Estados Unidos', 'Guatemala', 'Honduras', 'Nicarágua', 'Bolívia', 'Mundo', 'Criptomoeda', 'União Europeia')

conn.close()

# %%
##### INSERIR DADOS TABELA MÃE


data = (indicatorsdt, textdt, countriescat)

conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

for indi in indicatorsdt:
    command = '''
        INSERT INTO indicators (datatype)
        SELECT ? AS datatype
        WHERE NOT EXISTS (
            SELECT 1 FROM indicators WHERE datatype = ?
        )
    '''
    conn.execute(command, (indi, indi))
    conn.commit()

for dt in textdt:
    command = '''
        INSERT INTO texts (datatype)
        SELECT ? AS datatype
        WHERE NOT EXISTS (
            SELECT 1 FROM indicators WHERE datatype = ?
        )
    '''
    conn.execute(command, (dt, dt))
    conn.commit()

# %% [markdown]
# # TABELAS FILHAS/NETAS

# %% [markdown]
# # Currencies

# %%
##### CURRENCIES
currencies_todf = {  # EDITAR ISSO PARA ADICIONAR OU REMOVER MOEDAS RELEVANTES A SEREM ANALISADAS
    
'pais': ['Brasil', 'Argentina', 'Chile', 'Colômbia', 'México', 'Peru', 'Uruguai', 'Venezuela', 'Belize', 'Costa Rica', 'Estados Unidos', 'Guatemala', 'Honduras', 'Nicarágua', 'Bolívia'],
'moeda': ['Real', 'Peso argentino', 'Peso chileno', 'Peso colombiano', 'Peso mexicano', 
          'Sol peruano', 'Peso uruguaio', 'Bolívar soberano', 'Dólar de Belize', 'Colón costa-riquenho', 'Dólar dos Estados Unidos', 'Quetzal guatemalteco', 
           'Lempira hondurenho', 'Córdoba nicaraguense', 'Boliviano'],
'codigo': ['BRL', 'ARS', 'CLP', 'COP', 'MXN', 'PEN', 'UYU', 'VES', 'BZD', 'CRC', 'USD', 'GTQ', 'HNL', 'NIO', 'BOB']
}

currenciesdf = pd.DataFrame(currencies_todf)
currenciesdf.head(20)
# Out:
#               pais                     moeda codigo
# 0           Brasil                      Real    BRL
# 1        Argentina            Peso argentino    ARS
# 2            Chile              Peso chileno    CLP
# 3         Colômbia           Peso colombiano    COP
# 4           México             Peso mexicano    MXN
# 5             Peru               Sol peruano    PEN
# 6          Uruguai             Peso uruguaio    UYU
# 7        Venezuela          Bolívar soberano    VES
# 8           Belize           Dólar de Belize    BZD
# 9       Costa Rica      Colón costa-riquenho    CRC
# 10  Estados Unidos  Dólar dos Estados Unidos    USD
# 11       Guatemala      Quetzal guatemalteco    GTQ
# 12        Honduras        Lempira hondurenho    HNL
# 13       Nicarágua      Córdoba nicaraguense    NIO
# 14         Bolívia                 Boliviano    BOB

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

for index, row in currenciesdf.iterrows():
    code = row['codigo']
    name = row['moeda']
    country = row['pais']
    datatype = 'currencies'
    dados = (code, name, country, datatype) 
    command = '''
        INSERT INTO currencies (currcode, currname, country, datatype)
        SELECT ?, ?, ?, ?
        WHERE NOT EXISTS (
            SELECT 1 FROM currencies 
            WHERE currcode = ? AND currname = ? AND country = ? AND datatype = ?
        )
    '''
    cursor.execute(command, dados + dados)
    conn.commit()
conn.close()

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

command = 'SELECT currcode FROM currencies'

cursor.execute(command)

# Recuperar os resultados da consulta
resultados = cursor.fetchall()

# Armazenar os valores da coluna em uma lista Python
coluna_lista = [row[0] for row in resultados]

# Exibir a lista
print(coluna_lista)
# Out:
# ['BRL', 'ARS', 'CLP', 'COP', 'MXN', 'PEN', 'UYU', 'VES', 'BZD', 'CRC', 'USD', 'GTQ', 'HNL', 'NIO', 'BOB']

# %%
for codeit in coluna_lista:
    codeit = codeit.lower()
    command = f'''
        CREATE TABLE IF NOT EXISTS {codeit}(
            id INTEGER PRIMARY KEY,
            code TEXT NOT NULL,
            date DATE,
            open REAL,
            high REAL,
            low REAL,
            close REAL,
            volume REAL,
            datatype TEXT NOT NULL
        );    
        '''
    cursor.execute(command)
    conn.commit()


# Fechar a conexão com o banco de dados
conn.close()

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

for currcode in coluna_lista:
    currcode = currcode.lower()
    command = f'SELECT MIN(date) FROM {currcode}'
    cursor.execute(command)
    lastdate = cursor.fetchall()
    lastdatetest = f'{lastdate}'
    lastdatetest = len(lastdatetest)
    if lastdatetest == 9: # GAMBIARRA MÁXIMA
        tenyragovar = tenyragodelta.strftime("%Y-%m-%d")
        todayvar = todaydelta.strftime("%Y-%m-%d")
        downloadv = yf.download(f"USD{currcode}=X", start=f"{tenyragovar}", end=f"{todayvar}")
        downloadv = downloadv.drop('Adj Close', axis=1)
        downloadv['datatype'] = 'currencies'
        downloadv['code'] = f'{currcode}'
        downloadv.reset_index(inplace=True)
        downloadv['Date'] = pd.to_datetime(downloadv['Date'])
        currcodel = currcode.lower()
        downloadv.to_sql(f'{currcodel}', conn, if_exists='append', index=False, dtype={'Date': 'DATE'})
        
    else:
        command = f'SELECT MAX(date) FROM {currcode}'
        cursor.execute(command)
        firstdate = cursor.fetchall()
        lastdatestr = lastdate[0][0].split()[0]
        lastdatedatetime = datetime.strptime(lastdatestr, '%Y-%m-%d')
        firstdatestr = firstdate[0][0].split()[0]
        firstdatedatetime = datetime.strptime(firstdatestr, '%Y-%m-%d')
        todayvar = todaydelta.strftime("%Y-%m-%d")
        firstdatestr = firstdatedatetime.strftime("%Y-%m-%d")
        print(firstdatedatetime)
        print(todaydelta)
        print(type(todaydelta))
        print(todayvar)
        print(firstdatestr)
        if firstdatestr == todaydelta:
            print('Up to date')
        else:
            downloadv = yf.download(f"USD{currcode}=X", start=f"{firstdatestr}", end=f"{todayvar}") # o Yahoo Finance só resgata os tickets de moeda depois do fechamento do dia. 
            # Rodar esse programa UMA VEZ POR DIA
            # PARA UMA ATUALIZAÇÃO: ADICIONAR UMA CHAVE DE "ATUALIZATION DATE"
            downloadv = downloadv.drop('Adj Close', axis=1)
            downloadv['datatype'] = 'currencies'
            downloadv['code'] = f'{currcode}'
            downloadv.reset_index(inplace=True)
            downloadv['Date'] = pd.to_datetime(downloadv['Date'])
            currcodel = currcode.lower()
            downloadv.to_sql(f'{currcodel}', conn, if_exists='replace', index=False, dtype={'Date': 'DATE'})
            print(downloadv)
            conn.commit()

conn.close()
# Out:
# 2024-05-11 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-11
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['USDBRL=X']: IndexError('index 0 is out of bounds for axis 0 with size 0')
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, datatype, code]
# Index: []
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close  Volume  \
# 0 2024-05-10  882.515503  882.822998  882.307495  882.515503       0
#
#      datatype code
# 0  currencies  ars
# 2024-05-11 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-11
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close  Volume  \
# 0 2024-05-11  926.099976  926.099976  926.099976  926.099976       0
#
#      datatype code
# 0  currencies  clp
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open         High         Low       Close  Volume  \
# 0 2024-05-10  3888.76001  3899.850098  3879.26001  3888.76001       0
#
#      datatype code
# 0  currencies  cop
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High      Low      Close  Volume    datatype  \
# 0 2024-05-10  16.779499  16.812149  16.7113  16.779499       0  currencies
#
#   code
# 0  mxn
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date  Open      High       Low  Close  Volume    datatype code
# 0 2024-05-10  3.72  3.633488  3.616317   3.72       0  currencies  pen
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Volume    datatype  \
# 0 2024-05-10  37.914738  37.914738  37.887783  38.080242       0  currencies
#
#   code
# 0  uyu
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Volume    datatype  \
# 0 2024-05-10  36.491344  36.491344  36.491344  36.491344       0  currencies
#
#   code
# 0  ves
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date      Open      High       Low     Close  Volume    datatype code
# 0 2024-05-10  1.961028  1.969163  1.961028  1.969533       0  currencies  bzd
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close  Volume  \
# 0 2024-05-10  496.764771  499.480469  496.764771  498.928528       0
#
#      datatype code
# 0  currencies  crc
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['USDUSD=X']: IndexError('index 0 is out of bounds for axis 0 with size 0')
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date      Open      High       Low     Close  Volume    datatype code
# 0 2024-05-10  7.552403  7.584051  7.552403  7.585018       0  currencies  gtq
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date      Open       High       Low      Close  Volume    datatype  \
# 0 2024-05-10  24.08798  24.250408  24.08798  24.610001       0  currencies
#
#   code
# 0  hnl
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Volume    datatype  \
# 0 2024-05-10  36.197498  36.347782  36.197498  36.529999       0  currencies
#
#   code
# 0  nio
# 2024-05-10 00:00:00
# 2024-05-12 00:00:00
# <class 'datetime.datetime'>
# 2024-05-12
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
#         Date      Open      High       Low     Close  Volume    datatype code
# 0 2024-05-10  6.696074  6.724092  6.696074  6.725054       0  currencies  bob

# %% [markdown]
# # Cripto

# %%
### Cripto

cripto_df = pd.read_excel("cripto.xlsx")
print(cripto_df)
# Out:
#            criptoname criptocode
# 0             Bitcoin        BTC
# 1            Ethereum        ETH
# 2        Binance Coin        BNB
# 3              Solana        SOL
# 4             Cardano        ADA
# 5              Tether       USDT
# 6                 XRP        XRP
# 7            Polkadot        DOT
# 8            USD Coin       USDC
# 9            Dogecoin       DOGE
# 10          Avalanche       AVAX
# 11          Chainlink       LINK
# 12              Terra       LUNA
# 13           Litecoin        LTC
# 14           Algorand       ALGO
# 15          Shiba Inu       SHIB
# 16            Polygon      MATIC
# 17       Bitcoin Cash        BCH
# 18            Stellar        XLM
# 19  Internet Computer        ICP
# 20    Wrapped Bitcoin       WBTC
# 21   Ethereum Classic        ETC
# 22            VeChain        VET
# 23           Filecoin        FIL
# 24               TRON        TRX
# 25      Theta Network      THETA
# 26             Cosmos       ATOM
# 27          FTX Token        FTT
# 28                Dai        DAI
# 29               Aave       AAVE

# %%
def updatecripto(cripto):
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    cripto = pd.DataFrame(cripto)
    for index, row in cripto.iterrows():
        code = row['criptocode']
        name = row['criptoname']
        datatype = 'criptocurrencies'
        dados = (code, name, datatype) 
        command = '''
            INSERT INTO cripto (criptocode, criptoname, datatype)
            SELECT ?, ?, ?
            WHERE NOT EXISTS (
                SELECT 1 FROM cripto
                WHERE criptocode = ? AND criptoname = ? AND datatype = ?
            )
        '''
        cursor.execute(command, dados + dados)
        conn.commit()
    # SELECIONA TODOS OS CÓDIGOS DE TICKERS QUE VAMOS VER NO NOSSO DB
    command = 'SELECT criptocode FROM cripto'
    cursor.execute(command)
    
    
    # RECUPERA A CONSULTA EM UMA LISTA DE TUPLAS
    resultados = cursor.fetchall()
    # Armazenar os valores da coluna em uma lista Python comum
    coluna_lista = [row[0] for row in resultados]
    # CRIA UMA TABELA PARA CADA CÓDIGO
    for codeit in coluna_lista:
        codeit = codeit.lower()
        command = f'''
            CREATE TABLE IF NOT EXISTS "{codeit}"(
                id INTEGER PRIMARY KEY,
                code TEXT NOT NULL,
                date DATE,
                open REAL,
                high REAL,
                low REAL,
                close REAL,
                volume REAL,
                datatype TEXT NOT NULL
            );    
            '''
        cursor.execute(command)
        conn.commit()
       



    ############################## PREENCHER CADA TABELA COM O YAHOO FINANCE



    for commcode in coluna_lista: ### COMMCODE AQUI DEVERIA SER TICCODE
        attdate = datecheck(commcode)
        print(attdate)
        if attdate == "no att":
            print(f"Sem att para o ticker {commcode}")
        else:
            
            try:
                downloadv = yf.download(f"{commcode}", start=f"{attdate}", end=f"{todayvar}")
            except Exception as e:
                ex = f"{e}"
                download_errors.append(ex)
                print(f"O erro do código {commcode} foi {ex}")
            downloadv = downloadv.drop('Adj Close', axis=1)
            downloadv['datatype'] = 'cripto'
            downloadv['code'] = f'{commcode}'
            downloadv.reset_index(inplace=True)
            downloadv['Date'] = pd.to_datetime(downloadv['Date'])
            commcodel = commcode.lower()
            downloadv.to_sql(f'{commcodel}', conn, if_exists='replace', index=False, dtype={'Date': 'DATE'})
            conn.commit()
    conn.close()

############################ executando a função

updatecripto(cripto_df)
# Out:
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ETH']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2020-04-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ADA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-15 -> 2024-05-12)')
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['USDT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['XRP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-15 -> 2024-05-12)')
# 2017-03-13
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['DOGE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['AVAX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ALGO']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-15 -> 2024-05-12)')
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['SHIB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['MATIC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['ICP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2014-05-15 -> 2024-05-12)')
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['WBTC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2022-03-02
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2018-01-30
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['THETA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['FTT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2018-03-02
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['AAVE']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %% [markdown]
# # Commodities

# %%
########################### commodities
commodities_todf = {
    'commodity': ['Ouro', 'Prata', 'Petróleo Crude (WTI)', 'Petróleo Brent Crude', 'Cobre', 'Gás Natural', 'Milho', 'Trigo', 'Café', 'Açúcar'],
    'codigo': ['GC=F', 'SI=F', 'CL=F', 'BZ=F', 'HG=F', 'NG=F', 'C=F', 'W=F', 'KC=F', 'SB=F']
}
commoditiesdf = pd.DataFrame(commodities_todf)

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

command = 'SELECT commcode FROM commodities'

cursor.execute(command)

# Recuperar os resultados da consulta
resultados = cursor.fetchall()

# Armazenar os valores da coluna em uma lista Python
coluna_lista = [row[0] for row in resultados]

# Exibir a lista
print(coluna_lista)
# Out:
# ['GC=F', 'SI=F', 'CL=F', 'BZ=F', 'HG=F', 'NG=F', 'C=F', 'W=F', 'KC=F', 'SB=F']

# %%
def updatecommodities(dcticket):
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    dcticketdf = pd.DataFrame(dcticket)
    for index, row in dcticketdf.iterrows():
        code = row['codigo']
        name = row['commodity']
        datatype = 'commodities'
        dados = (code, name, datatype) 
        command = '''
            INSERT INTO commodities (commcode, comname, datatype)
            SELECT ?, ?, ?
            WHERE NOT EXISTS (
                SELECT 1 FROM commodities
                WHERE commcode = ? AND comname = ? AND datatype = ?
            )
        '''
        cursor.execute(command, dados + dados)
        conn.commit()
    # SELECIONA TODOS OS CÓDIGOS DE TICKERS QUE VAMOS VER NO NOSSO DB
    command = 'SELECT commcode FROM commodities'
    cursor.execute(command)
    
    
    # RECUPERA A CONSULTA EM UMA LISTA DE TUPLAS
    resultados = cursor.fetchall()
    # Armazenar os valores da coluna em uma lista Python comum
    coluna_lista = [row[0] for row in resultados]
    # CRIA UMA TABELA PARA CADA CÓDIGO
    for codeit in coluna_lista:
        codeit = codeit.lower()
        command = f'''
            CREATE TABLE IF NOT EXISTS "{codeit}"(
                id INTEGER PRIMARY KEY,
                code TEXT NOT NULL,
                date DATE,
                open REAL,
                high REAL,
                low REAL,
                close REAL,
                volume REAL,
                datatype TEXT NOT NULL
            );    
            '''
        cursor.execute(command)
        conn.commit()
       



    ############################## PREENCHER CADA TABELA COM O YAHOO FINANCE



    for commcode in coluna_lista: ### COMMCODE AQUI DEVERIA SER TICCODE
        attdate = datecheck(commcode)
        print(attdate)
        if attdate == "no att":
            print(f"Sem att para o ticker {commcode}")
        else:
            
            try:
                downloadv = yf.download(f"{commcode}", start=f"{attdate}", end=f"{todayvar}")
            except Exception as e:
                ex = f"{e}"
                download_errors.append(ex)
                print(f"O erro do código {commcode} foi {ex}")
            downloadv = downloadv.drop('Adj Close', axis=1)
            downloadv['datatype'] = 'commodities'
            downloadv['code'] = f'{commcode}'
            downloadv.reset_index(inplace=True)
            downloadv['Date'] = pd.to_datetime(downloadv['Date'])
            commcodel = commcode.lower()
            conn = sqlite3.connect('yfhistoric.db')
            cursor = conn.cursor()
            for index, row in downloadv.iterrows():
                dateit = row['Date']
                openit = row['Open']
                highit = row['High']
                lowit = row['Low']
                closeit = row['Close']
                volumeit = row['Volume']
                datatype = row['datatype']
                code = row['code']
                dateit = dateit.strftime('%Y-%m-%d %H:%M:%S')
                dados = (dateit, openit, highit, lowit, closeit, volumeit, datatype, code) 
                command = f'''
                INSERT INTO "{commcode}" (Date, Open, High, Low, Close, Volume, datatype, code)
                SELECT ?, ?, ?, ?, ?, ?, ?, ?
                WHERE NOT EXISTS (
                    SELECT 1 FROM "{commcode}"
                    WHERE Date = ? AND Open = ? AND High = ? AND Low = ? AND Close = ? AND Volume = ? AND datatype = ? AND code = ?
                    )
                    '''
                cursor.execute(command, dados + dados)
                conn.commit()
    conn.close()

updatecommodities(commoditiesdf)
# Out:
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Tickets
#
# >Estava com problemas para fazer a função if de consulta da última data de atualização e diversas formas de fazer o download para não sobrecarregar o Yahoo Finance, mas parece que o yf é robusto
# >e fazer download de 10 anos dos tickers não vai ser problema. Mas é algo a ser otimizado. Uma forma é fazer uma subtração do lastdate. Pra frente veremos.
# >O mesmo vale para as saídas de erro com tickers com código incorreto, isso depende dos ajustes que tem que ser feitos com o código pronto.

# %%
###### CRIAÇÃO E MANUTENÇÃO DIRETÓRIO TICKERS ####

# Nome da pasta que você deseja verificar/criar
nome_pasta = "tickets"
# Verificar se o diretório existe
if not os.path.exists(nome_pasta):
    # Se não existir, criar o diretório
    os.makedirs(nome_pasta)
    
# Diretório onde estão os arquivos Excel
diretorio_tickets = "tickets"

# Lista para armazenar os dataframes
tickets = []

# Verificar se o diretório existe
if os.path.exists(diretorio_tickets):
    # Listar todos os arquivos na pasta
    arquivos_excel = [arquivo for arquivo in os.listdir(diretorio_tickets) if arquivo.endswith('.xlsx')] # LISTA TODOS OS 
    
    # Ler cada arquivo Excel e adicionar o dataframe à lista
    for arquivo in arquivos_excel:
        caminho_arquivo = os.path.join(diretorio_tickets, arquivo)
        df = pd.read_excel(caminho_arquivo)
        tickets.append(df) # UMA LISTA DE DATFRAMES
else:
    print(f"O diretório '{diretorio_tickets}' não existe.")

# %%
caminho_arquivo_e = f"tickererrors_{today}.txt"
logging.basicConfig(filename=caminho_arquivo_e, level=logging.INFO, format='%(asctime)s @ %(levelname)s @ %(message)s')
logger = logging.getLogger()

def updateticket(dcticket):
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    dcticketdf = pd.DataFrame(dcticket)
    for index, row in dcticketdf.iterrows():
        code = row['codigo']
        name = row['empresa']
        country = row['pais']
        niche = row['nicho']
        datatype = 'tickets'
        dados = (code, name, datatype, niche, country) 
        command = '''
            INSERT INTO tickets (ticcode, ticname, datatype, ticcat, country)
            SELECT ?, ?, ?, ?, ?
            WHERE NOT EXISTS (
                SELECT 1 FROM tickets
                WHERE ticcode = ? AND ticname = ? AND datatype = ? AND ticcat = ? AND country = ?
            )
        '''
        cursor.execute(command, dados + dados)
        conn.commit()
    # SELECIONA TODOS OS CÓDIGOS DE TICKERS QUE VAMOS VER NO NOSSO DB
    command = 'SELECT ticcode FROM tickets'
    cursor.execute(command)
    
    
    # RECUPERA A CONSULTA EM UMA LISTA DE TUPLAS
    resultados = cursor.fetchall()
    # Armazenar os valores da coluna em uma lista Python comum
    coluna_lista = [row[0] for row in resultados]
    # CRIA UMA TABELA PARA CADA CÓDIGO
    for codeit in coluna_lista:
        codeit = codeit.lower()
        command = f'''
            CREATE TABLE IF NOT EXISTS "{codeit}"(
                id INTEGER PRIMARY KEY,
                code TEXT NOT NULL,
                date DATE,
                open REAL,
                high REAL,
                low REAL,
                close REAL,
                volume REAL,
                datatype TEXT NOT NULL
            );    
            '''
        cursor.execute(command)
        conn.commit()
       



    ############################## PREENCHER CADA TABELA COM O YAHOO FINANCE



    for commcode in coluna_lista: ### COMMCODE AQUI DEVERIA SER TICCODE
        attdate = datecheck(commcode)
        print(attdate)
        if attdate == "no att":
            pass
        else:
            downloadv = yf.download(f"{commcode}", start=f"{attdate}", end=f"{todayvar}")
            downloadv = downloadv.drop('Adj Close', axis=1)
            downloadv['datatype'] = 'tickets'
            downloadv['code'] = f'{commcode}'
            downloadv.reset_index(inplace=True)
            downloadv['Date'] = pd.to_datetime(downloadv['Date'])
            commcodel = commcode.lower()
            ######
            conn = sqlite3.connect('yfhistoric.db')
            cursor = conn.cursor()
            for index, row in downloadv.iterrows():
                dateit = row['Date']
                openit = row['Open']
                highit = row['High']
                lowit = row['Low']
                closeit = row['Close']
                volumeit = row['Volume']
                datatype = row['datatype']
                code = row['code']
                dateit = dateit.strftime('%Y-%m-%d %H:%M:%S')
                dados = (dateit, openit, highit, lowit, closeit, volumeit, datatype, code) 
                command = f'''
                INSERT INTO "{commcode}" (Date, Open, High, Low, Close, Volume, datatype, code)
                SELECT ?, ?, ?, ?, ?, ?, ?, ?
                WHERE NOT EXISTS (
                    SELECT 1 FROM "{commcode}"
                    WHERE Date = ? AND Open = ? AND High = ? AND Low = ? AND Close = ? AND Volume = ? AND datatype = ? AND code = ?
                    )
                    '''
                cursor.execute(command, dados + dados)
                conn.commit()
            ###########
            
    conn.close()

############################ executando a função

for tic in tickets:
    updateticket(tic)
    
# Fechar o logger
logging.shutdown()
# Out:
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2016-10-26
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2016-10-26
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2022-03-02
# [*********************100%%**********************]  1 of 1 completed
# 2020-01-24
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2022-03-01
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2022-03-01
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2018-01-30
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2018-02-22
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2019-01-08
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2018-06-28
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2020-11-30
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2016-10-26
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2016-10-26
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2022-03-02
# [*********************100%%**********************]  1 of 1 completed
# 2020-01-24
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2022-03-01
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# ...
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2022-05-24
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2019-01-08
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2018-06-28
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2020-11-30
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2019-06-14
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2021-09-30
# [*********************100%%**********************]  1 of 1 completed
# 2021-09-30
# [*********************100%%**********************]  1 of 1 completed
# 2024-05-10
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed
# 2014-05-15
# [*********************100%%**********************]  1 of 1 completed

# %%
#################### TABELA COUNTRIES

## AQUI A TABELA COUNTRIES REGISTRA TODOS OS PAÍSES TRATADOS ATÉ O MOMENTO
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND sql LIKE '%country%'")
tables = cursor.fetchall()
tables = [tupla[0] for tupla in tables]

print(tables)

for tab in tables:
    print(tab)
    command = f''' 
            INSERT INTO countries (country)
            SELECT DISTINCT country FROM {tab}
            WHERE NOT EXISTS (
                SELECT 1 FROM countries WHERE country = {tab}.country 
            )
            '''
  
    cursor.execute(command)
    conn.commit()
    


latam = ['Argentina', 'Bolívia', 'Brasil', 'Chile', 'Colômbia', 'Costa Rica', 'Cuba', 'Equador',
        'El Salvador', 'Guiana', 'Guatemala', 'Haiti', 'Honduras', 'México',
        'Nicarágua', 'Panamá', 'Paraguai', 'Peru', 'República Dominicana', 'Suriname', 
        'Uruguai', 'Venezuela', 'Belize'] # O CONCEITO DE AMÉRICA LATINA AQUI É EXPANDIDO. SÃO TODOS PAÍSES PRA BAIXO DO RIO BRAVO, INCLUINDO CARIBE.



command = "SELECT country FROM countries"
cursor.execute(command)
countriesvar = cursor.fetchall()
countriesvar = [tupla[0] for tupla in countriesvar]

countriesvar = pd.DataFrame(countriesvar, columns = ['country'])

# Cria um novo dataframe com os países adicionais
new_countries_df = pd.DataFrame({'country': latam})

# Adiciona os novos países ao dataframe existente
countriesvar = countriesvar.append(new_countries_df, ignore_index=True)

# Remove duplicatas, se houver
countriesvar = countriesvar.drop_duplicates().reset_index(drop=True)


print(countriesvar)


countriesvar['latam'] = ['Latam' if country in latam else 'Not Latam' for country in countriesvar['country']]

countriesvar.to_sql('countries', conn, if_exists='replace', index=False)


alpha3code = pd.read_excel('alpha.xlsx') # IMPORTANTE: SE FAZ NECESSÁRIO UM ARQUIVO COM UMA LISTA DE ALPHA3 CODE PARA CONSULTA DE AGREGADOS


countriesvar = pd.merge(countriesvar, alpha3code, on='country', how='left')
countriesvar.to_sql('countries', conn, if_exists='replace', index=False)

conn.close()
# Out:
# ['currencies', 'tickets', 'news', 'summary', 'countries', 'mlearning', 'projection_tendencies', 'folha_de_sao_paulo', 'estadao']
# currencies
# tickets
# news
# summary
# countries
# mlearning
# projection_tendencies
# folha_de_sao_paulo
# estadao
#                    country
# 0                   Brasil
# 1                Argentina
# 2                    Chile
# 3                 Colômbia
# 4                   México
# 5                     Peru
# 6                  Uruguai
# 7                Venezuela
# 8                   Belize
# 9               Costa Rica
# 10          Estados Unidos
# 11               Guatemala
# 12                Honduras
# 13               Nicarágua
# 14                 Bolívia
# 15                   Japão
# 16                Alemanha
# 17                     EUA
# 18           Coreia do Sul
# 19                  Suécia
# 20                  Itália
# 21                  França
# 22             Reino Unido
# 23                   China
# 24                   Índia
# 25                 Espanha
# 26                 Irlanda
# 27          Arábia Saudita
# 28                 Holanda
# 29                  Rússia
# 30                  Kuwait
# 31  Emirados Árabes Unidos
# 32                 Noruega
# 33               Indonésia
# 34                  Canadá
# 35               Austrália
# 36                   Suíça
# 37           África do Sul
# 38               Dinamarca
# 39                  Israel
# 40                Portugal
# 41               Hong Kong
# 42                Paraguai
# 43                Mongólia
# 44                    Cuba
# 45                 Equador
# 46             El Salvador
# 47                  Guiana
# 48                   Haiti
# 49                  Panamá
# 50    República Dominicana
# 51                Suriname
# 52                Colombia
# 53              Inglaterra
# 54                  Russia
# C:\Users\yanme\AppData\Local\Temp\ipykernel_15176\4098830755.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   countriesvar = countriesvar.append(new_countries_df, ignore_index=True)

# %% [markdown]
# # AGREGADOS

# %% [markdown]
# Os dados são extraidos através da API do World Bank. Eles tem pesos diferentes.
#
# O PIB é o Produto Interno Bruto em dólares americanos (USD). Não é ajustado pela inflação
# PIB/capta é em USD, normal.
# POPCRESC é a porcentagem de crescimento da população desse país.
# TXIFLA é a porcentagem de crescimento da inflação
# DIVPUB é a porcentagem do PIB que um país tem como dívida pública

# %%
############## AGREGADOS
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

# Regatar alpha3code que é o código ISO9001 padrão mundial para referir-se aos países.
command = "SELECT alpha3code FROM countries"
cursor.execute(command)
alpha3cod = cursor.fetchall()
alpha3cod = [tupla[0] for tupla in alpha3cod]

# Insere/atualiza os códigos dos agregados no World Bank
agrcodes = pd.read_excel('pandas_datareaderagregates.xlsx')
agrcodes.to_sql('agregates', conn, if_exists='replace', index=False)

agrcodes = sqltodf('agregates')

print(agrcodes)
# Out:
#                                         agrname          agrcodewb    agrcode
# 0  PIB nominal (USD, não corrigido pela infla)      NY.GDP.MKTP.CD        PIB
# 1                           PIB per Capta (USD)     NY.GDP.PCAP.CD  PIBPCAPTA
# 2                               População Total        SP.POP.TOTL   POPTOTAL
# 3                           Taxa de Crescimento        SP.POP.GROW   POPCRESC
# 4                              Taxa de Inflação     FP.CPI.TOTL.ZG    TXINFLA
# 5                                    Desemprego     SL.UEM.TOTL.ZS      DESEM
# 6                                Dívida Pública  GC.DOD.TOTL.GD.ZS     DIVPUB
# 7                                 Taxa de Juros        FR.INR.LEND      TXJUR
# 8                             Exportações (USD)     NE.EXP.GNFS.CD        EXP
# 9                                   Importações     NE.IMP.GNFS.CD        IMP

# %%
# Sistema de data e tipos de variáveis
todayyear = datetime.today()
tenyearsago = todayyear - timedelta(365 * 10)
todayyear = todayyear.strftime("%Y")
tenyearsago = tenyearsago.strftime("%Y")
todayyear = f'{todayyear}'
tenyearsago = f'{tenyearsago}'

# Reorganização Alpha 3 Codes 
alpha3cod = list(filter(lambda x: x is not None, alpha3cod))




for index, row in agrcodes.iterrows():
    name2 = row['agrcode']
    name2 = f'{name2}'
    print(name2)
    agr = row['agrcodewb']
    for alp in alpha3cod:
        data = wbdata.get_data(agr, country=alp, date=(tenyearsago, todayyear))
        data = pd.DataFrame(data)
        data['datatype'] = 'agregates'
        data['agrcode'] = name2
        name = f"{alp}_WB_{name2}"
        name = name.replace(".", "_") # Dando problema na consulta e preenchimento do country acima no BD SQL
        name = f'{name}'
        drop = ['indicator', 'country', 'obs_status', 'unit', 'decimal']
        data = data.drop(columns=drop, inplace=False)
        data.rename(columns={'countryiso3code': 'iso3code'}, inplace=True)
        print(data)
        conn = sqlite3.connect('yfhistoric.db')
        cursor = conn.cursor()
        data.to_sql(name, conn, if_exists='replace', index=False)
    conn.close()

    
conn.close()
# Out:
# PIB
#   iso3code  date         value   datatype agrcode
# 0      BRA  2023           NaN  agregates     PIB
# 1      BRA  2022  1.920096e+12  agregates     PIB
# 2      BRA  2021  1.649623e+12  agregates     PIB
# 3      BRA  2020  1.476107e+12  agregates     PIB
# 4      BRA  2019  1.873288e+12  agregates     PIB
# 5      BRA  2018  1.916934e+12  agregates     PIB
# 6      BRA  2017  2.063515e+12  agregates     PIB
# 7      BRA  2016  1.795693e+12  agregates     PIB
# 8      BRA  2015  1.802212e+12  agregates     PIB
# 9      BRA  2014  2.456044e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      ARG  2023           NaN  agregates     PIB
# 1      ARG  2022  6.311334e+11  agregates     PIB
# 2      ARG  2021  4.879026e+11  agregates     PIB
# 3      ARG  2020  3.857405e+11  agregates     PIB
# 4      ARG  2019  4.477547e+11  agregates     PIB
# 5      ARG  2018  5.248199e+11  agregates     PIB
# 6      ARG  2017  6.436284e+11  agregates     PIB
# 7      ARG  2016  5.575323e+11  agregates     PIB
# 8      ARG  2015  5.947493e+11  agregates     PIB
# 9      ARG  2014  5.263197e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      CHL  2023           NaN  agregates     PIB
# 1      CHL  2022  3.010247e+11  agregates     PIB
# 2      CHL  2021  3.165812e+11  agregates     PIB
# 3      CHL  2020  2.542582e+11  agregates     PIB
# 4      CHL  2019  2.785989e+11  agregates     PIB
# 5      CHL  2018  2.958576e+11  agregates     PIB
# 6      CHL  2017  2.761543e+11  agregates     PIB
# 7      CHL  2016  2.493449e+11  agregates     PIB
# 8      CHL  2015  2.424504e+11  agregates     PIB
# 9      CHL  2014  2.595610e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      COL  2023           NaN  agregates     PIB
# 1      COL  2022  3.436221e+11  agregates     PIB
# 2      COL  2021  3.185118e+11  agregates     PIB
# 3      COL  2020  2.701510e+11  agregates     PIB
# 4      COL  2019  3.230317e+11  agregates     PIB
# 5      COL  2018  3.341982e+11  agregates     PIB
# 6      COL  2017  3.118669e+11  agregates     PIB
# 7      COL  2016  2.827201e+11  agregates     PIB
# 8      COL  2015  2.934924e+11  agregates     PIB
# 9      COL  2014  3.812409e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      MEX  2023           NaN  agregates     PIB
# 1      MEX  2022  1.465854e+12  agregates     PIB
# 2      MEX  2021  1.312558e+12  agregates     PIB
# 3      MEX  2020  1.120741e+12  agregates     PIB
# 4      MEX  2019  1.305212e+12  agregates     PIB
# 5      MEX  2018  1.256300e+12  agregates     PIB
# 6      MEX  2017  1.190721e+12  agregates     PIB
# 7      MEX  2016  1.112233e+12  agregates     PIB
# 8      MEX  2015  1.213294e+12  agregates     PIB
# 9      MEX  2014  1.364508e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      PER  2023           NaN  agregates     PIB
# 1      PER  2022  2.426316e+11  agregates     PIB
# 2      PER  2021  2.237178e+11  agregates     PIB
# 3      PER  2020  2.019476e+11  agregates     PIB
# 4      PER  2019  2.283258e+11  agregates     PIB
# 5      PER  2018  2.225970e+11  agregates     PIB
# 6      PER  2017  2.110080e+11  agregates     PIB
# 7      PER  2016  1.918981e+11  agregates     PIB
# 8      PER  2015  1.898030e+11  agregates     PIB
# 9      PER  2014  2.007863e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      URY  2023           NaN  agregates     PIB
# 1      URY  2022  7.117715e+10  agregates     PIB
# 2      URY  2021  6.141227e+10  agregates     PIB
# 3      URY  2020  5.366691e+10  agregates     PIB
# 4      URY  2019  6.204859e+10  agregates     PIB
# 5      URY  2018  6.520307e+10  agregates     PIB
# 6      URY  2017  6.500605e+10  agregates     PIB
# 7      URY  2016  5.748079e+10  agregates     PIB
# 8      URY  2015  5.768033e+10  agregates     PIB
# 9      URY  2014  6.149619e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      VEN  2023           NaN  agregates     PIB
# 1      VEN  2022           NaN  agregates     PIB
# 2      VEN  2021           NaN  agregates     PIB
# 3      VEN  2020           NaN  agregates     PIB
# 4      VEN  2019           NaN  agregates     PIB
# 5      VEN  2018           NaN  agregates     PIB
# 6      VEN  2017           NaN  agregates     PIB
# 7      VEN  2016           NaN  agregates     PIB
# 8      VEN  2015           NaN  agregates     PIB
# 9      VEN  2014  4.823593e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      BLZ  2023           NaN  agregates     PIB
# 1      BLZ  2022  2.830508e+09  agregates     PIB
# 2      BLZ  2021  2.424575e+09  agregates     PIB
# 3      BLZ  2020  2.047728e+09  agregates     PIB
# 4      BLZ  2019  2.386792e+09  agregates     PIB
# 5      BLZ  2018  2.292787e+09  agregates     PIB
# 6      BLZ  2017  2.266665e+09  agregates     PIB
# 7      BLZ  2016  2.240594e+09  agregates     PIB
# 8      BLZ  2015  2.194709e+09  agregates     PIB
# 9      BLZ  2014  2.125126e+09  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      CRI  2023           NaN  agregates     PIB
# 1      CRI  2022  6.924363e+10  agregates     PIB
# 2      CRI  2021  6.496073e+10  agregates     PIB
# 3      CRI  2020  6.239561e+10  agregates     PIB
# 4      CRI  2019  6.441767e+10  agregates     PIB
# 5      CRI  2018  6.242016e+10  agregates     PIB
# 6      CRI  2017  6.051604e+10  agregates     PIB
# 7      CRI  2016  5.884702e+10  agregates     PIB
# 8      CRI  2015  5.644192e+10  agregates     PIB
# 9      CRI  2014  5.201641e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      USA  2023           NaN  agregates     PIB
# 1      USA  2022  2.543970e+13  agregates     PIB
# 2      USA  2021  2.331508e+13  agregates     PIB
# 3      USA  2020  2.106047e+13  agregates     PIB
# 4      USA  2019  2.138098e+13  agregates     PIB
# 5      USA  2018  2.053306e+13  agregates     PIB
# 6      USA  2017  1.947734e+13  agregates     PIB
# 7      USA  2016  1.869511e+13  agregates     PIB
# 8      USA  2015  1.820602e+13  agregates     PIB
# 9      USA  2014  1.755068e+13  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      GTM  2023           NaN  agregates     PIB
# 1      GTM  2022  9.500333e+10  agregates     PIB
# 2      GTM  2021  8.605308e+10  agregates     PIB
# 3      GTM  2020  7.771518e+10  agregates     PIB
# 4      GTM  2019  7.717232e+10  agregates     PIB
# 5      GTM  2018  7.332837e+10  agregates     PIB
# 6      GTM  2017  7.165375e+10  agregates     PIB
# 7      GTM  2016  6.605340e+10  agregates     PIB
# 8      GTM  2015  6.218606e+10  agregates     PIB
# 9      GTM  2014  5.785215e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      HND  2023           NaN  agregates     PIB
# 1      HND  2022  3.171770e+10  agregates     PIB
# 2      HND  2021  2.848872e+10  agregates     PIB
# 3      HND  2020  2.382786e+10  agregates     PIB
# 4      HND  2019  2.508994e+10  agregates     PIB
# 5      HND  2018  2.406775e+10  agregates     PIB
# 6      HND  2017  2.313625e+10  agregates     PIB
# 7      HND  2016  2.171760e+10  agregates     PIB
# 8      HND  2015  2.097979e+10  agregates     PIB
# 9      HND  2014  1.975653e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      NIC  2023           NaN  agregates     PIB
# 1      NIC  2022  1.567158e+10  agregates     PIB
# 2      NIC  2021  1.414588e+10  agregates     PIB
# 3      NIC  2020  1.267816e+10  agregates     PIB
# 4      NIC  2019  1.269903e+10  agregates     PIB
# 5      NIC  2018  1.302523e+10  agregates     PIB
# 6      NIC  2017  1.378592e+10  agregates     PIB
# 7      NIC  2016  1.328610e+10  agregates     PIB
# 8      NIC  2015  1.275669e+10  agregates     PIB
# 9      NIC  2014  1.188043e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      BOL  2023           NaN  agregates     PIB
# 1      BOL  2022  4.400828e+10  agregates     PIB
# 2      BOL  2021  4.040611e+10  agregates     PIB
# 3      BOL  2020  3.662984e+10  agregates     PIB
# 4      BOL  2019  4.089532e+10  agregates     PIB
# 5      BOL  2018  4.028765e+10  agregates     PIB
# 6      BOL  2017  3.750864e+10  agregates     PIB
# 7      BOL  2016  3.394113e+10  agregates     PIB
# 8      BOL  2015  3.300020e+10  agregates     PIB
# 9      BOL  2014  3.299619e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      JPN  2023           NaN  agregates     PIB
# 1      JPN  2022  4.256411e+12  agregates     PIB
# 2      JPN  2021  5.034621e+12  agregates     PIB
# 3      JPN  2020  5.055587e+12  agregates     PIB
# 4      JPN  2019  5.117994e+12  agregates     PIB
# 5      JPN  2018  5.040881e+12  agregates     PIB
# 6      JPN  2017  4.930837e+12  agregates     PIB
# 7      JPN  2016  5.003678e+12  agregates     PIB
# 8      JPN  2015  4.444931e+12  agregates     PIB
# 9      JPN  2014  4.896994e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      DEU  2023           NaN  agregates     PIB
# 1      DEU  2022  4.082469e+12  agregates     PIB
# 2      DEU  2021  4.278504e+12  agregates     PIB
# 3      DEU  2020  3.887727e+12  agregates     PIB
# 4      DEU  2019  3.889178e+12  agregates     PIB
# 5      DEU  2018  3.974443e+12  agregates     PIB
# 6      DEU  2017  3.690849e+12  agregates     PIB
# 7      DEU  2016  3.469853e+12  agregates     PIB
# 8      DEU  2015  3.357586e+12  agregates     PIB
# 9      DEU  2014  3.889093e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      USA  2023           NaN  agregates     PIB
# 1      USA  2022  2.543970e+13  agregates     PIB
# 2      USA  2021  2.331508e+13  agregates     PIB
# 3      USA  2020  2.106047e+13  agregates     PIB
# 4      USA  2019  2.138098e+13  agregates     PIB
# 5      USA  2018  2.053306e+13  agregates     PIB
# 6      USA  2017  1.947734e+13  agregates     PIB
# 7      USA  2016  1.869511e+13  agregates     PIB
# 8      USA  2015  1.820602e+13  agregates     PIB
# 9      USA  2014  1.755068e+13  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      KOR  2023           NaN  agregates     PIB
# 1      KOR  2022  1.673916e+12  agregates     PIB
# 2      KOR  2021  1.818432e+12  agregates     PIB
# 3      KOR  2020  1.644313e+12  agregates     PIB
# 4      KOR  2019  1.651423e+12  agregates     PIB
# 5      KOR  2018  1.725373e+12  agregates     PIB
# 6      KOR  2017  1.623074e+12  agregates     PIB
# 7      KOR  2016  1.499680e+12  agregates     PIB
# 8      KOR  2015  1.466039e+12  agregates     PIB
# 9      KOR  2014  1.484489e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      SWE  2023           NaN  agregates     PIB
# 1      SWE  2022  5.917181e+11  agregates     PIB
# 2      SWE  2021  6.397150e+11  agregates     PIB
# 3      SWE  2020  5.470542e+11  agregates     PIB
# 4      SWE  2019  5.338795e+11  agregates     PIB
# 5      SWE  2018  5.554554e+11  agregates     PIB
# 6      SWE  2017  5.410187e+11  agregates     PIB
# 7      SWE  2016  5.156547e+11  agregates     PIB
# 8      SWE  2015  5.051038e+11  agregates     PIB
# 9      SWE  2014  5.819640e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      ITA  2023           NaN  agregates     PIB
# 1      ITA  2022  2.049737e+12  agregates     PIB
# 2      ITA  2021  2.155360e+12  agregates     PIB
# 3      ITA  2020  1.897462e+12  agregates     PIB
# 4      ITA  2019  2.011302e+12  agregates     PIB
# 5      ITA  2018  2.091932e+12  agregates     PIB
# 6      ITA  2017  1.961796e+12  agregates     PIB
# 7      ITA  2016  1.877072e+12  agregates     PIB
# 8      ITA  2015  1.836638e+12  agregates     PIB
# 9      ITA  2014  2.162010e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      FRA  2023           NaN  agregates     PIB
# 1      FRA  2022  2.779092e+12  agregates     PIB
# 2      FRA  2021  2.959356e+12  agregates     PIB
# 3      FRA  2020  2.647419e+12  agregates     PIB
# 4      FRA  2019  2.728870e+12  agregates     PIB
# 5      FRA  2018  2.790957e+12  agregates     PIB
# 6      FRA  2017  2.595151e+12  agregates     PIB
# 7      FRA  2016  2.472964e+12  agregates     PIB
# 8      FRA  2015  2.439189e+12  agregates     PIB
# 9      FRA  2014  2.855964e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      GBR  2023           NaN  agregates     PIB
# 1      GBR  2022  3.089073e+12  agregates     PIB
# 2      GBR  2021  3.141506e+12  agregates     PIB
# 3      GBR  2020  2.697807e+12  agregates     PIB
# 4      GBR  2019  2.851407e+12  agregates     PIB
# 5      GBR  2018  2.871340e+12  agregates     PIB
# 6      GBR  2017  2.680148e+12  agregates     PIB
# 7      GBR  2016  2.689107e+12  agregates     PIB
# 8      GBR  2015  2.927911e+12  agregates     PIB
# 9      GBR  2014  3.064708e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      CHN  2023           NaN  agregates     PIB
# 1      CHN  2022  1.796317e+13  agregates     PIB
# 2      CHN  2021  1.782046e+13  agregates     PIB
# 3      CHN  2020  1.468774e+13  agregates     PIB
# 4      CHN  2019  1.427997e+13  agregates     PIB
# 5      CHN  2018  1.389491e+13  agregates     PIB
# 6      CHN  2017  1.231049e+13  agregates     PIB
# 7      CHN  2016  1.123331e+13  agregates     PIB
# 8      CHN  2015  1.106157e+13  agregates     PIB
# 9      CHN  2014  1.047562e+13  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      IND  2023           NaN  agregates     PIB
# 1      IND  2022  3.416646e+12  agregates     PIB
# 2      IND  2021  3.150307e+12  agregates     PIB
# 3      IND  2020  2.671595e+12  agregates     PIB
# 4      IND  2019  2.835606e+12  agregates     PIB
# 5      IND  2018  2.702930e+12  agregates     PIB
# 6      IND  2017  2.651474e+12  agregates     PIB
# 7      IND  2016  2.294797e+12  agregates     PIB
# 8      IND  2015  2.103588e+12  agregates     PIB
# 9      IND  2014  2.039126e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      ESP  2023           NaN  agregates     PIB
# 1      ESP  2022  1.417800e+12  agregates     PIB
# 2      ESP  2021  1.445652e+12  agregates     PIB
# 3      ESP  2020  1.278129e+12  agregates     PIB
# 4      ESP  2019  1.394320e+12  agregates     PIB
# 5      ESP  2018  1.421703e+12  agregates     PIB
# 6      ESP  2017  1.313245e+12  agregates     PIB
# 7      ESP  2016  1.233555e+12  agregates     PIB
# 8      ESP  2015  1.196157e+12  agregates     PIB
# 9      ESP  2014  1.371821e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      IRL  2023           NaN  agregates     PIB
# 1      IRL  2022  5.331400e+11  agregates     PIB
# 2      IRL  2021  5.133918e+11  agregates     PIB
# 3      IRL  2020  4.286087e+11  agregates     PIB
# 4      IRL  2019  3.989330e+11  agregates     PIB
# 5      IRL  2018  3.866934e+11  agregates     PIB
# 6      IRL  2017  3.372418e+11  agregates     PIB
# 7      IRL  2016  2.985593e+11  agregates     PIB
# 8      IRL  2015  2.923642e+11  agregates     PIB
# 9      IRL  2014  2.596819e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      SAU  2023           NaN  agregates     PIB
# 1      SAU  2022  1.108572e+12  agregates     PIB
# 2      SAU  2021  8.741561e+11  agregates     PIB
# 3      SAU  2020  7.342712e+11  agregates     PIB
# 4      SAU  2019  8.385647e+11  agregates     PIB
# 5      SAU  2018  8.465838e+11  agregates     PIB
# 6      SAU  2017  7.149947e+11  agregates     PIB
# 7      SAU  2016  6.659999e+11  agregates     PIB
# 8      SAU  2015  6.694844e+11  agregates     PIB
# 9      SAU  2014  7.666059e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      NLD  2023           NaN  agregates     PIB
# 1      NLD  2022  1.009399e+12  agregates     PIB
# 2      NLD  2021  1.029678e+12  agregates     PIB
# 3      NLD  2020  9.097935e+11  agregates     PIB
# 4      NLD  2019  9.101943e+11  agregates     PIB
# 5      NLD  2018  9.140434e+11  agregates     PIB
# 6      NLD  2017  8.338696e+11  agregates     PIB
# 7      NLD  2016  7.840604e+11  agregates     PIB
# 8      NLD  2015  7.655728e+11  agregates     PIB
# 9      NLD  2014  8.921680e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      RUS  2023           NaN  agregates     PIB
# 1      RUS  2022  2.240422e+12  agregates     PIB
# 2      RUS  2021  1.836892e+12  agregates     PIB
# 3      RUS  2020  1.493076e+12  agregates     PIB
# 4      RUS  2019  1.693115e+12  agregates     PIB
# 5      RUS  2018  1.657329e+12  agregates     PIB
# 6      RUS  2017  1.574199e+12  agregates     PIB
# 7      RUS  2016  1.276786e+12  agregates     PIB
# 8      RUS  2015  1.363482e+12  agregates     PIB
# 9      RUS  2014  2.059242e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      KWT  2023           NaN  agregates     PIB
# 1      KWT  2022  1.753633e+11  agregates     PIB
# 2      KWT  2021  1.373843e+11  agregates     PIB
# 3      KWT  2020  1.059488e+11  agregates     PIB
# 4      KWT  2019  1.361918e+11  agregates     PIB
# 5      KWT  2018  1.382025e+11  agregates     PIB
# 6      KWT  2017  1.206875e+11  agregates     PIB
# 7      KWT  2016  1.094063e+11  agregates     PIB
# 8      KWT  2015  1.145856e+11  agregates     PIB
# 9      KWT  2014  1.626503e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      ARE  2023           NaN  agregates     PIB
# 1      ARE  2022  5.070640e+11  agregates     PIB
# 2      ARE  2021  4.151788e+11  agregates     PIB
# 3      ARE  2020  3.494730e+11  agregates     PIB
# 4      ARE  2019  4.179897e+11  agregates     PIB
# 5      ARE  2018  4.270494e+11  agregates     PIB
# 6      ARE  2017  3.905168e+11  agregates     PIB
# 7      ARE  2016  3.692553e+11  agregates     PIB
# 8      ARE  2015  3.702755e+11  agregates     PIB
# 9      ARE  2014  4.141054e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      NOR  2023           NaN  agregates     PIB
# 1      NOR  2022  5.933490e+11  agregates     PIB
# 2      NOR  2021  5.033680e+11  agregates     PIB
# 3      NOR  2020  3.676334e+11  agregates     PIB
# 4      NOR  2019  4.087428e+11  agregates     PIB
# 5      NOR  2018  4.397886e+11  agregates     PIB
# 6      NOR  2017  4.017453e+11  agregates     PIB
# 7      NOR  2016  3.709565e+11  agregates     PIB
# 8      NOR  2015  3.881595e+11  agregates     PIB
# 9      NOR  2014  5.017365e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      IDN  2023           NaN  agregates     PIB
# 1      IDN  2022  1.319100e+12  agregates     PIB
# 2      IDN  2021  1.186505e+12  agregates     PIB
# 3      IDN  2020  1.059055e+12  agregates     PIB
# 4      IDN  2019  1.119100e+12  agregates     PIB
# 5      IDN  2018  1.042272e+12  agregates     PIB
# 6      IDN  2017  1.015619e+12  agregates     PIB
# 7      IDN  2016  9.318774e+11  agregates     PIB
# 8      IDN  2015  8.608542e+11  agregates     PIB
# 9      IDN  2014  8.908148e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      CAN  2023           NaN  agregates     PIB
# 1      CAN  2022  2.161483e+12  agregates     PIB
# 2      CAN  2021  2.007472e+12  agregates     PIB
# 3      CAN  2020  1.655685e+12  agregates     PIB
# 4      CAN  2019  1.743725e+12  agregates     PIB
# 5      CAN  2018  1.725329e+12  agregates     PIB
# 6      CAN  2017  1.649266e+12  agregates     PIB
# 7      CAN  2016  1.527995e+12  agregates     PIB
# 8      CAN  2015  1.556509e+12  agregates     PIB
# 9      CAN  2014  1.805750e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      AUS  2023           NaN  agregates     PIB
# 1      AUS  2022  1.692957e+12  agregates     PIB
# 2      AUS  2021  1.559034e+12  agregates     PIB
# 3      AUS  2020  1.330382e+12  agregates     PIB
# 4      AUS  2019  1.394671e+12  agregates     PIB
# 5      AUS  2018  1.429734e+12  agregates     PIB
# 6      AUS  2017  1.326882e+12  agregates     PIB
# 7      AUS  2016  1.207581e+12  agregates     PIB
# 8      AUS  2015  1.351769e+12  agregates     PIB
# 9      AUS  2014  1.468598e+12  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      CHE  2023           NaN  agregates     PIB
# 1      CHE  2022  8.184266e+11  agregates     PIB
# 2      CHE  2021  8.134088e+11  agregates     PIB
# 3      CHE  2020  7.419994e+11  agregates     PIB
# 4      CHE  2019  7.213691e+11  agregates     PIB
# 5      CHE  2018  7.255687e+11  agregates     PIB
# 6      CHE  2017  6.952008e+11  agregates     PIB
# 7      CHE  2016  6.878955e+11  agregates     PIB
# 8      CHE  2015  6.941182e+11  agregates     PIB
# 9      CHE  2014  7.265378e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      ZAF  2023           NaN  agregates     PIB
# 1      ZAF  2022  4.052709e+11  agregates     PIB
# 2      ZAF  2021  4.201178e+11  agregates     PIB
# 3      ZAF  2020  3.382914e+11  agregates     PIB
# 4      ZAF  2019  3.893300e+11  agregates     PIB
# 5      ZAF  2018  4.052607e+11  agregates     PIB
# 6      ZAF  2017  3.814488e+11  agregates     PIB
# 7      ZAF  2016  3.235855e+11  agregates     PIB
# 8      ZAF  2015  3.467098e+11  agregates     PIB
# 9      ZAF  2014  3.811989e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      DNK  2023           NaN  agregates     PIB
# 1      DNK  2022  4.001672e+11  agregates     PIB
# 2      DNK  2021  4.056880e+11  agregates     PIB
# 3      DNK  2020  3.547627e+11  agregates     PIB
# 4      DNK  2019  3.464987e+11  agregates     PIB
# 5      DNK  2018  3.568412e+11  agregates     PIB
# 6      DNK  2017  3.321211e+11  agregates     PIB
# 7      DNK  2016  3.131159e+11  agregates     PIB
# 8      DNK  2015  3.026731e+11  agregates     PIB
# 9      DNK  2014  3.529936e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      ISR  2023           NaN  agregates     PIB
# 1      ISR  2022  5.250024e+11  agregates     PIB
# 2      ISR  2021  4.885265e+11  agregates     PIB
# 3      ISR  2020  4.132677e+11  agregates     PIB
# 4      ISR  2019  4.024705e+11  agregates     PIB
# 5      ISR  2018  3.766915e+11  agregates     PIB
# 6      ISR  2017  3.582454e+11  agregates     PIB
# 7      ISR  2016  3.221028e+11  agregates     PIB
# 8      ISR  2015  3.034143e+11  agregates     PIB
# 9      ISR  2014  3.143301e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      PRT  2023           NaN  agregates     PIB
# 1      PRT  2022  2.551967e+11  agregates     PIB
# 2      PRT  2021  2.555348e+11  agregates     PIB
# 3      PRT  2020  2.290319e+11  agregates     PIB
# 4      PRT  2019  2.399869e+11  agregates     PIB
# 5      PRT  2018  2.423131e+11  agregates     PIB
# 6      PRT  2017  2.213579e+11  agregates     PIB
# 7      PRT  2016  2.064262e+11  agregates     PIB
# 8      PRT  2015  1.993941e+11  agregates     PIB
# 9      PRT  2014  2.299020e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      HKG  2023           NaN  agregates     PIB
# 1      HKG  2022  3.598386e+11  agregates     PIB
# 2      HKG  2021  3.689114e+11  agregates     PIB
# 3      HKG  2020  3.449431e+11  agregates     PIB
# 4      HKG  2019  3.630745e+11  agregates     PIB
# 5      HKG  2018  3.617311e+11  agregates     PIB
# 6      HKG  2017  3.412733e+11  agregates     PIB
# 7      HKG  2016  3.208603e+11  agregates     PIB
# 8      HKG  2015  3.093856e+11  agregates     PIB
# 9      HKG  2014  2.914600e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      PRY  2023           NaN  agregates     PIB
# 1      PRY  2022  4.172230e+10  agregates     PIB
# 2      PRY  2021  3.995090e+10  agregates     PIB
# 3      PRY  2020  3.543218e+10  agregates     PIB
# 4      PRY  2019  3.792534e+10  agregates     PIB
# 5      PRY  2018  4.022545e+10  agregates     PIB
# 6      PRY  2017  3.899713e+10  agregates     PIB
# 7      PRY  2016  3.608970e+10  agregates     PIB
# 8      PRY  2015  3.621145e+10  agregates     PIB
# 9      PRY  2014  4.037793e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      MNG  2023           NaN  agregates     PIB
# 1      MNG  2022  1.714647e+10  agregates     PIB
# 2      MNG  2021  1.528644e+10  agregates     PIB
# 3      MNG  2020  1.331298e+10  agregates     PIB
# 4      MNG  2019  1.420636e+10  agregates     PIB
# 5      MNG  2018  1.317809e+10  agregates     PIB
# 6      MNG  2017  1.148085e+10  agregates     PIB
# 7      MNG  2016  1.118135e+10  agregates     PIB
# 8      MNG  2015  1.161989e+10  agregates     PIB
# 9      MNG  2014  1.222651e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      CUB  2023           NaN  agregates     PIB
# 1      CUB  2022           NaN  agregates     PIB
# 2      CUB  2021           NaN  agregates     PIB
# 3      CUB  2020  1.073518e+11  agregates     PIB
# 4      CUB  2019  1.034276e+11  agregates     PIB
# 5      CUB  2018  1.000500e+11  agregates     PIB
# 6      CUB  2017  9.685065e+10  agregates     PIB
# 7      CUB  2016  9.137041e+10  agregates     PIB
# 8      CUB  2015  8.713280e+10  agregates     PIB
# 9      CUB  2014  8.065610e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      ECU  2023           NaN  agregates     PIB
# 1      ECU  2022  1.150495e+11  agregates     PIB
# 2      ECU  2021  1.061659e+11  agregates     PIB
# 3      ECU  2020  9.929112e+10  agregates     PIB
# 4      ECU  2019  1.081080e+11  agregates     PIB
# 5      ECU  2018  1.075620e+11  agregates     PIB
# 6      ECU  2017  1.042959e+11  agregates     PIB
# 7      ECU  2016  9.993770e+10  agregates     PIB
# 8      ECU  2015  9.929038e+10  agregates     PIB
# 9      ECU  2014  1.017263e+11  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      SLV  2023           NaN  agregates     PIB
# 1      SLV  2022  3.248872e+10  agregates     PIB
# 2      SLV  2021  2.945124e+10  agregates     PIB
# 3      SLV  2020  2.493008e+10  agregates     PIB
# 4      SLV  2019  2.688114e+10  agregates     PIB
# 5      SLV  2018  2.602085e+10  agregates     PIB
# 6      SLV  2017  2.497919e+10  agregates     PIB
# 7      SLV  2016  2.419143e+10  agregates     PIB
# 8      SLV  2015  2.343824e+10  agregates     PIB
# 9      SLV  2014  2.259347e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      GUY  2023           NaN  agregates     PIB
# 1      GUY  2022  1.471839e+10  agregates     PIB
# 2      GUY  2021  8.041362e+09  agregates     PIB
# 3      GUY  2020  5.471257e+09  agregates     PIB
# 4      GUY  2019  5.173760e+09  agregates     PIB
# 5      GUY  2018  4.787637e+09  agregates     PIB
# 6      GUY  2017  4.748174e+09  agregates     PIB
# 7      GUY  2016  4.482697e+09  agregates     PIB
# 8      GUY  2015  4.279840e+09  agregates     PIB
# 9      GUY  2014  4.127660e+09  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      HTI  2023           NaN  agregates     PIB
# 1      HTI  2022  2.025355e+10  agregates     PIB
# 2      HTI  2021  2.087741e+10  agregates     PIB
# 3      HTI  2020  1.450822e+10  agregates     PIB
# 4      HTI  2019  1.501609e+10  agregates     PIB
# 5      HTI  2018  1.640386e+10  agregates     PIB
# 6      HTI  2017  1.509336e+10  agregates     PIB
# 7      HTI  2016  1.406928e+10  agregates     PIB
# 8      HTI  2015  1.484963e+10  agregates     PIB
# 9      HTI  2014  1.514688e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      PAN  2023           NaN  agregates     PIB
# 1      PAN  2022  7.652251e+10  agregates     PIB
# 2      PAN  2021  6.740674e+10  agregates     PIB
# 3      PAN  2020  5.708684e+10  agregates     PIB
# 4      PAN  2019  6.972179e+10  agregates     PIB
# 5      PAN  2018  6.729417e+10  agregates     PIB
# 6      PAN  2017  6.220270e+10  agregates     PIB
# 7      PAN  2016  5.790770e+10  agregates     PIB
# 8      PAN  2015  5.409180e+10  agregates     PIB
# 9      PAN  2014  4.992140e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      DOM  2023           NaN  agregates     PIB
# 1      DOM  2022  1.135374e+11  agregates     PIB
# 2      DOM  2021  9.424343e+10  agregates     PIB
# 3      DOM  2020  7.884466e+10  agregates     PIB
# 4      DOM  2019  8.894137e+10  agregates     PIB
# 5      DOM  2018  8.555539e+10  agregates     PIB
# 6      DOM  2017  7.999805e+10  agregates     PIB
# 7      DOM  2016  7.570465e+10  agregates     PIB
# 8      DOM  2015  7.116483e+10  agregates     PIB
# 9      DOM  2014  6.717996e+10  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      SUR  2023           NaN  agregates     PIB
# 1      SUR  2022  3.620988e+09  agregates     PIB
# 2      SUR  2021  3.081402e+09  agregates     PIB
# 3      SUR  2020  2.911807e+09  agregates     PIB
# 4      SUR  2019  4.016041e+09  agregates     PIB
# 5      SUR  2018  3.996199e+09  agregates     PIB
# 6      SUR  2017  3.591679e+09  agregates     PIB
# 7      SUR  2016  3.317422e+09  agregates     PIB
# 8      SUR  2015  5.126238e+09  agregates     PIB
# 9      SUR  2014  5.240606e+09  agregates     PIB
#   iso3code  date         value   datatype agrcode
# 0      RUS  2023           NaN  agregates     PIB
# 1      RUS  2022  2.240422e+12  agregates     PIB
# 2      RUS  2021  1.836892e+12  agregates     PIB
# 3      RUS  2020  1.493076e+12  agregates     PIB
# 4      RUS  2019  1.693115e+12  agregates     PIB
# 5      RUS  2018  1.657329e+12  agregates     PIB
# 6      RUS  2017  1.574199e+12  agregates     PIB
# 7      RUS  2016  1.276786e+12  agregates     PIB
# 8      RUS  2015  1.363482e+12  agregates     PIB
# 9      RUS  2014  2.059242e+12  agregates     PIB
# PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      BRA  2023           NaN  agregates  PIBPCAPTA
# 1      BRA  2022   8917.674911  agregates  PIBPCAPTA
# 2      BRA  2021   7696.784830  agregates  PIBPCAPTA
# 3      BRA  2020   6923.699912  agregates  PIBPCAPTA
# 4      BRA  2019   8845.324149  agregates  PIBPCAPTA
# 5      BRA  2018   9121.020995  agregates  PIBPCAPTA
# 6      BRA  2017   9896.718895  agregates  PIBPCAPTA
# 7      BRA  2016   8680.736469  agregates  PIBPCAPTA
# 8      BRA  2015   8783.215424  agregates  PIBPCAPTA
# 9      BRA  2014  12071.404464  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      ARG  2023           NaN  agregates  PIBPCAPTA
# 1      ARG  2022  13650.604629  agregates  PIBPCAPTA
# 2      ARG  2021  10650.860460  agregates  PIBPCAPTA
# 3      ARG  2020   8500.837939  agregates  PIBPCAPTA
# 4      ARG  2019   9963.674162  agregates  PIBPCAPTA
# 5      ARG  2018  11795.162745  agregates  PIBPCAPTA
# 6      ARG  2017  14613.035649  agregates  PIBPCAPTA
# 7      ARG  2016  12790.264140  agregates  PIBPCAPTA
# 8      ARG  2015  13789.060425  agregates  PIBPCAPTA
# 9      ARG  2014  12334.798245  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      CHL  2023           NaN  agregates  PIBPCAPTA
# 1      CHL  2022  15355.479740  agregates  PIBPCAPTA
# 2      CHL  2021  16240.607776  agregates  PIBPCAPTA
# 3      CHL  2020  13173.784794  agregates  PIBPCAPTA
# 4      CHL  2019  14632.690308  agregates  PIBPCAPTA
# 5      CHL  2018  15820.033357  agregates  PIBPCAPTA
# 6      CHL  2017  15034.058425  agregates  PIBPCAPTA
# 7      CHL  2016  13788.240016  agregates  PIBPCAPTA
# 8      CHL  2015  13567.357217  agregates  PIBPCAPTA
# 9      CHL  2014  14675.150873  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      COL  2023          NaN  agregates  PIBPCAPTA
# 1      COL  2022  6624.165393  agregates  PIBPCAPTA
# 2      COL  2021  6182.707099  agregates  PIBPCAPTA
# 3      COL  2020  5304.289129  agregates  PIBPCAPTA
# 4      COL  2019  6436.509215  agregates  PIBPCAPTA
# 5      COL  2018  6782.037920  agregates  PIBPCAPTA
# 6      COL  2017  6449.970987  agregates  PIBPCAPTA
# 7      COL  2016  5936.261022  agregates  PIBPCAPTA
# 8      COL  2015  6228.651622  agregates  PIBPCAPTA
# 9      COL  2014  8167.472842  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      MEX  2023           NaN  agregates  PIBPCAPTA
# 1      MEX  2022  11496.522872  agregates  PIBPCAPTA
# 2      MEX  2021  10359.149863  agregates  PIBPCAPTA
# 3      MEX  2020   8894.890650  agregates  PIBPCAPTA
# 4      MEX  2019  10434.578365  agregates  PIBPCAPTA
# 5      MEX  2018  10130.320698  agregates  PIBPCAPTA
# 6      MEX  2017   9693.330091  agregates  PIBPCAPTA
# 7      MEX  2016   9152.737223  agregates  PIBPCAPTA
# 8      MEX  2015  10098.173181  agregates  PIBPCAPTA
# 9      MEX  2014  11490.021690  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      PER  2023          NaN  agregates  PIBPCAPTA
# 1      PER  2022  7125.829931  agregates  PIBPCAPTA
# 2      PER  2021  6635.464148  agregates  PIBPCAPTA
# 3      PER  2020  6063.626923  agregates  PIBPCAPTA
# 4      PER  2019  6955.880824  agregates  PIBPCAPTA
# 5      PER  2018  6912.103988  agregates  PIBPCAPTA
# 6      PER  2017  6676.308793  agregates  PIBPCAPTA
# 7      PER  2016  6163.860425  agregates  PIBPCAPTA
# 8      PER  2015  6180.119268  agregates  PIBPCAPTA
# 9      PER  2014  6614.830820  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      URY  2023           NaN  agregates  PIBPCAPTA
# 1      URY  2022  20795.042354  agregates  PIBPCAPTA
# 2      URY  2021  17923.995333  agregates  PIBPCAPTA
# 3      URY  2020  15650.499303  agregates  PIBPCAPTA
# 4      URY  2019  18098.361549  agregates  PIBPCAPTA
# 5      URY  2018  19026.049817  agregates  PIBPCAPTA
# 6      URY  2017  18995.397020  agregates  PIBPCAPTA
# 7      URY  2016  16837.940380  agregates  PIBPCAPTA
# 8      URY  2015  16950.753169  agregates  PIBPCAPTA
# 9      URY  2014  18131.578847  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      VEN  2023           NaN  agregates  PIBPCAPTA
# 1      VEN  2022           NaN  agregates  PIBPCAPTA
# 2      VEN  2021           NaN  agregates  PIBPCAPTA
# 3      VEN  2020           NaN  agregates  PIBPCAPTA
# 4      VEN  2019           NaN  agregates  PIBPCAPTA
# 5      VEN  2018           NaN  agregates  PIBPCAPTA
# 6      VEN  2017           NaN  agregates  PIBPCAPTA
# 7      VEN  2016           NaN  agregates  PIBPCAPTA
# 8      VEN  2015           NaN  agregates  PIBPCAPTA
# 9      VEN  2014  15975.729375  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      BLZ  2023          NaN  agregates  PIBPCAPTA
# 1      BLZ  2022  6984.216960  agregates  PIBPCAPTA
# 2      BLZ  2021  6060.968223  agregates  PIBPCAPTA
# 3      BLZ  2020  5185.158070  agregates  PIBPCAPTA
# 4      BLZ  2019  6134.215233  agregates  PIBPCAPTA
# 5      BLZ  2018  6001.024262  agregates  PIBPCAPTA
# 6      BLZ  2017  6049.391948  agregates  PIBPCAPTA
# 7      BLZ  2016  6099.957102  agregates  PIBPCAPTA
# 8      BLZ  2015  6098.600080  agregates  PIBPCAPTA
# 9      BLZ  2014  6031.548402  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      CRI  2023           NaN  agregates  PIBPCAPTA
# 1      CRI  2022  13365.356399  agregates  PIBPCAPTA
# 2      CRI  2021  12604.048837  agregates  PIBPCAPTA
# 3      CRI  2020  12179.256674  agregates  PIBPCAPTA
# 4      CRI  2019  12669.341155  agregates  PIBPCAPTA
# 5      CRI  2018  12383.149952  agregates  PIBPCAPTA
# 6      CRI  2017  12118.133625  agregates  PIBPCAPTA
# 7      CRI  2016  11899.813983  agregates  PIBPCAPTA
# 8      CRI  2015  11529.955173  agregates  PIBPCAPTA
# 9      CRI  2014  10737.678881  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      USA  2023           NaN  agregates  PIBPCAPTA
# 1      USA  2022  76329.582265  agregates  PIBPCAPTA
# 2      USA  2021  70219.472454  agregates  PIBPCAPTA
# 3      USA  2020  63528.634303  agregates  PIBPCAPTA
# 4      USA  2019  65120.394663  agregates  PIBPCAPTA
# 5      USA  2018  62823.309438  agregates  PIBPCAPTA
# 6      USA  2017  59907.754261  agregates  PIBPCAPTA
# 7      USA  2016  57866.744934  agregates  PIBPCAPTA
# 8      USA  2015  56762.729452  agregates  PIBPCAPTA
# 9      USA  2014  55123.849787  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      GTM  2023          NaN  agregates  PIBPCAPTA
# 1      GTM  2022  5473.208564  agregates  PIBPCAPTA
# 2      GTM  2021  5029.477555  agregates  PIBPCAPTA
# 3      GTM  2020  4609.897258  agregates  PIBPCAPTA
# 4      GTM  2019  4647.807541  agregates  PIBPCAPTA
# 5      GTM  2018  4485.752135  agregates  PIBPCAPTA
# 6      GTM  2017  4454.024509  agregates  PIBPCAPTA
# 7      GTM  2016  4173.281349  agregates  PIBPCAPTA
# 8      GTM  2015  3994.629085  agregates  PIBPCAPTA
# 9      GTM  2014  3779.626205  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      HND  2023          NaN  agregates  PIBPCAPTA
# 1      HND  2022  3040.173046  agregates  PIBPCAPTA
# 2      HND  2021  2771.722654  agregates  PIBPCAPTA
# 3      HND  2020  2354.121434  agregates  PIBPCAPTA
# 4      HND  2019  2519.366185  agregates  PIBPCAPTA
# 5      HND  2018  2457.686042  agregates  PIBPCAPTA
# 6      HND  2017  2403.306088  agregates  PIBPCAPTA
# 7      HND  2016  2295.536270  agregates  PIBPCAPTA
# 8      HND  2015  2257.225284  agregates  PIBPCAPTA
# 9      HND  2014  2164.424550  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      NIC  2023          NaN  agregates  PIBPCAPTA
# 1      NIC  2022  2255.425995  agregates  PIBPCAPTA
# 2      NIC  2021  2064.929246  agregates  PIBPCAPTA
# 3      NIC  2020  1876.607378  agregates  PIBPCAPTA
# 4      NIC  2019  1905.638328  agregates  PIBPCAPTA
# 5      NIC  2018  1981.858367  agregates  PIBPCAPTA
# 6      NIC  2017  2127.282818  agregates  PIBPCAPTA
# 7      NIC  2016  2079.451027  agregates  PIBPCAPTA
# 8      NIC  2015  2025.321432  agregates  PIBPCAPTA
# 9      NIC  2014  1913.521348  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      BOL  2023          NaN  agregates  PIBPCAPTA
# 1      BOL  2022  3600.121635  agregates  PIBPCAPTA
# 2      BOL  2021  3345.023002  agregates  PIBPCAPTA
# 3      BOL  2020  3068.812555  agregates  PIBPCAPTA
# 4      BOL  2019  3472.380831  agregates  PIBPCAPTA
# 5      BOL  2018  3471.006951  agregates  PIBPCAPTA
# 6      BOL  2017  3280.008214  agregates  PIBPCAPTA
# 7      BOL  2016  3013.502707  agregates  PIBPCAPTA
# 8      BOL  2015  2975.648811  agregates  PIBPCAPTA
# 9      BOL  2014  3022.462884  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      JPN  2023           NaN  agregates  PIBPCAPTA
# 1      JPN  2022  34017.271808  agregates  PIBPCAPTA
# 2      JPN  2021  40058.537328  agregates  PIBPCAPTA
# 3      JPN  2020  40040.765506  agregates  PIBPCAPTA
# 4      JPN  2019  40415.956765  agregates  PIBPCAPTA
# 5      JPN  2018  39751.133098  agregates  PIBPCAPTA
# 6      JPN  2017  38834.052934  agregates  PIBPCAPTA
# 7      JPN  2016  39375.473162  agregates  PIBPCAPTA
# 8      JPN  2015  34960.639384  agregates  PIBPCAPTA
# 9      JPN  2014  38475.395246  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      DEU  2023           NaN  agregates  PIBPCAPTA
# 1      DEU  2022  48717.991140  agregates  PIBPCAPTA
# 2      DEU  2021  51426.750365  agregates  PIBPCAPTA
# 3      DEU  2020  46749.476228  agregates  PIBPCAPTA
# 4      DEU  2019  46805.138433  agregates  PIBPCAPTA
# 5      DEU  2018  47939.278288  agregates  PIBPCAPTA
# 6      DEU  2017  44652.589172  agregates  PIBPCAPTA
# 7      DEU  2016  42136.120791  agregates  PIBPCAPTA
# 8      DEU  2015  41103.256436  agregates  PIBPCAPTA
# 9      DEU  2014  48023.869985  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      USA  2023           NaN  agregates  PIBPCAPTA
# 1      USA  2022  76329.582265  agregates  PIBPCAPTA
# 2      USA  2021  70219.472454  agregates  PIBPCAPTA
# 3      USA  2020  63528.634303  agregates  PIBPCAPTA
# 4      USA  2019  65120.394663  agregates  PIBPCAPTA
# 5      USA  2018  62823.309438  agregates  PIBPCAPTA
# 6      USA  2017  59907.754261  agregates  PIBPCAPTA
# 7      USA  2016  57866.744934  agregates  PIBPCAPTA
# 8      USA  2015  56762.729452  agregates  PIBPCAPTA
# 9      USA  2014  55123.849787  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      KOR  2023           NaN  agregates  PIBPCAPTA
# 1      KOR  2022  32422.574486  agregates  PIBPCAPTA
# 2      KOR  2021  35142.264267  agregates  PIBPCAPTA
# 3      KOR  2020  31721.298914  agregates  PIBPCAPTA
# 4      KOR  2019  31902.416905  agregates  PIBPCAPTA
# 5      KOR  2018  33447.156284  agregates  PIBPCAPTA
# 6      KOR  2017  31600.735874  agregates  PIBPCAPTA
# 7      KOR  2016  29280.440317  agregates  PIBPCAPTA
# 8      KOR  2015  28737.439171  agregates  PIBPCAPTA
# 9      KOR  2014  29252.931238  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      SWE  2023           NaN  agregates  PIBPCAPTA
# 1      SWE  2022  56424.284699  agregates  PIBPCAPTA
# 2      SWE  2021  61417.680877  agregates  PIBPCAPTA
# 3      SWE  2020  52837.903978  agregates  PIBPCAPTA
# 4      SWE  2019  51939.429745  agregates  PIBPCAPTA
# 5      SWE  2018  54589.060386  agregates  PIBPCAPTA
# 6      SWE  2017  53791.508730  agregates  PIBPCAPTA
# 7      SWE  2016  51965.157153  agregates  PIBPCAPTA
# 8      SWE  2015  51545.483610  agregates  PIBPCAPTA
# 9      SWE  2014  60020.360458  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      ITA  2023           NaN  agregates  PIBPCAPTA
# 1      ITA  2022  34776.423234  agregates  PIBPCAPTA
# 2      ITA  2021  36449.258338  agregates  PIBPCAPTA
# 3      ITA  2020  31922.919163  agregates  PIBPCAPTA
# 4      ITA  2019  33673.750963  agregates  PIBPCAPTA
# 5      ITA  2018  34622.169666  agregates  PIBPCAPTA
# 6      ITA  2017  32406.720315  agregates  PIBPCAPTA
# 7      ITA  2016  30960.731509  agregates  PIBPCAPTA
# 8      ITA  2015  30242.386135  agregates  PIBPCAPTA
# 9      ITA  2014  35565.721377  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      FRA  2023           NaN  agregates  PIBPCAPTA
# 1      FRA  2022  40886.253268  agregates  PIBPCAPTA
# 2      FRA  2021  43671.308410  agregates  PIBPCAPTA
# 3      FRA  2020  39179.744260  agregates  PIBPCAPTA
# 4      FRA  2019  40494.898294  agregates  PIBPCAPTA
# 5      FRA  2018  41557.854859  agregates  PIBPCAPTA
# 6      FRA  2017  38781.049487  agregates  PIBPCAPTA
# 7      FRA  2016  37062.533572  agregates  PIBPCAPTA
# 8      FRA  2015  36652.922305  agregates  PIBPCAPTA
# 9      FRA  2014  43068.548724  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      GBR  2023           NaN  agregates  PIBPCAPTA
# 1      GBR  2022  46125.255751  agregates  PIBPCAPTA
# 2      GBR  2021  46869.759058  agregates  PIBPCAPTA
# 3      GBR  2020  40217.009012  agregates  PIBPCAPTA
# 4      GBR  2019  42662.535374  agregates  PIBPCAPTA
# 5      GBR  2018  43203.814106  agregates  PIBPCAPTA
# 6      GBR  2017  40572.121482  agregates  PIBPCAPTA
# 7      GBR  2016  40985.235138  agregates  PIBPCAPTA
# 8      GBR  2015  44964.391144  agregates  PIBPCAPTA
# 9      GBR  2014  47439.616590  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      CHN  2023           NaN  agregates  PIBPCAPTA
# 1      CHN  2022  12720.216318  agregates  PIBPCAPTA
# 2      CHN  2021  12617.505104  agregates  PIBPCAPTA
# 3      CHN  2020  10408.719554  agregates  PIBPCAPTA
# 4      CHN  2019  10143.860221  agregates  PIBPCAPTA
# 5      CHN  2018   9905.406383  agregates  PIBPCAPTA
# 6      CHN  2017   8817.045608  agregates  PIBPCAPTA
# 7      CHN  2016   8094.390167  agregates  PIBPCAPTA
# 8      CHN  2015   8016.445595  agregates  PIBPCAPTA
# 9      CHN  2014   7636.074340  agregates  PIBPCAPTA
#   iso3code  date        value   datatype    agrcode
# 0      IND  2023          NaN  agregates  PIBPCAPTA
# 1      IND  2022  2410.888021  agregates  PIBPCAPTA
# 2      IND  2021  2238.127142  agregates  PIBPCAPTA
# 3      IND  2020  1913.219733  agregates  PIBPCAPTA
# 4      IND  2019  2050.163800  agregates  PIBPCAPTA
# 5      IND  2018  1974.377731  agregates  PIBPCAPTA
# 6      IND  2017  1957.969813  agregates  PIBPCAPTA
# 7      IND  2016  1714.279537  agregates  PIBPCAPTA
# 8      IND  2015  1590.174331  agregates  PIBPCAPTA
# 9      IND  2014  1559.863779  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      ESP  2023           NaN  agregates  PIBPCAPTA
# 1      ESP  2022  29674.544286  agregates  PIBPCAPTA
# 2      ESP  2021  30488.820953  agregates  PIBPCAPTA
# 3      ESP  2020  26984.296277  agregates  PIBPCAPTA
# 4      ESP  2019  29581.518551  agregates  PIBPCAPTA
# 5      ESP  2018  30379.721113  agregates  PIBPCAPTA
# 6      ESP  2017  28185.321367  agregates  PIBPCAPTA
# 7      ESP  2016  26537.159489  agregates  PIBPCAPTA
# 8      ESP  2015  25754.361029  agregates  PIBPCAPTA
# 9      ESP  2014  29513.651180  agregates  PIBPCAPTA
#   iso3code  date          value   datatype    agrcode
# 0      IRL  2023            NaN  agregates  PIBPCAPTA
# 1      IRL  2022  103983.291336  agregates  PIBPCAPTA
# 2      IRL  2021  102001.798249  agregates  PIBPCAPTA
# 3      IRL  2020   85973.088488  agregates  PIBPCAPTA
# 4      IRL  2019   80848.301902  agregates  PIBPCAPTA
# 5      IRL  2018   79446.939109  agregates  PIBPCAPTA
# 6      IRL  2017   70150.737016  agregates  PIBPCAPTA
# 7      IRL  2016   62784.065688  agregates  PIBPCAPTA
# 8      IRL  2015   62179.264266  agregates  PIBPCAPTA
# 9      IRL  2014   55752.764984  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      SAU  2023           NaN  agregates  PIBPCAPTA
# 1      SAU  2022  30447.883707  agregates  PIBPCAPTA
# 2      SAU  2021  24315.618551  agregates  PIBPCAPTA
# 3      SAU  2020  20398.060987  agregates  PIBPCAPTA
# 4      SAU  2019  23405.706100  agregates  PIBPCAPTA
# 5      SAU  2018  24175.583314  agregates  PIBPCAPTA
# 6      SAU  2017  20910.482962  agregates  PIBPCAPTA
# 7      SAU  2016  19930.407544  agregates  PIBPCAPTA
# 8      SAU  2015  20442.366063  agregates  PIBPCAPTA
# 9      SAU  2014  23862.801186  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      NLD  2023           NaN  agregates  PIBPCAPTA
# 1      NLD  2022  57025.012456  agregates  PIBPCAPTA
# 2      NLD  2021  58727.870547  agregates  PIBPCAPTA
# 3      NLD  2020  52162.570115  agregates  PIBPCAPTA
# 4      NLD  2019  52476.273253  agregates  PIBPCAPTA
# 5      NLD  2018  53044.532435  agregates  PIBPCAPTA
# 6      NLD  2017  48675.222335  agregates  PIBPCAPTA
# 7      NLD  2016  46039.105928  agregates  PIBPCAPTA
# 8      NLD  2015  45193.403219  agregates  PIBPCAPTA
# 9      NLD  2014  52900.537415  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      RUS  2023           NaN  agregates  PIBPCAPTA
# 1      RUS  2022  15270.706055  agregates  PIBPCAPTA
# 2      RUS  2021  12532.050781  agregates  PIBPCAPTA
# 3      RUS  2020  10194.441406  agregates  PIBPCAPTA
# 4      RUS  2019  11536.258789  agregates  PIBPCAPTA
# 5      RUS  2018  11287.354492  agregates  PIBPCAPTA
# 6      RUS  2017  10720.332031  agregates  PIBPCAPTA
# 7      RUS  2016   8704.894531  agregates  PIBPCAPTA
# 8      RUS  2015   9313.021484  agregates  PIBPCAPTA
# 9      RUS  2014  14095.646484  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      KWT  2023           NaN  agregates  PIBPCAPTA
# 1      KWT  2022  41079.522700  agregates  PIBPCAPTA
# 2      KWT  2021  32324.840904  agregates  PIBPCAPTA
# 3      KWT  2020  24297.710802  agregates  PIBPCAPTA
# 4      KWT  2019  30666.237131  agregates  PIBPCAPTA
# 5      KWT  2018  32012.187525  agregates  PIBPCAPTA
# 6      KWT  2017  29258.266327  agregates  PIBPCAPTA
# 7      KWT  2016  27026.687660  agregates  PIBPCAPTA
# 8      KWT  2015  29315.198508  agregates  PIBPCAPTA
# 9      KWT  2014  43239.835178  agregates  PIBPCAPTA
#   iso3code  date         value   datatype    agrcode
# 0      ARE  2023           NaN  agregates  PIBPCAPTA
# 1      ARE  2022  53707.980081  agregates  PIBPCAPTA
# 2      ARE  2021  44332.340051  agregates  PIBPCAPTA
# 3      ARE  2020  37629.174169  agregates  PIBPCAPTA
# 4      ARE  2019  45376.170838  agregates  PIBPCAPTA
# 5      ARE  2018  46722.268718  agregates  PIBPCAPTA
# 6      ARE  2017  43063.967477  agregates  PIBPCAPTA
# 7      ARE  2016  41054.539570  agregates  PIBPCAPTA
# 8      ARE  2015  41525.138903  agregates  PIBPCAPTA
# 9      ARE  2014  46865.964598  agregates  PIBPCAPTA
#   iso3code  date          value   datatype    agrcode
# 0      NOR  2023            NaN  agregates  PIBPCAPTA
# 1      NOR  2022  108729.186903  agregates  PIBPCAPTA
# 2      NOR  2021   93072.892512  agregates  PIBPCAPTA
# ...
# 6      CHN  2017  2.208519e+12  agregates     IMP
# 7      CHN  2016  1.944491e+12  agregates     IMP
# 8      CHN  2015  2.003261e+12  agregates     IMP
# 9      CHN  2014  2.241276e+12  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      IND  2023           NaN  agregates     IMP
# 1      IND  2022  9.034575e+11  agregates     IMP
# 2      IND  2021  7.609029e+11  agregates     IMP
# 3      IND  2020  5.102447e+11  agregates     IMP
# 4      IND  2019  6.023151e+11  agregates     IMP
# 5      IND  2018  6.403008e+11  agregates     IMP
# 6      IND  2017  5.820180e+11  agregates     IMP
# 7      IND  2016  4.801691e+11  agregates     IMP
# 8      IND  2015  4.650976e+11  agregates     IMP
# 9      IND  2014  5.292394e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      ESP  2023           NaN  agregates     IMP
# 1      ESP  2022  5.623343e+11  agregates     IMP
# 2      ESP  2021  4.801713e+11  agregates     IMP
# 3      ESP  2020  3.750058e+11  agregates     IMP
# 4      ESP  2019  4.457221e+11  agregates     IMP
# 5      ESP  2018  4.610565e+11  agregates     IMP
# 6      ESP  2017  4.140202e+11  agregates     IMP
# 7      ESP  2016  3.685545e+11  agregates     IMP
# 8      ESP  2015  3.656932e+11  agregates     IMP
# 9      ESP  2014  4.166258e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      IRL  2023           NaN  agregates     IMP
# 1      IRL  2022  5.181032e+11  agregates     IMP
# 2      IRL  2021  4.808706e+11  agregates     IMP
# 3      IRL  2020  4.891306e+11  agregates     IMP
# 4      IRL  2019  4.966358e+11  agregates     IMP
# 5      IRL  2018  3.637166e+11  agregates     IMP
# 6      IRL  2017  3.329703e+11  agregates     IMP
# 7      IRL  2016  3.171632e+11  agregates     IMP
# 8      IRL  2015  2.723247e+11  agregates     IMP
# 9      IRL  2014  2.387554e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      SAU  2023           NaN  agregates     IMP
# 1      SAU  2022  2.582129e+11  agregates     IMP
# 2      SAU  2021  2.130158e+11  agregates     IMP
# 3      SAU  2020  1.821837e+11  agregates     IMP
# 4      SAU  2019  2.189408e+11  agregates     IMP
# 5      SAU  2018  2.095894e+11  agregates     IMP
# 6      SAU  2017  2.019757e+11  agregates     IMP
# 7      SAU  2016  1.981102e+11  agregates     IMP
# 8      SAU  2015  2.473073e+11  agregates     IMP
# 9      SAU  2014  2.553831e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      NLD  2023           NaN  agregates     IMP
# 1      NLD  2022  8.373927e+11  agregates     IMP
# 2      NLD  2021  7.501306e+11  agregates     IMP
# 3      NLD  2020  6.204455e+11  agregates     IMP
# 4      NLD  2019  6.620113e+11  agregates     IMP
# 5      NLD  2018  6.776695e+11  agregates     IMP
# 6      NLD  2017  6.056932e+11  agregates     IMP
# 7      NLD  2016  5.435381e+11  agregates     IMP
# 8      NLD  2015  5.753867e+11  agregates     IMP
# 9      NLD  2014  6.198413e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      RUS  2023           NaN  agregates     IMP
# 1      RUS  2022  3.491746e+11  agregates     IMP
# 2      RUS  2021  3.795542e+11  agregates     IMP
# 3      RUS  2020  3.052552e+11  agregates     IMP
# 4      RUS  2019  3.520887e+11  agregates     IMP
# 5      RUS  2018  3.445196e+11  agregates     IMP
# 6      RUS  2017  3.272075e+11  agregates     IMP
# 7      RUS  2016  2.638305e+11  agregates     IMP
# 8      RUS  2015  2.816403e+11  agregates     IMP
# 9      RUS  2014  4.260621e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      KWT  2023           NaN  agregates     IMP
# 1      KWT  2022           NaN  agregates     IMP
# 2      KWT  2021           NaN  agregates     IMP
# 3      KWT  2020           NaN  agregates     IMP
# 4      KWT  2019  6.113585e+10  agregates     IMP
# 5      KWT  2018  6.304795e+10  agregates     IMP
# 6      KWT  2017  5.629317e+10  agregates     IMP
# 7      KWT  2016  5.309181e+10  agregates     IMP
# 8      KWT  2015  5.148711e+10  agregates     IMP
# 9      KWT  2014  5.128493e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      ARE  2023           NaN  agregates     IMP
# 1      ARE  2022           NaN  agregates     IMP
# 2      ARE  2021           NaN  agregates     IMP
# 3      ARE  2020  2.468863e+11  agregates     IMP
# 4      ARE  2019  2.955998e+11  agregates     IMP
# 5      ARE  2018  2.815357e+11  agregates     IMP
# 6      ARE  2017  2.907828e+11  agregates     IMP
# 7      ARE  2016  2.704425e+11  agregates     IMP
# 8      ARE  2015  2.662764e+11  agregates     IMP
# 9      ARE  2014  2.778884e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      NOR  2023           NaN  agregates     IMP
# 1      NOR  2022  1.609112e+11  agregates     IMP
# 2      NOR  2021  1.418814e+11  agregates     IMP
# 3      NOR  2020  1.218471e+11  agregates     IMP
# 4      NOR  2019  1.400144e+11  agregates     IMP
# 5      NOR  2018  1.397744e+11  agregates     IMP
# 6      NOR  2017  1.300711e+11  agregates     IMP
# 7      NOR  2016  1.230785e+11  agregates     IMP
# 8      NOR  2015  1.236547e+11  agregates     IMP
# 9      NOR  2014  1.475592e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      IDN  2023           NaN  agregates     IMP
# 1      IDN  2022  2.757032e+11  agregates     IMP
# 2      IDN  2021  2.229400e+11  agregates     IMP
# 3      IDN  2020  1.656468e+11  agregates     IMP
# 4      IDN  2019  2.130346e+11  agregates     IMP
# 5      IDN  2018  2.300456e+11  agregates     IMP
# 6      IDN  2017  1.947773e+11  agregates     IMP
# 7      IDN  2016  1.708350e+11  agregates     IMP
# 8      IDN  2015  1.788637e+11  agregates     IMP
# 9      IDN  2014  2.174852e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      CAN  2023           NaN  agregates     IMP
# 1      CAN  2022  7.287192e+11  agregates     IMP
# 2      CAN  2021  6.264881e+11  agregates     IMP
# 3      CAN  2020  5.245726e+11  agregates     IMP
# 4      CAN  2019  5.897067e+11  agregates     IMP
# 5      CAN  2018  5.913476e+11  agregates     IMP
# 6      CAN  2017  5.549227e+11  agregates     IMP
# 7      CAN  2016  5.173960e+11  agregates     IMP
# 8      CAN  2015  5.341151e+11  agregates     IMP
# 9      CAN  2014  5.894344e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      AUS  2023           NaN  agregates     IMP
# 1      AUS  2022  3.336753e+11  agregates     IMP
# 2      AUS  2021  2.763472e+11  agregates     IMP
# 3      AUS  2020  2.684134e+11  agregates     IMP
# 4      AUS  2019  3.017675e+11  agregates     IMP
# 5      AUS  2018  3.073001e+11  agregates     IMP
# 6      AUS  2017  2.748462e+11  agregates     IMP
# 7      AUS  2016  2.600213e+11  agregates     IMP
# 8      AUS  2015  2.911190e+11  agregates     IMP
# 9      AUS  2014  3.137027e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      CHE  2023           NaN  agregates     IMP
# 1      CHE  2022  5.175233e+11  agregates     IMP
# 2      CHE  2021  4.796558e+11  agregates     IMP
# 3      CHE  2020  4.280626e+11  agregates     IMP
# 4      CHE  2019  4.123506e+11  agregates     IMP
# 5      CHE  2018  4.132137e+11  agregates     IMP
# 6      CHE  2017  3.981646e+11  agregates     IMP
# 7      CHE  2016  3.903683e+11  agregates     IMP
# 8      CHE  2015  3.700311e+11  agregates     IMP
# 9      CHE  2014  3.986960e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      ZAF  2023           NaN  agregates     IMP
# 1      ZAF  2022  1.277507e+11  agregates     IMP
# 2      ZAF  2021  1.049173e+11  agregates     IMP
# 3      ZAF  2020  7.834657e+10  agregates     IMP
# 4      ZAF  2019  1.039350e+11  agregates     IMP
# 5      ZAF  2018  1.093738e+11  agregates     IMP
# 6      ZAF  2017  9.992378e+10  agregates     IMP
# 7      ZAF  2016  8.964991e+10  agregates     IMP
# 8      ZAF  2015  1.005910e+11  agregates     IMP
# 9      ZAF  2014  1.162617e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      DNK  2023           NaN  agregates     IMP
# 1      DNK  2022  2.357676e+11  agregates     IMP
# 2      DNK  2021  2.109953e+11  agregates     IMP
# 3      DNK  2020  1.725427e+11  agregates     IMP
# 4      DNK  2019  1.787159e+11  agregates     IMP
# 5      DNK  2018  1.799022e+11  agregates     IMP
# 6      DNK  2017  1.590927e+11  agregates     IMP
# 7      DNK  2016  1.463593e+11  agregates     IMP
# 8      DNK  2015  1.471901e+11  agregates     IMP
# 9      DNK  2014  1.682042e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      ISR  2023           NaN  agregates     IMP
# 1      ISR  2022  1.510746e+11  agregates     IMP
# 2      ISR  2021  1.260284e+11  agregates     IMP
# 3      ISR  2020  9.689509e+10  agregates     IMP
# 4      ISR  2019  1.095532e+11  agregates     IMP
# 5      ISR  2018  1.093198e+11  agregates     IMP
# 6      ISR  2017  9.786594e+10  agregates     IMP
# 7      ISR  2016  9.047554e+10  agregates     IMP
# 8      ISR  2015  8.508055e+10  agregates     IMP
# 9      ISR  2014  9.521130e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      PRT  2023           NaN  agregates     IMP
# 1      PRT  2022  1.327180e+11  agregates     IMP
# 2      PRT  2021  1.130082e+11  agregates     IMP
# 3      PRT  2020  8.975922e+10  agregates     IMP
# 4      PRT  2019  1.033295e+11  agregates     IMP
# 5      PRT  2018  1.041535e+11  agregates     IMP
# 6      PRT  2017  9.233916e+10  agregates     IMP
# 7      PRT  2016  8.063709e+10  agregates     IMP
# 8      PRT  2015  7.950994e+10  agregates     IMP
# 9      PRT  2014  9.211330e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      HKG  2023           NaN  agregates     IMP
# 1      HKG  2022  6.834407e+11  agregates     IMP
# 2      HKG  2021  7.321774e+11  agregates     IMP
# 3      HKG  2020  6.014954e+11  agregates     IMP
# 4      HKG  2019  6.393460e+11  agregates     IMP
# 5      HKG  2018  6.820558e+11  agregates     IMP
# 6      HKG  2017  6.412295e+11  agregates     IMP
# 7      HKG  2016  5.926999e+11  agregates     IMP
# 8      HKG  2015  5.986870e+11  agregates     IMP
# 9      HKG  2014  6.204759e+11  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      PRY  2023           NaN  agregates     IMP
# 1      PRY  2022  1.642867e+10  agregates     IMP
# 2      PRY  2021  1.368525e+10  agregates     IMP
# 3      PRY  2020  1.044880e+10  agregates     IMP
# 4      PRY  2019  1.332502e+10  agregates     IMP
# 5      PRY  2018  1.416579e+10  agregates     IMP
# 6      PRY  2017  1.283429e+10  agregates     IMP
# 7      PRY  2016  1.104925e+10  agregates     IMP
# 8      PRY  2015  1.165299e+10  agregates     IMP
# 9      PRY  2014  1.357478e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      MNG  2023           NaN  agregates     IMP
# 1      MNG  2022  1.221970e+10  agregates     IMP
# 2      MNG  2021  9.255820e+09  agregates     IMP
# 3      MNG  2020  7.345877e+09  agregates     IMP
# 4      MNG  2019  9.259603e+09  agregates     IMP
# 5      MNG  2018  8.986287e+09  agregates     IMP
# 6      MNG  2017  6.517244e+09  agregates     IMP
# 7      MNG  2016  5.611142e+09  agregates     IMP
# 8      MNG  2015  5.283520e+09  agregates     IMP
# 9      MNG  2014  6.978077e+09  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      CUB  2023           NaN  agregates     IMP
# 1      CUB  2022           NaN  agregates     IMP
# 2      CUB  2021           NaN  agregates     IMP
# 3      CUB  2020  8.067000e+09  agregates     IMP
# 4      CUB  2019  1.097100e+10  agregates     IMP
# 5      CUB  2018  1.256700e+10  agregates     IMP
# 6      CUB  2017  1.130400e+10  agregates     IMP
# 7      CUB  2016  1.122600e+10  agregates     IMP
# 8      CUB  2015  1.260500e+10  agregates     IMP
# 9      CUB  2014  1.386500e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      ECU  2023           NaN  agregates     IMP
# 1      ECU  2022  3.281025e+10  agregates     IMP
# 2      ECU  2021  2.675130e+10  agregates     IMP
# 3      ECU  2020  1.937895e+10  agregates     IMP
# 4      ECU  2019  2.489560e+10  agregates     IMP
# 5      ECU  2018  2.555399e+10  agregates     IMP
# 6      ECU  2017  2.251633e+10  agregates     IMP
# 7      ECU  2016  1.900470e+10  agregates     IMP
# 8      ECU  2015  2.381545e+10  agregates     IMP
# 9      ECU  2014  3.016828e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      SLV  2023           NaN  agregates     IMP
# 1      SLV  2022  1.807044e+10  agregates     IMP
# 2      SLV  2021  1.545868e+10  agregates     IMP
# 3      SLV  2020  1.040031e+10  agregates     IMP
# 4      SLV  2019  1.238847e+10  agregates     IMP
# 5      SLV  2018  1.215154e+10  agregates     IMP
# 6      SLV  2017  1.130930e+10  agregates     IMP
# 7      SLV  2016  1.073144e+10  agregates     IMP
# 8      SLV  2015  1.103334e+10  agregates     IMP
# 9      SLV  2014  1.096948e+10  agregates     IMP
#   iso3code  date value   datatype agrcode
# 0      GUY  2023  None  agregates     IMP
# 1      GUY  2022  None  agregates     IMP
# 2      GUY  2021  None  agregates     IMP
# 3      GUY  2020  None  agregates     IMP
# 4      GUY  2019  None  agregates     IMP
# 5      GUY  2018  None  agregates     IMP
# 6      GUY  2017  None  agregates     IMP
# 7      GUY  2016  None  agregates     IMP
# 8      GUY  2015  None  agregates     IMP
# 9      GUY  2014  None  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      HTI  2023           NaN  agregates     IMP
# 1      HTI  2022  5.932425e+09  agregates     IMP
# 2      HTI  2021  6.269039e+09  agregates     IMP
# 3      HTI  2020  3.983064e+09  agregates     IMP
# 4      HTI  2019  5.107129e+09  agregates     IMP
# 5      HTI  2018  5.635999e+09  agregates     IMP
# 6      HTI  2017  4.689669e+09  agregates     IMP
# 7      HTI  2016  4.193901e+09  agregates     IMP
# 8      HTI  2015  4.481320e+09  agregates     IMP
# 9      HTI  2014  4.752591e+09  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      PAN  2023           NaN  agregates     IMP
# 1      PAN  2022           NaN  agregates     IMP
# 2      PAN  2021           NaN  agregates     IMP
# 3      PAN  2020           NaN  agregates     IMP
# 4      PAN  2019           NaN  agregates     IMP
# 5      PAN  2018           NaN  agregates     IMP
# 6      PAN  2017  2.837949e+10  agregates     IMP
# 7      PAN  2016  2.631060e+10  agregates     IMP
# 8      PAN  2015  2.826380e+10  agregates     IMP
# 9      PAN  2014  3.181650e+10  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      DOM  2023           NaN  agregates     IMP
# 1      DOM  2022  3.652360e+10  agregates     IMP
# 2      DOM  2021  2.919865e+10  agregates     IMP
# 3      DOM  2020  2.049800e+10  agregates     IMP
# 4      DOM  2019  2.485188e+10  agregates     IMP
# 5      DOM  2018  2.438717e+10  agregates     IMP
# 6      DOM  2017  2.123383e+10  agregates     IMP
# 7      DOM  2016  2.095247e+10  agregates     IMP
# 8      DOM  2015  2.021757e+10  agregates     IMP
# 9      DOM  2014  2.038578e+10  agregates     IMP
#   iso3code  date value   datatype agrcode
# 0      SUR  2023  None  agregates     IMP
# 1      SUR  2022  None  agregates     IMP
# 2      SUR  2021  None  agregates     IMP
# 3      SUR  2020  None  agregates     IMP
# 4      SUR  2019  None  agregates     IMP
# 5      SUR  2018  None  agregates     IMP
# 6      SUR  2017  None  agregates     IMP
# 7      SUR  2016  None  agregates     IMP
# 8      SUR  2015  None  agregates     IMP
# 9      SUR  2014  None  agregates     IMP
#   iso3code  date         value   datatype agrcode
# 0      RUS  2023           NaN  agregates     IMP
# 1      RUS  2022  3.491746e+11  agregates     IMP
# 2      RUS  2021  3.795542e+11  agregates     IMP
# 3      RUS  2020  3.052552e+11  agregates     IMP
# 4      RUS  2019  3.520887e+11  agregates     IMP
# 5      RUS  2018  3.445196e+11  agregates     IMP
# 6      RUS  2017  3.272075e+11  agregates     IMP
# 7      RUS  2016  2.638305e+11  agregates     IMP
# 8      RUS  2015  2.816403e+11  agregates     IMP
# 9      RUS  2014  4.260621e+11  agregates     IMP

# %% [markdown]
# # Projeções
# ##

# %% [markdown]
# Aqui vamos fazer as projeções diárias e projeções aproveitando os dados coletados.
#
# ### PROJEÇÕES DIÁRIAS:
# + Variação do High e Low
# + Tendência de um ticker em curto-prazo (definir posteriormente)
#
# ### PROJEÇÕES PERMANENTES
# + PIB dos países exportadores de petróleo vs empresas de petróleo a nível mundial ou local
# + Preço do petróleo nas duas formas vs PIB dos petroleiros
# + Mesma lógica pra outras commodities
# + Commodities em geral vs PIB da América Latina em geral. vs Inflação, desemprego, etc

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()
cursor.execute('''
    CREATE TABLE IF NOT EXISTS mlearning(
        id INTEGER PRIMARY KEY,
        model TEXT NOT NULL,
        dataorigin TEXT NOT NULL, 
        period DATE,
        country TEXT NOT NULL,
        datatype TEXT NOT NULL,
        FOREIGN KEY (datatype) REFERENCES text(datatype)
        FOREIGN KEY (country) REFERENCES countries(country)
    );    
    ''') 
# dataorigin é o código do ticker, moeda, commoditie etc. 
# period é a data inicial e final da análise. 
# model é o modelo de previsão


conn.close()

# %%
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()
cursor.execute(f'''
    CREATE TABLE IF NOT EXISTS projection_tendencies(
        id INTEGER PRIMARY KEY,
        code TEXT NOT NULL,
        y1_reg REAL, 
        y1_r2 REAL,
        y1_var REAL,
        m6_reg REAL, 
        m6_r2 REAL,
        m6_var REAL,
        m3_reg REAL, 
        m3_r2 REAL,
        m3_var REAL,
        m1_reg REAL, 
        m1_r2 REAL,
        m1_var REAL,
        w1_reg REAL, 
        w1_r2 REAL,
        w1_var REAL,
        d1_diff REAL,
        d3_diff REAL,
        w1_diff REAL,
        last_date DATE, 
        country TEXT NOT NULL,
        datatype TEXT NOT NULL
    );    
    ''') 


conn.close()

# %% [markdown]
# + reg é Regressão Linear clássica, mas onde é apresentado apenas o beta2 (y = b1 +b2X)
# + r2 é coeficiente de correlação pra ver se os dados são relevantes
# + var é variância média do open e close nesse período
# + last_date é a data da última atualização
# -
# + yx = ano atrás, mx é meses atrás, wx é semanas atrás

# %%
petr4 = sqltodf("petr4.sa")
petr4['date'] = pd.to_datetime(petr4['date'])



def regression(df):
    # Converter datas para números inteiros (número de dias desde uma data de referência)
    df['Date_Integer'] = (df['date'] - pd.Timestamp('1970-01-01')).dt.days

    # Definir X e Y
    X = df[['Date_Integer']]  # Data como números inteiros
    Y = df['open']  # Valores

    # Criação do modelo de regressão linear
    model = LinearRegression()

    # Treinamento do modelo nos dados de treinamento
    model.fit(X, Y)

    # Previsões nos dados de teste
    predictions = model.predict(X)
    
    b2 = model.coef_[0]
    b1 = model.intercept_
    # Avaliação do desempenho do modelo (opcional)
    mse = mean_squared_error(Y, predictions)
    print(f'''Regressão 
        {b1} = b1
        {b2} = b2
        {mse} = mse
        ----''')
    return b1, b2, mse
# Chamar a função com o DataFrame 'petr4'
regression(petr4)
# Out:
# Regressão
#         -102.64956871443172 = b1
#         0.006905476781844931 = b2
#         20.701999684013447 = mse
#         ----
# (-102.64956871443172, 0.006905476781844931, 20.701999684013447)

# %%
# Variância média entre o High e o Low de uma série de dados. Amplitude do movimento através do dia

def highlowvar(df):
    hl_diff = []
    for index, row in df.iterrows():
        high = row['high']
        low = row['low']
        diff = high - low
        hl_diff.append(diff)
    mean = np.mean(hl_diff)
    return mean

# %%
def cutdf_time_today(df, period, num):
    df['date'] = pd.to_datetime(df['date'])
    datecut = dateop(period, num)
    mask = df['date'] >= datecut
    df = df[mask]
    return df
def cutdf_time(df, date, period, num):
    df['date'] = pd.to_datetime(df['date'])
    datecut = dateop_cut(date, period, num)
    mask = df['date'] >= datecut
    df = df[mask]
    return df

petr4_t = cutdf_time_today(petr4, "y", 5)
# Out:
#         id      code       date       open       high        low      close  \
# 1242  1243  PETR4.SA 2019-05-14  26.170000  26.230000  25.850000  26.000000
# 1243  1244  PETR4.SA 2019-05-15  25.740000  25.889999  25.660000  25.879999
# 1244  1245  PETR4.SA 2019-05-16  25.770000  26.040001  25.240000  25.270000
# 1245  1246  PETR4.SA 2019-05-17  25.049999  25.420000  24.469999  24.680000
# 1246  1247  PETR4.SA 2019-05-20  24.680000  25.520000  24.639999  25.520000
# 1247  1248  PETR4.SA 2019-05-21  25.700001  26.490000  25.420000  26.490000
# 1248  1249  PETR4.SA 2019-05-22  26.340000  26.469999  25.959999  26.290001
# 1249  1250  PETR4.SA 2019-05-23  25.900000  25.920000  25.520000  25.840000
# 1250  1251  PETR4.SA 2019-05-24  26.150000  26.360001  25.930000  26.090000
# 1251  1252  PETR4.SA 2019-05-27  26.299999  26.540001  26.170000  26.240000
#
#           volume datatype  Date_Integer
# 1242  34968600.0  tickets         18030
# 1243  37053900.0  tickets         18031
# 1244  46502200.0  tickets         18032
# 1245  67291200.0  tickets         18033
# 1246  54472000.0  tickets         18036
# 1247  57846700.0  tickets         18037
# 1248  48439300.0  tickets         18038
# 1249  49527400.0  tickets         18039
# 1250  35915100.0  tickets         18040
# 1251  33892000.0  tickets         18043

# %%
######### MUDAR NOMES DAS COLUNAS PARA NÃO TER CONFLITO

# Conecte-se ao banco de dados SQLite
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

# Obtenha uma lista de todas as tabelas no banco de dados
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Itere sobre cada tabela
for table in tables:
    table_name = table[0]
    # Obtenha uma lista de todas as colunas na tabela
    cursor.execute(f"PRAGMA table_info('{table_name}');")
    columns = cursor.fetchall()
    # Itere sobre cada coluna na tabela
    for column in columns:
        old_column_name = column[1]
        # Renomeie a coluna para caixa baixa
        new_column_name = old_column_name.lower()
        cursor.execute(f"ALTER TABLE '{table_name}' RENAME COLUMN '{old_column_name}' TO '{new_column_name}';")

# Confirme as alterações e feche a conexão
conn.commit()
conn.close()

# %%
def sqlreg(tabela, data1, period, num):
    df = sqltodf(tabela)
    df = cutdf_time(df, data1, period, num)
    reg = regression(df)
    return reg
todaydt = datetime.now()

test = sqlreg('petr4_sa', todaydt, "y", 2)
print(test)
# Out:
# (-271.704273326887, 0.01555836139496291, 17.812231831041746)

# %%
# Diferença média entre o High e o Low de um período
def sqlhighlowvar(tabela, data1, period, num):
    df = sqltodf(tabela)
    df = cutdf_time(df, data1, period, num)
    mean = highlowvar(df)
    return mean

# %%
def sqldiff(tabela, data1, period, num):
    df = sqltodf(tabela)
    df = cutdf_time(df, data1, period, num)
    df.sort_values(by='date', inplace=True)
    valor_mais_antigo = df['open'].iloc[0]
    valor_mais_recente = df['open'].iloc[-1]
    diff = valor_mais_recente - valor_mais_antigo
    return diff
test = sqldiff('petr4_sa', todaydt, "d", 3)
print(test)
# Out:
# 0.779998779296875

# %%
def sqllastdate(tabela):
    df = sqltodf(tabela)
    df = cutdf_time_today(df, "d", 2)
    df.sort_values(by='date', inplace=True)
    lastdate = df['date'].iloc[-1]
    return lastdate
test = sqllastdate('petr4_sa')
print(test)
# Out:
# 2024-05-10 00:00:00

# %%
def proj_ten_method(code, method, period, num):
    if method == "reg":
        out = sqlreg(code, todaydt, period, num)
        out = out[1]
        return out
    elif method == "r2":
        out = sqlreg(code, todaydt, period, num)
        out = out[2]
        return out
    elif method == "var":
        out = sqlhighlowvar(code, todaydt, period, num)
        return out
    elif method == "diff":
        out = sqldiff(code, todaydt, period, num)
        return out
    elif method == "last_date":
        out = sqllastdate(code)
        return out
    else:
        print(f"entrada errada, {code}, {method}, {period}, {num}")
        # Processar usando método padrão ou mostrar um erro se nenhum método válido for fornecido

# %%
def sqlcolumnname(tablename):
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    table_columns = []
    cursor.execute(f"PRAGMA table_info({tablename})")
    for coluna in cursor.fetchall():
        name = coluna[1]  
        table_columns.append(name)
    # Fechar a conexão com o banco de dados
    conn.close()
    return table_columns

tablename = 'projection_tendencies'
listtest = sqlcolumnname(tablename)
print(list1)
# Out:
# ['id', 'code', 'y1_reg', 'y1_r2', 'y1_var', 'm6_reg', 'm6_r2', 'm6_var', 'm3_reg', 'm3_r2', 'm3_var', 'm1_reg', 'm1_r2', 'm1_var', 'w1_reg', 'w1_r2', 'w1_var', 'd1_diff', 'd3_diff', 'w1_diff', 'last_date', 'country', 'datatype']

# %%
def proj_ten_filter(name):
    if len(name) >= 2 and name[0].isalpha() and name[1].isdigit() and '_' in name:
        period = name[0]
        num = name[1]
        method = name.split('_')[1]
        list1 = (method, period, num)
        return list1
    elif name == "last_date":
        list1 = name, 0, 0
        return list1
    else:
        return None

vartest = listtest[-3]

print(proj_ten_filter(vartest))
# Out:
# ('last_date', 0, 0)

# %%
dtreg = {
    "currencies": "currcode",
    "commodities": "commcode",
    "tickets": "ticcode",
    "cripto": "criptocode"}

# %%
all_codes = pd.DataFrame(columns=("code", "datatype", "country", "cat"))

print(all_codes)
# Out:
# Empty DataFrame
# Columns: [code, datatype, country, cat]
# Index: []

# %%
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    cursor.execute(f"SELECT {val}, datatype, country FROM {ke}")
    valores_coluna = cursor.fetchall()
    conn.close()

# %%
showsql('commodities')
# Out:
#    id commcode               comname     datatype
# 0   1     GC=F                  Ouro  commodities
# 1   2     SI=F                 Prata  commodities
# 2   3     CL=F  Petróleo Crude (WTI)  commodities
# 3   4     BZ=F  Petróleo Brent Crude  commodities
# 4   5     HG=F                 Cobre  commodities
# 5   6     NG=F           Gás Natural  commodities
# 6   7      C=F                 Milho  commodities
# 7   8      W=F                 Trigo  commodities
# 8   9     KC=F                  Café  commodities
# 9  10     SB=F                Açúcar  commodities

# %%
showsql('bz_com_f')
# Out:
#         id  code                 date        open        high         low  \
# 0        1  BZ=F  2014-05-15 00:00:00  110.150002  110.589996  109.800003
# 1        2  BZ=F  2014-05-16 00:00:00  110.419998  110.419998  110.419998
# 2        3  BZ=F  2014-05-19 00:00:00  109.800003  110.300003  109.320000
# 3        4  BZ=F  2014-05-20 00:00:00  109.209999  110.000000  109.000000
# 4        5  BZ=F  2014-05-21 00:00:00  109.750000  110.730003  109.709999
# ...    ...   ...                  ...         ...         ...         ...
# 2504  2505  BZ=F  2024-05-06 00:00:00   82.980003   83.820000   82.760002
# 2505  2506  BZ=F  2024-05-07 00:00:00   83.589996   83.870003   82.400002
# 2506  2507  BZ=F  2024-05-08 00:00:00   83.040001   83.820000   81.720001
# 2507  2508  BZ=F  2024-05-09 00:00:00   83.779999   84.330002   83.459999
# 2508  2509  BZ=F  2024-05-10 00:00:00   84.209999   84.519997   82.709999
#
#            close   volume     datatype
# 0     110.440002     81.0  commodities
# 1     110.419998   6131.0  commodities
# 2     109.370003   7101.0  commodities
# 3     109.690002  10468.0  commodities
# 4     110.550003   7242.0  commodities
# ...          ...      ...          ...
# 2504   83.330002  23246.0  commodities
# 2505   83.160004  33414.0  commodities
# 2506   83.580002  35419.0  commodities
# 2507   83.879997  25231.0  commodities
# 2508   82.730003  24501.0  commodities
#
# [2509 rows x 9 columns]

# %%
df = sqltodf('tickets')
niche = df['ticcat'].unique() 
print(niche)
# Out:
# ['Petróleo e Gás' 'Serviços Financeiros' 'Tecnologia' 'Telecomunicações'
#  'Agricultura' 'Energia' 'Metalurgia' 'Alimentício' 'Imobiliário'
#  'Consultoria' 'Mineração' 'Bebidas' 'Tecnologia Financeira' 'Varejo'
#  'Diversificado' 'Logística' 'Construção Civil' 'Papel e Celulose'
#  'Automotivo' 'Saúde' 'Transporte Aéreo' 'Aluguel de Carros'
#  'Infraestrutura' 'Petroquímica' 'Seguros' 'Indústria' 'Petróleo e gás'
#  'Serviços financeiros' 'Seguros e investimentos' 'Cimento e energia'
#  'Materiais de construção' 'Alimentos e bebidas' 'Gás natural'
#  'Energia e infraestrutura' 'Construção' 'Transporte' 'Conglomerado'
#  'Farmacêutico' 'Químico' 'Mídia' 'Distribuição' 'Imóveis' 'Automotiva'
#  'Índices das Bolsas']

# %%
# Todas as empresas petroliferas ('Petróleo e gás', 'Petróleo e Gás', 'Petroquímica')

conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()
cursor.execute('''
SELECT ticcode
FROM tickets
WHERE ticcat IN ('Petróleo e gás', 'Petróleo e Gás', 'Petroquímica');

    ''') 
petroleo = cursor.fetchall()
petroleo = [row[0] for row in petroleo]
print(petroleo)

conn.close()
# Out:
# ['YPFD.BA', 'YPFL.BA', 'TGSU2.BA', 'PETR4.SA', 'BRKM5.SA', 'ECOPETROL', 'RLP.LM', '2222.SR', 'XOM', 'RDS.A', 'PTR', 'BP', 'TTE', 'CVX', 'OGZPY', 'ROSN.ME', 'KPC', 'PTR', 'ENI', 'ABD.NE', 'SNP', 'VLO', 'PSX', 'PBR', 'RELIANCE', 'EQNR', 'PERT.JK', 'COP', 'EOG', 'LKOH.ME', 'MPC', 'PXX', '2010.SE', 'ENB', 'BHP', 'OXY', 'SLB', 'HAL', 'BKR', 'WFT', 'RIG', 'VAL', 'DO', 'NE', 'RDC', 'ESV', 'SDRL', 'AKSO.OL', 'FTI', 'SPM.MI', 'MDR', 'SUBC.L', 'RBS', 'OSXB3', 'QGOG3']

# %%
print(commodities_todf)
# Out:
# {'commodity': ['Ouro', 'Prata', 'Petróleo Crude (WTI)', 'Petróleo Brent Crude', 'Cobre', 'Gás Natural', 'Milho', 'Trigo', 'Café', 'Açúcar'], 'codigo': ['GC=F', 'SI=F', 'CL=F', 'BZ=F', 'HG=F', 'NG=F', 'C=F', 'W=F', 'KC=F', 'SB=F']}

# %%
# CORRELAÇÃO ENTRE O PIB DOS PAÍSES PRODUTORES DE PETRÓLEO E A MÉDIA ANUAL DO PREÇO DO PETRÓLEO
try:
    petrocrude = sqltodf("CL=F")

    petroticker = {}
    chaves_vazias = []
    base_petro = {}


    # 2. Criar um DataFrame base com todas as datas únicas
    base_petro = pd.DataFrame({'date': sorted(list(all_dates))})

    # 3. Mesclar os DataFrames de séries temporais com o DataFrame base
    petroticker = {}
    chaves_vazias = []

    pet0 = f"{petroleo[0]}"
    petroticker = sqltodf(pet0)
    petroticker = closedate(petroticker) # Pegar o primeiro DF 
    petroleo = petroleo[1:]



    for petro in petroleo: 
        pet = sqltodf(petro)
        pet = closedate(pet) 
        petroticker = pd.merge(petroticker, pet, on='date', how='left', suffixes=('_base', '_petro'))
        petroticker = petroticker.dropna(axis=1, how='all')



    print(petroticker)
except:
    pass

# %% [markdown]
# # News e Texts
# #### Para essa parte é necessário um processo de Scrapping das páginas dos principais jornais de cada país. A parte complicada é essa. Como exemplo eu produzi um scrapping de 4 páginas, 3 do Brasil e uma da Argentina. O que é complicado é encontrar a secção nos códigos fonte HTML onde você encontra as headlines, normalmente os jornais "mudam de padrão" dessa informação para não ser tão fácil "raspar" a página através apenas da página inicial. Isso significa que o trabalho é passar de página em página e identificar os 35 box de headlines nos sites escolhidos ('news_source.xlsx'). Uma alternativa que tive em mente é um algoritimo de linguagem natural (NLP) pra encontrar a headline ou uma LLM comum que analise o HTML inteiro para tal. Para a LLM analisando o código inteiro a limitação é a quantidade de tokens de processamento que torna impossível "em uma tacada só" e não sei se teremos efetividade se "desmembrarmos" o código, fora o tempo de processamento porque são, no exemplo da Folha de São Paulo, 400.000 tokens. 12,000 linhas de HTML.
# #### Vou construir manualmente por enquanto, mas é um processo que com certeza pode ser automatizado com algum tipo de ferramenta da área de IA.
#
# #### Para a produção dos resumos duas opções foram cogitadas: o Gemini que é rápido e fácil, mas limitado. A outra opção é rodar alguma LLM localmente através de uma biblioteca ou programa mesmo. Os problemas que isso gera são: custo de processamento; possível imprecisão pelo fato das LLMs rodando localmente serem menos potentes; demora na produção. A vantagem possível é futuramente fazer um "fine tuning" para que a LLM se adeque à tarefa.
# #### Pelo fato de que as notícias podem conter conteúdo "nocivo" e o Gemini não processar algumas, vamos optar primeiramente pelo LLM Studio que é simples e rápido.

# %%
####### Sites que foram pensados

newspaperDF = pd.read_excel('news_source.xlsx')
newspaperDF.head(40)
# Out:
#        country              newspaper                          mainlink
# 0       Brasil     Folha de São Paulo     https://www.folha.uol.com.br/
# 1       Brasil                Estadao       https://www.estadao.com.br/
# 2       Brasil           Uol Economia      https://economia.uol.com.br/
# 3    Argentina                 Clarín           https://www.clarin.com/
# 4    Argentina              La Nacion      https://www.lanacion.com.ar/
# 5    Argentina                 Ambito           https://www.ambito.com/
# 6     Colombia              El Tiempo         https://www.eltiempo.com/
# 7     Colombia          El Espectador     https://www.elespectador.com/
# 8     Colombia             Portafolio        https://www.portafolio.co/
# 9       México           El Universal   https://www.eluniversal.com.mx/
# 10      México                Reforma          https://www.reforma.com/
# 11      México          El Financiero  https://www.elfinanciero.com.mx/
# 12        Peru            El Comercio            https://elcomercio.pe/
# 13        Peru           La Republica           https://larepublica.pe/
# 14        Peru                Gestion               https://gestion.pe/
# 15       Chile            El Mercurio   https://digital.elmercurio.com/
# 16       Chile             La Tercera        https://www.latercera.com/
# 17       Chile     Diario Financierop                https://www.df.cl/
# 18     Bolívia               El Deber           https://eldeber.com.bo/
# 19     Bolívia               La Razon         https://www.la-razon.com/
# 20    Paraguai                    ABC           https://www.abc.com.py/
# 21    Paraguai         Ultima Hora PY       https://www.ultimahora.com/
# 22     Equador            El Universo       https://www.eluniverso.com/
# 23     Uruguai          El Observador  https://www.elobservador.com.uy/
# 24  Inglaterra           The Guardian      https://www.theguardian.com/
# 25     Espanha           El País [ES]       https://elpais.com/america/
# 26      França               Le Monde        https://www.lemonde.fr/en/
# 27         EUA        Washington Post   https://www.washingtonpost.com/
# 28       China          Peoples Daily              http://en.people.cn/
# 29       China            Xinhua News          https://english.news.cn/
# 30      Russia     Rossiyskaya Gazeta                    https://rg.ru/
# 31      Russia             Kommersant        https://www.kommersant.ru/
# 32        Cuba                 Granma            https://www.granma.cu/
# 33    Alemanha  Frankfurter Rundschau                https://www.fr.de/

# %%
######### SQL manual para armazenar os textos

conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

for index, row in newspaperDF.iterrows():
    code = row['mainlink']
    name = row['newspaper']
    country = row['country']
    datatype = 'news'
    dados = (code, name, country, datatype) 
    command = '''
        INSERT INTO news (newspaperlink , newspapername, country, datatype)
        SELECT ?, ?, ?, ?
        WHERE NOT EXISTS (
            SELECT 1 FROM news
            WHERE newspapername = ? AND newspaperlink = ? AND country = ? AND datatype = ?
        )
    '''
    cursor.execute(command, dados + dados)
    conn.commit()
conn.close()

# %%
# Sumarização

# OPÇÃO 1: LLM STUDIO
def llmstudio(noticia):
    # Point to the local server
    client = OpenAI(base_url="http://localhost:1234/v1", api_key="not-needed")

    completion = client.chat.completions.create(
      model="local-model", # this field is currently unused
      messages=[
        {"role": "system", "content": "Você agora é um jornalista preocupado em resumir notícias. A forma com que você escreverá é como se estivesse escrevendo essa notícia em um site. Você está escrevendo para um resumo geral de notícias que aparecerá em uma pequena caixa em um site. Você resumirá a notícia em no máximo 500 caracteres e 3 parágrafos."},
        {"role": "user", "content": f"Resuma em português a seguinte notícia em aproximadamente 500 caracteres e 3 parágrafos:{noticia}"}
      ],
      temperature=0.5,
      timeout = 999  
    )

    texto = completion.choices[0].message
    # Acessando o texto da mensagem
    texto_noticia = texto.content
    return texto_noticia
    
# OPÇÃO 2: SUMARRIZER DO HUGGINFACE (APENAS EM PT-PT)


def ptt5(text):
    token_name = 'unicamp-dl/ptt5-base-portuguese-vocab'
    model_name = 'phpaiola/ptt5-base-summ-xlsum'

    tokenizer = T5Tokenizer.from_pretrained(token_name )
    model_pt = T5ForConditionalGeneration.from_pretrained(model_name)
    inputs = tokenizer.encode(text, max_length=9999, truncation=True, return_tensors='pt')
    summary_ids = model_pt.generate(inputs, max_length=700, min_length=300, num_beams=3, no_repeat_ngram_size=3, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0])
    return summary

# %%
# Tradutor para línguas diferentes do português. O SUMMARIZADOR SÓ RESUME EM PORTUGUÊS!!!

def to_pt(text):
    translator = Translator()
    translated_text = translator.translate(text, dest='pt')
    return translated_text.text

# %%
# Por uma questão de visualização e redundancia, vamos utilizar o próprio sistema também para armazenar os "sumários" e "notícias cruas"

foldersumtext = "text_summaries"
text_summaries = os.path.join(rootdire, foldersumtext)
todaytsfolder = os.path.join(text_summaries, today)
if os.path.exists(text_summaries):
    todaytsfolder = os.path.join(text_summaries, today)
    print(f"trying {todaytsfolder}")
    if os.path.exists(todaytsfolder):
          print("Todays folder for texts and summaries already exists")
    else:
          try:
              os.mkdir(todaytsfolder)
              print("Making diretory")
          except Exception as e:
              print(e)
else:      
    try:
            os.mkdir(text_summaries)
            os.mkdir(todaytsfolder)
            print(f"Making diretory {todaysfolder}")
    except Exception as e:
              print(e)
# Out:
# trying C:\Users\yanme\OneDrive\Área de Trabalho\Portifólio\yfanalise\text_summaries\2024-05-12
# Todays folder for texts and summaries already exists

# %%
# Função para pegar as notícias, sumarizar, traduzir se necessário
def newsatt(journal_url, country, journal_name, arg):
    # Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
    response = requests.get(journal_url)
    response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida

    # Criando um objeto BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    arg = f'''arg'''
    exec(arg)

    headline_text = {}
    summaries = {}
    print(headlines)
    # Acessando os links e obtendo o texto de cada manchete
    for headline in headlines:
        link = headline['href']  # Obtendo o link da manchete

        # Adicionando '12ft.io/' ao link para contornar o paywall
        link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

        # Inicializando o objeto Article da biblioteca newspaper3k
        article = newspaper.Article(link)

        # Baixando e parseando o conteúdo da manchete
        article.download()
        article.parse()

        # Obtendo o texto da manchete
        hlarticle = article.text.strip()
        headline_text[headline] = hlarticle
        if country != "Brasil":
            headline_text[headline] = to_pt(headline_text[headline])
        else:
            pass
        summary = ptt5(headline_text[headline])
        summaries[headline] = summary 
        print(headline_text[headline])
        print('*' * 50) 
        print(summary)
        print('!' * 500)
        name = link.replace("/", "_")
        name = name.replace("https://webcache.googleusercontent.com/search?q=cache:https:__www1.folha.uol.com.br_", " ")
        name = name.strip()
        country = country.lower()
        mother_folder = os.path.join(todaytsfolder, country)
        os.makedirs(mother_folder)
        journal_name = journal_name.lower()
        mother_folder = os.path.join(mother_folder, journal_name)
        os.makedirs(mother_folder)
        print(f"@@@@@@@@ {name} @@@@@@@@@@@@@")
        caminho_arquivo = f'{name}.txt' 
        caminho_arquivo = os.path.join(mother_folder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(headline_text[headline])

        caminho_arquivo = f'sum_{name}.txt'
        caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
        with open(caminho_arquivo, "w") as arquivo:
        # Escrever o texto no arquivo
            arquivo.write(summary)

# %%
news_source = pd.read_excel("news_source_arg.xlsx")

news_source.head(4)
# Out:
#      country           newspaper                       mainlink  \
# 0     Brasil  Folha de São Paulo  https://www.folha.uol.com.br/
# 1     Brasil             Estadao    https://www.estadao.com.br/
# 2     Brasil        Uol Economia   https://economia.uol.com.br/
# 3  Argentina              Clarín        https://www.clarin.com/
#
#                                                  arg
# 0  headlines = soup.select('.c-rotate-headlines__...
# 1  headline_section = soup.find('div', class_='no...
# 2  headline_section = soup.find('div', class_='ro...
# 3  headline_section = soup.find(attrs={attribute:...

# %%
teste = '''for index, rows in news_source.iterrows(): #journal_url, country, journal_name, argument
    country = rows['country']
    journal_name = rows['newspaper']
    journal_url = rows['mainlink']
    arg = rows['arg']
    print(f" ############## Tentando {journal_name}") 
    newsatt(journal_url, country, journal_name, arg)'''

# %%
def sqljournal(journal_name, country, journal_url, news_link, crudenews, summ_news):
    journal_name = unidecode(journal_name)
    journal_name = journal_name.lower()
    journal_name = journal_name.replace(' ', '_')
    conn = sqlite3.connect('yfhistoric.db')
    cursor = conn.cursor()
    cursor.execute(f'''
        CREATE TABLE IF NOT EXISTS {journal_name}(
            id INTEGER PRIMARY KEY,
            country TEXT,
            journal_name TEXT,
            date DATE,
            journal_url TEXT,
            news_link TEXT,
            crudenews TEXT, 
            summ_news TEXT,
            datatype TEXT

        );    
        ''')
    conn.commit()
    
   
    command =f'''
        INSERT INTO {journal_name} (country, journal_name, date, journal_url, news_link, crudenews, summ_news, datatype)
        SELECT ?, ?, ?, ?, ?, ?, ?, ?
        WHERE NOT EXISTS (
            SELECT 1 FROM {journal_name}
            WHERE country = ? AND journal_name = ? AND date = ? AND journal_url = ? AND news_link = ? AND crudenews = ? AND summ_news = ? AND datatype = ?
        )
    '''
    country = country
    date = today
    datatype = 'news'
    dados = (country, journal_name, date, journal_url, news_link, crudenews, summ_news, datatype)
    # Falta fazer a VAR DADOS
    cursor.execute(command, dados + dados)
    
    conn.commit()
    conn.close()

# %%
##### Folha de São Paulo


journal_url = 'https://www1.folha.uol.com.br/'

# Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
response = requests.get(journal_url)
response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida

# Criando um objeto BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Encontrando as manchetes
headlines = soup.select('.c-rotate-headlines__link')[:3]  # Extrai os três primeiros links das manchetes ####### A PARTE DIFÍCIL ESTÁ AQUI

headline_text = {}
summaries = {}

# Acessando os links e obtendo o texto de cada manchete
for headline in headlines:
    link = headline['href']  # Obtendo o link da manchete
    news_link = link
    
    # Adicionando '12ft.io/' ao link para contornar o paywall
    link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

    # Inicializando o objeto Article da biblioteca newspaper3k
    article = newspaper.Article(link)

    # Baixando e parseando o conteúdo da manchete
    article.download()
    article.parse()

    # Obtendo o texto da manchete
    hlarticle = article.text.strip()
    headline_text[headline] = hlarticle
    summary = ptt5(headline_text[headline])
    summaries[headline] = summary 
    print(headline_text[headline])
    print('*' * 50) 
    print(summary)
    print('!' * 500)
    name = link.replace("/", "_")
    name = name.replace("https://webcache.googleusercontent.com/search?q=cache:https:__www1.folha.uol.com.br_", " ")
    name = name.replace("https:__webcache.googleusercontent.com_search?q=cache:https:__f5.folha.uol.com.br", " ")
    name = name.replace("https:__webcache.googleusercontent.com_search?q=cache:", " ")
    name = name.strip()
    print(f"@@@@@@@@ {name} @@@@@@@@@@@@@")
    caminho_arquivo = f'{name}.txt' 
    caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
    with open(caminho_arquivo, "w") as arquivo:
    # Escrever o texto no arquivo
        arquivo.write(headline_text[headline])
    
    caminho_arquivo = f'sum_{name}.txt'
    caminho_arquivo = os.path.join(todaytsfolder, caminho_arquivo)
    with open(caminho_arquivo, "w") as arquivo:
    # Escrever o texto no arquivo
        arquivo.write(summary)
    sqljournal("Folha de São Paulo", "Brasil", journal_url, news_link, headline_text[headline], summary)
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# São Leopoldo (RS)
#
# O almoço de família de Dia das Mães dos desabrigados do Rio Grande do Sul deste ano dará lugar a tristeza e a atividades comandadas por voluntários para animar as mulheres que tiveram as casas alagadas e destruídas.
#
# Franciele Brito se olha em um espelho após ser maquiada em ação da organização em abrigo de São Leopoldo - Foto: Pedro Ladeira/Folhapress - Folhapress
#
# As enchentes que atingiram o estado já causaram mais de cem mortes e obrigaram mais de 600 mil pessoas a saírem de suas casas
#
# Ginásios, instituições de ensino e associações abriram suas portas para receber os cerca de 80 mil desabrigados no estado. Voluntários e funcionários das prefeituras tentam organizar a rotina dos espaços.
#
# Para este domingo (12), Dia das Mães, eles preparam atividades com mães e filhos a fim de animar as famílias, que, na maioria dos casos, perderam a casa, os bens e as memórias que estavam dentro dela.
#
# No centro esportivo municipal de São Leopoldo, cidade que tem cerca de 235 mil habitantes e 180 mil desalojados, os responsáveis pelo espaço organizaram neste sábado um grande salão de beleza improvisado para as mulheres. O local chegou a abrigar 2.000 pessoas, e atualmente ainda tem 800.
#
# A dona de casa Muriele Bronzane, 20, tem três filhos e conta que antes da chuva tinha combinado com o resto da família, que morava no mesmo bairro, um almoço para este domingo. Agora, foi para o abrigo porque, além dela, todos os parentes também perderam suas casas.
#
# Ela gostou da iniciativa dos organizadores. "Fiz cabelo, unha e maquiagem. Foi muito bom para renovar a autoestima, se sentir mais mulher, mais mãe", diz.
#
# O marido dela fazia gesso e perdeu todas as ferramentas de trabalho. Muriele diz que ainda não contou para os filhos que sua residência esta tomada de água até o teto.
#
# "Na hora que a gente voltar lá não quero levar eles para não verem a situação que ficou a casa. Todas as coisinhas deles estavam lá, o material escolar, os brinquedos, as roupas, a TV que eles gostavam", lamenta.
#
# A Unisinos, uma das maiores universidades privadas do país, também fez um abrigo em seu ginásio esportivo. Situada em São Leopoldo, recebe cerca de 2.000 pessoas atingidas pela enchente, com cinco refeições diárias.
#
# Os organizadores dizem que ali se formou uma espécie de mini-prefeitura, com divisão de tarefas e responsabilidades. Professores, funcionários e alunos ajudam na gestão do abrigo.
#
# A instituição fará uma missa com o reitor, que é padre, na manhã de domingo (12). As atividades no local não serão voltadas exclusivamente às mães. Oficinas com brincadeiras interativas e musicais também estão planejadas.
#
# "Vamos falar que é o dia da família, porque se a gente direcionar só para as mães, como ficam as mulheres que não estão com as mães ou filhos aqui? E os homens que estão longe da mãe? Como isso vai ficar na cabeça das pessoas?", diz a psicóloga Joana Pereira, voluntária no local.
#
# A atendente Roseane Freitas, 23, tem um casal de filhos, um com seis meses e outra com três anos, e está na Unisinos há uma semana. Ela diz que a adaptação da filha mais velha no abrigo foi complicada.
#
# Roseana Freitas, abrigada no abrigo da Unisinos, em São Leopoldo, com o filho de seis meses e a filha de 3 anos - Foto: Pedro Ladeira/Folhapress - Folhapress
#
# "No início foi bem difícil, porque ela não está acostumada a conviver com tantas crianças. Ela sempre foi uma criança que brincava sozinha em casa. Agora é tudo novo. Ela não gosta de dividir os brinquedos, mas já está se adaptando melhor, aprendendo com a necessidade", afirma ela, que planeja ir à missa. "Vou se eu conseguir, porque minha menina não para, fica brincando 24 horas por dia e eu tenho que cuidar dela."
#
# A vendedora Janaína Lucas de Oliveira, 29, tem quatro filhos e está há uma semana no centro esportivo de São Leopoldo. "Nunca imaginei passar um Dia das Mães nessas condições e muito menos meu aniversário, que é no próximo dia 19. Já estava tudo pronto para a festa de 30 anos. Mas foi adiada. O que a gente pode fazer, não é?", lamenta.
#
# Ela ficou feliz com o salão de beleza improvisado no local pelos voluntários. "Bem bonita e agradável a ação. Muito bacana", elogia.
#
# Janaína conta que ficou amiga das pessoas que dormem nos colchões próximos ao dela e que ela chama de vizinhas. No entanto, afirma que a rotina está difícil. "Uns dormem 3h da manhã, outros às 2h, às vezes brigam", conta.
#
# A dona de casa Franciele Brito, 26, tem uma filha de 5 anos . "A pequena ficou doente e eu também fiquei. Dormir nesse chão é um horror. Peguei infecção no ouvido de dormir nesse chão gelado", afirma.
#
# Ela diz que a única pessoa da família que não foi atingida pela enchente é uma irmã que mora em Santa Catarina. O deslocamento para o outro estado vizinho está difícil. "A água nunca tinha chegado nem perto lá da minha casa. É muito triste ver o que aconteceu. E a chuva continua. Não sei quando vamos conseguir ir ver como ficou a casa", afirma.
#
# A dona de casa Marileia da Rosa, 40, comemora que seu filho está na casa de um amigo em local seguro, porque tem achado difícil viver no abrigo. Ela diz que morava com seu marido de aluguel e que a casa provavelmente foi destruída, porque as madeiras já estavam frágeis. Agora os dois e seus dois cachorros estão no abrigo.
#
# Marileia da Rosa, que perdeu a casa na inundação e agora está em abrigo em São Leopoldo - Foto: Pedro Ladeira/Folhapress - Folhapress
#
# Marileia pede que o governo dê um auxílio aluguel porque prevê dificuldade na recuperação. Ela é dona de casa e o marido não consegue trabalhar devido a um enfisema pulmonar.
#
# Ela diz que trata um quadro de depressão e que a situação a fez piorar. "Eu tomo remédio e tinha acabado. Agora consegui um. O que me atingiu mais foi a depressão, piorou muito", afirma.
#
# "Perdi todas minhas roupas. Está difícil até para conseguir uma calcinha e eu preciso de uma, já pedi", afirma.
#
# A doméstica Saionara de Oliveira, 56, está há uma semana no abrigo da Unisinos com o marido e a filha de 15 anos. Mesmo se estivesse em casa, porém, não iria fazer nenhuma celebração de Dia das Mães. "Eu não queria mesmo, faz dois meses que perdi meu filho. Mataram ele. Eu não ia comemorar".
# **************************************************
# <pad> O dia das Mães dos desabrigados do Rio Grande do Sul será marcado por tristeza, tristeza e muita tristeza. Desde o início da enchente que atingiu o Estado no início do ano, a cidade de São Leopoldo, no sul do Estado, se tornou palco de uma das maiores tragédias da história recente do país: a tragédia das enchentes que castigam o Rio Grande da Sul, que já deixaram mais de 600 mil mortos e obrigaram milhares de pessoas a deixar suas casas, deixando centenas de milhares de famílias destruídas e deixando mais de 300 mil mortos, segundo a Unisinos (Unisinos), a Universidade Estadual do Sul, em São Leopoldo (RS) e o Centro de Estudos de Famílias e a Universidade Católica de Santa Catarina (Unisul), em Santa Maria do Sul (RS), a partir desta segunda-feira, o dia das mães, para marcar os 30 anos da cidade. A data, no entanto, será marcada por uma missa para as mães e os filhos, em comemoração ao dia da família, para lembrar as famílias que foram atingidas pelas enchentes e deixaram suas casas. A festa de 30 anos começou neste domingo. O dia da mãe, no dia da festa, será celebrado no próximo dia 12 de dezembro. A missa de domingo será celebrada em homenagem às vítimas da enchente e às famílias que perderam suas casas e suas famílias. A celebração, que será celebrada no próximo domingo (12), será marcada para o dia do Trabalho, e também para os filhos.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# @@@@@@@@ https:__www1.folha.uol.com.br_cotidiano_2024_05_almoco-de-familia-da-lugar-a-tristeza-e-trabalho-de-voluntarios-para-animar-maes-em-abrigos-no-rs.shtml @@@@@@@@@@@@@
# São Leopoldo (RS)
#
# O almoço de família de Dia das Mães dos desabrigados do Rio Grande do Sul deste ano dará lugar a tristeza e a atividades comandadas por voluntários para animar as mulheres que tiveram as casas alagadas e destruídas.
#
# Franciele Brito se olha em um espelho após ser maquiada em ação da organização em abrigo de São Leopoldo - Foto: Pedro Ladeira/Folhapress - Folhapress
#
# As enchentes que atingiram o estado já causaram mais de cem mortes e obrigaram mais de 600 mil pessoas a saírem de suas casas
#
# Ginásios, instituições de ensino e associações abriram suas portas para receber os cerca de 80 mil desabrigados no estado. Voluntários e funcionários das prefeituras tentam organizar a rotina dos espaços.
#
# Para este domingo (12), Dia das Mães, eles preparam atividades com mães e filhos a fim de animar as famílias, que, na maioria dos casos, perderam a casa, os bens e as memórias que estavam dentro dela.
#
# No centro esportivo municipal de São Leopoldo, cidade que tem cerca de 235 mil habitantes e 180 mil desalojados, os responsáveis pelo espaço organizaram neste sábado um grande salão de beleza improvisado para as mulheres. O local chegou a abrigar 2.000 pessoas, e atualmente ainda tem 800.
#
# A dona de casa Muriele Bronzane, 20, tem três filhos e conta que antes da chuva tinha combinado com o resto da família, que morava no mesmo bairro, um almoço para este domingo. Agora, foi para o abrigo porque, além dela, todos os parentes também perderam suas casas.
#
# Ela gostou da iniciativa dos organizadores. "Fiz cabelo, unha e maquiagem. Foi muito bom para renovar a autoestima, se sentir mais mulher, mais mãe", diz.
#
# O marido dela fazia gesso e perdeu todas as ferramentas de trabalho. Muriele diz que ainda não contou para os filhos que sua residência esta tomada de água até o teto.
#
# "Na hora que a gente voltar lá não quero levar eles para não verem a situação que ficou a casa. Todas as coisinhas deles estavam lá, o material escolar, os brinquedos, as roupas, a TV que eles gostavam", lamenta.
#
# A Unisinos, uma das maiores universidades privadas do país, também fez um abrigo em seu ginásio esportivo. Situada em São Leopoldo, recebe cerca de 2.000 pessoas atingidas pela enchente, com cinco refeições diárias.
#
# Os organizadores dizem que ali se formou uma espécie de mini-prefeitura, com divisão de tarefas e responsabilidades. Professores, funcionários e alunos ajudam na gestão do abrigo.
#
# A instituição fará uma missa com o reitor, que é padre, na manhã de domingo (12). As atividades no local não serão voltadas exclusivamente às mães. Oficinas com brincadeiras interativas e musicais também estão planejadas.
#
# "Vamos falar que é o dia da família, porque se a gente direcionar só para as mães, como ficam as mulheres que não estão com as mães ou filhos aqui? E os homens que estão longe da mãe? Como isso vai ficar na cabeça das pessoas?", diz a psicóloga Joana Pereira, voluntária no local.
#
# A atendente Roseane Freitas, 23, tem um casal de filhos, um com seis meses e outra com três anos, e está na Unisinos há uma semana. Ela diz que a adaptação da filha mais velha no abrigo foi complicada.
#
# Roseana Freitas, abrigada no abrigo da Unisinos, em São Leopoldo, com o filho de seis meses e a filha de 3 anos - Foto: Pedro Ladeira/Folhapress - Folhapress
#
# "No início foi bem difícil, porque ela não está acostumada a conviver com tantas crianças. Ela sempre foi uma criança que brincava sozinha em casa. Agora é tudo novo. Ela não gosta de dividir os brinquedos, mas já está se adaptando melhor, aprendendo com a necessidade", afirma ela, que planeja ir à missa. "Vou se eu conseguir, porque minha menina não para, fica brincando 24 horas por dia e eu tenho que cuidar dela."
#
# A vendedora Janaína Lucas de Oliveira, 29, tem quatro filhos e está há uma semana no centro esportivo de São Leopoldo. "Nunca imaginei passar um Dia das Mães nessas condições e muito menos meu aniversário, que é no próximo dia 19. Já estava tudo pronto para a festa de 30 anos. Mas foi adiada. O que a gente pode fazer, não é?", lamenta.
#
# Ela ficou feliz com o salão de beleza improvisado no local pelos voluntários. "Bem bonita e agradável a ação. Muito bacana", elogia.
#
# Janaína conta que ficou amiga das pessoas que dormem nos colchões próximos ao dela e que ela chama de vizinhas. No entanto, afirma que a rotina está difícil. "Uns dormem 3h da manhã, outros às 2h, às vezes brigam", conta.
#
# A dona de casa Franciele Brito, 26, tem uma filha de 5 anos . "A pequena ficou doente e eu também fiquei. Dormir nesse chão é um horror. Peguei infecção no ouvido de dormir nesse chão gelado", afirma.
#
# Ela diz que a única pessoa da família que não foi atingida pela enchente é uma irmã que mora em Santa Catarina. O deslocamento para o outro estado vizinho está difícil. "A água nunca tinha chegado nem perto lá da minha casa. É muito triste ver o que aconteceu. E a chuva continua. Não sei quando vamos conseguir ir ver como ficou a casa", afirma.
#
# A dona de casa Marileia da Rosa, 40, comemora que seu filho está na casa de um amigo em local seguro, porque tem achado difícil viver no abrigo. Ela diz que morava com seu marido de aluguel e que a casa provavelmente foi destruída, porque as madeiras já estavam frágeis. Agora os dois e seus dois cachorros estão no abrigo.
#
# Marileia da Rosa, que perdeu a casa na inundação e agora está em abrigo em São Leopoldo - Foto: Pedro Ladeira/Folhapress - Folhapress
#
# Marileia pede que o governo dê um auxílio aluguel porque prevê dificuldade na recuperação. Ela é dona de casa e o marido não consegue trabalhar devido a um enfisema pulmonar.
#
# Ela diz que trata um quadro de depressão e que a situação a fez piorar. "Eu tomo remédio e tinha acabado. Agora consegui um. O que me atingiu mais foi a depressão, piorou muito", afirma.
#
# "Perdi todas minhas roupas. Está difícil até para conseguir uma calcinha e eu preciso de uma, já pedi", afirma.
#
# A doméstica Saionara de Oliveira, 56, está há uma semana no abrigo da Unisinos com o marido e a filha de 15 anos. Mesmo se estivesse em casa, porém, não iria fazer nenhuma celebração de Dia das Mães. "Eu não queria mesmo, faz dois meses que perdi meu filho. Mataram ele. Eu não ia comemorar".
# **************************************************
# <pad> O dia das Mães dos desabrigados do Rio Grande do Sul será marcado por tristeza, tristeza e muita tristeza. Desde o início da enchente que atingiu o Estado no início do ano, a cidade de São Leopoldo, no sul do Estado, se tornou palco de uma das maiores tragédias da história recente do país: a tragédia das enchentes que castigam o Rio Grande da Sul, que já deixaram mais de 600 mil mortos e obrigaram milhares de pessoas a deixar suas casas, deixando centenas de milhares de famílias destruídas e deixando mais de 300 mil mortos, segundo a Unisinos (Unisinos), a Universidade Estadual do Sul, em São Leopoldo (RS) e o Centro de Estudos de Famílias e a Universidade Católica de Santa Catarina (Unisul), em Santa Maria do Sul (RS), a partir desta segunda-feira, o dia das mães, para marcar os 30 anos da cidade. A data, no entanto, será marcada por uma missa para as mães e os filhos, em comemoração ao dia da família, para lembrar as famílias que foram atingidas pelas enchentes e deixaram suas casas. A festa de 30 anos começou neste domingo. O dia da mãe, no dia da festa, será celebrado no próximo dia 12 de dezembro. A missa de domingo será celebrada em homenagem às vítimas da enchente e às famílias que perderam suas casas e suas famílias. A celebração, que será celebrada no próximo domingo (12), será marcada para o dia do Trabalho, e também para os filhos.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# @@@@@@@@ https:__www1.folha.uol.com.br_cotidiano_2024_05_almoco-de-familia-da-lugar-a-tristeza-e-trabalho-de-voluntarios-para-animar-maes-em-abrigos-no-rs.shtml @@@@@@@@@@@@@
# O governo do Rio Grande do Sul estima inicialmente em R$ 30 bilhões o custo para mudar de local três cidades afetadas pelas enchentes no estado: Cruzeiro do Sul, Roca Sales e Muçum.
#
# Imagens de drone mostram a destruição no município de Roca Sales, no vale do Taquari, causadas pelas fortes chuvas - Pedro Ladeira/folhapress
#
# As três, com populações entre 5 e 10 mil habitantes, ficam à margem do rio Taquari, um dos mais afetados pelas fortes chuvas. No ano passado, em outro desastre no estado, já haviam sido inundadas.
#
# A conclusão agora é que ao menos parte das populações desses municípios terá de ser transferida para áreas mais altas, para evitar tragédias futuras. O custo de realizar a operação, no entanto, que envolve desapropriações e construções, é considerado um complicador para um estado que já enfrenta dificuldades fiscais.
# **************************************************
# <pad> O governo do Rio Grande do Sul anunciou nesta quarta-feira que vai transferir parte das áreas afetadas pelas fortes chuvas que atingiram o Estado no mês passado, para áreas mais atingidas pelas enchentes que já deixaram mais de 20 mil mortos no estado do Taquari, no sul do país. A estimativa é de que o custo total da operação seja o equivalente a cerca de R$ 230 bilhões, segundo estimativas do governo do Estado. A informação foi divulgada pela imprensa oficial do Estado, que prevê a desapropriação de mais de 300 mil pessoas até o fim do ano que vem. A previsão é de um total de 20 milhões de pessoas. O total é de 230 mil pessoas, de acordo com a agência de notícias Reuters, a R$ 470 milhões (R$ 430 milhões). A estimativa foi divulgada nesta terça-feira pelo Ministério das Relações Exteriores, o maior desastre da história recente do Rio de Janeiro, que já contabiliza mais de 2 bilhões de pessoas no estado. A soma soma é de 3,2 bilhões de habitantes, o que equivale a quase um quarto da população mundial, segundo dados do governo estadual, divulgados pela BBC Brasil, em janeiro de 2005. A estimativa era de que a região fosse inundada por enchentes no Estado, em março de 2005. O total de prejuízos, no entanto, é de cerca de US$ 270 bilhões. A conta começa a ser divulgada no mês que vem, em um ano, até o dia 30 de julho.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# @@@@@@@@ https:__www1.folha.uol.com.br_colunas_painel_2024_05_custo-de-deslocar-cidades-no-rs-chega-a-r-30-bi-estima-governo.shtml @@@@@@@@@@@@@

# %%
##### estadão

journal_url = 'https://www.estadao.com.br/'

# Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
response = requests.get(journal_url)
response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida

# Criando um objeto BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Encontrando a parte do HTML que contém as manchetes
headline_section = soup.find('div', class_='noticia-content-block')

        # Verificando se a seção de manchetes foi encontrada
if headline_section:
            # Extrair os links das manchetes
    headlines = headline_section.find_all('a')[:3]  # Extrai os três primeiros links das manchetes

    headlines_text = []

            # Acessando os links e obtendo o texto de cada manchete
    for headline in headlines:
        link = headline['href']  # Obtendo o link da manchete
        news_link = link        
                # Adicionando '12ft.io/' ao link para contornar o paywall
        link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

        # Inicializando o objeto Article da biblioteca newspaper3k
        article = newspaper.Article(link)

        # Baixando e parseando o conteúdo da manchete
        article.download()
        article.parse()

                
        hlarticle = article.text.strip()
        headline_text[headline] = hlarticle
        summary = ptt5(headline_text[headline])
        summaries[headline] = summary 
        print(headline_text[headline])
        print('*' * 50) 
        print(summary)
        print('!' * 500)
        sqljournal("Estadão", "Brasil", journal_url, news_link, headline_text[headline], summary)
else: 
    print('error')
# Out:
# Investimentos bilionários devem turbinar o Produto Interno Bruto (PIB) do Nordeste e fazer a economia local crescer num ritmo mais acelerado do que a média do Brasil no longo prazo. De acordo com um estudo realizado pela consultoria Tendências, a região deve ter uma expansão média de 3,4% ao ano entre 2026 e 2034, acima dos 2,5% que serão observados para o País nesse período.
#
# PUBLICIDADE As previsões positivas para o Nordeste - onde vivem quase 60 milhões de pessoas, que representam quase 30% da população brasileira - estão baseadas numa série de investimentos públicos e privados previstos para os próximos anos. Ao todo, eles devem somar R$ 750 bilhões. “O Nordeste vai ter um ganho de tração com exploração de gás natural e petróleo, energia eólica, concessão de aeroportos e com uma série de privatizações de companhias de energia elétrica e de saneamento”, afirma Lucas Assis, economista da consultoria Tendências.
#
# No período de 2026 e 2034, o segundo melhor crescimento será colhido pela região Norte (3,1%), seguida por Centro-Oeste (2,9%), Sudeste (2,2%) e Sul (2,1%).
#
# As projeções para o Brasil e, sobretudo, para a região Sul, no entanto, passaram a ter um viés de baixa por causa das enchentes no Rio Grande do Sul.
#
# Posição de destaque
#
# Se os números se confirmarem, o Nordeste vai voltar a ocupar uma posição de destaque no cenário econômico local. No início dos anos 2000, a região apresentou expressivo crescimento - e na maior parte do tempo, chegou a superar o desempenho brasileiro.
#
# “No começo dos anos 2000, a região Nordeste - e o Brasil como um todo - foi beneficiada por uma combinação de fatores muito particular naquele período”, diz Assis. “Houve o boom das commodities (no cenário internacional), o Brasil passou por uma série de políticas públicas de erradicação da pobreza, que beneficiou muito a região Nordeste em termos do consumo da família.”
#
# Publicidade
#
# Mas desde a crise do biênio 2015 e 2016, a região tem apresentado taxas de crescimento mais modestas, acompanhando o desempenho do País ou até ficando abaixo. A região é bastante influenciada pelos setores sensíveis ao ciclo econômico, como é o caso do setor de serviços. Em 2020, por exemplo, no ano de auge da pandemia, o PIB brasileiro recuou 3,3%, e o nordestino apresentou queda de 4,1%.
#
# Novo ciclo de crescimento
#
# Agora, o crescimento da região deve ser liderado pelo setor industrial. Segundo a Tendências, de 2026 a 2034, a previsão é que a indústria apresente um crescimento anual de 4,3%.
#
# Dos investimentos bilionários, a maior parte será público, impulsionado pelo novo Programa de Aceleração do Crescimento (PAC), uma das principais apostas do terceiro governo do presidente Luiz Inácio Lula da Silva na economia. Ao todo, o plano destinou R$ 700 bilhões para a região.
#
# “Os investimentos públicos em infraestrutura serão um importante impulsionador do Nordeste”, afirma Assis. “Isso tudo gera um efeito em cadeia para a economia no longo prazo.”
#
# No ano passado, ao anunciar a volta do PAC, o governo previu um investimento de cerca de R$ 1,7 trilhão em todo o País. “No caso da União, precisa ter a capacidade de fazer boas parcerias público privadas, porque os recursos públicos não são suficientes para bancar os projetos, e aumentar a capacidade de execução do PAC, que no passado foi muito baixa”, afirma Jorge Jatobá, economista da consultoria Ceplan.
#
# O conjunto Eólico Santo Agostinho, da Engie, no Rio Grande do Norte, é um dos grandes projetos no Nordeste (R$ 2,3 bilhões); são 14 parques eólicos e 70 aerogeradores. Foto: Canindé Soares/Estadão
#
# PUBLICIDADE Energia renovável Da iniciativa privada, os principais investimentos virão do setor de energias renováveis. Só do setor eólico há R$ 21 bilhões de parques em construção, com capacidade para gerar 3 mil megawatts (MW). Há ainda cerca de R$ 130 bilhões de projetos outorgados (18 mil MW), mas ainda não iniciados na região, segundo dados da Associação Brasileira de Energia Eólica (Abeeólica). “A cada R$ 1 que se investe em energia você devolve para o PIB R$ 2,9. Há um efeito de cadeia produtiva para todo o País. Olhando para o Nordeste o efeito é ainda mais amplo, pois nos últimos anos o IDHM (Índice de Desenvolvimento Humano dos Municípios) cresceu 20% com a chegada dos parques eólicos”, diz a presidente da Abeeólica, Elbia Gannoun. Um dos grandes projetos da região é o Conjunto Eólico Santo Agostinho, no Rio Grande do Norte, da Engie. Localizado nos municípios de Lajes (9,8 mil pessoas) e Pedro Avelino (6 mil pessoas), o empreendimento é formado por 14 parques eólicos e 70 aerogeradores. O projeto, de R$ 2,3 bilhões, terá capacidade instalada de 434 MW e já tem alguns aerogeradores em operação comercial desde o ano passado.
#
# A empresa tem outro megraprojeto em construção no Nordeste. Com R$ 6 bilhões de investimentos, o Conjunto Eólico Serra do Assuruá, na Bahia, poderá gerar 846 MW. O empreendimento terá 188 aerogeradores e está com 44% de obras concluídas.
#
# “O Nordeste do Brasil é um paraíso para desenvolver projetos de energia renovável, o fator de capacidade das eólicas é fantástico, representando uma excelente oportunidade de desenvolvimento para a região”, diz o CEO da Engie no Brasil, Maurício Bähr.
#
# Em alta Economia Quebra da unanimidade do Copom poderá acabar custando caro se não houver explicação Dólar nas alturas: a pergunta correta a fazer Brasil deve subir para 8ª posição no ranking das maiores economias do mundo em 2024, prevê FMI Segundo ele, com a abundância de energia na região pode-se atrair investimentos de empresas industriais que desejem produzir seus produtos com baixas emissões, um selo verde, garantindo sustentabilidade e atração de consumidores concientes com o bem-estar do planeta. Os projetos de energia solar também têm ajudado a turbinar os investimentos na região. Segundo dados da Associação Brasileira de Energia Solar (Absolar), no total são mais de R$ 60 bilhões em geração distribuída (aquela no telhado das casas) e geração centralizada (de grandes parques solares). Bahia, Piauí e Ceará são os Estados com maior volume de investimentos, com quase dois terços do volume total da região. Outro setores Um setor que tem ganhado relevância no Nordeste é o de saneamento. Diante da carência dos serviços, como água e esgoto, Estados e municípios da região decidiram apostar na iniciativa privada para melhorar e aumentar o atendimento da população. Os investimentos contratados até 2026 devem somar quase R$ 66 bilhões para um prazo médio de 30 anos, em 842 municípios, de acordo com um monitoramento realizado pela Abcon Sindcon (Associação e Sindicato Nacional das Concessionárias Privadas de Serviços Públicos de Água e Esgoto) com base nos dados da Radar PPP e do Banco Nacional de Desenvolvimento Econômico e Social (BNDES). A maior parte desses recursos a serem investidos, no entanto, deve se concentrar nos primeiros 10 e 15 anos por causa da necessidade de se cumprir o marco do saneamento, que prevê que 99% da população terá água tratada e 90% do esgoto precisará ser coletado até 2033.
#
# Publicidade
#
# Os principais investimentos em saneamento serão realizados em Pernambuco (quase R$ 24,8 bilhões), seguido por Maranhão (R$ 19 bilhões) e Piauí (R$ 9,9 bilhões).
#
# Mas também há investimentos em outros setores, como o automotivo. A Stellantis (dona das marcas Fiat, Peugeot e Citroën, Jeep e Ram), por exemplo, vai investir R$ 13 bilhões na fábrica do grupo em Goiania, no norte de Pernambuco. Esse montante faz parte do ciclo de investimento de R$ 30 bilhões para o Brasil entre 2025 e 2030.
#
# Além da expansão da fábrica, o plano da empresa prevê a ampliação do parque de fornecedores no entorno da fábrica de Goiana, dos atuais 38 para mais de 100 nos próximos anos - o que tende a turbinar o PIB dos municípios da região, gerando emprego e renda.
# **************************************************
# <pad> A região Nordeste do Brasil deve voltar a ocupar uma posição de destaque no ranking das maiores economias do mundo em 2026 e 2034, depois da pandemia de covid-19, que atingiu a região no início do ano passado, em meio a uma série de políticas públicas de erradicação da pobreza e à crise econômica. A região, no entanto, ainda é uma das regiões mais afetadas pela crise econômica do século passado. O crescimento da economia brasileira deve subir para 8a posição no ranking dos maiores países do mundo, de acordo com dados divulgados nesta terça-feira pela consultoria Tendências, que prevê um crescimento de 2,5% ao ano no período entre 2026 a 2034. O Brasil deve crescer mais do que o Brasil em 2033, em comparação com a região do Sudeste e Sul, em 2030, segundo dados do IBGE divulgados na quarta-feira (29/03). A região ainda é um paraíso para investimentos em infraestrutura e investimentos em energia elétrica e de energia solar, e o Brasil deve ser um dos países mais afetados pela pandemia do novo coronavírus em 2028 e 2021, segundo previsões de analistas ouvidos pela BBC Brasil. A afirmação foi feita em entrevista exclusiva à BBC Brasil, divulgada nesta sexta-feira pelo Centro-Oeste e o Nordeste Brasileiro, que deve chegar a R$ 7,2 trilhões de investimentos no ano que vem, em um relatório divulgado nesta quinta-feira por uma empresa de energia eólicas, em entrevista à BBC News Brasil.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Investimentos bilionários devem turbinar o Produto Interno Bruto (PIB) do Nordeste e fazer a economia local crescer num ritmo mais acelerado do que a média do Brasil no longo prazo. De acordo com um estudo realizado pela consultoria Tendências, a região deve ter uma expansão média de 3,4% ao ano entre 2026 e 2034, acima dos 2,5% que serão observados para o País nesse período.
#
# PUBLICIDADE As previsões positivas para o Nordeste - onde vivem quase 60 milhões de pessoas, que representam quase 30% da população brasileira - estão baseadas numa série de investimentos públicos e privados previstos para os próximos anos. Ao todo, eles devem somar R$ 750 bilhões. “O Nordeste vai ter um ganho de tração com exploração de gás natural e petróleo, energia eólica, concessão de aeroportos e com uma série de privatizações de companhias de energia elétrica e de saneamento”, afirma Lucas Assis, economista da consultoria Tendências.
#
# No período de 2026 e 2034, o segundo melhor crescimento será colhido pela região Norte (3,1%), seguida por Centro-Oeste (2,9%), Sudeste (2,2%) e Sul (2,1%).
#
# As projeções para o Brasil e, sobretudo, para a região Sul, no entanto, passaram a ter um viés de baixa por causa das enchentes no Rio Grande do Sul.
#
# Posição de destaque
#
# Se os números se confirmarem, o Nordeste vai voltar a ocupar uma posição de destaque no cenário econômico local. No início dos anos 2000, a região apresentou expressivo crescimento - e na maior parte do tempo, chegou a superar o desempenho brasileiro.
#
# “No começo dos anos 2000, a região Nordeste - e o Brasil como um todo - foi beneficiada por uma combinação de fatores muito particular naquele período”, diz Assis. “Houve o boom das commodities (no cenário internacional), o Brasil passou por uma série de políticas públicas de erradicação da pobreza, que beneficiou muito a região Nordeste em termos do consumo da família.”
#
# Publicidade
#
# Mas desde a crise do biênio 2015 e 2016, a região tem apresentado taxas de crescimento mais modestas, acompanhando o desempenho do País ou até ficando abaixo. A região é bastante influenciada pelos setores sensíveis ao ciclo econômico, como é o caso do setor de serviços. Em 2020, por exemplo, no ano de auge da pandemia, o PIB brasileiro recuou 3,3%, e o nordestino apresentou queda de 4,1%.
#
# Novo ciclo de crescimento
#
# Agora, o crescimento da região deve ser liderado pelo setor industrial. Segundo a Tendências, de 2026 a 2034, a previsão é que a indústria apresente um crescimento anual de 4,3%.
#
# Dos investimentos bilionários, a maior parte será público, impulsionado pelo novo Programa de Aceleração do Crescimento (PAC), uma das principais apostas do terceiro governo do presidente Luiz Inácio Lula da Silva na economia. Ao todo, o plano destinou R$ 700 bilhões para a região.
#
# “Os investimentos públicos em infraestrutura serão um importante impulsionador do Nordeste”, afirma Assis. “Isso tudo gera um efeito em cadeia para a economia no longo prazo.”
#
# No ano passado, ao anunciar a volta do PAC, o governo previu um investimento de cerca de R$ 1,7 trilhão em todo o País. “No caso da União, precisa ter a capacidade de fazer boas parcerias público privadas, porque os recursos públicos não são suficientes para bancar os projetos, e aumentar a capacidade de execução do PAC, que no passado foi muito baixa”, afirma Jorge Jatobá, economista da consultoria Ceplan.
#
# O conjunto Eólico Santo Agostinho, da Engie, no Rio Grande do Norte, é um dos grandes projetos no Nordeste (R$ 2,3 bilhões); são 14 parques eólicos e 70 aerogeradores. Foto: Canindé Soares/Estadão
#
# PUBLICIDADE Energia renovável Da iniciativa privada, os principais investimentos virão do setor de energias renováveis. Só do setor eólico há R$ 21 bilhões de parques em construção, com capacidade para gerar 3 mil megawatts (MW). Há ainda cerca de R$ 130 bilhões de projetos outorgados (18 mil MW), mas ainda não iniciados na região, segundo dados da Associação Brasileira de Energia Eólica (Abeeólica). “A cada R$ 1 que se investe em energia você devolve para o PIB R$ 2,9. Há um efeito de cadeia produtiva para todo o País. Olhando para o Nordeste o efeito é ainda mais amplo, pois nos últimos anos o IDHM (Índice de Desenvolvimento Humano dos Municípios) cresceu 20% com a chegada dos parques eólicos”, diz a presidente da Abeeólica, Elbia Gannoun. Um dos grandes projetos da região é o Conjunto Eólico Santo Agostinho, no Rio Grande do Norte, da Engie. Localizado nos municípios de Lajes (9,8 mil pessoas) e Pedro Avelino (6 mil pessoas), o empreendimento é formado por 14 parques eólicos e 70 aerogeradores. O projeto, de R$ 2,3 bilhões, terá capacidade instalada de 434 MW e já tem alguns aerogeradores em operação comercial desde o ano passado.
#
# A empresa tem outro megraprojeto em construção no Nordeste. Com R$ 6 bilhões de investimentos, o Conjunto Eólico Serra do Assuruá, na Bahia, poderá gerar 846 MW. O empreendimento terá 188 aerogeradores e está com 44% de obras concluídas.
#
# “O Nordeste do Brasil é um paraíso para desenvolver projetos de energia renovável, o fator de capacidade das eólicas é fantástico, representando uma excelente oportunidade de desenvolvimento para a região”, diz o CEO da Engie no Brasil, Maurício Bähr.
#
# Em alta Economia Quebra da unanimidade do Copom poderá acabar custando caro se não houver explicação Dólar nas alturas: a pergunta correta a fazer Brasil deve subir para 8ª posição no ranking das maiores economias do mundo em 2024, prevê FMI Segundo ele, com a abundância de energia na região pode-se atrair investimentos de empresas industriais que desejem produzir seus produtos com baixas emissões, um selo verde, garantindo sustentabilidade e atração de consumidores concientes com o bem-estar do planeta. Os projetos de energia solar também têm ajudado a turbinar os investimentos na região. Segundo dados da Associação Brasileira de Energia Solar (Absolar), no total são mais de R$ 60 bilhões em geração distribuída (aquela no telhado das casas) e geração centralizada (de grandes parques solares). Bahia, Piauí e Ceará são os Estados com maior volume de investimentos, com quase dois terços do volume total da região. Outro setores Um setor que tem ganhado relevância no Nordeste é o de saneamento. Diante da carência dos serviços, como água e esgoto, Estados e municípios da região decidiram apostar na iniciativa privada para melhorar e aumentar o atendimento da população. Os investimentos contratados até 2026 devem somar quase R$ 66 bilhões para um prazo médio de 30 anos, em 842 municípios, de acordo com um monitoramento realizado pela Abcon Sindcon (Associação e Sindicato Nacional das Concessionárias Privadas de Serviços Públicos de Água e Esgoto) com base nos dados da Radar PPP e do Banco Nacional de Desenvolvimento Econômico e Social (BNDES). A maior parte desses recursos a serem investidos, no entanto, deve se concentrar nos primeiros 10 e 15 anos por causa da necessidade de se cumprir o marco do saneamento, que prevê que 99% da população terá água tratada e 90% do esgoto precisará ser coletado até 2033.
#
# Publicidade
#
# Os principais investimentos em saneamento serão realizados em Pernambuco (quase R$ 24,8 bilhões), seguido por Maranhão (R$ 19 bilhões) e Piauí (R$ 9,9 bilhões).
#
# Mas também há investimentos em outros setores, como o automotivo. A Stellantis (dona das marcas Fiat, Peugeot e Citroën, Jeep e Ram), por exemplo, vai investir R$ 13 bilhões na fábrica do grupo em Goiania, no norte de Pernambuco. Esse montante faz parte do ciclo de investimento de R$ 30 bilhões para o Brasil entre 2025 e 2030.
#
# Além da expansão da fábrica, o plano da empresa prevê a ampliação do parque de fornecedores no entorno da fábrica de Goiana, dos atuais 38 para mais de 100 nos próximos anos - o que tende a turbinar o PIB dos municípios da região, gerando emprego e renda.
# **************************************************
# <pad> A região Nordeste do Brasil deve voltar a ocupar uma posição de destaque no ranking das maiores economias do mundo em 2026 e 2034, depois da pandemia de covid-19, que atingiu a região no início do ano passado, em meio a uma série de políticas públicas de erradicação da pobreza e à crise econômica. A região, no entanto, ainda é uma das regiões mais afetadas pela crise econômica do século passado. O crescimento da economia brasileira deve subir para 8a posição no ranking dos maiores países do mundo, de acordo com dados divulgados nesta terça-feira pela consultoria Tendências, que prevê um crescimento de 2,5% ao ano no período entre 2026 a 2034. O Brasil deve crescer mais do que o Brasil em 2033, em comparação com a região do Sudeste e Sul, em 2030, segundo dados do IBGE divulgados na quarta-feira (29/03). A região ainda é um paraíso para investimentos em infraestrutura e investimentos em energia elétrica e de energia solar, e o Brasil deve ser um dos países mais afetados pela pandemia do novo coronavírus em 2028 e 2021, segundo previsões de analistas ouvidos pela BBC Brasil. A afirmação foi feita em entrevista exclusiva à BBC Brasil, divulgada nesta sexta-feira pelo Centro-Oeste e o Nordeste Brasileiro, que deve chegar a R$ 7,2 trilhões de investimentos no ano que vem, em um relatório divulgado nesta quinta-feira por uma empresa de energia eólicas, em entrevista à BBC News Brasil.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# O Fundo Monetário Internacional (FMI) revisou para cima o PIB do Brasil para o ano de 2024. A atualização do relatório World Economic Outlook indica crescimento de 2,2% neste ano, ante o 1,7% calculado anteriormente. Caso sejam confirmadas as estimativas do FMI, o país deve subir uma posição no ranking das maiores economias do mundo (veja abaixo), saltando de 9º para 8º lugar.
#
# O relatório classifica o crescimento de 2,2% como moderado e afirma que ele se dá com base na consolidação fiscal e reflete as atuais políticas econômicas em vigor. “Os pressupostos da política monetária são consistentes, tendo como meta a convergência da inflação dentro da faixa de tolerância até o final de 2024″, diz o trecho do documento. Para o ano de 2025, a projeção de crescimento da economia brasileira é de 2,1%.
#
# Brasil deve subir para a 8ª posição no ranking das maiores economias do mundo, caso sejam confirmadas as estimativas do FMI. Foto: Tiago Queiroz/Estadão
#
# O Brasil voltou a figurar entre as 10 maiores economias do mundo no ano passado, alcançando a 9ª posição com a alta de 2,9% no PIB em 2023. Pelos cálculos do FMI, a soma do PIB brasileiro deve ser de US$ 2,331 trilhões, pouco acima da 9ª colocada, a Itália, com projeção de US$ 2,328 trilhões. O FMI indica que o Brasil continuará em 8º lugar até 2029, último ano para o qual faz projeções.
#
# PUBLICIDADE O fundo analisa que, apesar das muitas previsões sombrias devido aos efeitos da pandemia e à guerra entre Ucrânia e Rússia, o mundo evitou uma recessão, e o sistema bancário revelou-se em grande parte resiliente. Além disso, as economias dos mercados emergentes não sofreram paradas bruscas. Confira abaixo o ranking das maiores economias do mundo em 2024, segundo as projeções do FMI:
# **************************************************
# <pad> A economia brasileira deve crescer 2,2% neste ano, segundo projeções do Fundo Monetário Internacional (FMI), divulgadas nesta terça-feira. O Brasil é o país com a maior economia do mundo, com crescimento de 2,1%, segundo o relatório World Economic Outlook, divulgado nesta quarta-feira pelo governo brasileiro. A projeção é de 1,2%, segundo dados divulgados pelo governo nesta segunda-feira, e é o mais alto já registrado desde a pandemia de covid-19 em 2024. A estimativa é de 2,5% do Produto Interno Bruto (PIB) do mundo. Segundo o relatório, o Brasil deve subir para a 8a posição no ranking das maiores economias do mundo até 2029, segundo as projeções do FMI, divulgados nesta quarta (27/3). A taxa de crescimento é de 2%, o maior crescimento dos últimos 20 anos. Segundo a projeção, a economia brasileira crescerá 2,8% até 2028, segundo projeção divulgada nesta sexta-feira por um relatório divulgado nesta terça (horário de Brasília) nesta quarta. O país deve ficar em 8o lugar no ranking dos países mais ricos do mundo em 2025, o que deve ser o menor crescimento da história do planeta até 2030, segundo a projeção. A previsão é divulgada nesta quarta, com projeção de 4,2% no relatório divulgado pelo FMI (Fundo Monetório Interamericano de Desenvolvimento) e divulgada nesta quinta-feira no site da BBC Brasil.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
##### UOL

journal_url = 'https://economia.uol.com.br/'

# Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
response = requests.get(journal_url)
response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida

# Criando um objeto BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Encontrando a parte do HTML que contém as manchetes
headline_section = soup.find('div', class_='row')

        # Verificando se a seção de manchetes foi encontrada
if headline_section:
            # Extrair os links das manchetes
    headlines = headline_section.find_all('a')[:3]  # Extrai os três primeiros links das manchetes

    headlines_text = []

            # Acessando os links e obtendo o texto de cada manchete
    for headline in headlines:
        link = headline['href']  # Obtendo o link da manchete
        news_link = link        
                # Adicionando '12ft.io/' ao link para contornar o paywall
        link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

        # Inicializando o objeto Article da biblioteca newspaper3k
        article = newspaper.Article(link)

        # Baixando e parseando o conteúdo da manchete
        article.download()
        article.parse()

                
        hlarticle = article.text.strip()
        headline_text[headline] = hlarticle
        summary = ptt5(headline_text[headline])
        summaries[headline] = summary 
        print(headline_text[headline])
        print('*' * 50) 
        print(summary)
        print('!' * 500)
        sqljournal("Uol Economia", "Brasil", journal_url, news_link, headline_text[headline], summary)
else: 
    print('error')
# Out:
# Concursos públicos oferecem 36.496 vagas em todas as regiões do país, com salários de até R$ 24 mil.
#
# Concursos abertos
#
# O maior concurso tem 4.644 vagas. Elas são oferecidas pela Fundação Municipal de Saúde de Teresina (PI).
#
# O salário mais alto é de R$ 24 mil. O valor será pago para quem passar no concurso da Prefeitura de Santana de Parnaíba (SP).
# **************************************************
# <pad> A Prefeitura de Santana de Parnaíba (PI) realiza neste domingo o maior concurso público público da história do país, com vagas de até R$ 24 mil. O total de vagas é superior a R$ 4.644 vagas. O valor total do concurso é de R$ 3,2 mil, com salários de até 13.641.644.686 vagas, com chances de contratação até o dia 30 de junho. O número de vagas são limitadas para as regiões metropolitanas de Teresina (PI), com salários a partir de 13 de julho. A taxa de desemprego é de 3,3 milhões de vagas. A cidade é administrada por uma empresa de saneamento de água e energia elétrica, a Prefeitura Municipal de Santana do Parnaíba (SP), com vagas para o próximo ano de 2019. O valor do concurso será pago a partir desta segunda-feira. O salário será pago em R$ 2,24 mil (R$ 4,2 milhões) e o valor total da concorrência é de até US$ 280 mil. A seleção será divulgada no final do mês de novembro, com a data de abertura de inscrições para o final do ano. A notícia foi divulgada nesta terça-feira no site da Fundação Municipal de Saúde de São Paulo (Fundação do Estado) e foi divulgada pela primeira vez na internet. A informação foi divulgada pelo Ministério da Educação. A BBC Brasil divulgou o resultado do resultado do concurso público divulgado nesta terça (03/11). O resultado é divulgado no final da semana.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Newsletter
#
# OLHAR APURADO
#
# Uma curadoria diária com as opiniões dos colunistas do UOL sobre os principais assuntos do noticiário.
# **************************************************
# <pad> O jornal britânico UOL publicou nesta terça-feira uma coluna com os principais colunistas sobre o mundo do entretenimento e os principais assuntos da noite. A BBC Brasil convidou os leitores a compartilharem suas opiniões sobre os principais acontecimentos da semana e o que acham do mundo das notícias. O conteúdo da edição desta quarta-feira é o mais completo da história do UOL, o diário diário UOL. Leia o conteúdo da publicação no final da edição deste sábado. A notícia foi publicada na edição desta semana do jornal diário diário diário The UOL, com a opinião dos colunistas da BBC Brasil, da BBC Newsletter, Twitter e Twitter, sobre o atual momento da economia do país. O UOL é o principal canal de notícias do mundo da internet. O portal da BBC.com.br, o UOL e a BBC Brasil estão reunidos em um site que reúne informações sobre o jornal, notícias e notícias sobre a vida e as principais notícias do dia a dia, o que mostra os principais notícias dos principais assuntos do momento. O blog é um dos principais veículos de comunicação do mundo. O diário diário da BBC acompanha o noticiário da noite e o perfil dos principais notícias sobre o Brasil. O site é o único da história, com o link de notícias atualizado com a última edição do jornal. O íntegra da notícia é a BBC NewsLetter.com www.global.com/LHRRR$ 247.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# PMEs registraram crescimento no 1º trimestre
#
# Desempenho positivo no primeiro trimestre do ano. Siomara faz parte da fatia de pequenas e médias empresas (PMEs) que registram crescimento de 11,5% nos primeiros três meses do ano, segundo o Índice Omie de Desempenho Econômico das PMEs (IODE-PMEs).
#
# Queda dos juros ajudou. Felipe Beraldi, economista e gerente de indicadores e estudos econômicos da Omie, atribui o crescimento à melhora do mercado de trabalho, à queda da Selic (taxa básica de juros) e aos incentivos do governo federal.
#
# De modo geral, o mercado de PME tem um cenário favorável desde o segundo semestre do ano passado, com a retomada do mercado de trabalho, as políticas de incentivo, como a ampliação do Bolsa Família, o reajuste real do salário-mínimo, maior controle inflacionário, redução dos juros... tudo isso tem efeito positivo no poder de compra das famílias e reflete na economia.
#
# Felipe Beraldi, Economista e gerente de indicadores e estudos econômicos da Omie
#
# Conteúdo UOL
#
# Recuperação começou no ano passado. Décio Lima, presidente do Sebrae, também diz que a recuperação da economia brasileira e, consequentemente, das Pmes, iniciou no ano passado, quando o Brasil passou a ser o segundo colocado no mundo em termos de investimentos internacionais, perdendo apenas para os Estados Unidos.
#
# PMEs geram empregos. Ele também destacou que, "no acumulado do ano passado, houve um saldo de 1,48 milhão de novas contratações, o que resultou no menor patamar de desemprego registrado desde 2014". E que, "pelo terceiro ano seguido, as micro e pequenas empresas foram as grandes protagonistas na geração de novos postos de trabalho no país, respondendo por 8 em cada 10 empregos criados em 2023."
# **************************************************
# <pad> A economia brasileira cresceu no primeiro trimestre do ano passado, impulsionado pela recuperação do mercado de trabalho e pela redução dos juros, segundo dados do Sebrae (Sebrae, sigla em inglês), órgão que regula o mercado de emprego no Brasil. O crescimento foi registrado em 2023, segundo a economista Siomara Vieira de Lima, presidente do Sindicato dos Trabalhadores (Sindi-Brasileiros) e presidente do Conselho Nacional de Estatísticas (CES) do Ministério do Trabalho, em São Paulo (Sistema Econômico e Social) da Omie Conteúdo (Omie Contesúdo, em tradução livre), que divulgou nesta quarta-feira o ranking das maiores empresas do mundo, que medem o crescimento do país e prevê um crescimento de 6,5% no 1o trimestre de 2023. A estimativa é de que a economia brasileira encolheu 4% no primeiro semestre do ano que vem, em 2024. A taxa de desemprego é de 1%. O Brasil é o segundo maior em 20 anos, o maior índice de desemprego dos últimos 12 anos, em comparação com o mesmo período do ano anterior, em relação ao primeiro trimestre de 2021, segundo números divulgados nesta terça-feira. O número de empresas que geram empregos no país, o equivalente a 1,48 milhão de empregos. O índice é o menor desde o início do século passado, em dezembro de 2019. O levantamento foi divulgado nesta sexta-feira pelo Centro de Estudos Econômicos e Social (Centro de Estudos Estratégicos).</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
##### Clarín

journal_url = 'https://www.clarin.com/'

# Fazendo uma solicitação HTTP para obter o conteúdo da página inicial do jornal
response = requests.get(journal_url)
response.raise_for_status()  # Verificar se a solicitação foi bem-sucedida


# Criando um objeto BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Encontrando a parte do HTML que contém as manchetes
attribute = 'data-mrf-recirculation'
headline_section = soup.find(attrs={attribute: True})

headlines = headline_section.find_all('a')[:3]
        # Verificando se a seção de manchetes foi encontrada
if headline_section:
            # Extrair os links das manchetes
    headlines = headline_section.find_all('a')[:3]  # Extrai os três primeiros links das manchetes

    headlines_text = []

            # Acessando os links e obtendo o texto de cada manchete
    for headline in headlines:
        link = headline['href']  # Obtendo o link da manchete
        news_link = link        
                # Adicionando '12ft.io/' ao link para contornar o paywall
        link = 'https://webcache.googleusercontent.com/search?q=cache:' + link

        # Inicializando o objeto Article da biblioteca newspaper3k
        article = newspaper.Article(link)

        # Baixando e parseando o conteúdo da manchete
        article.download()
        article.parse()

                
        hlarticle = article.text.strip()
        headline_text[headline] = hlarticle
        headline_text[headline] = to_pt(headline_text[headline])
        summary = ptt5(headline_text[headline])
        summaries[headline] = summary 
        print(headline_text[headline])
        print('*' * 50) 
        print(summary)
        print('!' * 500)
        sqljournal("Clarín", "Argentina", journal_url, news_link, headline_text[headline], summary)
else: 
    print('error')
# Out:
# No entanto, cada vez mais economistas, e de opiniões diferentes, de Emmanuel Alvarez Agis a Fausto Spotorno e Marina Dal Poggetto, pensam que pode não ser este ano como a maioria previu há um mês. Pode não haver uma saída completa das ações como fez Mauricio Macri em dezembro de 2015 e, com sorte, diferentes restrições poderão ser levantadas por tentativa e erro.
#
# A eliminação destas restrições é algo que consta do roteiro e linha de trabalho entre a equipa económica e o corpo técnico do FMI não só para monitorizar o actual programa em vigor mas também para delinear o próximo que as autoridades já estão a negociar. O Governo pretende embolsar mais dinheiro de antecipação com o novo acordo de Instalações Alargadas que sucederia ao negociado por Martín Guzmán em 2022. Mas o mercado exclui cada vez mais que estas remoções sejam fáceis e viáveis ​​de remover em breve. Aqui estão as principais visões:
#
# Fausto Spotorno (Orlando Ferreres e Associados). “Não creio que este ano os estoques serão totalmente eliminados. Acho muito difícil por dois motivos. Na minha opinião, o Governo tem duas questões em mente para dar esse passo. A primeira, um Banco Central saudável. É muito difícil manter uma política monetária pós-estoque razoável sem um banco que possa operar normalmente. Você consegue imaginar o que aconteceria se houvesse um choque que causasse uma saída de capitais e não houvesse reservas? A principal política do BCRA hoje é sair do estado de falência. E a segunda é a eliminação do imposto PAIS. Veremos no final do ano o que acontece quando sua validade expirar. “O governo estará em posição de removê-lo?”
#
# Emmanuel Alvarez Agis (pxq): “A política cambial de atraso do dólar e a impossibilidade de reforçar as reservas do Banco Central de forma sustentável aumentam as chances de que a saída das ações se dê por meio de desvalorização, aumento da inflação e recessão. Se a saída das bolsas não ocorrer até o final do ano, parece difícil para La Libertada Avanza correr o risco de enfrentar uma possível tensão cambial em 2025, um ano eleitoral em que um governo liderado por um estranho deveria mostrar a sua capacidade de consolidação através de uma vitória". Segundo o ex-vice-ministro da Economia, é impossível sequer iniciar um plano de estabilização sem retirar as existências e é uma condição necessária para que a saída das existências seja bem sucedida como primeiro passo para um “novo regime macroeconómico”.
#
# Lorenzo Sigaut Gravina (Equilibra). “Parece que a saída do câmbio seria adiada”, observou ele em seu último relatório. Pelas contas do economista, a maior parte da colheita de soja e milho proporcionaria uma oferta adicional de US$ 1,5 bilhão por mês ao mercado financeiro de dólar. Tudo isto num contexto de inflação moderada, de taxas de juro abaixo do aumento dos preços e de adiamento dos aumentos da electricidade e do gás, atrasaria a saída das existências. Além disso, acrescenta Sigaut Gravina, o BOPREAL “recuperou a atractividade” para as empresas que necessitam de distribuir lucros e dividendos a accionistas não residentes. Esta semana foram subscritos US$ 1.709 milhões.
# **************************************************
# <pad> A saída das principais bolsas de valores da América Latina e do Caribe (FMI, na sigla em espanhol) é mais difícil para o Banco Central do que é hoje, segundo analistas e analistas ouvidos pela BBC Brasil. A saída do Banco Central não será suficiente para a saída de capitais, mas pode não ser o que muitos esperam, segundo os economistas que acompanham a crise política no mercado financeiro internacional, e que esperam que a saída das ações seja bem sucedida no ano que vem, em 2025, o que não acontecerá no final do ano. A opinião é de que o governo não está em posição de abandonar as suas políticas cambiais e, por outro lado, não haverá saída das suas ações, como havia sido previsto, segundo o relatório divulgado nesta terça-feira pelo Banco Central (BOREAL), divulgado nesta segunda-feira. A situação é ainda mais difícil de sair do país e, com isso, não será o melhor ano fiscal para o futuro. A partir de 2025 a saída da economia será bem sucedida, e não haverá uma saída significativa das principais instituições de economia do mundo, que já estão em situação de colapso e, assim como, a saída do mercado financeiro, será muito mais difícil que o previsto pelo mercado financeiro e, portanto, a partir do final deste ano, não serão suficientes para garantir a sua capacidade de reescrever um plano de estabilização e estabilização do sistema de crédito acionários e de austeridade.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# - A lei de Bases parece estar sujeita a um pouco de serra elétrica e um pouco de liquidificador. Você acha que o que sair do Congresso, se sair, vai cumprir os objetivos que foram traçados na hora de redigi-lo?
#
# -- Acho que é um primeiro passo importante que mostra que uma parte do Congresso tomou nota do mandato que a sociedade deu ao Presidente Milei. Definimos dois eixos centrais. Uma é que concede instrumentos ao Executivo para reorganizar o Estado. A outra procura promover o investimento, e isto é visto nos incentivos específicos para o sector energético e nos grandes projectos alcançados pelo regime de grandes investimentos. Há também progressos na promoção da inclusão laboral.
#
# -- Mas o Congresso reduziu os poderes delegados solicitados na primeira versão.
#
# -- É certo. E é poder, quase obrigação, eu diria, do Congresso ter ciúmes das delegações às quais delega, como bem diz o termo, os seus próprios poderes. Mas, ao mesmo tempo, a lei é generosa com a flexibilidade que dá ao governo para desempenhar a sua tarefa como Executivo. Aí acho que foi encontrado um bom equilíbrio. Talvez não seja tudo o que gostaríamos, mas é disso que se trata a democracia, encontrar aquilo que todos estamos dispostos a aceitar.
#
# -- Muitas outras coisas da lei básica original foram deixadas de lado. O governo vê isso como um fracasso?
#
# -- Acho que faz parte de um processo, não deve ser visto como um fracasso. Nesta nova versão, três grandes capítulos ficaram de fora: segurança, modernização da justiça e educação. O capítulo da justiça incluiu reformas adicionais ao Código Civil e Comercial que foram muito importantes para mim, e a proposta de educação foi uma das coisas mais revolucionárias que a lei continha. Mas entendeu-se que havia três questões que exigiam tratamento especial. .
#
# -- Por exemplo?
#
# -- Existem muitos. Todo o capítulo dos transportes, grande parte dos temas da agenda cultural, a maior parte dos temas da desregulamentação económica. Mudanças no código civil. Encontram-se coisas incomuns. Por exemplo, a lei dos fertilizantes forçou-o a solicitar autorização estatal para transportar fertilizantes porque os militares pensavam que eram precursores de explosivos.
#
# -- E por que você diz que o Código Civil e Comercial foi o mais importante?
#
# Porque no DNU já havíamos modificado o capítulo dos contratos para devolver aos indivíduos a liberdade de fazerem os seus contratos como quiserem, sem estarem sujeitos ao código. O DNU nesse sentido foi um banho de liberdade e o capítulo da lei de bases aprofunda isso. Por exemplo, eliminar a cláusula que dizia que um contrato só é válido se respeitar a “moralidade e os bons costumes”.
#
# Entrevista com Federico Sturzenegger, assessor do presidente Javier Milei. Foto: Emmanuel Fernández
#
# -- Você percebe que este debate deixou claro que há resistência por parte da classe dominante em conceder mais liberdades?
#
# - Sim. A liberdade é assustadora em algum momento. Por exemplo, disseram-nos que era perigoso deixar as pessoas assinarem um contrato de arrendamento por menos de dois anos. Perguntamos por quê? Saímos e nada aconteceu. Na verdade, os preços dos aluguéis subiram desde o DNU, 40% menos que a inflação!
#
# -- Por enquanto o DNU governa e a Lei o fundamenta em avana. Você acha que o que foi mostrado em matéria econômica nestes cinco meses, principalmente a redução do déficit fiscal, ajudou?
#
# -- Acredito que o DNU já esteja gerando mudanças importantes. A coisa do aluguel que acabei de mencionar, por exemplo. Parece que a liberdade não era tão ruim assim. Starlink já está operando. Em poucos meses teremos cobertura total por satélite do país, já que as próprias operadoras atuais poderão expandir sua cobertura contando com Starlink. As farmácias já podem vender online, embora apenas na Capital. Estamos prestes a finalizar a regulamentação de uma ampla desregulamentação do mercado aéreo que permitirá conectar todas as cidades médias da Argentina. É ridículo que Tandil e Olavarría não tenham ligação aérea com Buenos Aires. Inúmeras e absurdas restrições foram levantadas no comércio, eu poderia continuar indefinidamente. Mas você sabe o que é mais impressionante?
#
# - Qual é o mais importante?
#
# -- Que está sendo demonstrado que os países são pobres não porque não possam se desenvolver, mas porque não querem sê-lo, ou melhor, porque alguém se beneficia por não sê-lo.
#
# - Parece uma teoria da conspiração.
#
# – Aqui voltamos ao modelo de castas. Existe uma casta que beneficia de tudo isto, que beneficia de todas as regulamentações e de todas as restrições. Por trás de cada restrição não existe um sentimento de protecção para a sociedade como um todo, mas sim um emprego. É por isso que cada restrição à liberdade empobrece a nós, o povo argentino em geral, e beneficia alguns. A liberdade não só nos permite o crescimento, mas é a melhor política anticorrupção.
#
# -- A última experiência de certa liberdade de mercado foi a conversibilidade. Você acha que apesar de tudo o que se seguiu depois de 2002, os argentinos realmente esperam uma retirada ampla do Estado? Pergunto-lhe porque toda vez que há um transtorno (taxas antecipadas, ausência de repelente, abertura à importação), são exigidos controles, seja de preços ou seja lá o que for.
#
# Entrevista com Federico Sturzenegger, assessor do presidente Javier Milei. Fotos Emmanuel Fernández
#
# -- As reformas terão sucesso desde que demonstrem as suas virtudes. Temos o problema de que, além disso, esta transição ocorre num momento em que são herdados desequilíbrios fenomenais que precisam de ser corrigidos. Mas estamos confiantes de que este é o caminho e que muito mais benefícios serão observados rapidamente.
#
# -- Existe uma Argentina corporativa também armada pelo setor privado que quer um Estado “protetor”? É necessário reformulá-lo também? Como?
#
# -- Absolutamente. O que Milei chama de modelo empobrecedor de castas. E o adjetivo empobrecedor é bom porque quando esse modelo foi estabelecido com o ex-ditador Onganía, a Argentina era mais rica que a Espanha e a pobreza era de 5%. Hoje nem sequer nos podemos comparar com Espanha e a pobreza ultrapassa os 50%, por isso temos uma necessidade colectiva como Nação de inverter este sistema. E isso ocorreu num período em que a pobreza no mundo caiu de 50% para 9%. Ficamos tão para trás que nem percebemos a vantagem que os outros tiraram de nós.
#
# -- Qual é, para você, o exemplo típico de corporativismo que deveria ser eliminado?
#
# -- Existem muitos. Mas posso citar dois, mas apenas porque foram discutidos na lei de bases e ilustram o quão difícil é reverter esse modelo. Uma delas é a contribuição sindical para pessoas que não são sindicalizadas. O outro é o regime de pesca, que é um problema porque o royalty pago à pesca no mar argentino é de 0,15%, o que é um absurdo. Para ser franco, há pessoas que pescam o nosso peixe e não pagam nada por isso. Lá, a lei básica original estabelecia que os navios pesqueiros argentinos, quando seus contratos atuais expirassem, deveriam concorrer para obter o direito de pescar.
#
# -- Mas nenhum acabou sendo aprovado.
#
# Exato. É por isso que os dou como exemplos. Noutros países do mundo, quando conto sobre as contribuições solidárias de pessoas não sindicalizadas, eles não acreditam em mim, perguntam-me se é uma piada. A pesca é interessante por outros motivos. Nasceu do objetivo dos militares de promover a indústria naval “doando” a pesca. Os processos de mudança levam tempo e afetam interesses, mas se nos paralisarmos e nunca os enfrentarmos como sociedade não conseguiremos superar-nos.
#
# - Já que você falou sobre os sindicatos. As joint ventures deveriam ser gratuitas ou não? Por que se discute hoje o que é aprovado e o que não é?
#
# Acredito que as joint ventures deveriam ser gratuitas. Até que deveriam ser por empresas. Está muito comprovado que as negociações por empresa geram muito mais inclusão laboral e protegem muito melhor o emprego, até porque não estabelecem o mesmo padrão em todo o país. Hoje o padrão comum é responsável pela elevada exclusão laboral no norte e noroeste do país. Se um dia se avançasse nesse sentido, a aprovação do Estado não teria sentido.
#
# -- Existe um desejo exagerado de um “Estado atual” na grande maioria dos cidadãos? Isso não é uma mochila para a retirada do Estado?
#
# -- Não sei. Votaram em Javier Milei, que acredito ser um adversário do Estado.
#
# -- A lei básica e o DNU precisam de uma economia mais aberta para serem eficazes?
#
# -- Uma economia aberta sempre gerará um nível mais elevado de bem-estar, razão pela qual o presidente a incluiu na agenda de maio. Aqui as importações são vistas como uma ameaça, mas na realidade estimulam as exportações. Imagine que você tem mais importações sem mais exportações, o que acontece? O dólar obviamente vai subir porque há mais compradores de dólares do que vendedores. E isso estimula as exportações. É por isso que você não precisa ter medo da integração. Trar-nos-á melhores produtos, tecnologia, obrigar-nos-á a melhorar e, ainda por cima, impulsionará as nossas exportações.
#
# -- Continuando com o que foi dito acima, em que nível de abertura econômica você acha que os argentinos estão apostando?
#
# -- Acho que é um daqueles temas onde os benefícios são percebidos mais rapidamente.
#
# -- O Estado empreendedor deveria ser reduzido a zero?
#
# -- Em geral, as empresas públicas são ineficientes e sujeitas ao risco de corrupção. Caso contrário, olhe para todas essas coisas de seguros. Mas há outro problema ainda mais sério. Quando o Estado possui empresas, estas tendem a influenciar negativamente a regulação do setor. Porque repare que você transformou o regulado em regulador. Isso é algo que sempre deve ser evitado, mas com uma empresa pública é um dado adquirido. Dou-vos um exemplo: em 2014 foi aprovada uma lei que transferiu receitas petrolíferas no valor de quase 400 mil milhões de dólares do tesouro para as empresas petrolíferas. E essa lei foi produto do lobby da YPF. Então sim, é verdade, temos uma ação judicial de 16.000 milhões de euros para a expropriação da YPF, mas um custo ainda maior foi como a nacionalização da YPF afetou a regulação do setor petrolífero.
#
# -- Eles falam sobre fechar contratos em qualquer moeda. O peso tem futuro mesmo que a economia se normalize?
#
# O DNU já viabilizou contratos em qualquer moeda. O futuro do peso depende do peso. Não é um jogo de palavras. O que isto significa é que se o macro for estável e houver pouca inflação, o peso conseguirá sobreviver. Acho que o que o presidente se ressente é que o Estado lhe imponha uma moeda e depois lhe cobre o imposto inflacionário.
#
# Mas esta visão não é inconsistente com as ações?
#
# -- No curto prazo pode ser, mas acredito que hoje o Presidente e o Ministro da Economia subordinam todas as suas ideias à concretização do plano económico. E esse plano pode ser resumido em duas palavras: excedente fiscal.
#
# Só isso?
#
# Sim. Ela é a mãe das batalhas, aquela que manda tudo para você e o que ninguém ousou fazer. Uma vez resolvida a questão fiscal, a minha impressão é que as restantes questões são secundárias. Observe como os resultados fiscais despencaram o risco-país. E o resultado: os empréstimos hipotecários estão de volta. Porque o Estado deixa de sufocar o sistema pedindo recursos. E o risco mais baixo faz com que os bancos sejam encorajados a emprestar. Ao resolver a questão fiscal, o resto se ajusta.
#
# -- O Governo diz que pode fazer o mesmo progresso no seu caminho rumo ao equilíbrio fiscal sem a lei básica. Na sua opinião, como seria o reajuste com ou sem a lei de bases aprovada?
#
# -- Sem uma lei básica, a convergência para o equilíbrio fiscal ocorrerá com menor crescimento e mais impostos. Acho que é o pior cenário para todos.
#
# -- Mas há quem diga que foi longe demais no ajuste, até mesmo consultores que são muito positivos com o rumo econômico.
#
# -- Sim, mas não por causa da correção fiscal. Porque a correcção fiscal liberta recursos para o sector privado. Acredito que a recessão inicial tem origem nos riscos inerentes a qualquer transição política, ainda mais desta magnitude, que implica sempre uma retração nas decisões de investimento e consumo. Mas com a consolidação fiscal esta situação inverte-se e a situação normaliza-se. É por isso que estou optimista quanto à velocidade da recuperação.
#
# -- O presidente prometeu reduzir os impostos e o pacote fiscal aumenta-os. Isso também é uma concessão?
#
# - Não tanto lá. Porque você não está me falando da redução do imposto inflacionário, que felizmente já é visível. Todas as despesas são pagas. Portanto, a única maneira de reduzir os impostos é reduzir as despesas. Portanto, se você reduz os gastos, reduz os impostos, os impostos formais, inflacionários ou futuros. Então eu diria que o Presidente cumpriu esta questão. Porque a carga tributária total anda de mãos dadas com a queda dos gastos.
#
# -- O modelo adotado para este DNU é o famoso decreto de desregulamentação de Domingo Cavallo de 1991?
#
# -- Esse decreto deu à Argentina 20 anos de oxigênio. Cavallo foi impressionante. É claro que aquele decreto pisou muito fundo e por isso foi criticado. Mas o que Unamuno diz de que é bom falar sobre isso, mesmo que seja bom, aplica-se a ele. .
#
# -- Discute-se muito sobre as vantagens ou garantias concedidas às empresas que apresentam projetos no âmbito do RIGI. E as mesmas vantagens são solicitadas para projetos menores. O que pensou o Governo ao redigir aquele capítulo? O RIGI é a resposta às dúvidas sobre a insegurança jurídica que caracterizou a Argentina?
#
# -- Talvez você deva ver o RIGI mais como um ponto de chegada do que como um ponto de partida. Operar sem stocks ou numa economia mais aberta deverá ser a norma dentro de alguns anos. A chave aqui é que isto abrange apenas novos projetos, e é por isso que os projetos RIGI não podem gerar “dinheiro” nos seus primeiros anos. Isso é mais difícil de controlar em projetos pequenos ou curtos. Portanto, trata-se de atrair grandes novos investimentos a longo prazo. Pode ser um paliativo, a segurança jurídica da Argentina será resolvida pelo superávit fiscal.
#
# - Falamos sobre os caminhos do presidente. Ele te elogiou muito e te nomeou conselheiro. O que você viu nesses meses?
# **************************************************
# <pad> A nova lei de bases do governo argentino foi aprovada há quase um ano e foi aprovada pelo Congresso, mas não deve ser vista como um fracasso. É o que diz o presidente Javier Milei em entrevista exclusiva à BBC Brasil, em entrevista ao jornal argentino Clarín, em sua primeira entrevista coletiva desde que assumiu o comando do governo, em dezembro de 2002, quando assumiu o cargo de ministro da Economia, Fernando Henrique Cardoso (PMDB-RJ) e o ministro da Fazenda, Javier Milógio (MDN). A partir de maio, o governo do presidente Néstor Kirchner vai se reunir com representantes do governo e do Ministério da Economia (DNU) para discutir a crise econômica do país e a consolidação da economia e o crescimento do mercado de petróleo e do gás natural, e não apenas a crise política, mas também a crise financeira e o aumento dos impostos. A partir daí, os argentinos terão que sair do Congresso, se quiserem, ou não, o que é o mais importante para o país. A lei é um marco do desenvolvimento econômico e, por isso, é um dos pontos mais importantes para o crescimento econômico do que para o resto do mundo, que é um exemplo de como a economia está se comportando de forma ajustada e, portanto, é uma das mais importantes a ser revisto para a realidade. E, por outro lado, é o que mais mexe com o sistema de regulação do setor privado, o chamado “Estado Democrático” e o Banco Mundial (UNNP).</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# A pergunta de um dos confidentes de Milei não tinha propósito retórico. Pretendia conhecer o estado espiritual do Presidente quando não está sobrecarregado pela agenda diária, descobrir como atravessa os seus dias na montanha-russa do poder: perguntou-lhe se estava feliz, nervoso, stressado, apaixonado. Raramente Milei se depara com uma situação como essa: em sua esfera privada a solidão prevalece, muito mais desde sua separação da atriz Fátima Florez. Geralmente encontra-se de manhã, bem cedo, quando amanhece na Quinta de Olivos e aproveita para brincar com os seus cães mastins. O resto é um turbilhão permanente.
#
# O chefe de Estado completou cinco meses de mandato na sexta-feira. Teve momentos de cansaço, de superexcitação, de derrotas no Congresso, de querer gritar aos quatro ventos que a casta não o deixa governar, de fotos com presidentes e discursos que correram o mundo, de sofrer duas greves nacionais como nenhuma outro não tinha acontecido com nenhum dos seus antecessores e enfrentava uma marcha massiva por cortes na educação pública. Teve também espaços para comemorar algumas conquistas, até impensáveis ​​pela rapidez, que, segundo ele, estão construindo uma nova Argentina.
#
# Entre alguns importantes membros do Executivo circula uma previsão guardada a sete chaves: no início de 2025 a inflação não deverá passar de 3%. Os milleistas estão entusiasmados com uma projeção de 30% para o ano inteiro. É uma aposta muito ambiciosa. Mas é o que eles dizem. Eles acreditam que seria uma carta decisiva para que La Libertad Avanza tivesse chances de vencer as próximas eleições legislativas. Milei, por outro lado, fica chateada quando são feitas projeções.
#
# Tem mais: as aposentadorias despencaram (nos primeiros quatro meses, os aposentados que ganham o mínimo terão perdas de 24% e o restante, 37%) e o nível de emprego no setor privado voltou a reduzir em abril, que acumula um licença médica de seis meses ininterruptos. Os investigadores, por vezes confusos, não sabem se, no final, estes dados irão abalar a opinião pública ou se a tolerância será mantida. Os adversários mais fanáticos prevêem um futuro de sombras, se não uma grande crise. Alguns até levantam a possibilidade do helicóptero.
#
# Assim como até poucos dias se falava da possível saída de Sandra Pettovello da Capital Humano - responsabilizada por ter minimizado a marcha pela UBA - esta semana foi a vez da chefe da AFIP, Florencia Misrahi. A funcionária estava reunida com cerca de dez pessoas de sua equipe na quarta-feira quando uma delas lhe entregou um celular e disse: “Olha esse bilhete, diz que você pediu demissão”. Misrahi, segundo uma das testemunhas da palestra, respondeu: “Vamos continuar trabalhando”. Mas o homem insistiu: “Mas dizem que você pediu demissão…” Misrahi não vai embora. Conta com o aval de Luis Caputo, seu chefe direto, e com a piscadela de Karina Milei.
#
# O Presidente irrita-se quando se fala em movimentos no topo do Governo, embora tenha começado a aceitar que há iniciativas que não avançam tão rapidamente como gostaria. Há quem esteja de olho no Chefe da Casa Civil, Nicolás Posse, e estenda essa preocupação ao Congresso. A Lei de Bases eclipsa a agenda de La Libertad Avanza. Eles pressionam para que seja aprovado antes de 25 de maio, embora haja dúvidas cada vez maiores sobre se isso será possível: muitos senadores querem colocar as mãos no texto que foi aprovado nos Deputados, que devolveria a iniciativa à Câmara dos Deputados .
#
# A sanção da lei, acreditam os libertários, será essencial para injetar entusiasmo no Círculo Vermelho, cujos membros consideram - tal como o FMI - que nenhuma política é sustentável ao longo do tempo se não tiver o aval do Parlamento. Milei acumula outro recorde: nenhum outro presidente passou cinco meses sem ter um único projeto aprovado.
#
# “Digo aos empresários para colocarem um token agora, porque se as coisas correrem bem mais tarde será mais difícil entrar”, diz Juan Carlos De Pablo, o economista não oficial que mais visita Milei em Olivos. Os empresários, em sua maioria, olham para o cenário e preferem esperar antes de fazer manobras bruscas, apesar de muitos deles se aproximarem timidamente da nova administração em reuniões que não transcendem. Entre eles, vários que optaram por Massa nas eleições presidenciais e que foram em procissão ao encontro de Guillermo Michel, então chefe da Alfândega, para realizar reuniões mais que reservadas em seus escritórios no centro de Buenos Aires.
#
# O senador respondeu que uma lei tão importante não poderia ser aprovada em pouco tempo. É o que ele vem dizendo: pede mudanças no Regime de Incentivo aos Grandes Investimentos (RIGI), no capítulo de lavagem (que quem já o fez não possa lavar, que o prazo para servidores públicos seja estendido para dez anos e que Os empreiteiros estatais não podem entrar) e na reforma previdenciária. Francos e Menem cometeram alguns erros e tiveram que responder aos ataques de Milei.
# **************************************************
# <pad> Quando Karina Milei, a secretária de Estado da Presidência argentina, se depara com uma situação de solidão e solidão, ela se pergunta o que acontece e o que sente com o presidente, e com quem ele se comporta, e como ele é capaz de fazer o que quiser, diz ele, em entrevista exclusiva à BBC Brasil. A pergunta foi feita a um grupo de milicianos que se reúnem em Olivos, na capital argentina, para se encontrar com a chefe da AFIP (Agência Federal de Investigações e Estatísticas) e com a assessoria de imprensa do presidente, o senador argentino Carlos Menem, e a secretária da Fazenda, Karina Meira, e o chefe da Administração Federal de Buenos Aires (AFIP, na sigla em espanhol), que, segundo eles, é uma das mais ambiciosas da história recente do governo argentino, que está em crise há mais de um ano, e que não tem previsão para o ano que vem, segundo a imprensa argentina. Mas, para os argentinos, o presidente é um homem forte, com uma agenda de trabalho apertada, com a ajuda de seus assessores, que o acompanham de perto, com o apoio de seus superiores, e de sua equipe de apoio e apoio dos empresários, que se preparam para uma possível saída do governo, em um momento em que o país se prepara para o segundo semestre de 2018. O presidente, que já passou cinco meses no poder há cinco meses, é um dos mais bem-sucedidos.</s>
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# # Preparar para MYSQL

# %%
# Conectar ao banco de dados SQLite
conn = sqlite3.connect('yfhistoric.db')
cursor = conn.cursor()

# Obter todos os nomes de tabela do banco de dados
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
table_names = cursor.fetchall()

# Iterar sobre os nomes das tabelas e aplicar as substituições desejadas
for old_name in table_names:
    new_name = old_name[0].replace("=", "_com_").replace(".", "_").replace("^", "STOCK_")
    # Verificar se o novo nome já existe
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name=?", (new_name,))
    existing_table = cursor.fetchone()
    if existing_table:
        pass
    else:
        # Renomear a tabela
        cursor.execute(f"ALTER TABLE '{old_name[0]}' RENAME TO '{new_name}'")

# Confirmar as alterações
conn.commit()

# Fechar a conexão com o banco de dados
conn.close()

# %%
def ssh(command):    
    # Definir as informações de conexão
    hostname = '192.168.15.57'
    port = 22  # Porta padrão do SSH é 22
    username = 'yan'
    password = '121212'

    # Iniciar a conexão SSH
    client = paramiko.SSHClient()

    # Adicionar a chave do servidor SSH automaticamente (não recomendado para uso em produção)
    client.set_missing_host_key_policy(paramiko.AutoAddPolicy())

    try:
        # Conectar ao servidor
        client.connect(hostname, port, username, password)

        # Exemplo de comando a ser executado no servidor
        comando = command

        # Executar o comando no servidor
        stdin, stdout, stderr = client.exec_command(comando)

        # Ler a saída do comando
        output = stdout.read().decode()

        # Imprimir a saída
        print(output)

    finally:
        # Fechar a conexão
        client.close()

# %%
# Definir as informações de conexão FTP
ftp_host = '192.168.15.57'
ftp_username = 'yan'
ftp_password = '121212'

# Caminho local do arquivo a ser enviado
local_file_path = rootdire

# Caminho remoto onde o arquivo será enviado
remote_dir = '/home/yan/'

# Nome do arquivo no servidor remoto
remote_file_name = 'yfhistoric.db'

try:
    # Estabelecer conexão com o servidor FTP
    ftp = FTP(ftp_host)
    ftp.login(ftp_username, ftp_password)

    # Navegar até o diretório remoto
    ftp.cwd(remote_dir)

    # Abrir o arquivo local em modo de leitura binária
    with open(local_file_path, 'rb') as file:
        # Enviar o arquivo para o servidor remoto
        ftp.storbinary(f'STOR {remote_file_name}', file)

    print(f'O arquivo "{remote_file_name}" foi enviado com sucesso para o diretório "{remote_dir}" no servidor FTP.')

except Exception as e:
    print(f'Ocorreu um erro: {e}')

finally:
    # Fechar a conexão FTP
    ftp.quit()
# Out:
# db_to_mysql.py
# db_to_mysqlTEST.py
# Desktop
# Documents
# Downloads
# Music
# Pictures
# Public
# Templates
# Videos
# yfhistoric.db
# yfhistoricSQL.sql

# %%
import paramiko

def enviar_arquivo_via_sftp(local_file, remote_dir, remote_filename, host, username, password):
    try:
        # Criar uma conexão SSH
        transport = paramiko.Transport((host, 22))
        transport.connect(username=username, password=password)

        # Criar uma sessão SFTP
        sftp = paramiko.SFTPClient.from_transport(transport)

        # Enviar o arquivo local para o servidor remoto
        sftp.put(local_file, f'{remote_dir}/{remote_filename}')

        # Fechar a conexão SFTP
        sftp.close()

        print(f'O arquivo "{local_file}" foi enviado com sucesso para o diretório "{remote_dir}" no servidor remoto.')

    except Exception as e:
        print(f'Ocorreu um erro: {e}')

# Definir informações de conexão
host = '192.168.15.57'
username = 'yan'
password = '121212'

# Definir o caminho local do arquivo e o nome do arquivo remoto
local_file = 'yfhistoric.db'
remote_dir = '/home/yan'
remote_filename = 'yfhistoric.db'

# Chamar a função para enviar o arquivo
enviar_arquivo_via_sftp(local_file, remote_dir, remote_filename, host, username, password)
# Out:
# O arquivo "yfhistoric.db" foi enviado com sucesso para o diretório "/home/yan" no servidor remoto.

# %% [markdown]
# # À corrigir:
#
# + por razões de escalabilidade trocar todos os "codes" como ticcode, commcode, etc por "code" e deixar o resto para a lógica de datatype
# + fazer uma class de elapsed time. cada processo coloca um checkpoint de inicio e um de fim. a class salva os dados e a subtração de quanto tempo passou e salva num log em uma pasta de log
