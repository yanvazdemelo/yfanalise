# %%
#'''!pip install pymysql'''

# %%
import sqlite3
import pymysql
import pandas as pd
import numpy as np

# %%
# Conectar-se ao banco de dados SQLite
sqlite_conn = sqlite3.connect('yfhistoric.db')
sqlite_cursor = sqlite_conn.cursor()

# Conectar-se ao banco de dados MySQL
mysql_conn = pymysql.connect(host='192.168.15.57', user='yanadm', password='121212', database='yfhistoric')
mysql_cursor = mysql_conn.cursor()
mysql_cursor.execute("SET foreign_key_checks = 0")
# Out:
# 0

# %%
# Obter os nomes das tabelas do banco de dados SQLite
tables = sqlite_conn.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
table_names = [table[0] for table in tables]


# Criar um dicionário para armazenar os DataFrames de cada tabela
yfhistoricdic = {}

# Iterar sobre as tabelas e criar um DataFrame para cada uma
for table_name in table_names:
    # Ler os dados da tabela e criar um DataFrame
    df = pd.read_sql_query(f"SELECT * FROM '{table_name}';", sqlite_conn)
    # Armazenar o DataFrame no dicionário, usando o nome da tabela como chave
    yfhistoricdic[table_name] = df

# %%
# Substituir "=" por "000" em todas as chaves
yfhistoricdic = {key.replace("=", "_COM_"): value for key, value in yfhistoricdic.items()}
yfhistoricdic = {key.replace(".", "_"): value for key, value in yfhistoricdic.items()}
yfhistoricdic = {key.replace("^", "STOCK_"): value for key, value in yfhistoricdic.items()}
dataframes_dict = yfhistoricdic

# %%
pandas_to_mysql_types = {
    np.dtype('int64'): 'BIGINT',
    np.dtype('float64'): 'FLOAT',
    np.dtype('datetime64[ns]'): 'DATETIME',
    np.dtype('object'): 'TEXT'
}

# %%
# Iterar sobre o dicionário de DataFrames
for table_name, df in dataframes_dict.items():
    # Substituir valores NaN por None em cada DataFrame
    dataframes_dict[table_name] = df.where(pd.notna(df), None)

# %%
# Iterar sobre o dicionário de DataFrames
for table_name, df in dataframes_dict.items():
    # Criar a tabela no MySQL
    cursor = mysql_conn.cursor()
    # Substituir valores NaN por NULL
    df.fillna(value=pd.NA, inplace=True)  # Use pd.NA para representar NULL
    # Inferir os tipos de dados das colunas e criar a string de colunas para a criação da tabela
    columns = []
    for col, dtype in df.dtypes.items():
        mysql_type = pandas_to_mysql_types.get(dtype, 'TEXT')
        columns.append(f"`{col}` {mysql_type}")
    columns_str = ', '.join(columns)
    
    create_table_query = f"CREATE TABLE IF NOT EXISTS `{table_name}` ({columns_str})"
    cursor.execute(create_table_query)
    print(f"Tabela '{table_name}' criada no MySQL com sucesso.")

    # Inserir os dados na tabela
    for index, row in df.iterrows():
        placeholders = ', '.join(['%s' for _ in df.columns])
        insert_query = f'''INSERT INTO {table_name} ({', '.join(df.columns)}) VALUES ({placeholders})'''
        try:
            row = tuple(None if isinstance(valor, float) and np.isnan(valor) else valor for valor in row)
            cursor.execute(insert_query, tuple(row))
        except Exception as e:
            print(insert_query)
            print(f"Ocorreu um erro: {e}")
    print(f"Dados inseridos na tabela '{table_name}' no MySQL com sucesso.")

# Confirmar as alterações no MySQL
mysql_conn.commit()
# Out:
# Tabela 'indicators' criada no MySQL com sucesso.
# Dados inseridos na tabela 'indicators' no MySQL com sucesso.
# Tabela 'texts' criada no MySQL com sucesso.
# Dados inseridos na tabela 'texts' no MySQL com sucesso.
# Tabela 'niche' criada no MySQL com sucesso.
# Dados inseridos na tabela 'niche' no MySQL com sucesso.
# Tabela 'currencies' criada no MySQL com sucesso.
# Dados inseridos na tabela 'currencies' no MySQL com sucesso.
# Tabela 'tickets' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tickets' no MySQL com sucesso.
# Tabela 'commodities' criada no MySQL com sucesso.
# Dados inseridos na tabela 'commodities' no MySQL com sucesso.
# Tabela 'cripto' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cripto' no MySQL com sucesso.
# Tabela 'news' criada no MySQL com sucesso.
# Dados inseridos na tabela 'news' no MySQL com sucesso.
# Tabela 'summary' criada no MySQL com sucesso.
# Dados inseridos na tabela 'summary' no MySQL com sucesso.
# Tabela 'usd' criada no MySQL com sucesso.
# Dados inseridos na tabela 'usd' no MySQL com sucesso.
# Tabela 'mlearning' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mlearning' no MySQL com sucesso.
# Tabela 'brl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'brl' no MySQL com sucesso.
# Tabela 'ars' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ars' no MySQL com sucesso.
# Tabela 'clp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'clp' no MySQL com sucesso.
# Tabela 'mxn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mxn' no MySQL com sucesso.
# Tabela 'pen' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pen' no MySQL com sucesso.
# Tabela 'uyu' criada no MySQL com sucesso.
# Dados inseridos na tabela 'uyu' no MySQL com sucesso.
# Tabela 'ves' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ves' no MySQL com sucesso.
# Tabela 'bzd' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bzd' no MySQL com sucesso.
# Tabela 'crc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'crc' no MySQL com sucesso.
# Tabela 'gtq' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gtq' no MySQL com sucesso.
# Tabela 'hnl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hnl' no MySQL com sucesso.
# Tabela 'nio' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nio' no MySQL com sucesso.
# Tabela 'bob' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bob' no MySQL com sucesso.
# Tabela 'btc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'btc' no MySQL com sucesso.
# Tabela 'eth' criada no MySQL com sucesso.
# Dados inseridos na tabela 'eth' no MySQL com sucesso.
# Tabela 'bnb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bnb' no MySQL com sucesso.
# Tabela 'sol' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sol' no MySQL com sucesso.
# Tabela 'ada' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ada' no MySQL com sucesso.
# Tabela 'usdt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'usdt' no MySQL com sucesso.
# Tabela 'xrp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'xrp' no MySQL com sucesso.
# Tabela 'dot' criada no MySQL com sucesso.
# Dados inseridos na tabela 'dot' no MySQL com sucesso.
# Tabela 'usdc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'usdc' no MySQL com sucesso.
# Tabela 'doge' criada no MySQL com sucesso.
# Dados inseridos na tabela 'doge' no MySQL com sucesso.
# Tabela 'avax' criada no MySQL com sucesso.
# Dados inseridos na tabela 'avax' no MySQL com sucesso.
# Tabela 'link' criada no MySQL com sucesso.
# Dados inseridos na tabela 'link' no MySQL com sucesso.
# Tabela 'luna' criada no MySQL com sucesso.
# Dados inseridos na tabela 'luna' no MySQL com sucesso.
# Tabela 'ltc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ltc' no MySQL com sucesso.
# Tabela 'algo' criada no MySQL com sucesso.
# Dados inseridos na tabela 'algo' no MySQL com sucesso.
# Tabela 'shib' criada no MySQL com sucesso.
# Dados inseridos na tabela 'shib' no MySQL com sucesso.
# Tabela 'matic' criada no MySQL com sucesso.
# Dados inseridos na tabela 'matic' no MySQL com sucesso.
# Tabela 'xlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'xlm' no MySQL com sucesso.
# Tabela 'icp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'icp' no MySQL com sucesso.
# Tabela 'wbtc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wbtc' no MySQL com sucesso.
# Tabela 'etc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'etc' no MySQL com sucesso.
# Tabela 'vet' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vet' no MySQL com sucesso.
# Tabela 'fil' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fil' no MySQL com sucesso.
# Tabela 'trx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'trx' no MySQL com sucesso.
# Tabela 'theta' criada no MySQL com sucesso.
# Dados inseridos na tabela 'theta' no MySQL com sucesso.
# Tabela 'atom' criada no MySQL com sucesso.
# Dados inseridos na tabela 'atom' no MySQL com sucesso.
# Tabela 'ftt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ftt' no MySQL com sucesso.
# Tabela 'dai' criada no MySQL com sucesso.
# Dados inseridos na tabela 'dai' no MySQL com sucesso.
# Tabela 'aave' criada no MySQL com sucesso.
# Dados inseridos na tabela 'aave' no MySQL com sucesso.
# Tabela 'gc_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gc_com_f' no MySQL com sucesso.
# Tabela 'si_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'si_com_f' no MySQL com sucesso.
# Tabela 'cl_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cl_com_f' no MySQL com sucesso.
# Tabela 'bz_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bz_com_f' no MySQL com sucesso.
# Tabela 'hg_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hg_com_f' no MySQL com sucesso.
# Tabela 'ng_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ng_com_f' no MySQL com sucesso.
# Tabela 'c_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'c_com_f' no MySQL com sucesso.
# Tabela 'w_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'w_com_f' no MySQL com sucesso.
# Tabela 'kc_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'kc_com_f' no MySQL com sucesso.
# Tabela 'sb_com_f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sb_com_f' no MySQL com sucesso.
# Tabela 'ypfd_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ypfd_ba' no MySQL com sucesso.
# Tabela 'meli_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'meli_ba' no MySQL com sucesso.
# Tabela 'bbar_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbar_ba' no MySQL com sucesso.
# Tabela 'cres_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cres_ba' no MySQL com sucesso.
# Tabela 'pamp_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pamp_ba' no MySQL com sucesso.
# Tabela 'ts_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ts_ba' no MySQL com sucesso.
# Tabela 'glob_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'glob_ba' no MySQL com sucesso.
# Tabela 'bma_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bma_ba' no MySQL com sucesso.
# Tabela 'txar_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'txar_ba' no MySQL com sucesso.
# Tabela 'cepu_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cepu_ba' no MySQL com sucesso.
# Tabela 'rio_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rio_ba' no MySQL com sucesso.
# Tabela 'supv_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'supv_ba' no MySQL com sucesso.
# Tabela 'ypfl_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ypfl_ba' no MySQL com sucesso.
# Tabela 'bbva_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbva_ba' no MySQL com sucesso.
# Tabela 'desp_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'desp_ba' no MySQL com sucesso.
# Tabela 'ggal_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ggal_ba' no MySQL com sucesso.
# Tabela 'alua_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'alua_ba' no MySQL com sucesso.
# Tabela 'moli_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'moli_ba' no MySQL com sucesso.
# Tabela 'edn_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'edn_ba' no MySQL com sucesso.
# Tabela 'irsa_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'irsa_ba' no MySQL com sucesso.
# Tabela 'bpat_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bpat_ba' no MySQL com sucesso.
# Tabela 'teco2_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'teco2_ba' no MySQL com sucesso.
# Tabela 'erar_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'erar_ba' no MySQL com sucesso.
# Tabela 'ctio_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ctio_ba' no MySQL com sucesso.
# Tabela 'mola_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mola_ba' no MySQL com sucesso.
# Tabela 'tgsu2_ba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tgsu2_ba' no MySQL com sucesso.
# Tabela 'vale3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vale3_sa' no MySQL com sucesso.
# Tabela 'itub4_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'itub4_sa' no MySQL com sucesso.
# Tabela 'bbdc4_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbdc4_sa' no MySQL com sucesso.
# Tabela 'abev3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'abev3_sa' no MySQL com sucesso.
# Tabela 'bbas3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbas3_sa' no MySQL com sucesso.
# Tabela 'b3sa3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'b3sa3_sa' no MySQL com sucesso.
# Tabela 'petr4_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'petr4_sa' no MySQL com sucesso.
# Tabela 'ciel3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ciel3_sa' no MySQL com sucesso.
# Tabela 'elet6_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'elet6_sa' no MySQL com sucesso.
# Tabela 'mglu3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mglu3_sa' no MySQL com sucesso.
# Tabela 'vvar3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vvar3_sa' no MySQL com sucesso.
# Tabela 'ggbr4_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ggbr4_sa' no MySQL com sucesso.
# Tabela 'rail3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rail3_sa' no MySQL com sucesso.
# Tabela 'cyre3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cyre3_sa' no MySQL com sucesso.
# Tabela 'klbn11_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'klbn11_sa' no MySQL com sucesso.
# Tabela 'rapt4_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rapt4_sa' no MySQL com sucesso.
# Tabela 'ugpa3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ugpa3_sa' no MySQL com sucesso.
# Tabela 'usim5_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'usim5_sa' no MySQL com sucesso.
# Tabela 'lame4_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lame4_sa' no MySQL com sucesso.
# Tabela 'suzb3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'suzb3_sa' no MySQL com sucesso.
# Tabela 'flry3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'flry3_sa' no MySQL com sucesso.
# Tabela 'goll4_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'goll4_sa' no MySQL com sucesso.
# Tabela 'sanb11_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sanb11_sa' no MySQL com sucesso.
# Tabela 'rent3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rent3_sa' no MySQL com sucesso.
# Tabela 'ecor3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ecor3_sa' no MySQL com sucesso.
# Tabela 'brkm5_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'brkm5_sa' no MySQL com sucesso.
# Tabela 'wege3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wege3_sa' no MySQL com sucesso.
# Tabela 'jbss3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'jbss3_sa' no MySQL com sucesso.
# Tabela 'irbr3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'irbr3_sa' no MySQL com sucesso.
# Tabela 'ccro3_sa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ccro3_sa' no MySQL com sucesso.
# Tabela 'san_sn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'san_sn' no MySQL com sucesso.
# Tabela 'ltm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ltm' no MySQL com sucesso.
# Tabela 'sqm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sqm' no MySQL com sucesso.
# Tabela 'bch' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bch' no MySQL com sucesso.
# Tabela 'cap' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cap' no MySQL com sucesso.
# Tabela 'andina-a' criada no MySQL com sucesso.
# Dados inseridos na tabela 'andina-a' no MySQL com sucesso.
# Tabela 'enelam' criada no MySQL com sucesso.
# Dados inseridos na tabela 'enelam' no MySQL com sucesso.
# Tabela 'bice' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bice' no MySQL com sucesso.
# Tabela 'colbun' criada no MySQL com sucesso.
# Dados inseridos na tabela 'colbun' no MySQL com sucesso.
# Tabela 'entel' criada no MySQL com sucesso.
# Dados inseridos na tabela 'entel' no MySQL com sucesso.
# Tabela 'smu' criada no MySQL com sucesso.
# Dados inseridos na tabela 'smu' no MySQL com sucesso.
# Tabela 'falabella' criada no MySQL com sucesso.
# Dados inseridos na tabela 'falabella' no MySQL com sucesso.
# Tabela 'bsantander' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bsantander' no MySQL com sucesso.
# Tabela 'sonda' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sonda' no MySQL com sucesso.
# Tabela 'estado' criada no MySQL com sucesso.
# Dados inseridos na tabela 'estado' no MySQL com sucesso.
# Tabela 'parauco' criada no MySQL com sucesso.
# Dados inseridos na tabela 'parauco' no MySQL com sucesso.
# Tabela 'itaucorp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'itaucorp' no MySQL com sucesso.
# Tabela 'conchatoro' criada no MySQL com sucesso.
# Dados inseridos na tabela 'conchatoro' no MySQL com sucesso.
# Tabela 'saam' criada no MySQL com sucesso.
# Dados inseridos na tabela 'saam' no MySQL com sucesso.
# Tabela 'bsan_sn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bsan_sn' no MySQL com sucesso.
# Tabela 'security' criada no MySQL com sucesso.
# Dados inseridos na tabela 'security' no MySQL com sucesso.
# Tabela 'enelchile' criada no MySQL com sucesso.
# Dados inseridos na tabela 'enelchile' no MySQL com sucesso.
# Tabela 'ilc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ilc' no MySQL com sucesso.
# Tabela 'bci' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bci' no MySQL com sucesso.
# Tabela 'ecopetrol' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ecopetrol' no MySQL com sucesso.
# Tabela 'bic' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bic' no MySQL com sucesso.
# Tabela 'sur' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sur' no MySQL com sucesso.
# Tabela 'bolivar' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bolivar' no MySQL com sucesso.
# Tabela 'corona' criada no MySQL com sucesso.
# Dados inseridos na tabela 'corona' no MySQL com sucesso.
# Tabela 'nutresa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nutresa' no MySQL com sucesso.
# Tabela 'exito' criada no MySQL com sucesso.
# Dados inseridos na tabela 'exito' no MySQL com sucesso.
# Tabela 'cencosud' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cencosud' no MySQL com sucesso.
# Tabela 'aval' criada no MySQL com sucesso.
# Dados inseridos na tabela 'aval' no MySQL com sucesso.
# Tabela 'geb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'geb' no MySQL com sucesso.
# Tabela 'promigas' criada no MySQL com sucesso.
# Dados inseridos na tabela 'promigas' no MySQL com sucesso.
# Tabela 'epm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'epm' no MySQL com sucesso.
# Tabela 'celsia' criada no MySQL com sucesso.
# Dados inseridos na tabela 'celsia' no MySQL com sucesso.
# Tabela 'isa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'isa' no MySQL com sucesso.
# Tabela 'pfbcolom' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pfbcolom' no MySQL com sucesso.
# Tabela 'davivienda' criada no MySQL com sucesso.
# Dados inseridos na tabela 'davivienda' no MySQL com sucesso.
# Tabela 'gnc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gnc' no MySQL com sucesso.
# Tabela 'argos' criada no MySQL com sucesso.
# Dados inseridos na tabela 'argos' no MySQL com sucesso.
# Tabela 'sura' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sura' no MySQL com sucesso.
# Tabela 'pfg' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pfg' no MySQL com sucesso.
# Tabela 'amxl_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'amxl_mx' no MySQL com sucesso.
# Tabela 'gmexicob_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gmexicob_mx' no MySQL com sucesso.
# Tabela 'femsaubd_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'femsaubd_mx' no MySQL com sucesso.
# Tabela 'bimboa_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bimboa_mx' no MySQL com sucesso.
# Tabela 'cemexcpo_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cemexcpo_mx' no MySQL com sucesso.
# Tabela 'gfnorteo_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gfnorteo_mx' no MySQL com sucesso.
# Tabela 'elektra_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'elektra_mx' no MySQL com sucesso.
# Tabela 'gapb_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gapb_mx' no MySQL com sucesso.
# Tabela 'alfaa_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'alfaa_mx' no MySQL com sucesso.
# Tabela 'omab_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'omab_mx' no MySQL com sucesso.
# Tabela 'gcarsoa1_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gcarsoa1_mx' no MySQL com sucesso.
# Tabela 'labb_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'labb_mx' no MySQL com sucesso.
# Tabela 'asurb_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'asurb_mx' no MySQL com sucesso.
# Tabela 'gacmab_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gacmab_mx' no MySQL com sucesso.
# Tabela 'simecb_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'simecb_mx' no MySQL com sucesso.
# Tabela 'alpeka_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'alpeka_mx' no MySQL com sucesso.
# Tabela 'vlrs_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vlrs_mx' no MySQL com sucesso.
# Tabela 'gentera_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gentera_mx' no MySQL com sucesso.
# Tabela 'bsmxb_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bsmxb_mx' no MySQL com sucesso.
# Tabela 'tlevisacpo_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tlevisacpo_mx' no MySQL com sucesso.
# Tabela 'lalab_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lalab_mx' no MySQL com sucesso.
# Tabela 'herdez_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'herdez_mx' no MySQL com sucesso.
# Tabela 'gcc_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gcc_mx' no MySQL com sucesso.
# Tabela 'gigante_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gigante_mx' no MySQL com sucesso.
# Tabela 'bbajioo_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbajioo_mx' no MySQL com sucesso.
# Tabela 'gsanborb-1_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gsanborb-1_mx' no MySQL com sucesso.
# Tabela 'funo11_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'funo11_mx' no MySQL com sucesso.
# Tabela 'grumab_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'grumab_mx' no MySQL com sucesso.
# Tabela 'kuob_mx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'kuob_mx' no MySQL com sucesso.
# Tabela 'bap_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bap_lm' no MySQL com sucesso.
# Tabela 'scco' criada no MySQL com sucesso.
# Dados inseridos na tabela 'scco' no MySQL com sucesso.
# Tabela 'volc_ob' criada no MySQL com sucesso.
# Dados inseridos na tabela 'volc_ob' no MySQL com sucesso.
# Tabela 'bcp_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bcp_lm' no MySQL com sucesso.
# Tabela 'gra_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gra_lm' no MySQL com sucesso.
# Tabela 'ene_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ene_lm' no MySQL com sucesso.
# Tabela 'fer_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fer_lm' no MySQL com sucesso.
# Tabela 'bvn_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bvn_lm' no MySQL com sucesso.
# Tabela 'bco_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bco_lm' no MySQL com sucesso.
# Tabela 'ifs_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ifs_lm' no MySQL com sucesso.
# Tabela 'lap_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lap_lm' no MySQL com sucesso.
# Tabela 'cem_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cem_lm' no MySQL com sucesso.
# Tabela 'inre_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'inre_lm' no MySQL com sucesso.
# Tabela 'ipa_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ipa_lm' no MySQL com sucesso.
# Tabela 'alicorp_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'alicorp_lm' no MySQL com sucesso.
# Tabela 'copec' criada no MySQL com sucesso.
# Dados inseridos na tabela 'copec' no MySQL com sucesso.
# Tabela 'backus_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'backus_lm' no MySQL com sucesso.
# Tabela 'are_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'are_lm' no MySQL com sucesso.
# Tabela 'rlp_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rlp_lm' no MySQL com sucesso.
# Tabela 'pseg_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pseg_lm' no MySQL com sucesso.
# Tabela 'gloria_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gloria_lm' no MySQL com sucesso.
# Tabela 'scscb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'scscb' no MySQL com sucesso.
# Tabela 'rimac_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rimac_lm' no MySQL com sucesso.
# Tabela 'iilc_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'iilc_lm' no MySQL com sucesso.
# Tabela 'minsuri_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'minsuri_lm' no MySQL com sucesso.
# Tabela 'luz_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'luz_lm' no MySQL com sucesso.
# Tabela 'ucbp_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ucbp_lm' no MySQL com sucesso.
# Tabela 'tdp_lm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tdp_lm' no MySQL com sucesso.
# Tabela 'tm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tm' no MySQL com sucesso.
# Tabela 'vwagy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vwagy' no MySQL com sucesso.
# Tabela 'gm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gm' no MySQL com sucesso.
# Tabela 'bmwyy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bmwyy' no MySQL com sucesso.
# Tabela 'hmc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hmc' no MySQL com sucesso.
# Tabela 'f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'f' no MySQL com sucesso.
# Tabela 'nsany' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nsany' no MySQL com sucesso.
# Tabela 'audvf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'audvf' no MySQL com sucesso.
# Tabela 'volvy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'volvy' no MySQL com sucesso.
# Tabela 'fcau' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fcau' no MySQL com sucesso.
# Tabela 'rnsdf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rnsdf' no MySQL com sucesso.
# Tabela 'pugoy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pugoy' no MySQL com sucesso.
# Tabela 'fujhy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fujhy' no MySQL com sucesso.
# Tabela 'hymtf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hymtf' no MySQL com sucesso.
# Tabela 'mzday' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mzday' no MySQL com sucesso.
# Tabela 'ddaif' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ddaif' no MySQL com sucesso.
# Tabela 'msbhy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'msbhy' no MySQL com sucesso.
# Tabela 'poahy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'poahy' no MySQL com sucesso.
# Tabela 'gelyy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gelyy' no MySQL com sucesso.
# Tabela 'byddy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'byddy' no MySQL com sucesso.
# Tabela 'ttm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ttm' no MySQL com sucesso.
# Tabela 'szkmy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'szkmy' no MySQL com sucesso.
# Tabela 'race' criada no MySQL com sucesso.
# Dados inseridos na tabela 'race' no MySQL com sucesso.
# Tabela 'bntgf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bntgf' no MySQL com sucesso.
# Tabela 'vlkaf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vlkaf' no MySQL com sucesso.
# Tabela 'rycey' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rycey' no MySQL com sucesso.
# Tabela '601668_ss' criada no MySQL com sucesso.
# Dados inseridos na tabela '601668_ss' no MySQL com sucesso.
# Tabela '390_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '390_hk' no MySQL com sucesso.
# Tabela 'bouy_pa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bouy_pa' no MySQL com sucesso.
# Tabela 'lart_ns' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lart_ns' no MySQL com sucesso.
# Tabela '3333_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '3333_hk' no MySQL com sucesso.
# Tabela '1803_t' criada no MySQL com sucesso.
# Dados inseridos na tabela '1803_t' no MySQL com sucesso.
# Tabela 'ska_b' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ska_b' no MySQL com sucesso.
# Tabela '1201_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '1201_hk' no MySQL com sucesso.
# Tabela '601868_ss' criada no MySQL com sucesso.
# Dados inseridos na tabela '601868_ss' no MySQL com sucesso.
# Tabela '1802_t' criada no MySQL com sucesso.
# Dados inseridos na tabela '1802_t' no MySQL com sucesso.
# Tabela '3888_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '3888_hk' no MySQL com sucesso.
# Tabela '601608_ss' criada no MySQL com sucesso.
# Dados inseridos na tabela '601608_ss' no MySQL com sucesso.
# Tabela '3323_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '3323_hk' no MySQL com sucesso.
# Tabela '1313_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '1313_hk' no MySQL com sucesso.
# Tabela 'dg_pa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'dg_pa' no MySQL com sucesso.
# Tabela '1800_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '1800_hk' no MySQL com sucesso.
# Tabela 'crh_i' criada no MySQL com sucesso.
# Dados inseridos na tabela 'crh_i' no MySQL com sucesso.
# Tabela '1186_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '1186_hk' no MySQL com sucesso.
# Tabela '1801_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '1801_hk' no MySQL com sucesso.
# Tabela '1171_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '1171_hk' no MySQL com sucesso.
# Tabela 'acs_mc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'acs_mc' no MySQL com sucesso.
# Tabela '3969_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '3969_hk' no MySQL com sucesso.
# Tabela '0518_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '0518_hk' no MySQL com sucesso.
# Tabela '000668_sz' criada no MySQL com sucesso.
# Dados inseridos na tabela '000668_sz' no MySQL com sucesso.
# Tabela '600180_ss' criada no MySQL com sucesso.
# Dados inseridos na tabela '600180_ss' no MySQL com sucesso.
# Tabela '2718_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '2718_hk' no MySQL com sucesso.
# Tabela 'bby_l' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bby_l' no MySQL com sucesso.
# Tabela '6367_t' criada no MySQL com sucesso.
# Dados inseridos na tabela '6367_t' no MySQL com sucesso.
# Tabela 'utx_n' criada no MySQL com sucesso.
# Dados inseridos na tabela 'utx_n' no MySQL com sucesso.
# Tabela '2222_sr' criada no MySQL com sucesso.
# Dados inseridos na tabela '2222_sr' no MySQL com sucesso.
# Tabela 'xom' criada no MySQL com sucesso.
# Dados inseridos na tabela 'xom' no MySQL com sucesso.
# Tabela 'rds_a' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rds_a' no MySQL com sucesso.
# Tabela 'bp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bp' no MySQL com sucesso.
# Tabela 'tte' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tte' no MySQL com sucesso.
# Tabela 'cvx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cvx' no MySQL com sucesso.
# Tabela 'ogzpy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ogzpy' no MySQL com sucesso.
# Tabela 'rosn_me' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rosn_me' no MySQL com sucesso.
# Tabela 'kpc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'kpc' no MySQL com sucesso.
# Tabela 'ptr' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ptr' no MySQL com sucesso.
# Tabela 'eni' criada no MySQL com sucesso.
# Dados inseridos na tabela 'eni' no MySQL com sucesso.
# Tabela 'abd_ne' criada no MySQL com sucesso.
# Dados inseridos na tabela 'abd_ne' no MySQL com sucesso.
# Tabela 'snp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'snp' no MySQL com sucesso.
# Tabela 'vlo' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vlo' no MySQL com sucesso.
# Tabela 'psx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'psx' no MySQL com sucesso.
# Tabela 'pbr' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pbr' no MySQL com sucesso.
# Tabela 'reliance' criada no MySQL com sucesso.
# Dados inseridos na tabela 'reliance' no MySQL com sucesso.
# Tabela 'eqnr' criada no MySQL com sucesso.
# Dados inseridos na tabela 'eqnr' no MySQL com sucesso.
# Tabela 'pert_jk' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pert_jk' no MySQL com sucesso.
# Tabela 'cop' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cop' no MySQL com sucesso.
# Tabela 'eog' criada no MySQL com sucesso.
# Dados inseridos na tabela 'eog' no MySQL com sucesso.
# Tabela 'lkoh_me' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lkoh_me' no MySQL com sucesso.
# Tabela 'mpc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mpc' no MySQL com sucesso.
# Tabela 'pxx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pxx' no MySQL com sucesso.
# Tabela '2010_se' criada no MySQL com sucesso.
# Dados inseridos na tabela '2010_se' no MySQL com sucesso.
# Tabela 'enb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'enb' no MySQL com sucesso.
# Tabela 'oxy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'oxy' no MySQL com sucesso.
# Tabela 'slb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'slb' no MySQL com sucesso.
# Tabela 'hal' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hal' no MySQL com sucesso.
# Tabela 'bkr' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bkr' no MySQL com sucesso.
# Tabela 'wft' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wft' no MySQL com sucesso.
# Tabela 'rig' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rig' no MySQL com sucesso.
# Tabela 'val' criada no MySQL com sucesso.
# Dados inseridos na tabela 'val' no MySQL com sucesso.
# Tabela 'do' criada no MySQL com sucesso.
# Dados inseridos na tabela 'do' no MySQL com sucesso.
# Tabela 'ne' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ne' no MySQL com sucesso.
# Tabela 'rdc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rdc' no MySQL com sucesso.
# Tabela 'esv' criada no MySQL com sucesso.
# Dados inseridos na tabela 'esv' no MySQL com sucesso.
# Tabela 'sdrl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sdrl' no MySQL com sucesso.
# Tabela 'akso_ol' criada no MySQL com sucesso.
# Dados inseridos na tabela 'akso_ol' no MySQL com sucesso.
# Tabela 'fti' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fti' no MySQL com sucesso.
# Tabela 'spm_mi' criada no MySQL com sucesso.
# Dados inseridos na tabela 'spm_mi' no MySQL com sucesso.
# Tabela 'mdr' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mdr' no MySQL com sucesso.
# Tabela 'subc_l' criada no MySQL com sucesso.
# Dados inseridos na tabela 'subc_l' no MySQL com sucesso.
# Tabela 'rbs' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rbs' no MySQL com sucesso.
# Tabela 'osxb3' criada no MySQL com sucesso.
# Dados inseridos na tabela 'osxb3' no MySQL com sucesso.
# Tabela 'qgog3' criada no MySQL com sucesso.
# Dados inseridos na tabela 'qgog3' no MySQL com sucesso.
# Tabela 'jpm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'jpm' no MySQL com sucesso.
# Tabela 'brk_b' criada no MySQL com sucesso.
# Dados inseridos na tabela 'brk_b' no MySQL com sucesso.
# Tabela 'bac' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bac' no MySQL com sucesso.
# Tabela 'wfc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wfc' no MySQL com sucesso.
# Tabela 'c' criada no MySQL com sucesso.
# Dados inseridos na tabela 'c' no MySQL com sucesso.
# Tabela 'gs' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gs' no MySQL com sucesso.
# Tabela 'ms' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ms' no MySQL com sucesso.
# Tabela 'axp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'axp' no MySQL com sucesso.
# Tabela 'ma' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ma' no MySQL com sucesso.
# Tabela 'v' criada no MySQL com sucesso.
# Dados inseridos na tabela 'v' no MySQL com sucesso.
# Tabela 'schw' criada no MySQL com sucesso.
# Dados inseridos na tabela 'schw' no MySQL com sucesso.
# Tabela 'blk' criada no MySQL com sucesso.
# Dados inseridos na tabela 'blk' no MySQL com sucesso.
# Tabela 'spgi' criada no MySQL com sucesso.
# Dados inseridos na tabela 'spgi' no MySQL com sucesso.
# Tabela 'fis' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fis' no MySQL com sucesso.
# Tabela 'fisv' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fisv' no MySQL com sucesso.
# Tabela 'cof' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cof' no MySQL com sucesso.
# Tabela 'ndaq' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ndaq' no MySQL com sucesso.
# Tabela 'bk' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bk' no MySQL com sucesso.
# Tabela 'trow' criada no MySQL com sucesso.
# Dados inseridos na tabela 'trow' no MySQL com sucesso.
# Tabela 'stt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'stt' no MySQL com sucesso.
# Tabela 'bbt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbt' no MySQL com sucesso.
# Tabela 'ntrs' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ntrs' no MySQL com sucesso.
# Tabela 'ally' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ally' no MySQL com sucesso.
# Tabela 'etfc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'etfc' no MySQL com sucesso.
# Tabela 'dfs' criada no MySQL com sucesso.
# Dados inseridos na tabela 'dfs' no MySQL com sucesso.
# Tabela 'ice' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ice' no MySQL com sucesso.
# Tabela 'amp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'amp' no MySQL com sucesso.
# Tabela 'cme' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cme' no MySQL com sucesso.
# Tabela 'rjf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rjf' no MySQL com sucesso.
# Tabela 'trv' criada no MySQL com sucesso.
# Dados inseridos na tabela 'trv' no MySQL com sucesso.
# Tabela 'bhp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bhp' no MySQL com sucesso.
# Tabela 'rio' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rio' no MySQL com sucesso.
# Tabela 'vale' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vale' no MySQL com sucesso.
# Tabela 'glen_l' criada no MySQL com sucesso.
# Dados inseridos na tabela 'glen_l' no MySQL com sucesso.
# Tabela 'aal_l' criada no MySQL com sucesso.
# Dados inseridos na tabela 'aal_l' no MySQL com sucesso.
# Tabela 'fcx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fcx' no MySQL com sucesso.
# Tabela 'nem' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nem' no MySQL com sucesso.
# Tabela 'gold' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gold' no MySQL com sucesso.
# Tabela 'teck' criada no MySQL com sucesso.
# Dados inseridos na tabela 'teck' no MySQL com sucesso.
# Tabela 's32' criada no MySQL com sucesso.
# Dados inseridos na tabela 's32' no MySQL com sucesso.
# Tabela 'aa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'aa' no MySQL com sucesso.
# Tabela 'gfi' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gfi' no MySQL com sucesso.
# Tabela 'ncm_ax' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ncm_ax' no MySQL com sucesso.
# Tabela 'fmg_ax' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fmg_ax' no MySQL com sucesso.
# Tabela '2600_hk' criada no MySQL com sucesso.
# Dados inseridos na tabela '2600_hk' no MySQL com sucesso.
# Tabela 'codel_sn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'codel_sn' no MySQL com sucesso.
# Tabela 'gmkn_me' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gmkn_me' no MySQL com sucesso.
# Tabela 'mos' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mos' no MySQL com sucesso.
# Tabela 'lyc_ax' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lyc_ax' no MySQL com sucesso.
# Tabela 'inco_jk' criada no MySQL com sucesso.
# Dados inseridos na tabela 'inco_jk' no MySQL com sucesso.
# Tabela 'fm_to' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fm_to' no MySQL com sucesso.
# Tabela 'wpm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wpm' no MySQL com sucesso.
# Tabela 'hbm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hbm' no MySQL com sucesso.
# Tabela 'trq' criada no MySQL com sucesso.
# Dados inseridos na tabela 'trq' no MySQL com sucesso.
# Tabela 'ozl_ax' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ozl_ax' no MySQL com sucesso.
# Tabela 'lun_to' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lun_to' no MySQL com sucesso.
# Tabela 'evn_ax' criada no MySQL com sucesso.
# Dados inseridos na tabela 'evn_ax' no MySQL com sucesso.
# Tabela 'paas' criada no MySQL com sucesso.
# Dados inseridos na tabela 'paas' no MySQL com sucesso.
# Tabela 'nst_ax' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nst_ax' no MySQL com sucesso.
# Tabela 'kgc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'kgc' no MySQL com sucesso.
# Tabela 'hl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hl' no MySQL com sucesso.
# Tabela 'auy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'auy' no MySQL com sucesso.
# Tabela 'ssrm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ssrm' no MySQL com sucesso.
# Tabela 'kl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'kl' no MySQL com sucesso.
# Tabela 'agi' criada no MySQL com sucesso.
# Dados inseridos na tabela 'agi' no MySQL com sucesso.
# Tabela 'iag' criada no MySQL com sucesso.
# Dados inseridos na tabela 'iag' no MySQL com sucesso.
# Tabela 'aem' criada no MySQL com sucesso.
# Dados inseridos na tabela 'aem' no MySQL com sucesso.
# Tabela 'ngd' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ngd' no MySQL com sucesso.
# Tabela 'edv_to' criada no MySQL com sucesso.
# Dados inseridos na tabela 'edv_to' no MySQL com sucesso.
# Tabela 'hmy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hmy' no MySQL com sucesso.
# Tabela 'cey_l' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cey_l' no MySQL com sucesso.
# Tabela 'hoc_l' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hoc_l' no MySQL com sucesso.
# Tabela 'mag' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mag' no MySQL com sucesso.
# Tabela 'pvg' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pvg' no MySQL com sucesso.
# Tabela 'or_to' criada no MySQL com sucesso.
# Dados inseridos na tabela 'or_to' no MySQL com sucesso.
# Tabela '600547_ss' criada no MySQL com sucesso.
# Dados inseridos na tabela '600547_ss' no MySQL com sucesso.
# Tabela 'svm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'svm' no MySQL com sucesso.
# Tabela 'rgld' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rgld' no MySQL com sucesso.
# Tabela 'poly_l' criada no MySQL com sucesso.
# Dados inseridos na tabela 'poly_l' no MySQL com sucesso.
# Tabela 'sand' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sand' no MySQL com sucesso.
# Tabela 'nak' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nak' no MySQL com sucesso.
# Tabela 'fsm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fsm' no MySQL com sucesso.
# Tabela 'lug_to' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lug_to' no MySQL com sucesso.
# Tabela 'jnj' criada no MySQL com sucesso.
# Dados inseridos na tabela 'jnj' no MySQL com sucesso.
# Tabela 'rog' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rog' no MySQL com sucesso.
# Tabela 'pfe' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pfe' no MySQL com sucesso.
# Tabela 'novn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'novn' no MySQL com sucesso.
# Tabela 'mrk' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mrk' no MySQL com sucesso.
# Tabela 'abt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'abt' no MySQL com sucesso.
# Tabela 'sny' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sny' no MySQL com sucesso.
# Tabela 'gsk' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gsk' no MySQL com sucesso.
# Tabela 'mdt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mdt' no MySQL com sucesso.
# Tabela 'bmy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bmy' no MySQL com sucesso.
# Tabela 'lly' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lly' no MySQL com sucesso.
# Tabela 'amgn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'amgn' no MySQL com sucesso.
# Tabela 'azn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'azn' no MySQL com sucesso.
# Tabela 'nvo' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nvo' no MySQL com sucesso.
# Tabela '4502_t' criada no MySQL com sucesso.
# Dados inseridos na tabela '4502_t' no MySQL com sucesso.
# Tabela 'gild' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gild' no MySQL com sucesso.
# Tabela 'bayn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bayn' no MySQL com sucesso.
# Tabela 'bdx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bdx' no MySQL com sucesso.
# Tabela 'teva' criada no MySQL com sucesso.
# Dados inseridos na tabela 'teva' no MySQL com sucesso.
# Tabela 'syk' criada no MySQL com sucesso.
# Dados inseridos na tabela 'syk' no MySQL com sucesso.
# Tabela 'abbv' criada no MySQL com sucesso.
# Dados inseridos na tabela 'abbv' no MySQL com sucesso.
# Tabela 'biib' criada no MySQL com sucesso.
# Dados inseridos na tabela 'biib' no MySQL com sucesso.
# Tabela 'regn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'regn' no MySQL com sucesso.
# Tabela 'vrtx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vrtx' no MySQL com sucesso.
# Tabela 'alxn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'alxn' no MySQL com sucesso.
# Tabela 'shpg' criada no MySQL com sucesso.
# Dados inseridos na tabela 'shpg' no MySQL com sucesso.
# Tabela 'zts' criada no MySQL com sucesso.
# Dados inseridos na tabela 'zts' no MySQL com sucesso.
# Tabela 'fre' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fre' no MySQL com sucesso.
# Tabela 'ci' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ci' no MySQL com sucesso.
# Tabela 'cah' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cah' no MySQL com sucesso.
# Tabela 'aapl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'aapl' no MySQL com sucesso.
# Tabela 'msft' criada no MySQL com sucesso.
# Dados inseridos na tabela 'msft' no MySQL com sucesso.
# Tabela 'googl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'googl' no MySQL com sucesso.
# Tabela 'fb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fb' no MySQL com sucesso.
# Tabela 'tsla' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tsla' no MySQL com sucesso.
# Tabela 'nvda' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nvda' no MySQL com sucesso.
# Tabela 'adbe' criada no MySQL com sucesso.
# Dados inseridos na tabela 'adbe' no MySQL com sucesso.
# Tabela 'intc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'intc' no MySQL com sucesso.
# Tabela 'ibm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ibm' no MySQL com sucesso.
# Tabela 'nflx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nflx' no MySQL com sucesso.
# Tabela 'crm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'crm' no MySQL com sucesso.
# Tabela 'tcehy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tcehy' no MySQL com sucesso.
# Tabela 'orcl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'orcl' no MySQL com sucesso.
# Tabela 'csco' criada no MySQL com sucesso.
# Dados inseridos na tabela 'csco' no MySQL com sucesso.
# Tabela 'qcom' criada no MySQL com sucesso.
# Dados inseridos na tabela 'qcom' no MySQL com sucesso.
# Tabela 'pypl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pypl' no MySQL com sucesso.
# Tabela 'sne' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sne' no MySQL com sucesso.
# Tabela 'sq' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sq' no MySQL com sucesso.
# Tabela 'twtr' criada no MySQL com sucesso.
# Dados inseridos na tabela 'twtr' no MySQL com sucesso.
# Tabela 'uber' criada no MySQL com sucesso.
# Dados inseridos na tabela 'uber' no MySQL com sucesso.
# Tabela 'zm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'zm' no MySQL com sucesso.
# Tabela 'pltr' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pltr' no MySQL com sucesso.
# Tabela 'snow' criada no MySQL com sucesso.
# Dados inseridos na tabela 'snow' no MySQL com sucesso.
# Tabela 'pins' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pins' no MySQL com sucesso.
# Tabela 'docu' criada no MySQL com sucesso.
# Dados inseridos na tabela 'docu' no MySQL com sucesso.
# Tabela 'twlo' criada no MySQL com sucesso.
# Dados inseridos na tabela 'twlo' no MySQL com sucesso.
# Tabela 'now' criada no MySQL com sucesso.
# Dados inseridos na tabela 'now' no MySQL com sucesso.
# Tabela 'wmt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wmt' no MySQL com sucesso.
# Tabela 'amzn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'amzn' no MySQL com sucesso.
# Tabela 'baba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'baba' no MySQL com sucesso.
# Tabela 'cost' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cost' no MySQL com sucesso.
# Tabela 'hd' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hd' no MySQL com sucesso.
# Tabela 'low' criada no MySQL com sucesso.
# Dados inseridos na tabela 'low' no MySQL com sucesso.
# Tabela 'itx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'itx' no MySQL com sucesso.
# Tabela 'ca' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ca' no MySQL com sucesso.
# Tabela 'jd' criada no MySQL com sucesso.
# Dados inseridos na tabela 'jd' no MySQL com sucesso.
# Tabela 'tgt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tgt' no MySQL com sucesso.
# Tabela 'cvs' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cvs' no MySQL com sucesso.
# Tabela 'lvmuy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lvmuy' no MySQL com sucesso.
# Tabela 'wow' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wow' no MySQL com sucesso.
# Tabela 'kr' criada no MySQL com sucesso.
# Dados inseridos na tabela 'kr' no MySQL com sucesso.
# Tabela '3382_t' criada no MySQL com sucesso.
# Dados inseridos na tabela '3382_t' no MySQL com sucesso.
# Tabela 'wba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wba' no MySQL com sucesso.
# Tabela 'bby' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bby' no MySQL com sucesso.
# ...
# Dados inseridos na tabela 'CRI_WB_TXJUR' no MySQL com sucesso.
# Tabela 'GTM_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'GTM_WB_TXJUR' no MySQL com sucesso.
# Tabela 'HND_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'HND_WB_TXJUR' no MySQL com sucesso.
# Tabela 'NIC_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'NIC_WB_TXJUR' no MySQL com sucesso.
# Tabela 'BOL_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'BOL_WB_TXJUR' no MySQL com sucesso.
# Tabela 'JPN_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'JPN_WB_TXJUR' no MySQL com sucesso.
# Tabela 'DEU_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'DEU_WB_TXJUR' no MySQL com sucesso.
# Tabela 'USA_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'USA_WB_TXJUR' no MySQL com sucesso.
# Tabela 'KOR_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'KOR_WB_TXJUR' no MySQL com sucesso.
# Tabela 'SWE_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SWE_WB_TXJUR' no MySQL com sucesso.
# Tabela 'ITA_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ITA_WB_TXJUR' no MySQL com sucesso.
# Tabela 'FRA_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'FRA_WB_TXJUR' no MySQL com sucesso.
# Tabela 'GBR_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'GBR_WB_TXJUR' no MySQL com sucesso.
# Tabela 'CHN_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CHN_WB_TXJUR' no MySQL com sucesso.
# Tabela 'IND_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'IND_WB_TXJUR' no MySQL com sucesso.
# Tabela 'ESP_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ESP_WB_TXJUR' no MySQL com sucesso.
# Tabela 'IRL_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'IRL_WB_TXJUR' no MySQL com sucesso.
# Tabela 'SAU_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SAU_WB_TXJUR' no MySQL com sucesso.
# Tabela 'NLD_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'NLD_WB_TXJUR' no MySQL com sucesso.
# Tabela 'KWT_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'KWT_WB_TXJUR' no MySQL com sucesso.
# Tabela 'ARE_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ARE_WB_TXJUR' no MySQL com sucesso.
# Tabela 'NOR_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'NOR_WB_TXJUR' no MySQL com sucesso.
# Tabela 'IDN_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'IDN_WB_TXJUR' no MySQL com sucesso.
# Tabela 'CAN_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CAN_WB_TXJUR' no MySQL com sucesso.
# Tabela 'AUS_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'AUS_WB_TXJUR' no MySQL com sucesso.
# Tabela 'CHE_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CHE_WB_TXJUR' no MySQL com sucesso.
# Tabela 'ZAF_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ZAF_WB_TXJUR' no MySQL com sucesso.
# Tabela 'DNK_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'DNK_WB_TXJUR' no MySQL com sucesso.
# Tabela 'ISR_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ISR_WB_TXJUR' no MySQL com sucesso.
# Tabela 'PRT_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PRT_WB_TXJUR' no MySQL com sucesso.
# Tabela 'HKG_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'HKG_WB_TXJUR' no MySQL com sucesso.
# Tabela 'PRY_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PRY_WB_TXJUR' no MySQL com sucesso.
# Tabela 'MNG_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'MNG_WB_TXJUR' no MySQL com sucesso.
# Tabela 'CUB_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CUB_WB_TXJUR' no MySQL com sucesso.
# Tabela 'ECU_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ECU_WB_TXJUR' no MySQL com sucesso.
# Tabela 'SLV_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SLV_WB_TXJUR' no MySQL com sucesso.
# Tabela 'GUY_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'GUY_WB_TXJUR' no MySQL com sucesso.
# Tabela 'HTI_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'HTI_WB_TXJUR' no MySQL com sucesso.
# Tabela 'PAN_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PAN_WB_TXJUR' no MySQL com sucesso.
# Tabela 'DOM_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'DOM_WB_TXJUR' no MySQL com sucesso.
# Tabela 'SUR_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SUR_WB_TXJUR' no MySQL com sucesso.
# Tabela 'RUS_WB_TXJUR' criada no MySQL com sucesso.
# Dados inseridos na tabela 'RUS_WB_TXJUR' no MySQL com sucesso.
# Tabela 'BRA_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'BRA_WB_EXP' no MySQL com sucesso.
# Tabela 'ARG_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ARG_WB_EXP' no MySQL com sucesso.
# Tabela 'CHL_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CHL_WB_EXP' no MySQL com sucesso.
# Tabela 'COL_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'COL_WB_EXP' no MySQL com sucesso.
# Tabela 'MEX_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'MEX_WB_EXP' no MySQL com sucesso.
# Tabela 'PER_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PER_WB_EXP' no MySQL com sucesso.
# Tabela 'URY_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'URY_WB_EXP' no MySQL com sucesso.
# Tabela 'VEN_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'VEN_WB_EXP' no MySQL com sucesso.
# Tabela 'BLZ_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'BLZ_WB_EXP' no MySQL com sucesso.
# Tabela 'CRI_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CRI_WB_EXP' no MySQL com sucesso.
# Tabela 'GTM_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'GTM_WB_EXP' no MySQL com sucesso.
# Tabela 'HND_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'HND_WB_EXP' no MySQL com sucesso.
# Tabela 'NIC_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'NIC_WB_EXP' no MySQL com sucesso.
# Tabela 'BOL_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'BOL_WB_EXP' no MySQL com sucesso.
# Tabela 'JPN_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'JPN_WB_EXP' no MySQL com sucesso.
# Tabela 'DEU_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'DEU_WB_EXP' no MySQL com sucesso.
# Tabela 'USA_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'USA_WB_EXP' no MySQL com sucesso.
# Tabela 'KOR_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'KOR_WB_EXP' no MySQL com sucesso.
# Tabela 'SWE_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SWE_WB_EXP' no MySQL com sucesso.
# Tabela 'ITA_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ITA_WB_EXP' no MySQL com sucesso.
# Tabela 'FRA_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'FRA_WB_EXP' no MySQL com sucesso.
# Tabela 'GBR_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'GBR_WB_EXP' no MySQL com sucesso.
# Tabela 'CHN_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CHN_WB_EXP' no MySQL com sucesso.
# Tabela 'IND_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'IND_WB_EXP' no MySQL com sucesso.
# Tabela 'ESP_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ESP_WB_EXP' no MySQL com sucesso.
# Tabela 'IRL_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'IRL_WB_EXP' no MySQL com sucesso.
# Tabela 'SAU_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SAU_WB_EXP' no MySQL com sucesso.
# Tabela 'NLD_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'NLD_WB_EXP' no MySQL com sucesso.
# Tabela 'KWT_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'KWT_WB_EXP' no MySQL com sucesso.
# Tabela 'ARE_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ARE_WB_EXP' no MySQL com sucesso.
# Tabela 'NOR_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'NOR_WB_EXP' no MySQL com sucesso.
# Tabela 'IDN_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'IDN_WB_EXP' no MySQL com sucesso.
# Tabela 'CAN_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CAN_WB_EXP' no MySQL com sucesso.
# Tabela 'AUS_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'AUS_WB_EXP' no MySQL com sucesso.
# Tabela 'CHE_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CHE_WB_EXP' no MySQL com sucesso.
# Tabela 'ZAF_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ZAF_WB_EXP' no MySQL com sucesso.
# Tabela 'DNK_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'DNK_WB_EXP' no MySQL com sucesso.
# Tabela 'ISR_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ISR_WB_EXP' no MySQL com sucesso.
# Tabela 'PRT_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PRT_WB_EXP' no MySQL com sucesso.
# Tabela 'HKG_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'HKG_WB_EXP' no MySQL com sucesso.
# Tabela 'PRY_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PRY_WB_EXP' no MySQL com sucesso.
# Tabela 'MNG_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'MNG_WB_EXP' no MySQL com sucesso.
# Tabela 'CUB_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CUB_WB_EXP' no MySQL com sucesso.
# Tabela 'ECU_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ECU_WB_EXP' no MySQL com sucesso.
# Tabela 'SLV_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SLV_WB_EXP' no MySQL com sucesso.
# Tabela 'GUY_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'GUY_WB_EXP' no MySQL com sucesso.
# Tabela 'HTI_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'HTI_WB_EXP' no MySQL com sucesso.
# Tabela 'PAN_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PAN_WB_EXP' no MySQL com sucesso.
# Tabela 'DOM_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'DOM_WB_EXP' no MySQL com sucesso.
# Tabela 'SUR_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SUR_WB_EXP' no MySQL com sucesso.
# Tabela 'RUS_WB_EXP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'RUS_WB_EXP' no MySQL com sucesso.
# Tabela 'BRA_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'BRA_WB_IMP' no MySQL com sucesso.
# Tabela 'ARG_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ARG_WB_IMP' no MySQL com sucesso.
# Tabela 'CHL_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CHL_WB_IMP' no MySQL com sucesso.
# Tabela 'COL_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'COL_WB_IMP' no MySQL com sucesso.
# Tabela 'MEX_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'MEX_WB_IMP' no MySQL com sucesso.
# Tabela 'PER_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PER_WB_IMP' no MySQL com sucesso.
# Tabela 'URY_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'URY_WB_IMP' no MySQL com sucesso.
# Tabela 'VEN_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'VEN_WB_IMP' no MySQL com sucesso.
# Tabela 'BLZ_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'BLZ_WB_IMP' no MySQL com sucesso.
# Tabela 'CRI_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CRI_WB_IMP' no MySQL com sucesso.
# Tabela 'GTM_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'GTM_WB_IMP' no MySQL com sucesso.
# Tabela 'HND_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'HND_WB_IMP' no MySQL com sucesso.
# Tabela 'NIC_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'NIC_WB_IMP' no MySQL com sucesso.
# Tabela 'BOL_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'BOL_WB_IMP' no MySQL com sucesso.
# Tabela 'JPN_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'JPN_WB_IMP' no MySQL com sucesso.
# Tabela 'DEU_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'DEU_WB_IMP' no MySQL com sucesso.
# Tabela 'USA_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'USA_WB_IMP' no MySQL com sucesso.
# Tabela 'KOR_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'KOR_WB_IMP' no MySQL com sucesso.
# Tabela 'SWE_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SWE_WB_IMP' no MySQL com sucesso.
# Tabela 'ITA_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ITA_WB_IMP' no MySQL com sucesso.
# Tabela 'FRA_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'FRA_WB_IMP' no MySQL com sucesso.
# Tabela 'GBR_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'GBR_WB_IMP' no MySQL com sucesso.
# Tabela 'CHN_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CHN_WB_IMP' no MySQL com sucesso.
# Tabela 'IND_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'IND_WB_IMP' no MySQL com sucesso.
# Tabela 'ESP_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ESP_WB_IMP' no MySQL com sucesso.
# Tabela 'IRL_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'IRL_WB_IMP' no MySQL com sucesso.
# Tabela 'SAU_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SAU_WB_IMP' no MySQL com sucesso.
# Tabela 'NLD_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'NLD_WB_IMP' no MySQL com sucesso.
# Tabela 'KWT_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'KWT_WB_IMP' no MySQL com sucesso.
# Tabela 'ARE_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ARE_WB_IMP' no MySQL com sucesso.
# Tabela 'NOR_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'NOR_WB_IMP' no MySQL com sucesso.
# Tabela 'IDN_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'IDN_WB_IMP' no MySQL com sucesso.
# Tabela 'CAN_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CAN_WB_IMP' no MySQL com sucesso.
# Tabela 'AUS_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'AUS_WB_IMP' no MySQL com sucesso.
# Tabela 'CHE_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CHE_WB_IMP' no MySQL com sucesso.
# Tabela 'ZAF_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ZAF_WB_IMP' no MySQL com sucesso.
# Tabela 'DNK_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'DNK_WB_IMP' no MySQL com sucesso.
# Tabela 'ISR_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ISR_WB_IMP' no MySQL com sucesso.
# Tabela 'PRT_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PRT_WB_IMP' no MySQL com sucesso.
# Tabela 'HKG_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'HKG_WB_IMP' no MySQL com sucesso.
# Tabela 'PRY_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PRY_WB_IMP' no MySQL com sucesso.
# Tabela 'MNG_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'MNG_WB_IMP' no MySQL com sucesso.
# Tabela 'CUB_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'CUB_WB_IMP' no MySQL com sucesso.
# Tabela 'ECU_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ECU_WB_IMP' no MySQL com sucesso.
# Tabela 'SLV_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SLV_WB_IMP' no MySQL com sucesso.
# Tabela 'GUY_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'GUY_WB_IMP' no MySQL com sucesso.
# Tabela 'HTI_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'HTI_WB_IMP' no MySQL com sucesso.
# Tabela 'PAN_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'PAN_WB_IMP' no MySQL com sucesso.
# Tabela 'DOM_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'DOM_WB_IMP' no MySQL com sucesso.
# Tabela 'SUR_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'SUR_WB_IMP' no MySQL com sucesso.
# Tabela 'RUS_WB_IMP' criada no MySQL com sucesso.
# Dados inseridos na tabela 'RUS_WB_IMP' no MySQL com sucesso.

# %%
sqlite_conn.close()
mysql_conn.close()
