# %%
'''!pip install pymysql'''
# Out:
# '!pip install pymysql'

# %%
import sqlite3
import pymysql
import pandas as pd
import numpy as np

# %%
# Conectar-se ao banco de dados SQLite
sqlite_conn = sqlite3.connect('yfhistoric.db')
sqlite_cursor = sqlite_conn.cursor()

# Conectar-se ao banco de dados MySQL
mysql_conn = pymysql.connect(host='192.168.15.57', user='yanadm', password='121212', database='yfhistoric')
mysql_cursor = mysql_conn.cursor()
mysql_cursor.execute("SET foreign_key_checks = 0")
# Out:
# 0

# %%
# Obter os nomes das tabelas do banco de dados SQLite
tables = sqlite_conn.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
table_names = [table[0] for table in tables]


# Criar um dicionário para armazenar os DataFrames de cada tabela
yfhistoricdic = {}

# Iterar sobre as tabelas e criar um DataFrame para cada uma
for table_name in table_names:
    # Ler os dados da tabela e criar um DataFrame
    df = pd.read_sql_query(f"SELECT * FROM '{table_name}';", sqlite_conn)
    # Armazenar o DataFrame no dicionário, usando o nome da tabela como chave
    yfhistoricdic[table_name] = df

# %%
# Substituir "=" por "000" em todas as chaves
yfhistoricdic = {key.replace("=", "000"): value for key, value in yfhistoricdic.items()}
yfhistoricdic = {key.replace(".", "XXX"): value for key, value in yfhistoricdic.items()}
yfhistoricdic = {key.replace("^", "STOCK"): value for key, value in yfhistoricdic.items()}
dataframes_dict = yfhistoricdic

# %%
pandas_to_mysql_types = {
    np.dtype('int64'): 'BIGINT',
    np.dtype('float64'): 'FLOAT',
    np.dtype('datetime64[ns]'): 'DATETIME',
    np.dtype('object'): 'TEXT'
}

# %%
# Iterar sobre o dicionário de DataFrames
for table_name, df in dataframes_dict.items():
    # Criar a tabela no MySQL
    cursor = mysql_conn.cursor()
    # Substituir valores NaN por NULL
    df.fillna(value=pd.NA, inplace=True)  # Use pd.NA para representar NULL
    # Inferir os tipos de dados das colunas e criar a string de colunas para a criação da tabela
    columns = []
    for col, dtype in df.dtypes.items():
        mysql_type = pandas_to_mysql_types.get(dtype, 'TEXT')
        columns.append(f"`{col}` {mysql_type}")
    columns_str = ', '.join(columns)
    
    create_table_query = f"CREATE TABLE IF NOT EXISTS `{table_name}` ({columns_str})"
    cursor.execute(create_table_query)
    print(f"Tabela '{table_name}' criada no MySQL com sucesso.")

    # Inserir os dados na tabela
    for index, row in df.iterrows():
        placeholders = ', '.join(['%s' for _ in df.columns])
        insert_query = f'''INSERT INTO {table_name} ({', '.join(df.columns)}) VALUES ({placeholders})'''
        try:
            cursor.execute(insert_query, tuple(row))
        except Exception as e:
            print(insert_query)
            print(f"Ocorreu um erro: {e}")
    print(f"Dados inseridos na tabela '{table_name}' no MySQL com sucesso.")

# Confirmar as alterações no MySQL
mysql_conn.commit()
# Out:
# Tabela 'indicators' criada no MySQL com sucesso.
# Dados inseridos na tabela 'indicators' no MySQL com sucesso.
# Tabela 'texts' criada no MySQL com sucesso.
# Dados inseridos na tabela 'texts' no MySQL com sucesso.
# Tabela 'niche' criada no MySQL com sucesso.
# Dados inseridos na tabela 'niche' no MySQL com sucesso.
# Tabela 'currencies' criada no MySQL com sucesso.
# Dados inseridos na tabela 'currencies' no MySQL com sucesso.
# Tabela 'tickets' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tickets' no MySQL com sucesso.
# Tabela 'commodities' criada no MySQL com sucesso.
# Dados inseridos na tabela 'commodities' no MySQL com sucesso.
# Tabela 'cripto' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cripto' no MySQL com sucesso.
# Tabela 'news' criada no MySQL com sucesso.
# Dados inseridos na tabela 'news' no MySQL com sucesso.
# Tabela 'summary' criada no MySQL com sucesso.
# Dados inseridos na tabela 'summary' no MySQL com sucesso.
# Tabela 'usd' criada no MySQL com sucesso.
# Dados inseridos na tabela 'usd' no MySQL com sucesso.
# Tabela 'mlearning' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mlearning' no MySQL com sucesso.
# Tabela 'brl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'brl' no MySQL com sucesso.
# Tabela 'ars' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ars' no MySQL com sucesso.
# Tabela 'clp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'clp' no MySQL com sucesso.
# Tabela 'mxn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mxn' no MySQL com sucesso.
# Tabela 'pen' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pen' no MySQL com sucesso.
# Tabela 'uyu' criada no MySQL com sucesso.
# Dados inseridos na tabela 'uyu' no MySQL com sucesso.
# Tabela 'ves' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ves' no MySQL com sucesso.
# Tabela 'bzd' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bzd' no MySQL com sucesso.
# Tabela 'crc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'crc' no MySQL com sucesso.
# Tabela 'gtq' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gtq' no MySQL com sucesso.
# Tabela 'hnl' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hnl' no MySQL com sucesso.
# Tabela 'nio' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nio' no MySQL com sucesso.
# Tabela 'bob' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bob' no MySQL com sucesso.
# Tabela 'btc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'btc' no MySQL com sucesso.
# Tabela 'eth' criada no MySQL com sucesso.
# Dados inseridos na tabela 'eth' no MySQL com sucesso.
# Tabela 'bnb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bnb' no MySQL com sucesso.
# Tabela 'sol' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sol' no MySQL com sucesso.
# Tabela 'ada' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ada' no MySQL com sucesso.
# Tabela 'usdt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'usdt' no MySQL com sucesso.
# Tabela 'xrp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'xrp' no MySQL com sucesso.
# Tabela 'dot' criada no MySQL com sucesso.
# Dados inseridos na tabela 'dot' no MySQL com sucesso.
# Tabela 'usdc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'usdc' no MySQL com sucesso.
# Tabela 'doge' criada no MySQL com sucesso.
# Dados inseridos na tabela 'doge' no MySQL com sucesso.
# Tabela 'avax' criada no MySQL com sucesso.
# Dados inseridos na tabela 'avax' no MySQL com sucesso.
# Tabela 'link' criada no MySQL com sucesso.
# Dados inseridos na tabela 'link' no MySQL com sucesso.
# Tabela 'luna' criada no MySQL com sucesso.
# Dados inseridos na tabela 'luna' no MySQL com sucesso.
# Tabela 'ltc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ltc' no MySQL com sucesso.
# Tabela 'algo' criada no MySQL com sucesso.
# Dados inseridos na tabela 'algo' no MySQL com sucesso.
# Tabela 'shib' criada no MySQL com sucesso.
# Dados inseridos na tabela 'shib' no MySQL com sucesso.
# Tabela 'matic' criada no MySQL com sucesso.
# Dados inseridos na tabela 'matic' no MySQL com sucesso.
# Tabela 'xlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'xlm' no MySQL com sucesso.
# Tabela 'icp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'icp' no MySQL com sucesso.
# Tabela 'wbtc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wbtc' no MySQL com sucesso.
# Tabela 'etc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'etc' no MySQL com sucesso.
# Tabela 'vet' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vet' no MySQL com sucesso.
# Tabela 'fil' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fil' no MySQL com sucesso.
# Tabela 'trx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'trx' no MySQL com sucesso.
# Tabela 'theta' criada no MySQL com sucesso.
# Dados inseridos na tabela 'theta' no MySQL com sucesso.
# Tabela 'atom' criada no MySQL com sucesso.
# Dados inseridos na tabela 'atom' no MySQL com sucesso.
# Tabela 'ftt' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ftt' no MySQL com sucesso.
# Tabela 'dai' criada no MySQL com sucesso.
# Dados inseridos na tabela 'dai' no MySQL com sucesso.
# Tabela 'aave' criada no MySQL com sucesso.
# Dados inseridos na tabela 'aave' no MySQL com sucesso.
# Tabela 'gc000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gc000f' no MySQL com sucesso.
# Tabela 'si000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'si000f' no MySQL com sucesso.
# Tabela 'cl000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cl000f' no MySQL com sucesso.
# Tabela 'bz000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bz000f' no MySQL com sucesso.
# Tabela 'hg000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hg000f' no MySQL com sucesso.
# Tabela 'ng000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ng000f' no MySQL com sucesso.
# Tabela 'c000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'c000f' no MySQL com sucesso.
# Tabela 'w000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'w000f' no MySQL com sucesso.
# Tabela 'kc000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'kc000f' no MySQL com sucesso.
# Tabela 'sb000f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sb000f' no MySQL com sucesso.
# Tabela 'ypfdXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ypfdXXXba' no MySQL com sucesso.
# Tabela 'meliXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'meliXXXba' no MySQL com sucesso.
# Tabela 'bbarXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbarXXXba' no MySQL com sucesso.
# Tabela 'cresXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cresXXXba' no MySQL com sucesso.
# Tabela 'pampXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pampXXXba' no MySQL com sucesso.
# Tabela 'tsXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tsXXXba' no MySQL com sucesso.
# Tabela 'globXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'globXXXba' no MySQL com sucesso.
# Tabela 'bmaXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bmaXXXba' no MySQL com sucesso.
# Tabela 'txarXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'txarXXXba' no MySQL com sucesso.
# Tabela 'cepuXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cepuXXXba' no MySQL com sucesso.
# Tabela 'rioXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rioXXXba' no MySQL com sucesso.
# Tabela 'supvXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'supvXXXba' no MySQL com sucesso.
# Tabela 'ypflXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ypflXXXba' no MySQL com sucesso.
# Tabela 'bbvaXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbvaXXXba' no MySQL com sucesso.
# Tabela 'despXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'despXXXba' no MySQL com sucesso.
# Tabela 'ggalXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ggalXXXba' no MySQL com sucesso.
# Tabela 'aluaXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'aluaXXXba' no MySQL com sucesso.
# Tabela 'moliXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'moliXXXba' no MySQL com sucesso.
# Tabela 'ednXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ednXXXba' no MySQL com sucesso.
# Tabela 'irsaXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'irsaXXXba' no MySQL com sucesso.
# Tabela 'bpatXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bpatXXXba' no MySQL com sucesso.
# Tabela 'teco2XXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'teco2XXXba' no MySQL com sucesso.
# Tabela 'erarXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'erarXXXba' no MySQL com sucesso.
# Tabela 'ctioXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ctioXXXba' no MySQL com sucesso.
# Tabela 'molaXXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'molaXXXba' no MySQL com sucesso.
# Tabela 'tgsu2XXXba' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tgsu2XXXba' no MySQL com sucesso.
# Tabela 'vale3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vale3XXXsa' no MySQL com sucesso.
# Tabela 'itub4XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'itub4XXXsa' no MySQL com sucesso.
# Tabela 'bbdc4XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbdc4XXXsa' no MySQL com sucesso.
# Tabela 'abev3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'abev3XXXsa' no MySQL com sucesso.
# Tabela 'bbas3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbas3XXXsa' no MySQL com sucesso.
# Tabela 'b3sa3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'b3sa3XXXsa' no MySQL com sucesso.
# Tabela 'petr4XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'petr4XXXsa' no MySQL com sucesso.
# Tabela 'ciel3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ciel3XXXsa' no MySQL com sucesso.
# Tabela 'elet6XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'elet6XXXsa' no MySQL com sucesso.
# Tabela 'mglu3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mglu3XXXsa' no MySQL com sucesso.
# Tabela 'vvar3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vvar3XXXsa' no MySQL com sucesso.
# Tabela 'ggbr4XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ggbr4XXXsa' no MySQL com sucesso.
# Tabela 'rail3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rail3XXXsa' no MySQL com sucesso.
# Tabela 'cyre3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cyre3XXXsa' no MySQL com sucesso.
# Tabela 'klbn11XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'klbn11XXXsa' no MySQL com sucesso.
# Tabela 'rapt4XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rapt4XXXsa' no MySQL com sucesso.
# Tabela 'ugpa3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ugpa3XXXsa' no MySQL com sucesso.
# Tabela 'usim5XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'usim5XXXsa' no MySQL com sucesso.
# Tabela 'lame4XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lame4XXXsa' no MySQL com sucesso.
# Tabela 'suzb3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'suzb3XXXsa' no MySQL com sucesso.
# Tabela 'flry3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'flry3XXXsa' no MySQL com sucesso.
# Tabela 'goll4XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'goll4XXXsa' no MySQL com sucesso.
# Tabela 'sanb11XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sanb11XXXsa' no MySQL com sucesso.
# Tabela 'rent3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rent3XXXsa' no MySQL com sucesso.
# Tabela 'ecor3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ecor3XXXsa' no MySQL com sucesso.
# Tabela 'brkm5XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'brkm5XXXsa' no MySQL com sucesso.
# Tabela 'wege3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'wege3XXXsa' no MySQL com sucesso.
# Tabela 'jbss3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'jbss3XXXsa' no MySQL com sucesso.
# Tabela 'irbr3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'irbr3XXXsa' no MySQL com sucesso.
# Tabela 'ccro3XXXsa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ccro3XXXsa' no MySQL com sucesso.
# Tabela 'sanXXXsn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sanXXXsn' no MySQL com sucesso.
# Tabela 'ltm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ltm' no MySQL com sucesso.
# Tabela 'sqm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sqm' no MySQL com sucesso.
# Tabela 'bch' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bch' no MySQL com sucesso.
# Tabela 'cap' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cap' no MySQL com sucesso.
# Tabela 'andina-a' criada no MySQL com sucesso.
# Dados inseridos na tabela 'andina-a' no MySQL com sucesso.
# Tabela 'enelam' criada no MySQL com sucesso.
# Dados inseridos na tabela 'enelam' no MySQL com sucesso.
# Tabela 'bice' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bice' no MySQL com sucesso.
# Tabela 'colbun' criada no MySQL com sucesso.
# Dados inseridos na tabela 'colbun' no MySQL com sucesso.
# Tabela 'entel' criada no MySQL com sucesso.
# Dados inseridos na tabela 'entel' no MySQL com sucesso.
# Tabela 'smu' criada no MySQL com sucesso.
# Dados inseridos na tabela 'smu' no MySQL com sucesso.
# Tabela 'falabella' criada no MySQL com sucesso.
# Dados inseridos na tabela 'falabella' no MySQL com sucesso.
# Tabela 'bsantander' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bsantander' no MySQL com sucesso.
# Tabela 'sonda' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sonda' no MySQL com sucesso.
# Tabela 'estado' criada no MySQL com sucesso.
# Dados inseridos na tabela 'estado' no MySQL com sucesso.
# Tabela 'parauco' criada no MySQL com sucesso.
# Dados inseridos na tabela 'parauco' no MySQL com sucesso.
# Tabela 'itaucorp' criada no MySQL com sucesso.
# Dados inseridos na tabela 'itaucorp' no MySQL com sucesso.
# Tabela 'conchatoro' criada no MySQL com sucesso.
# Dados inseridos na tabela 'conchatoro' no MySQL com sucesso.
# Tabela 'saam' criada no MySQL com sucesso.
# Dados inseridos na tabela 'saam' no MySQL com sucesso.
# Tabela 'bsanXXXsn' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bsanXXXsn' no MySQL com sucesso.
# Tabela 'security' criada no MySQL com sucesso.
# Dados inseridos na tabela 'security' no MySQL com sucesso.
# Tabela 'enelchile' criada no MySQL com sucesso.
# Dados inseridos na tabela 'enelchile' no MySQL com sucesso.
# Tabela 'ilc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ilc' no MySQL com sucesso.
# Tabela 'bci' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bci' no MySQL com sucesso.
# Tabela 'ecopetrol' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ecopetrol' no MySQL com sucesso.
# Tabela 'bic' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bic' no MySQL com sucesso.
# Tabela 'sur' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sur' no MySQL com sucesso.
# Tabela 'bolivar' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bolivar' no MySQL com sucesso.
# Tabela 'corona' criada no MySQL com sucesso.
# Dados inseridos na tabela 'corona' no MySQL com sucesso.
# Tabela 'nutresa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nutresa' no MySQL com sucesso.
# Tabela 'exito' criada no MySQL com sucesso.
# Dados inseridos na tabela 'exito' no MySQL com sucesso.
# Tabela 'cencosud' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cencosud' no MySQL com sucesso.
# Tabela 'aval' criada no MySQL com sucesso.
# Dados inseridos na tabela 'aval' no MySQL com sucesso.
# Tabela 'geb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'geb' no MySQL com sucesso.
# Tabela 'promigas' criada no MySQL com sucesso.
# Dados inseridos na tabela 'promigas' no MySQL com sucesso.
# Tabela 'epm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'epm' no MySQL com sucesso.
# Tabela 'celsia' criada no MySQL com sucesso.
# Dados inseridos na tabela 'celsia' no MySQL com sucesso.
# Tabela 'isa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'isa' no MySQL com sucesso.
# Tabela 'pfbcolom' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pfbcolom' no MySQL com sucesso.
# Tabela 'davivienda' criada no MySQL com sucesso.
# Dados inseridos na tabela 'davivienda' no MySQL com sucesso.
# Tabela 'gnc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gnc' no MySQL com sucesso.
# Tabela 'argos' criada no MySQL com sucesso.
# Dados inseridos na tabela 'argos' no MySQL com sucesso.
# Tabela 'sura' criada no MySQL com sucesso.
# Dados inseridos na tabela 'sura' no MySQL com sucesso.
# Tabela 'pfg' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pfg' no MySQL com sucesso.
# Tabela 'amxlXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'amxlXXXmx' no MySQL com sucesso.
# Tabela 'gmexicobXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gmexicobXXXmx' no MySQL com sucesso.
# Tabela 'femsaubdXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'femsaubdXXXmx' no MySQL com sucesso.
# Tabela 'bimboaXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bimboaXXXmx' no MySQL com sucesso.
# Tabela 'cemexcpoXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cemexcpoXXXmx' no MySQL com sucesso.
# Tabela 'gfnorteoXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gfnorteoXXXmx' no MySQL com sucesso.
# Tabela 'elektraXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'elektraXXXmx' no MySQL com sucesso.
# Tabela 'gapbXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gapbXXXmx' no MySQL com sucesso.
# Tabela 'alfaaXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'alfaaXXXmx' no MySQL com sucesso.
# Tabela 'omabXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'omabXXXmx' no MySQL com sucesso.
# Tabela 'gcarsoa1XXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gcarsoa1XXXmx' no MySQL com sucesso.
# Tabela 'labbXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'labbXXXmx' no MySQL com sucesso.
# Tabela 'asurbXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'asurbXXXmx' no MySQL com sucesso.
# Tabela 'gacmabXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gacmabXXXmx' no MySQL com sucesso.
# Tabela 'simecbXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'simecbXXXmx' no MySQL com sucesso.
# Tabela 'alpekaXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'alpekaXXXmx' no MySQL com sucesso.
# Tabela 'vlrsXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vlrsXXXmx' no MySQL com sucesso.
# Tabela 'genteraXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'genteraXXXmx' no MySQL com sucesso.
# Tabela 'bsmxbXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bsmxbXXXmx' no MySQL com sucesso.
# Tabela 'tlevisacpoXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tlevisacpoXXXmx' no MySQL com sucesso.
# Tabela 'lalabXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lalabXXXmx' no MySQL com sucesso.
# Tabela 'herdezXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'herdezXXXmx' no MySQL com sucesso.
# Tabela 'gccXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gccXXXmx' no MySQL com sucesso.
# Tabela 'giganteXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'giganteXXXmx' no MySQL com sucesso.
# Tabela 'bbajiooXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bbajiooXXXmx' no MySQL com sucesso.
# Tabela 'gsanborb-1XXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gsanborb-1XXXmx' no MySQL com sucesso.
# Tabela 'funo11XXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'funo11XXXmx' no MySQL com sucesso.
# Tabela 'grumabXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'grumabXXXmx' no MySQL com sucesso.
# Tabela 'kuobXXXmx' criada no MySQL com sucesso.
# Dados inseridos na tabela 'kuobXXXmx' no MySQL com sucesso.
# Tabela 'bapXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bapXXXlm' no MySQL com sucesso.
# Tabela 'scco' criada no MySQL com sucesso.
# Dados inseridos na tabela 'scco' no MySQL com sucesso.
# Tabela 'volcXXXob' criada no MySQL com sucesso.
# Dados inseridos na tabela 'volcXXXob' no MySQL com sucesso.
# Tabela 'bcpXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bcpXXXlm' no MySQL com sucesso.
# Tabela 'graXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'graXXXlm' no MySQL com sucesso.
# Tabela 'eneXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'eneXXXlm' no MySQL com sucesso.
# Tabela 'ferXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ferXXXlm' no MySQL com sucesso.
# Tabela 'bvnXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bvnXXXlm' no MySQL com sucesso.
# Tabela 'bcoXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bcoXXXlm' no MySQL com sucesso.
# Tabela 'ifsXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ifsXXXlm' no MySQL com sucesso.
# Tabela 'lapXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lapXXXlm' no MySQL com sucesso.
# Tabela 'cemXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'cemXXXlm' no MySQL com sucesso.
# Tabela 'inreXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'inreXXXlm' no MySQL com sucesso.
# Tabela 'ipaXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ipaXXXlm' no MySQL com sucesso.
# Tabela 'alicorpXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'alicorpXXXlm' no MySQL com sucesso.
# Tabela 'copec' criada no MySQL com sucesso.
# Dados inseridos na tabela 'copec' no MySQL com sucesso.
# Tabela 'backusXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'backusXXXlm' no MySQL com sucesso.
# Tabela 'areXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'areXXXlm' no MySQL com sucesso.
# Tabela 'rlpXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rlpXXXlm' no MySQL com sucesso.
# Tabela 'psegXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'psegXXXlm' no MySQL com sucesso.
# Tabela 'gloriaXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gloriaXXXlm' no MySQL com sucesso.
# Tabela 'scscb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'scscb' no MySQL com sucesso.
# Tabela 'rimacXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rimacXXXlm' no MySQL com sucesso.
# Tabela 'iilcXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'iilcXXXlm' no MySQL com sucesso.
# Tabela 'minsuriXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'minsuriXXXlm' no MySQL com sucesso.
# Tabela 'luzXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'luzXXXlm' no MySQL com sucesso.
# Tabela 'ucbpXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ucbpXXXlm' no MySQL com sucesso.
# Tabela 'tdpXXXlm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tdpXXXlm' no MySQL com sucesso.
# Tabela 'tm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'tm' no MySQL com sucesso.
# Tabela 'vwagy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vwagy' no MySQL com sucesso.
# Tabela 'gm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gm' no MySQL com sucesso.
# Tabela 'bmwyy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bmwyy' no MySQL com sucesso.
# Tabela 'hmc' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hmc' no MySQL com sucesso.
# Tabela 'f' criada no MySQL com sucesso.
# Dados inseridos na tabela 'f' no MySQL com sucesso.
# Tabela 'nsany' criada no MySQL com sucesso.
# Dados inseridos na tabela 'nsany' no MySQL com sucesso.
# Tabela 'audvf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'audvf' no MySQL com sucesso.
# Tabela 'volvy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'volvy' no MySQL com sucesso.
# Tabela 'fcau' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fcau' no MySQL com sucesso.
# Tabela 'rnsdf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rnsdf' no MySQL com sucesso.
# Tabela 'pugoy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'pugoy' no MySQL com sucesso.
# Tabela 'fujhy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'fujhy' no MySQL com sucesso.
# Tabela 'hymtf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'hymtf' no MySQL com sucesso.
# Tabela 'mzday' criada no MySQL com sucesso.
# Dados inseridos na tabela 'mzday' no MySQL com sucesso.
# Tabela 'ddaif' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ddaif' no MySQL com sucesso.
# Tabela 'msbhy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'msbhy' no MySQL com sucesso.
# Tabela 'poahy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'poahy' no MySQL com sucesso.
# Tabela 'gelyy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'gelyy' no MySQL com sucesso.
# Tabela 'byddy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'byddy' no MySQL com sucesso.
# Tabela 'ttm' criada no MySQL com sucesso.
# Dados inseridos na tabela 'ttm' no MySQL com sucesso.
# Tabela 'szkmy' criada no MySQL com sucesso.
# Dados inseridos na tabela 'szkmy' no MySQL com sucesso.
# Tabela 'race' criada no MySQL com sucesso.
# Dados inseridos na tabela 'race' no MySQL com sucesso.
# Tabela 'bntgf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bntgf' no MySQL com sucesso.
# Tabela 'vlkaf' criada no MySQL com sucesso.
# Dados inseridos na tabela 'vlkaf' no MySQL com sucesso.
# Tabela 'rycey' criada no MySQL com sucesso.
# Dados inseridos na tabela 'rycey' no MySQL com sucesso.
# Tabela '601668XXXss' criada no MySQL com sucesso.
# Dados inseridos na tabela '601668XXXss' no MySQL com sucesso.
# Tabela '390XXXhk' criada no MySQL com sucesso.
# Dados inseridos na tabela '390XXXhk' no MySQL com sucesso.
# Tabela 'bouyXXXpa' criada no MySQL com sucesso.
# Dados inseridos na tabela 'bouyXXXpa' no MySQL com sucesso.
# Tabela 'lartXXXns' criada no MySQL com sucesso.
# Dados inseridos na tabela 'lartXXXns' no MySQL com sucesso.
# Tabela '3333XXXhk' criada no MySQL com sucesso.
# Dados inseridos na tabela '3333XXXhk' no MySQL com sucesso.
# Tabela '1803XXXt' criada no MySQL com sucesso.
# Dados inseridos na tabela '1803XXXt' no MySQL com sucesso.
# Tabela 'skaXXXb' criada no MySQL com sucesso.
# Dados inseridos na tabela 'skaXXXb' no MySQL com sucesso.
# Tabela '1201XXXhk' criada no MySQL com sucesso.
# Dados inseridos na tabela '1201XXXhk' no MySQL com sucesso.
# Tabela '601868XXXss' criada no MySQL com sucesso.

# %%
test = yfhistoricdic['601668XXXss']
